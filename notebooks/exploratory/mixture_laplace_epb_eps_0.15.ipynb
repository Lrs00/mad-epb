# %% [markdown]
# ## Mixture laplace

# %%
using Distributions, Random, Statistics, MultipleTesting, Empirikos, Hypatia, LinearAlgebra
using StatsPlots

# =========================================================
# Draw from a mixture of Laplace errors
# baseline: variance 1
# contamination: variance tau^2
# =========================================================
function rand_mixture_laplace_errors(
    rng::AbstractRNG,
    n::Int;
    eps::Float64 = 0.05,
    tau::Float64 = 8.0
)
    b_main = 1 / sqrt(2)           # Var = 1
    b_out  = tau / sqrt(2)         # Var = tau^2

    z = Vector{Float64}(undef, n)

    @inbounds for j in 1:n
        if rand(rng) < eps
            z[j] = rand(rng, Laplace(0.0, b_out))
        else
            z[j] = rand(rng, Laplace(0.0, b_main))
        end
    end

    return z
end

# =========================================================
# Simulation with mixture-Laplace errors
# =========================================================
Random.seed!(105)

n_values = [4,5,6,8,10,20,30,40]

G = 1000
R = 100

p_signal = 0.1

# This is now the constant standardized signal
β_signal = 4.0

# parametric variance model
s0_sq_true = 1.0
d0_true    = 4.0

# mixture-Laplace parameters
eps_mix = 0.15
tau_mix = 9.0

datasets = Dict{Tuple{Int,Int}, Any}()

for n in n_values
    for r in 1:R

        rng = MersenneTwister(10_000 + 100n + r)

        is_DE = rand(rng, G) .< p_signal

        # gene-specific variance
        σ2 = rand(
            rng,
            InverseGamma(
                d0_true / 2,
                d0_true * s0_sq_true / 2
            ),
            G
        )

        σ = sqrt.(σ2)

        # data generation
        Y = Vector{Vector{Float64}}(undef, G)

        @inbounds for i in 1:G

            # IMPORTANT CHANGE:
            # scale signal by 1/sqrt(n)
            βi = is_DE[i] ?
                 β_signal * σ[i] / sqrt(n) :
                 0.0

            z = rand_mixture_laplace_errors(
                rng,
                n;
                eps = eps_mix,
                tau = tau_mix
            )

            Y[i] = βi .+ σ[i] .* z
        end

        datasets[(n, r)] = (
            Y = Y,
            is_DE = is_DE,
            σ = σ,
            σ2 = σ2,
            error_dist = "Laplace Mixture",
            eps_mix = eps_mix,
            tau_mix = tau_mix,
            β_signal = β_signal,
            signal_scaled_by_sqrt_n = true,
            s0_sq_true = s0_sq_true,
            d0_true = d0_true
        )
    end
end

# %%
limma_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full per-gene p-values
limma_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level top-100 results
limma_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running LIMMA simulation for n = $n ==========")

    ν = n - 1

    power_vals  = Float64[]
    fdr_vals    = Float64[]
    tp_vals     = Float64[]
    fp_vals     = Float64[]
    top100_vals = Float64[]

    for r in 1:R

        try
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ

            # -------------------------------------------------
            # Per-gene statistics
            # -------------------------------------------------
            β_hat = [mean(Y[i]) for i in 1:G]

            s_hat = [
                std(Y[i], corrected=true)
                for i in 1:G
            ]

            se_hat_squared = (s_hat .^ 2) ./ n


            # -------------------------------------------------
            # LIMMA samples
            # -------------------------------------------------
            samples = [
                Empirikos.NormalChiSquareSample(
                    β_hat[i],
                    se_hat_squared[i],
                    ν
                )
                for i in 1:G
            ]


            # -------------------------------------------------
            # Fit LIMMA EB test
            # -------------------------------------------------
            test_limma = Empirikos.EmpiricalPartiallyBayesTTest(
                α = 0.05,
                prior = Empirikos.Limma(),
                solver = Hypatia.Optimizer
            )

            res_limma = fit(test_limma, samples)


            # -------------------------------------------------
            # Extract p-values and rejection decisions
            # -------------------------------------------------
            pvals_limma = res_limma.pvalue
            rej_limma   = res_limma.rj_idx


            # =================================================
            # SAVE THE RAW P-VALUES
            # =================================================
            limma_pvals_store[(n,r)] = copy(pvals_limma)


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej_limma .& is_DE)
            FP = sum(rej_limma .& .!is_DE)

            power = TP / max(sum(is_DE), 1)

            fdr = FP / max(sum(rej_limma), 1)


            # =================================================
            # Ranking metric: true signals among top 100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals_limma)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level ranking result
            limma_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


        catch err

            @warn "Skipping Rep $r for n=$n due to numerical error: $err"

            continue
        end
    end


    # =========================================================
    # Average over replicates
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(limma_summary["n"], n)

    push!(limma_summary["TP"], mean_TP)
    push!(limma_summary["FP"], mean_FP)

    push!(limma_summary["Power"], mean_power)
    push!(limma_summary["FDR"], mean_fdr)

    push!(limma_summary["TP_top100"], mean_top100)


    println(
        "n = $n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println("\n========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========")

for i in eachindex(limma_summary["n"])

    println(
        "n = $(limma_summary["n"][i]) → " *
        "Power=$(round(limma_summary["Power"][i], digits=5)), " *
        "FDR=$(round(limma_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(limma_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running LIMMA simulation for n = 4 ==========
# n = 4 → Power=0.001 | FDR=0.0 | TP=0.1 | FP=0.0 | TP@100=68.7
#
# ========== Running LIMMA simulation for n = 5 ==========
# n = 5 → Power=0.005 | FDR=0.0 | TP=0.5 | FP=0.0 | TP@100=67.1
#
# ========== Running LIMMA simulation for n = 6 ==========
# n = 6 → Power=0.02 | FDR=0.0 | TP=1.9 | FP=0.0 | TP@100=64.9
#
# ========== Running LIMMA simulation for n = 8 ==========
# n = 8 → Power=0.047 | FDR=0.0 | TP=4.7 | FP=0.0 | TP@100=61.3
#
# ========== Running LIMMA simulation for n = 10 ==========
# n = 10 → Power=0.065 | FDR=0.0 | TP=6.6 | FP=0.0 | TP@100=59.3
#
# ========== Running LIMMA simulation for n = 20 ==========
# n = 20 → Power=0.047 | FDR=0.0 | TP=4.8 | FP=0.0 | TP@100=49.7
#
# ========== Running LIMMA simulation for n = 30 ==========
# n = 30 → Power=0.021 | FDR=0.002 | TP=2.0 | FP=0.0 | TP@100=43.1
#
# ========== Running LIMMA simulation for n = 40 ==========
# n = 40 → Power=0.015 | FDR=0.007 | TP=1.5 | FP=0.0 | TP@100=40.3
#
# ========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → Power=0.0006, FDR=0.0, TP@100=68.73
# n = 5 → Power=0.0047, FDR=0.0, TP@100=67.09
# n = 6 → Power=0.01985, FDR=0.0, TP@100=64.9
# n = 8 → Power=0.04658, FDR=0.0, TP@100=61.3
# n = 10 → Power=0.06501, FDR=0.0, TP@100=59.32
# n = 20 → Power=0.04718, FDR=0.0, TP@100=49.74
# n = 30 → Power=0.02083, FDR=0.00167, TP@100=43.08
# n = 40 → Power=0.01507, FDR=0.00667, TP@100=40.29

# %% [markdown]
# ## NP +SD

# %%
R = 100

# =========================================================
# Storage for summary results
# =========================================================
epb_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full raw p-values for every successful replicate
epb_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level TP@100
epb_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running EPB NPMLE simulation for n = $n ==========")

    ν = n - 1

    power_vals  = Float64[]
    fdr_vals    = Float64[]
    tp_vals     = Float64[]
    fp_vals     = Float64[]
    top100_vals = Float64[]

    for r in 1:R

        try
            # -------------------------------------------------
            # Get the same simulated dataset
            # -------------------------------------------------
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ


            # -------------------------------------------------
            # Compute per-gene statistics
            # -------------------------------------------------
            β_hat = [mean(Y[i]) for i in 1:G]

            s_hat = [
                std(Y[i], corrected=true)
                for i in 1:G
            ]

            se_hat_squared = (s_hat .^ 2) ./ n


            # -------------------------------------------------
            # Build Normal-Chi-square samples
            # -------------------------------------------------
            samples = [
                Empirikos.NormalChiSquareSample(
                    β_hat[i],
                    se_hat_squared[i],
                    ν
                )
                for i in 1:G
            ]


            # -------------------------------------------------
            # Fit EPB with nonparametric NPMLE prior
            # -------------------------------------------------
            test_epb = Empirikos.EmpiricalPartiallyBayesTTest(
                α = 0.05,
                solver = Hypatia.Optimizer
            )

            res_epb = fit(test_epb, samples)


            # -------------------------------------------------
            # Extract p-values and rejection decisions
            # -------------------------------------------------
            pvals_epb = res_epb.pvalue
            rej_epb   = res_epb.rj_idx


            # =================================================
            # SAVE RAW P-VALUES
            # =================================================
            epb_pvals_store[(n,r)] = copy(pvals_epb)


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej_epb .& is_DE)
            FP = sum(rej_epb .& .!is_DE)

            power = TP / max(sum(is_DE), 1)

            fdr = FP / max(sum(rej_epb), 1)


            # =================================================
            # Ranking metric: true DE genes among top 100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals_epb)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level TP@100
            epb_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            println(
                "Rep $r → " *
                "Power=$(round(power, digits=3)) | " *
                "FDR=$(round(fdr, digits=3)) | " *
                "Rej=$(sum(rej_epb)) | " *
                "TP@100=$TP_top100"
            )


        catch e

            @warn "Skipping Rep $r for n=$n due to error: $e"

            continue
        end
    end


    # =========================================================
    # Average over successful replicates
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(epb_summary["n"], n)

    push!(epb_summary["TP"], mean_TP)
    push!(epb_summary["FP"], mean_FP)

    push!(epb_summary["Power"], mean_power)
    push!(epb_summary["FDR"], mean_fdr)

    push!(epb_summary["TP_top100"], mean_top100)


    println(
        "n = $n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println("\n========== EPB SUMMARY ACROSS SAMPLE SIZES ==========")

for i in eachindex(epb_summary["n"])

    println(
        "n = $(epb_summary["n"][i]) → " *
        "TP=$(round(epb_summary["TP"][i], digits=3)), " *
        "FP=$(round(epb_summary["FP"][i], digits=3)), " *
        "Power=$(round(epb_summary["Power"][i], digits=5)), " *
        "FDR=$(round(epb_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(epb_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running EPB NPMLE simulation for n = 4 ==========
#
#  iter        p_obj        d_obj |  abs_gap    x_feas    z_feas |      tau       kap        mu | dir_res     prox  step     alpha
#     0   3.2373e-02  -1.8449e+02 | 2.30e+03  9.75e+01  4.57e+00 | 1.00e+00  1.00e+00  1.00e+00 |
#     1  
#    62  -1.2499e+01  -1.2843e+01 | 1.54e+00  1.66e-01  6.22e-03 | 3.85e-01  1.73e-03  6.68e-04 | 1.4e-12  4.0e-01  co-a  1.00e-01
#    63  -1.1835e+01  -1.2144e+01 | 1.38e+00  1.49e-01  5.57e-03 | 3.88e-01  1.55e-03  6.01e-04 | 1.2e-12  3.3e-01  co-a  1.00e-01
#    64  -1.1227e+01  -1.1502e+01 | 1.24e+00  1.33e-01  4.98e-03 | 3.90e-01  1.39e-03  5.41e-04 | 1.4e-12  2.7e-01  co-a  1.00e-01
#    65  -1.0670e+01  -1.0916e+01 | 1.12e+00  1.19e-01  4.45e-03 | 3.93e-01  1.24e-03  4.86e-04 | 1.5e-12  2.1e-01  co-a  1.00e-01
#    66  -1.0162e+01  -1.0382e+01 | 1.01e+00  1.06e-01  3.97e-03 | 3.96e-01  1.11e-03  4.38e-04 | 1.3e-12  1.6e-01  co-a  1.00e-01
#    67  -9.6998e+00  -9.8964e+00 | 9.06e-01  9.47e-02  3.55e-03 | 3.99e-01  9.87e-04  3.94e-04 | 2.9e-12  1.2e-01  co-a  1.00e-01
#    68  -9.2805e+00  -9.4560e+00 | 8.15e-01  8.46e-02  3.17e-03 | 4.02e-01  8.80e-04  3.54e-04 | 1.3e-12  9.1e-02  co-a  1.00e-01
#    69  -8.1433e+00  -8.2630e+00 | 5.71e-01  5.76e-02  2.16e-03 | 4.13e-01  5.99e-04  2.48e-04 | 1.2e-12  9.0e-01  co-a  3.00e-01
#    70  -8.1243e+00  -8.2430e+00 | 5.65e-01  5.72e-02  2.14e-03 | 4.12e-01  5.95e-04  2.45e-04 | 1.6e-10  7.9e-01  co-a  1.00e-02
#    71  -8.0910e+00  -8.2081e+00 | 5.59e-01  5.64e-02  2.11e-03 | 4.14e-01  5.87e-04  2.43e-04 | 3.0e-11  4.2e-01  co-a  1.00e-02
#    72  -7.8343e+00  -7.9392e+00 | 5.03e-01  5.05e-02  1.89e-03 | 4.16e-01  5.26e-04  2.19e-04 | 5.3e-12  5.8e-01  co-a  1.00e-01
#    73  -7.1246e+00  -7.1961e+00 | 3.51e-01  3.44e-02  1.29e-03 | 4.27e-01  3.57e-04  1.53e-04 | 1.7e-12  6.7e-01  co-a  3.00e-01
# Excessive output truncated after 524321 bytes.

# %%
# =========================================================
# Final summary
# =========================================================
println("\n========== EPB SUMMARY ACROSS SAMPLE SIZES ==========")

for i in eachindex(epb_summary["n"])

    println(
        "n = $(epb_summary["n"][i]) → " *
        "TP=$(round(epb_summary["TP"][i], digits=3)), " *
        "FP=$(round(epb_summary["FP"][i], digits=3)), " *
        "Power=$(round(epb_summary["Power"][i], digits=5)), " *
        "FDR=$(round(epb_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(epb_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== EPB SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=0.04, FP=0.0, Power=0.0004, FDR=0.0, TP@100=67.34
# n = 5 → TP=0.61, FP=0.0, Power=0.00592, FDR=0.0, TP@100=65.92
# n = 6 → TP=2.06, FP=0.0, Power=0.02112, FDR=0.0, TP@100=63.6
# n = 8 → TP=6.69, FP=0.0, Power=0.0663, FDR=0.0, TP@100=60.66
# n = 10 → TP=9.17, FP=0.0, Power=0.09107, FDR=0.0, TP@100=58.48
# n = 20 → TP=6.768, FP=0.02, Power=0.06698, FDR=0.00198, TP@100=49.343
# n = 30 → TP=3.14, FP=0.01, Power=0.03164, FDR=0.002, TP@100=42.93
# n = 40 → TP=2.25, FP=0.02, Power=0.02237, FDR=0.00667, TP@100=40.1

# %% [markdown]
# ## MAD P

# %%
using FastGaussQuadrature
using Distributions
using StatsFuns: logsumexp
using Optim
using MultipleTesting
using Statistics, Random, LinearAlgebra
using ApproxFun, SpecialFunctions

# =========================================================
# 1. Exact MAD-about-mean likelihood
# =========================================================

struct MADDistribution{T<:Real,S<:Integer} <: ContinuousUnivariateDistribution
    σ::T
    n::S
end

import Distributions: pdf, logpdf, insupport, minimum, maximum

function G_recursive(max_r::Int; a=0.0, b=100)
    d = Interval(a, b)
    G = Vector{Fun}(undef, max_r+1)
    G[1] = Fun(x -> 1.0, d)
    for r in 1:max_r
        integrand = Fun(x -> exp(-(x^2)/(2r*(r+1))), d) * G[r]
        G[r+1] = cumsum(integrand)
    end
    return G
end

const _Gcache = Dict{Int,Vector{Fun}}()
_getG(n) = get!(_Gcache, n) do
    G_recursive(n)
end

function _pdf_sigma1(n::Int, m::Real)
    m < 0 && return zero(float(m))
    z   = n * m / 2
    cst = n^(3/2) / (2^((n+1)/2) * π^((n-1)/2))
    G   = _getG(n)
    s   = 0.0
    @inbounds for k in 1:(n-1)
        s += binomial(n, k) * exp(-(m^2 * n^3) / (8k*(n-k))) * G[k](z) * G[n-k](z)
    end
    return cst * s
end

insupport(::MADDistribution, x::Real) = x ≥ 0
minimum(::MADDistribution) = 0.0
maximum(::MADDistribution) = Inf

pdf(d::MADDistribution, m::Real) =
    m < 0 ? 0.0 : (1 / d.σ) * _pdf_sigma1(d.n, m / d.σ)

function logpdf(d::MADDistribution, m::Real)
    m < 0 && return -Inf
    σ, n = d.σ, d.n
    z    = n * m / (2σ)
    logC = (3/2)*log(n) - ((n+1)/2)*log(2) - ((n-1)/2)*log(π)
    G    = _getG(n)

    logs = Float64[]
    @inbounds for k in 1:(n-1)
        val1 = G[k](z)
        val2 = G[n-k](z)
        if val1 > 0 && val2 > 0
            push!(logs,
                log(binomial(n, k)) -
                (m^2 * n^3) / (8σ^2 * k*(n-k)) +
                log(val1) + log(val2)
            )
        end
    end

    return -log(σ) + logC + (isempty(logs) ? -Inf : logsumexp(logs))
end

# =========================================================
# 2. Parametric prior on sigma^2
# =========================================================

struct InverseScaledChiSquare{T,S} <: ContinuousUnivariateDistribution
    σ²::T
    ν::S
end

function Distributions.InverseGamma(d::InverseScaledChiSquare)
    InverseGamma(d.ν / 2, d.ν * d.σ² / 2)
end

Distributions.pdf(d::InverseScaledChiSquare, x::Real) = pdf(InverseGamma(d), x)
Distributions.logpdf(d::InverseScaledChiSquare, x::Real) = logpdf(InverseGamma(d), x)

prior_sigma2(σ0², ν0) = InverseScaledChiSquare(σ0², ν0)

# =========================================================
# 3. Gauss-Legendre quadrature on (0,1)
# =========================================================

function gausslegendre01(K::Int)
    x, w = gausslegendre(K)   # nodes/weights on [-1,1]
    u = (x .+ 1) ./ 2         # map to (0,1)
    w = w ./ 2
    return u, w
end

# =========================================================
# 4. Marginal likelihood by Gauss-Legendre quadrature
#    transform s2 = u/(1-u), u in (0,1)
# =========================================================
function marginal_mad_logdensity_gl(
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    prior = prior_sigma2(σ0², ν0)

    logvals = similar(u_nodes)
    @inbounds for j in eachindex(u_nodes)
        u = clamp(u_nodes[j], 1e-12, 1 - 1e-12)
        s2 = u / (1 - u)
        jac = 1 / (1 - u)^2

        logvals[j] =
            logpdf(MADDistribution(sqrt(s2), n), D) +
            logpdf(prior, s2) +
            log(jac) +
            log(u_weights[j])
    end

    return logsumexp(logvals)
end

# =========================================================
# 5. Negative log marginal likelihood across genes
# =========================================================

function negloglik_mad_parametric_gl(
    par::Vector{Float64},
    mad_obs::Vector{Float64},
    n::Int,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    η, ξ = par
    σ0² = exp(η)
    ν0  = exp(ξ)

    total = 0.0
    @inbounds for D in mad_obs
        total -= marginal_mad_logdensity_gl(D, n, σ0², ν0, u_nodes, u_weights)
    end
    return total
end

# =========================================================
# 6. Fit prior hyperparameters by Gaussian quadrature
# =========================================================

function fit_mad_parametric_prior_gl(
    mad_obs::Vector{Float64},
    n::Int;
    K_quad::Int = 64,
    init_logσ0² = log(max(median(mad_obs)^2, 1e-6)),
    init_logν0  = log(10.0),
    max_iter::Int = 80
)
    u_nodes, u_weights = gausslegendre01(K_quad)

    obj(par) = negloglik_mad_parametric_gl(par, mad_obs, n, u_nodes, u_weights)

    res = optimize(
        obj,
        [init_logσ0², init_logν0],
        NelderMead(),
        Optim.Options(iterations=max_iter, show_trace=false)
    )

    ηhat, ξhat = Optim.minimizer(res)

    return (
        σ0² = exp(ηhat),
        ν0  = exp(ξhat),
        optim = res,
        u_nodes = u_nodes,
        u_weights = u_weights
    )
end

# =========================================================
# 7. Posterior weights on same quadrature nodes
# =========================================================

function posterior_sigma2_weights_mad_gl(
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    prior = prior_sigma2(σ0², ν0)

    logpost = similar(u_nodes)
    s2_nodes = similar(u_nodes)

    @inbounds for j in eachindex(u_nodes)
        u = clamp(u_nodes[j], 1e-12, 1 - 1e-12)
        s2 = u / (1 - u)
        s2_nodes[j] = s2
        jac = 1 / (1 - u)^2

        logpost[j] =
            logpdf(MADDistribution(sqrt(s2), n), D) +
            logpdf(prior, s2) +
            log(jac) +
            log(u_weights[j])
    end

    m = maximum(logpost)
    w = exp.(logpost .- m)
    w ./= sum(w)

    return s2_nodes, w
end

# =========================================================
# 8. Posterior-averaged p-value
# =========================================================

function mad_parametric_pvalue_gl(
    β_tilde::Float64,
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    s2_nodes, w = posterior_sigma2_weights_mad_gl(D, n, σ0², ν0, u_nodes, u_weights)
    σ_nodes = sqrt.(s2_nodes)
    tails = 2 .* ccdf.(Normal.(0, σ_nodes), abs(β_tilde))
    return dot(tails, w)
end
# Out:
# WARNING: redefinition of constant Main._Gcache. This may fail, cause incorrect answers, or produce other errors.
# mad_parametric_pvalue_gl (generic function with 1 method)

# %%
# =========================================================
# 9. Simulation loop: MAD_mean + parametric prior
# =========================================================

mad_param_gl_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

mad_param_gl_prior_summary = Dict(
    "n" => Int[],
    "sigma0_sq_mean" => Float64[],
    "nu0_mean" => Float64[]
)

# Store replicate-level results
mad_param_gl_prior_reps = Dict(
    "n" => Int[],
    "rep" => Int[],
    "sigma0_sq_hat" => Float64[],
    "nu0_hat" => Float64[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# NEW: store all raw p-values
mad_param_pvals_store =
    Dict{Tuple{Int,Int}, Vector{Float64}}()

# NEW: store replicate-level TP@100
mad_param_top100_store =
    Dict{Tuple{Int,Int}, Int}()


for n in n_values

    println(
        "\n========== Running MAD_mean + parametric prior " *
        "(Gauss-Legendre) for n = $n =========="
    )

    tp_vals = Float64[]
    fp_vals = Float64[]
    power_vals = Float64[]
    fdr_vals = Float64[]
    top100_vals = Float64[]

    sigma0_sq_vals = Float64[]
    nu0_vals = Float64[]


    for r in 1:R

        try
            println("n=$n, rep=$r: loading data...")

            Y = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ_true = datasets[(n,r)].σ


            # =================================================
            # Compute statistics
            # =================================================
            println("n=$n, rep=$r: computing statistics...")

            β_hat = [
                mean(Y[i])
                for i in 1:G
            ]

            mad_obs = [
                mean(abs.(Y[i] .- β_hat[i]))
                for i in 1:G
            ]

            β_tilde = sqrt(n) .* β_hat

            idx_fit = 1:length(mad_obs)


            # =================================================
            # Fit parametric MAD prior
            # =================================================
            println(
                "n=$n, rep=$r: fitting Gauss-Legendre parametric prior..."
            )

            @time fit_prior =
                fit_mad_parametric_prior_gl(
                    mad_obs[idx_fit],
                    n;
                    K_quad = 100,
                    max_iter = 80
                )

            σ0²_hat = fit_prior.σ0²
            ν0_hat  = fit_prior.ν0

            u_nodes   = fit_prior.u_nodes
            u_weights = fit_prior.u_weights


            push!(sigma0_sq_vals, σ0²_hat)
            push!(nu0_vals, ν0_hat)


            println(
                "n=$n, rep=$r: prior fit done. " *
                "σ0²=$(round(σ0²_hat, digits=4)), " *
                "ν0=$(round(ν0_hat, digits=3))"
            )


            # =================================================
            # Compute RAW p-values
            # =================================================
            println("n=$n, rep=$r: computing p-values...")

            pvals = [
                mad_parametric_pvalue_gl(
                    β_tilde[i],
                    mad_obs[i],
                    n,
                    σ0²_hat,
                    ν0_hat,
                    u_nodes,
                    u_weights
                )
                for i in 1:G
            ]


            # =================================================
            # NEW: store raw p-values
            # =================================================
            mad_param_pvals_store[(n,r)] = copy(pvals)


            # =================================================
            # NEW: ranking metric TP@100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])

            mad_param_top100_store[(n,r)] =
                TP_top100


            # =================================================
            # BH rejection
            # =================================================
            adj_p = adjust(
                pvals,
                BenjaminiHochberg()
            )

            rej = adj_p .<= 0.05


            # =================================================
            # Standard metrics
            # =================================================
            TP = sum(rej .& is_DE)
            FP = sum(rej .& .!is_DE)

            power =
                TP / max(sum(is_DE), 1)

            fdr =
                FP / max(sum(rej), 1)


            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            # =================================================
            # Store replicate-level prior + performance
            # =================================================
            push!(mad_param_gl_prior_reps["n"], n)
            push!(mad_param_gl_prior_reps["rep"], r)

            push!(
                mad_param_gl_prior_reps["sigma0_sq_hat"],
                σ0²_hat
            )

            push!(
                mad_param_gl_prior_reps["nu0_hat"],
                ν0_hat
            )

            push!(mad_param_gl_prior_reps["TP"], TP)
            push!(mad_param_gl_prior_reps["FP"], FP)

            push!(
                mad_param_gl_prior_reps["Power"],
                power
            )

            push!(
                mad_param_gl_prior_reps["FDR"],
                fdr
            )

            push!(
                mad_param_gl_prior_reps["TP_top100"],
                TP_top100
            )


            println(
                "n=$n, rep=$r done → " *
                "Power=$(round(power, digits=3)) | " *
                "FDR=$(round(fdr, digits=3)) | " *
                "TP@100=$TP_top100"
            )


        catch e

            println(
                "⚠️ Skipping Rep $r for n=$n due to error: " *
                "$(typeof(e)) : $e"
            )

            continue
        end
    end


    # =========================================================
    # Summarize over successful replicates
    # =========================================================
    if !isempty(tp_vals)

        mean_TP = mean(tp_vals)
        mean_FP = mean(fp_vals)

        mean_power = mean(power_vals)
        mean_fdr = mean(fdr_vals)

        mean_top100 = mean(top100_vals)


        push!(mad_param_gl_summary["n"], n)

        push!(
            mad_param_gl_summary["TP"],
            mean_TP
        )

        push!(
            mad_param_gl_summary["FP"],
            mean_FP
        )

        push!(
            mad_param_gl_summary["Power"],
            mean_power
        )

        push!(
            mad_param_gl_summary["FDR"],
            mean_fdr
        )

        push!(
            mad_param_gl_summary["TP_top100"],
            mean_top100
        )


        # Prior summary
        push!(
            mad_param_gl_prior_summary["n"],
            n
        )

        push!(
            mad_param_gl_prior_summary["sigma0_sq_mean"],
            mean(sigma0_sq_vals)
        )

        push!(
            mad_param_gl_prior_summary["nu0_mean"],
            mean(nu0_vals)
        )


        println(
            "✅ Done n=$n → " *
            "Power=$(round(mean_power, digits=3)) | " *
            "FDR=$(round(mean_fdr, digits=3)) | " *
            "TP=$(round(mean_TP, digits=1)) | " *
            "FP=$(round(mean_FP, digits=1)) | " *
            "TP@100=$(round(mean_top100, digits=1))"
        )

    else

        println("⚠️ No successful reps for n=$n")

    end
end
# Out:
# ========== Running MAD_mean + parametric prior (Gauss-Legendre) for n = 4 ==========
# n=4, rep=1: loading data...
# n=4, rep=1: computing statistics...
# n=4, rep=1: fitting Gauss-Legendre parametric prior...
#   8.927418 seconds (226.57 M allocations: 4.247 GiB, 2.97% gc time, 7.96% compilation time)
# n=4, rep=1: prior fit done. σ0²=1.1861, ν0=1.046
# n=4, rep=1: computing p-values...
# n=4, rep=1 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=2: loading data...
# n=4, rep=2: computing statistics...
# n=4, rep=2: fitting Gauss-Legendre parametric prior...
#   7.560020 seconds (206.23 M allocations: 3.764 GiB, 2.11% gc time)
# n=4, rep=2: prior fit done. σ0²=1.1848, ν0=1.144
# n=4, rep=2: computing p-values...
# n=4, rep=2 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=3: loading data...
# n=4, rep=3: computing statistics...
# n=4, rep=3: fitting Gauss-Legendre parametric prior...
#   8.392970 seconds (228.83 M allocations: 4.176 GiB, 2.07% gc time)
# n=4, rep=3: prior fit done. σ0²=1.2143, ν0=1.06
# n=4, rep=3: computing p-values...
# n=4, rep=3 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=4: loading data...
# n=4, rep=4: computing statistics...
# n=4, rep=4: fitting Gauss-Legendre parametric prior...
#   7.928362 seconds (217.39 M allocations: 3.968 GiB, 2.10% gc time)
# n=4, rep=4: prior fit done. σ0²=1.2697, ν0=1.096
# n=4, rep=4: computing p-values...
# n=4, rep=4 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=5: loading data...
# n=4, rep=5: computing statistics...
# n=4, rep=5: fitting Gauss-Legendre parametric prior...
#   7.874679 seconds (214.94 M allocations: 3.923 GiB, 2.05% gc time)
# n=4, rep=5: prior fit done. σ0²=1.1275, ν0=1.163
# n=4, rep=5: computing p-values...
# n=4, rep=5 done → Power=0.0 | FDR=0.0 | TP@100=81
# n=4, rep=6: loading data...
# n=4, rep=6: computing statistics...
# n=4, rep=6: fitting Gauss-Legendre parametric prior...
#   8.168665 seconds (223.39 M allocations: 4.078 GiB, 2.07% gc time)
# n=4, rep=6: prior fit done. σ0²=1.036, ν0=1.094
# n=4, rep=6: computing p-values...
# n=4, rep=6 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=7: loading data...
# n=4, rep=7: computing statistics...
# n=4, rep=7: fitting Gauss-Legendre parametric prior...
#   7.964905 seconds (217.63 M allocations: 3.972 GiB, 2.11% gc time)
# n=4, rep=7: prior fit done. σ0²=1.246, ν0=1.156
# n=4, rep=7: computing p-values...
# n=4, rep=7 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=8: loading data...
# n=4, rep=8: computing statistics...
# n=4, rep=8: fitting Gauss-Legendre parametric prior...
#   8.091210 seconds (220.46 M allocations: 4.024 GiB, 2.07% gc time)
# n=4, rep=8: prior fit done. σ0²=1.2069, ν0=1.133
# n=4, rep=8: computing p-values...
# n=4, rep=8 done → Power=0.0 | FDR=0.0 | TP@100=75
# n=4, rep=9: loading data...
# n=4, rep=9: computing statistics...
# n=4, rep=9: fitting Gauss-Legendre parametric prior...
#   7.584597 seconds (206.20 M allocations: 3.764 GiB, 2.05% gc time)
# n=4, rep=9: prior fit done. σ0²=1.2132, ν0=1.119
# n=4, rep=9: computing p-values...
# n=4, rep=9 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=4, rep=10: loading data...
# n=4, rep=10: computing statistics...
# n=4, rep=10: fitting Gauss-Legendre parametric prior...
#   7.703256 seconds (208.99 M allocations: 3.815 GiB, 2.08% gc time)
# n=4, rep=10: prior fit done. σ0²=1.1533, ν0=1.11
# n=4, rep=10: computing p-values...
# n=4, rep=10 done → Power=0.0 | FDR=0.0 | TP@100=72
# n=4, rep=11: loading data...
# n=4, rep=11: computing statistics...
# n=4, rep=11: fitting Gauss-Legendre parametric prior...
#   7.840106 seconds (211.95 M allocations: 3.869 GiB, 2.04% gc time)
# n=4, rep=11: prior fit done. σ0²=1.0597, ν0=1.09
# n=4, rep=11: computing p-values...
# n=4, rep=11 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=12: loading data...
# n=4, rep=12: computing statistics...
# n=4, rep=12: fitting Gauss-Legendre parametric prior...
#   9.261349 seconds (249.05 M allocations: 4.546 GiB, 2.03% gc time)
# n=4, rep=12: prior fit done. σ0²=1.0958, ν0=1.06
# n=4, rep=12: computing p-values...
# n=4, rep=12 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=13: loading data...
# n=4, rep=13: computing statistics...
# n=4, rep=13: fitting Gauss-Legendre parametric prior...
#   7.903318 seconds (211.82 M allocations: 3.866 GiB, 2.04% gc time)
# n=4, rep=13: prior fit done. σ0²=1.1307, ν0=1.098
# n=4, rep=13: computing p-values...
# n=4, rep=13 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=14: loading data...
# n=4, rep=14: computing statistics...
# n=4, rep=14: fitting Gauss-Legendre parametric prior...
#   7.390570 seconds (197.35 M allocations: 3.602 GiB, 2.04% gc time)
# n=4, rep=14: prior fit done. σ0²=1.2767, ν0=1.106
# n=4, rep=14: computing p-values...
# n=4, rep=14 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=15: loading data...
# n=4, rep=15: computing statistics...
# n=4, rep=15: fitting Gauss-Legendre parametric prior...
#   7.831548 seconds (209.12 M allocations: 3.817 GiB, 2.03% gc time)
# n=4, rep=15: prior fit done. σ0²=1.0967, ν0=1.121
# n=4, rep=15: computing p-values...
# n=4, rep=15 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=16: loading data...
# n=4, rep=16: computing statistics...
# n=4, rep=16: fitting Gauss-Legendre parametric prior...
#   7.408929 seconds (197.37 M allocations: 3.602 GiB, 2.02% gc time)
# n=4, rep=16: prior fit done. σ0²=1.0318, ν0=1.019
# n=4, rep=16: computing p-values...
# n=4, rep=16 done → Power=0.01 | FDR=0.0 | TP@100=66
# n=4, rep=17: loading data...
# n=4, rep=17: computing statistics...
# n=4, rep=17: fitting Gauss-Legendre parametric prior...
#   7.844109 seconds (208.90 M allocations: 3.813 GiB, 2.04% gc time)
# n=4, rep=17: prior fit done. σ0²=1.1691, ν0=1.09
# n=4, rep=17: computing p-values...
# n=4, rep=17 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=18: loading data...
# n=4, rep=18: computing statistics...
# n=4, rep=18: fitting Gauss-Legendre parametric prior...
#   8.199745 seconds (217.79 M allocations: 3.975 GiB, 2.04% gc time)
# n=4, rep=18: prior fit done. σ0²=1.0676, ν0=1.142
# n=4, rep=18: computing p-values...
# n=4, rep=18 done → Power=0.0 | FDR=0.0 | TP@100=80
# n=4, rep=19: loading data...
# n=4, rep=19: computing statistics...
# n=4, rep=19: fitting Gauss-Legendre parametric prior...
#   7.894156 seconds (209.07 M allocations: 3.816 GiB, 2.04% gc time)
# n=4, rep=19: prior fit done. σ0²=1.231, ν0=1.158
# n=4, rep=19: computing p-values...
# n=4, rep=19 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=20: loading data...
# n=4, rep=20: computing statistics...
# n=4, rep=20: fitting Gauss-Legendre parametric prior...
#   8.552358 seconds (226.26 M allocations: 4.130 GiB, 2.03% gc time)
# n=4, rep=20: prior fit done. σ0²=1.1949, ν0=1.172
# n=4, rep=20: computing p-values...
# n=4, rep=20 done → Power=0.0 | FDR=0.0 | TP@100=61
# n=4, rep=21: loading data...
# n=4, rep=21: computing statistics...
# n=4, rep=21: fitting Gauss-Legendre parametric prior...
#   8.882713 seconds (234.96 M allocations: 4.289 GiB, 2.04% gc time)
# n=4, rep=21: prior fit done. σ0²=1.2089, ν0=1.196
# n=4, rep=21: computing p-values...
# n=4, rep=21 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=22: loading data...
# n=4, rep=22: computing statistics...
# n=4, rep=22: fitting Gauss-Legendre parametric prior...
#   8.251490 seconds (217.60 M allocations: 3.972 GiB, 2.00% gc time)
# n=4, rep=22: prior fit done. σ0²=1.2597, ν0=1.16
# n=4, rep=22: computing p-values...
# n=4, rep=22 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=23: loading data...
# n=4, rep=23: computing statistics...
# n=4, rep=23: fitting Gauss-Legendre parametric prior...
#   8.679692 seconds (229.10 M allocations: 4.182 GiB, 2.01% gc time)
# n=4, rep=23: prior fit done. σ0²=1.0615, ν0=1.103
# n=4, rep=23: computing p-values...
# n=4, rep=23 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=24: loading data...
# n=4, rep=24: computing statistics...
# n=4, rep=24: fitting Gauss-Legendre parametric prior...
#   8.193381 seconds (214.93 M allocations: 3.923 GiB, 2.01% gc time)
# n=4, rep=24: prior fit done. σ0²=1.1797, ν0=1.18
# n=4, rep=24: computing p-values...
# n=4, rep=24 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=25: loading data...
# n=4, rep=25: computing statistics...
# n=4, rep=25: fitting Gauss-Legendre parametric prior...
#   8.828659 seconds (231.85 M allocations: 4.232 GiB, 2.02% gc time)
# n=4, rep=25: prior fit done. σ0²=1.1633, ν0=1.129
# n=4, rep=25: computing p-values...
# n=4, rep=25 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=26: loading data...
# n=4, rep=26: computing statistics...
# n=4, rep=26: fitting Gauss-Legendre parametric prior...
#   8.607810 seconds (226.09 M allocations: 4.126 GiB, 2.01% gc time)
# n=4, rep=26: prior fit done. σ0²=1.1323, ν0=1.083
# n=4, rep=26: computing p-values...
# n=4, rep=26 done → Power=0.0 | FDR=0.0 | TP@100=77
# n=4, rep=27: loading data...
# n=4, rep=27: computing statistics...
# n=4, rep=27: fitting Gauss-Legendre parametric prior...
#   8.863538 seconds (231.95 M allocations: 4.234 GiB, 2.03% gc time)
# n=4, rep=27: prior fit done. σ0²=1.2401, ν0=1.127
# n=4, rep=27: computing p-values...
# n=4, rep=27 done → Power=0.0 | FDR=0.0 | TP@100=80
# n=4, rep=28: loading data...
# n=4, rep=28: computing statistics...
# n=4, rep=28: fitting Gauss-Legendre parametric prior...
#   7.884416 seconds (206.25 M allocations: 3.765 GiB, 2.03% gc time)
# n=4, rep=28: prior fit done. σ0²=1.2371, ν0=1.172
# n=4, rep=28: computing p-values...
# n=4, rep=28 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=4, rep=29: loading data...
# n=4, rep=29: computing statistics...
# n=4, rep=29: fitting Gauss-Legendre parametric prior...
#   9.498968 seconds (249.01 M allocations: 4.545 GiB, 2.04% gc time)
# n=4, rep=29: prior fit done. σ0²=1.2122, ν0=1.123
# n=4, rep=29: computing p-values...
# n=4, rep=29 done → Power=0.0 | FDR=0.0 | TP@100=78
# n=4, rep=30: loading data...
# n=4, rep=30: computing statistics...
# n=4, rep=30: fitting Gauss-Legendre parametric prior...
#   7.990390 seconds (209.08 M allocations: 3.816 GiB, 1.99% gc time)
# n=4, rep=30: prior fit done. σ0²=1.1343, ν0=1.13
# n=4, rep=30: computing p-values...
# n=4, rep=30 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=31: loading data...
# n=4, rep=31: computing statistics...
# n=4, rep=31: fitting Gauss-Legendre parametric prior...
#   8.560177 seconds (223.14 M allocations: 4.073 GiB, 2.02% gc time)
# n=4, rep=31: prior fit done. σ0²=1.102, ν0=1.055
# n=4, rep=31: computing p-values...
# n=4, rep=31 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=32: loading data...
# n=4, rep=32: computing statistics...
# n=4, rep=32: fitting Gauss-Legendre parametric prior...
#   8.140797 seconds (211.91 M allocations: 3.868 GiB, 2.00% gc time)
# n=4, rep=32: prior fit done. σ0²=1.1518, ν0=1.139
# n=4, rep=32: computing p-values...
# n=4, rep=32 done → Power=0.0 | FDR=0.0 | TP@100=72
# n=4, rep=33: loading data...
# n=4, rep=33: computing statistics...
# n=4, rep=33: fitting Gauss-Legendre parametric prior...
#   8.578140 seconds (223.41 M allocations: 4.078 GiB, 2.02% gc time)
# n=4, rep=33: prior fit done. σ0²=1.1274, ν0=1.098
# n=4, rep=33: computing p-values...
# n=4, rep=33 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=4, rep=34: loading data...
# n=4, rep=34: computing statistics...
# n=4, rep=34: fitting Gauss-Legendre parametric prior...
#   8.676727 seconds (226.03 M allocations: 4.125 GiB, 2.02% gc time)
# n=4, rep=34: prior fit done. σ0²=1.1175, ν0=1.053
# n=4, rep=34: computing p-values...
# n=4, rep=34 done → Power=0.01 | FDR=0.0 | TP@100=60
# n=4, rep=35: loading data...
# n=4, rep=35: computing statistics...
# n=4, rep=35: fitting Gauss-Legendre parametric prior...
#   8.238901 seconds (214.59 M allocations: 3.917 GiB, 2.02% gc time)
# n=4, rep=35: prior fit done. σ0²=1.1225, ν0=1.062
# n=4, rep=35: computing p-values...
# n=4, rep=35 done → Power=0.009 | FDR=0.0 | TP@100=70
# n=4, rep=36: loading data...
# n=4, rep=36: computing statistics...
# n=4, rep=36: fitting Gauss-Legendre parametric prior...
#   7.829585 seconds (203.30 M allocations: 3.711 GiB, 2.00% gc time)
# n=4, rep=36: prior fit done. σ0²=1.1993, ν0=1.134
# n=4, rep=36: computing p-values...
# n=4, rep=36 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=37: loading data...
# n=4, rep=37: computing statistics...
# n=4, rep=37: fitting Gauss-Legendre parametric prior...
#   8.169037 seconds (211.95 M allocations: 3.869 GiB, 2.01% gc time)
# n=4, rep=37: prior fit done. σ0²=1.1445, ν0=1.118
# n=4, rep=37: computing p-values...
# n=4, rep=37 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=38: loading data...
# n=4, rep=38: computing statistics...
# n=4, rep=38: fitting Gauss-Legendre parametric prior...
#   8.930090 seconds (231.84 M allocations: 4.232 GiB, 2.03% gc time)
# n=4, rep=38: prior fit done. σ0²=1.1471, ν0=1.105
# n=4, rep=38: computing p-values...
# n=4, rep=38 done → Power=0.011 | FDR=0.0 | TP@100=59
# n=4, rep=39: loading data...
# n=4, rep=39: computing statistics...
# n=4, rep=39: fitting Gauss-Legendre parametric prior...
#   7.697029 seconds (200.27 M allocations: 3.655 GiB, 2.00% gc time)
# n=4, rep=39: prior fit done. σ0²=1.1287, ν0=1.068
# n=4, rep=39: computing p-values...
# n=4, rep=39 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=40: loading data...
# n=4, rep=40: computing statistics...
# n=4, rep=40: fitting Gauss-Legendre parametric prior...
#   8.856383 seconds (229.26 M allocations: 4.185 GiB, 1.99% gc time)
# n=4, rep=40: prior fit done. σ0²=1.2255, ν0=1.194
# n=4, rep=40: computing p-values...
# n=4, rep=40 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=4, rep=41: loading data...
# n=4, rep=41: computing statistics...
# n=4, rep=41: fitting Gauss-Legendre parametric prior...
#   8.399553 seconds (217.64 M allocations: 3.973 GiB, 2.01% gc time)
# n=4, rep=41: prior fit done. σ0²=1.2139, ν0=1.129
# n=4, rep=41: computing p-values...
# n=4, rep=41 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=42: loading data...
# n=4, rep=42: computing statistics...
# n=4, rep=42: fitting Gauss-Legendre parametric prior...
#   8.142033 seconds (209.02 M allocations: 3.815 GiB, 2.14% gc time)
# n=4, rep=42: prior fit done. σ0²=1.056, ν0=1.082
# n=4, rep=42: computing p-values...
# n=4, rep=42 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=43: loading data...
# n=4, rep=43: computing statistics...
# n=4, rep=43: fitting Gauss-Legendre parametric prior...
#   9.956486 seconds (257.60 M allocations: 4.702 GiB, 2.02% gc time)
# n=4, rep=43: prior fit done. σ0²=1.1358, ν0=1.124
# n=4, rep=43: computing p-values...
# n=4, rep=43 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=44: loading data...
# n=4, rep=44: computing statistics...
# n=4, rep=44: fitting Gauss-Legendre parametric prior...
#   8.768650 seconds (226.39 M allocations: 4.132 GiB, 2.01% gc time)
# n=4, rep=44: prior fit done. σ0²=1.1134, ν0=1.148
# n=4, rep=44: computing p-values...
# n=4, rep=44 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=4, rep=45: loading data...
# n=4, rep=45: computing statistics...
# n=4, rep=45: fitting Gauss-Legendre parametric prior...
#   7.855565 seconds (203.22 M allocations: 3.709 GiB, 1.99% gc time)
# n=4, rep=45: prior fit done. σ0²=1.1362, ν0=1.131
# n=4, rep=45: computing p-values...
# n=4, rep=45 done → Power=0.0 | FDR=0.0 | TP@100=78
# n=4, rep=46: loading data...
# n=4, rep=46: computing statistics...
# n=4, rep=46: fitting Gauss-Legendre parametric prior...
#   8.225017 seconds (212.00 M allocations: 3.870 GiB, 2.02% gc time)
# n=4, rep=46: prior fit done. σ0²=1.1195, ν0=1.134
# n=4, rep=46: computing p-values...
# n=4, rep=46 done → Power=0.0 | FDR=0.0 | TP@100=61
# n=4, rep=47: loading data...
# n=4, rep=47: computing statistics...
# n=4, rep=47: fitting Gauss-Legendre parametric prior...
#   7.862264 seconds (203.47 M allocations: 3.714 GiB, 2.03% gc time)
# n=4, rep=47: prior fit done. σ0²=1.1866, ν0=1.18
# n=4, rep=47: computing p-values...
# n=4, rep=47 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=48: loading data...
# n=4, rep=48: computing statistics...
# n=4, rep=48: fitting Gauss-Legendre parametric prior...
#   9.655845 seconds (249.24 M allocations: 4.549 GiB, 2.01% gc time)
# n=4, rep=48: prior fit done. σ0²=1.0849, ν0=1.106
# n=4, rep=48: computing p-values...
# n=4, rep=48 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=49: loading data...
# n=4, rep=49: computing statistics...
# n=4, rep=49: fitting Gauss-Legendre parametric prior...
#   8.382465 seconds (217.43 M allocations: 3.968 GiB, 2.02% gc time)
# n=4, rep=49: prior fit done. σ0²=1.32, ν0=1.123
# n=4, rep=49: computing p-values...
# n=4, rep=49 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=50: loading data...
# n=4, rep=50: computing statistics...
# n=4, rep=50: fitting Gauss-Legendre parametric prior...
#   8.533226 seconds (220.42 M allocations: 4.023 GiB, 2.01% gc time)
# n=4, rep=50: prior fit done. σ0²=1.2663, ν0=1.134
# n=4, rep=50: computing p-values...
# n=4, rep=50 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=51: loading data...
# n=4, rep=51: computing statistics...
# n=4, rep=51: fitting Gauss-Legendre parametric prior...
#   7.096640 seconds (183.19 M allocations: 3.344 GiB, 2.04% gc time)
# n=4, rep=51: prior fit done. σ0²=1.1172, ν0=1.09
# n=4, rep=51: computing p-values...
# n=4, rep=51 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=52: loading data...
# n=4, rep=52: computing statistics...
# n=4, rep=52: fitting Gauss-Legendre parametric prior...
#   8.632029 seconds (222.98 M allocations: 4.070 GiB, 2.03% gc time)
# n=4, rep=52: prior fit done. σ0²=1.2969, ν0=1.081
# n=4, rep=52: computing p-values...
# n=4, rep=52 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=53: loading data...
# n=4, rep=53: computing statistics...
# n=4, rep=53: fitting Gauss-Legendre parametric prior...
#   8.014084 seconds (206.16 M allocations: 3.763 GiB, 2.04% gc time)
# n=4, rep=53: prior fit done. σ0²=1.2022, ν0=1.153
# n=4, rep=53: computing p-values...
# n=4, rep=53 done → Power=0.011 | FDR=0.0 | TP@100=69
# n=4, rep=54: loading data...
# n=4, rep=54: computing statistics...
# n=4, rep=54: fitting Gauss-Legendre parametric prior...
#   8.000662 seconds (206.22 M allocations: 3.764 GiB, 2.03% gc time)
# n=4, rep=54: prior fit done. σ0²=1.3655, ν0=1.223
# n=4, rep=54: computing p-values...
# n=4, rep=54 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=4, rep=55: loading data...
# n=4, rep=55: computing statistics...
# n=4, rep=55: fitting Gauss-Legendre parametric prior...
#   8.438765 seconds (217.61 M allocations: 3.972 GiB, 2.01% gc time)
# n=4, rep=55: prior fit done. σ0²=1.1729, ν0=1.11
# n=4, rep=55: computing p-values...
# n=4, rep=55 done → Power=0.0 | FDR=0.0 | TP@100=77
# n=4, rep=56: loading data...
# n=4, rep=56: computing statistics...
# n=4, rep=56: fitting Gauss-Legendre parametric prior...
#   9.102480 seconds (234.55 M allocations: 4.281 GiB, 2.02% gc time)
# n=4, rep=56: prior fit done. σ0²=1.23, ν0=1.061
# n=4, rep=56: computing p-values...
# n=4, rep=56 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=57: loading data...
# n=4, rep=57: computing statistics...
# n=4, rep=57: fitting Gauss-Legendre parametric prior...
#   8.981324 seconds (231.50 M allocations: 4.225 GiB, 2.02% gc time)
# n=4, rep=57: prior fit done. σ0²=1.4251, ν0=1.089
# n=4, rep=57: computing p-values...
# n=4, rep=57 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=58: loading data...
# n=4, rep=58: computing statistics...
# n=4, rep=58: fitting Gauss-Legendre parametric prior...
#   7.788918 seconds (200.49 M allocations: 3.659 GiB, 2.08% gc time)
# n=4, rep=58: prior fit done. σ0²=1.2549, ν0=1.18
# n=4, rep=58: computing p-values...
# n=4, rep=58 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=59: loading data...
# n=4, rep=59: computing statistics...
# n=4, rep=59: fitting Gauss-Legendre parametric prior...
#   8.152699 seconds (209.25 M allocations: 3.820 GiB, 2.03% gc time)
# n=4, rep=59: prior fit done. σ0²=1.0994, ν0=1.127
# n=4, rep=59: computing p-values...
# n=4, rep=59 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=60: loading data...
# n=4, rep=60: computing statistics...
# n=4, rep=60: fitting Gauss-Legendre parametric prior...
#   8.666027 seconds (223.37 M allocations: 4.077 GiB, 2.03% gc time)
# n=4, rep=60: prior fit done. σ0²=1.1532, ν0=1.129
# n=4, rep=60: computing p-values...
# n=4, rep=60 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=61: loading data...
# n=4, rep=61: computing statistics...
# n=4, rep=61: fitting Gauss-Legendre parametric prior...
#   8.202251 seconds (212.02 M allocations: 3.870 GiB, 2.01% gc time)
# n=4, rep=61: prior fit done. σ0²=1.0707, ν0=1.125
# n=4, rep=61: computing p-values...
# n=4, rep=61 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=62: loading data...
# n=4, rep=62: computing statistics...
# n=4, rep=62: fitting Gauss-Legendre parametric prior...
#   7.827086 seconds (203.46 M allocations: 3.714 GiB, 2.03% gc time)
# n=4, rep=62: prior fit done. σ0²=1.1155, ν0=1.161
# n=4, rep=62: computing p-values...
# n=4, rep=62 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=4, rep=63: loading data...
# n=4, rep=63: computing statistics...
# n=4, rep=63: fitting Gauss-Legendre parametric prior...
#   9.140773 seconds (237.80 M allocations: 4.341 GiB, 2.04% gc time)
# n=4, rep=63: prior fit done. σ0²=1.1137, ν0=1.153
# n=4, rep=63: computing p-values...
# n=4, rep=63 done → Power=0.0 | FDR=0.0 | TP@100=82
# n=4, rep=64: loading data...
# n=4, rep=64: computing statistics...
# n=4, rep=64: fitting Gauss-Legendre parametric prior...
#   7.458759 seconds (194.65 M allocations: 3.553 GiB, 2.06% gc time)
# n=4, rep=64: prior fit done. σ0²=1.1036, ν0=1.092
# n=4, rep=64: computing p-values...
# n=4, rep=64 done → Power=0.0 | FDR=0.0 | TP@100=75
# n=4, rep=65: loading data...
# n=4, rep=65: computing statistics...
# n=4, rep=65: fitting Gauss-Legendre parametric prior...
#   8.083770 seconds (211.44 M allocations: 3.859 GiB, 2.06% gc time)
# n=4, rep=65: prior fit done. σ0²=1.4121, ν0=1.113
# n=4, rep=65: computing p-values...
# n=4, rep=65 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=4, rep=66: loading data...
# n=4, rep=66: computing statistics...
# n=4, rep=66: fitting Gauss-Legendre parametric prior...
#   8.800885 seconds (223.50 M allocations: 4.080 GiB, 2.37% gc time)
# n=4, rep=66: prior fit done. σ0²=1.0032, ν0=1.096
# n=4, rep=66: computing p-values...
# n=4, rep=66 done → Power=0.0 | FDR=0.0 | TP@100=80
# n=4, rep=67: loading data...
# n=4, rep=67: computing statistics...
# n=4, rep=67: fitting Gauss-Legendre parametric prior...
#   8.541950 seconds (223.30 M allocations: 4.076 GiB, 2.03% gc time)
# n=4, rep=67: prior fit done. σ0²=1.2051, ν0=1.119
# n=4, rep=67: computing p-values...
# n=4, rep=67 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=68: loading data...
# n=4, rep=68: computing statistics...
# n=4, rep=68: fitting Gauss-Legendre parametric prior...
#   7.753229 seconds (203.15 M allocations: 3.708 GiB, 2.06% gc time)
# n=4, rep=68: prior fit done. σ0²=1.0628, ν0=1.043
# n=4, rep=68: computing p-values...
# n=4, rep=68 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=4, rep=69: loading data...
# n=4, rep=69: computing statistics...
# n=4, rep=69: fitting Gauss-Legendre parametric prior...
#   9.184052 seconds (240.68 M allocations: 4.393 GiB, 2.05% gc time)
# n=4, rep=69: prior fit done. σ0²=1.1891, ν0=1.147
# n=4, rep=69: computing p-values...
# n=4, rep=69 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=70: loading data...
# n=4, rep=70: computing statistics...
# n=4, rep=70: fitting Gauss-Legendre parametric prior...
#   7.858286 seconds (206.32 M allocations: 3.766 GiB, 2.06% gc time)
# n=4, rep=70: prior fit done. σ0²=1.0748, ν0=1.133
# n=4, rep=70: computing p-values...
# n=4, rep=70 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=71: loading data...
# n=4, rep=71: computing statistics...
# n=4, rep=71: fitting Gauss-Legendre parametric prior...
#   9.513638 seconds (249.28 M allocations: 4.550 GiB, 2.04% gc time)
# n=4, rep=71: prior fit done. σ0²=1.0939, ν0=1.147
# n=4, rep=71: computing p-values...
# n=4, rep=71 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=4, rep=72: loading data...
# n=4, rep=72: computing statistics...
# n=4, rep=72: fitting Gauss-Legendre parametric prior...
#   8.860806 seconds (232.16 M allocations: 4.238 GiB, 2.05% gc time)
# n=4, rep=72: prior fit done. σ0²=1.0281, ν0=1.129
# n=4, rep=72: computing p-values...
# n=4, rep=72 done → Power=0.0 | FDR=0.0 | TP@100=81
# n=4, rep=73: loading data...
# n=4, rep=73: computing statistics...
# n=4, rep=73: fitting Gauss-Legendre parametric prior...
#   8.402155 seconds (220.67 M allocations: 4.028 GiB, 2.06% gc time)
# n=4, rep=73: prior fit done. σ0²=1.2339, ν0=1.169
# n=4, rep=73: computing p-values...
# n=4, rep=73 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=74: loading data...
# n=4, rep=74: computing statistics...
# n=4, rep=74: fitting Gauss-Legendre parametric prior...
#   8.054025 seconds (211.71 M allocations: 3.864 GiB, 2.07% gc time)
# n=4, rep=74: prior fit done. σ0²=1.1938, ν0=1.109
# n=4, rep=74: computing p-values...
# n=4, rep=74 done → Power=0.0 | FDR=0.0 | TP@100=55
# n=4, rep=75: loading data...
# n=4, rep=75: computing statistics...
# n=4, rep=75: fitting Gauss-Legendre parametric prior...
#   7.937543 seconds (209.11 M allocations: 3.817 GiB, 2.04% gc time)
# n=4, rep=75: prior fit done. σ0²=1.3888, ν0=1.231
# n=4, rep=75: computing p-values...
# n=4, rep=75 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=76: loading data...
# n=4, rep=76: computing statistics...
# n=4, rep=76: fitting Gauss-Legendre parametric prior...
#   8.576791 seconds (223.40 M allocations: 4.078 GiB, 2.15% gc time)
# n=4, rep=76: prior fit done. σ0²=1.1847, ν0=1.151
# n=4, rep=76: computing p-values...
# n=4, rep=76 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=77: loading data...
# n=4, rep=77: computing statistics...
# n=4, rep=77: fitting Gauss-Legendre parametric prior...
#   9.507732 seconds (249.02 M allocations: 4.545 GiB, 2.16% gc time)
# n=4, rep=77: prior fit done. σ0²=1.1868, ν0=1.123
# n=4, rep=77: computing p-values...
# n=4, rep=77 done → Power=0.0 | FDR=0.0 | TP@100=80
# n=4, rep=78: loading data...
# n=4, rep=78: computing statistics...
# n=4, rep=78: fitting Gauss-Legendre parametric prior...
#   8.406549 seconds (220.10 M allocations: 4.017 GiB, 2.16% gc time)
# n=4, rep=78: prior fit done. σ0²=1.3163, ν0=1.07
# n=4, rep=78: computing p-values...
# n=4, rep=78 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=79: loading data...
# n=4, rep=79: computing statistics...
# n=4, rep=79: fitting Gauss-Legendre parametric prior...
#   8.881518 seconds (231.68 M allocations: 4.228 GiB, 2.21% gc time)
# n=4, rep=79: prior fit done. σ0²=1.2101, ν0=1.077
# n=4, rep=79: computing p-values...
# n=4, rep=79 done → Power=0.0 | FDR=0.0 | TP@100=75
# n=4, rep=80: loading data...
# n=4, rep=80: computing statistics...
# n=4, rep=80: fitting Gauss-Legendre parametric prior...
#   9.812417 seconds (257.87 M allocations: 4.707 GiB, 2.05% gc time)
# n=4, rep=80: prior fit done. σ0²=1.1464, ν0=1.158
# n=4, rep=80: computing p-values...
# n=4, rep=80 done → Power=0.0 | FDR=0.0 | TP@100=78
# n=4, rep=81: loading data...
# n=4, rep=81: computing statistics...
# n=4, rep=81: fitting Gauss-Legendre parametric prior...
#   8.166275 seconds (214.45 M allocations: 3.914 GiB, 2.04% gc time)
# n=4, rep=81: prior fit done. σ0²=1.3468, ν0=1.123
# n=4, rep=81: computing p-values...
# n=4, rep=81 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=82: loading data...
# n=4, rep=82: computing statistics...
# n=4, rep=82: fitting Gauss-Legendre parametric prior...
#   7.304080 seconds (191.89 M allocations: 3.502 GiB, 2.05% gc time)
# n=4, rep=82: prior fit done. σ0²=1.1495, ν0=1.123
# n=4, rep=82: computing p-values...
# n=4, rep=82 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=4, rep=83: loading data...
# n=4, rep=83: computing statistics...
# n=4, rep=83: fitting Gauss-Legendre parametric prior...
#   8.718961 seconds (228.49 M allocations: 4.170 GiB, 2.10% gc time)
# n=4, rep=83: prior fit done. σ0²=1.1816, ν0=1.009
# n=4, rep=83: computing p-values...
# n=4, rep=83 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=84: loading data...
# n=4, rep=84: computing statistics...
# n=4, rep=84: fitting Gauss-Legendre parametric prior...
#   7.540832 seconds (197.49 M allocations: 3.605 GiB, 2.10% gc time)
# n=4, rep=84: prior fit done. σ0²=1.2306, ν0=1.107
# n=4, rep=84: computing p-values...
# n=4, rep=84 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=85: loading data...
# n=4, rep=85: computing statistics...
# n=4, rep=85: fitting Gauss-Legendre parametric prior...
#   8.601564 seconds (226.08 M allocations: 4.126 GiB, 2.05% gc time)
# n=4, rep=85: prior fit done. σ0²=1.392, ν0=1.161
# n=4, rep=85: computing p-values...
# n=4, rep=85 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=86: loading data...
# n=4, rep=86: computing statistics...
# n=4, rep=86: fitting Gauss-Legendre parametric prior...
#   9.474441 seconds (249.11 M allocations: 4.547 GiB, 2.10% gc time)
# n=4, rep=86: prior fit done. σ0²=1.1241, ν0=1.107
# n=4, rep=86: computing p-values...
# n=4, rep=86 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=87: loading data...
# n=4, rep=87: computing statistics...
# n=4, rep=87: fitting Gauss-Legendre parametric prior...
#   7.882682 seconds (206.23 M allocations: 3.764 GiB, 2.13% gc time)
# n=4, rep=87: prior fit done. σ0²=1.1723, ν0=1.141
# n=4, rep=87: computing p-values...
# n=4, rep=87 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=88: loading data...
# n=4, rep=88: computing statistics...
# n=4, rep=88: fitting Gauss-Legendre parametric prior...
#  10.857926 seconds (280.86 M allocations: 5.127 GiB, 2.40% gc time)
# n=4, rep=88: prior fit done. σ0²=1.2264, ν0=1.227
# n=4, rep=88: computing p-values...
# n=4, rep=88 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=4, rep=89: loading data...
# n=4, rep=89: computing statistics...
# n=4, rep=89: fitting Gauss-Legendre parametric prior...
#   9.371709 seconds (243.69 M allocations: 4.448 GiB, 2.22% gc time)
# n=4, rep=89: prior fit done. σ0²=1.1934, ν0=1.214
# n=4, rep=89: computing p-values...
# n=4, rep=89 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=90: loading data...
# n=4, rep=90: computing statistics...
# n=4, rep=90: fitting Gauss-Legendre parametric prior...
#   8.282506 seconds (211.91 M allocations: 3.868 GiB, 2.22% gc time)
# n=4, rep=90: prior fit done. σ0²=1.1445, ν0=1.111
# n=4, rep=90: computing p-values...
# n=4, rep=90 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=91: loading data...
# n=4, rep=91: computing statistics...
# n=4, rep=91: fitting Gauss-Legendre parametric prior...
#   8.868500 seconds (229.04 M allocations: 4.181 GiB, 2.15% gc time)
# n=4, rep=91: prior fit done. σ0²=1.2759, ν0=1.151
# n=4, rep=91: computing p-values...
# n=4, rep=91 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=92: loading data...
# n=4, rep=92: computing statistics...
# n=4, rep=92: fitting Gauss-Legendre parametric prior...
#  10.008736 seconds (260.70 M allocations: 4.759 GiB, 2.10% gc time)
# n=4, rep=92: prior fit done. σ0²=1.0117, ν0=1.078
# n=4, rep=92: computing p-values...
# n=4, rep=92 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=4, rep=93: loading data...
# n=4, rep=93: computing statistics...
# n=4, rep=93: fitting Gauss-Legendre parametric prior...
#   8.506245 seconds (220.40 M allocations: 4.023 GiB, 2.16% gc time)
# n=4, rep=93: prior fit done. σ0²=1.2243, ν0=1.122
# n=4, rep=93: computing p-values...
# n=4, rep=93 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=4, rep=94: loading data...
# n=4, rep=94: computing statistics...
# n=4, rep=94: fitting Gauss-Legendre parametric prior...
#   8.590214 seconds (223.40 M allocations: 4.078 GiB, 2.11% gc time)
# n=4, rep=94: prior fit done. σ0²=1.233, ν0=1.162
# n=4, rep=94: computing p-values...
# n=4, rep=94 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=95: loading data...
# n=4, rep=95: computing statistics...
# n=4, rep=95: fitting Gauss-Legendre parametric prior...
#   7.884799 seconds (206.18 M allocations: 3.763 GiB, 2.04% gc time)
# n=4, rep=95: prior fit done. σ0²=1.1906, ν0=1.131
# n=4, rep=95: computing p-values...
# n=4, rep=95 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=96: loading data...
# n=4, rep=96: computing statistics...
# n=4, rep=96: fitting Gauss-Legendre parametric prior...
#   9.319626 seconds (243.74 M allocations: 4.449 GiB, 2.04% gc time)
# n=4, rep=96: prior fit done. σ0²=1.0512, ν0=1.171
# n=4, rep=96: computing p-values...
# n=4, rep=96 done → Power=0.0 | FDR=0.0 | TP@100=72
# n=4, rep=97: loading data...
# n=4, rep=97: computing statistics...
# n=4, rep=97: fitting Gauss-Legendre parametric prior...
#   7.972400 seconds (208.96 M allocations: 3.814 GiB, 2.09% gc time)
# n=4, rep=97: prior fit done. σ0²=1.2258, ν0=1.114
# n=4, rep=97: computing p-values...
# n=4, rep=97 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=98: loading data...
# n=4, rep=98: computing statistics...
# n=4, rep=98: fitting Gauss-Legendre parametric prior...
#   8.712300 seconds (228.69 M allocations: 4.174 GiB, 2.05% gc time)
# n=4, rep=98: prior fit done. σ0²=1.3664, ν0=1.088
# n=4, rep=98: computing p-values...
# n=4, rep=98 done → Power=0.0 | FDR=0.0 | TP@100=75
# n=4, rep=99: loading data...
# n=4, rep=99: computing statistics...
# n=4, rep=99: fitting Gauss-Legendre parametric prior...
#  10.918856 seconds (286.71 M allocations: 5.234 GiB, 2.06% gc time)
# n=4, rep=99: prior fit done. σ0²=1.1452, ν0=1.198
# n=4, rep=99: computing p-values...
# n=4, rep=99 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=100: loading data...
# n=4, rep=100: computing statistics...
# n=4, rep=100: fitting Gauss-Legendre parametric prior...
#   8.398297 seconds (220.56 M allocations: 4.026 GiB, 2.08% gc time)
# n=4, rep=100: prior fit done. σ0²=1.1018, ν0=1.1
# n=4, rep=100: computing p-values...
# n=4, rep=100 done → Power=0.009 | FDR=0.0 | TP@100=71
# ✅ Done n=4 → Power=0.001 | FDR=0.0 | TP=0.1 | FP=0.0 | TP@100=68.7
#
# ========== Running MAD_mean + parametric prior (Gauss-Legendre) for n = 5 ==========
# n=5, rep=1: loading data...
# n=5, rep=1: computing statistics...
# n=5, rep=1: fitting Gauss-Legendre parametric prior...
#  12.243993 seconds (306.71 M allocations: 5.355 GiB, 1.85% gc time)
# n=5, rep=1: prior fit done. σ0²=1.2714, ν0=1.218
# n=5, rep=1: computing p-values...
# n=5, rep=1 done → Power=0.0 | FDR=0.0 | TP@100=58
# n=5, rep=2: loading data...
# n=5, rep=2: computing statistics...
# n=5, rep=2: fitting Gauss-Legendre parametric prior...
#  12.016691 seconds (302.48 M allocations: 5.280 GiB, 1.85% gc time)
# n=5, rep=2: prior fit done. σ0²=1.233, ν0=1.144
# n=5, rep=2: computing p-values...
# n=5, rep=2 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=5, rep=3: loading data...
# n=5, rep=3: computing statistics...
# n=5, rep=3: fitting Gauss-Legendre parametric prior...
#  11.750311 seconds (295.46 M allocations: 5.158 GiB, 1.95% gc time)
# n=5, rep=3: prior fit done. σ0²=1.3108, ν0=1.192
# n=5, rep=3: computing p-values...
# n=5, rep=3 done → Power=0.009 | FDR=0.0 | TP@100=71
# n=5, rep=4: loading data...
# n=5, rep=4: computing statistics...
# n=5, rep=4: fitting Gauss-Legendre parametric prior...
#  12.590524 seconds (309.74 M allocations: 5.406 GiB, 2.11% gc time)
# n=5, rep=4: prior fit done. σ0²=1.4163, ν0=1.143
# n=5, rep=4: computing p-values...
# n=5, rep=4 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=5, rep=5: loading data...
# n=5, rep=5: computing statistics...
# n=5, rep=5: fitting Gauss-Legendre parametric prior...
#  11.457456 seconds (287.85 M allocations: 5.025 GiB, 1.83% gc time)
# n=5, rep=5: prior fit done. σ0²=1.2422, ν0=1.185
# n=5, rep=5: computing p-values...
# n=5, rep=5 done → Power=0.011 | FDR=0.0 | TP@100=66
# n=5, rep=6: loading data...
# n=5, rep=6: computing statistics...
# n=5, rep=6: fitting Gauss-Legendre parametric prior...
#  12.023406 seconds (302.10 M allocations: 5.273 GiB, 1.84% gc time)
# n=5, rep=6: prior fit done. σ0²=1.3802, ν0=1.109
# n=5, rep=6: computing p-values...
# n=5, rep=6 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=5, rep=7: loading data...
# n=5, rep=7: computing statistics...
# n=5, rep=7: fitting Gauss-Legendre parametric prior...
#  12.310419 seconds (310.03 M allocations: 5.412 GiB, 1.83% gc time)
# n=5, rep=7: prior fit done. σ0²=1.2998, ν0=1.121
# n=5, rep=7: computing p-values...
# n=5, rep=7 done → Power=0.01 | FDR=0.0 | TP@100=65
# n=5, rep=8: loading data...
# n=5, rep=8: computing statistics...
# n=5, rep=8: fitting Gauss-Legendre parametric prior...
#  12.174836 seconds (306.44 M allocations: 5.349 GiB, 1.83% gc time)
# n=5, rep=8: prior fit done. σ0²=1.4472, ν0=1.24
# n=5, rep=8: computing p-values...
# n=5, rep=8 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=5, rep=9: loading data...
# n=5, rep=9: computing statistics...
# n=5, rep=9: fitting Gauss-Legendre parametric prior...
#  13.688198 seconds (343.86 M allocations: 6.002 GiB, 1.85% gc time)
# n=5, rep=9: prior fit done. σ0²=1.2325, ν0=1.154
# n=5, rep=9: computing p-values...
# n=5, rep=9 done → Power=0.0 | FDR=0.0 | TP@100=83
# n=5, rep=10: loading data...
# n=5, rep=10: computing statistics...
# n=5, rep=10: fitting Gauss-Legendre parametric prior...
#  11.300156 seconds (284.19 M allocations: 4.961 GiB, 1.86% gc time)
# n=5, rep=10: prior fit done. σ0²=1.2464, ν0=1.181
# n=5, rep=10: computing p-values...
# n=5, rep=10 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=5, rep=11: loading data...
# n=5, rep=11: computing statistics...
# n=5, rep=11: fitting Gauss-Legendre parametric prior...
#  12.006437 seconds (302.60 M allocations: 5.282 GiB, 1.86% gc time)
# n=5, rep=11: prior fit done. σ0²=1.4337, ν0=1.201
# n=5, rep=11: computing p-values...
# n=5, rep=11 done → Power=0.0 | FDR=0.0 | TP@100=72
# n=5, rep=12: loading data...
# n=5, rep=12: computing statistics...
# n=5, rep=12: fitting Gauss-Legendre parametric prior...
#  11.579026 seconds (291.74 M allocations: 5.093 GiB, 1.86% gc time)
# n=5, rep=12: prior fit done. σ0²=1.3813, ν0=1.233
# n=5, rep=12: computing p-values...
# n=5, rep=12 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=5, rep=13: loading data...
# n=5, rep=13: computing statistics...
# n=5, rep=13: fitting Gauss-Legendre parametric prior...
#  13.056551 seconds (328.76 M allocations: 5.739 GiB, 1.85% gc time)
# n=5, rep=13: prior fit done. σ0²=1.3913, ν0=1.177
# n=5, rep=13: computing p-values...
# n=5, rep=13 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=5, rep=14: loading data...
# n=5, rep=14: computing statistics...
# n=5, rep=14: fitting Gauss-Legendre parametric prior...
#  12.463936 seconds (313.68 M allocations: 5.475 GiB, 1.85% gc time)
# n=5, rep=14: prior fit done. σ0²=1.4414, ν0=1.199
# n=5, rep=14: computing p-values...
# n=5, rep=14 done → Power=0.01 | FDR=0.0 | TP@100=64
# n=5, rep=15: loading data...
# n=5, rep=15: computing statistics...
# n=5, rep=15: fitting Gauss-Legendre parametric prior...
#  12.019646 seconds (302.62 M allocations: 5.282 GiB, 1.86% gc time)
# n=5, rep=15: prior fit done. σ0²=1.3907, ν0=1.209
# n=5, rep=15: computing p-values...
# n=5, rep=15 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=5, rep=16: loading data...
# n=5, rep=16: computing statistics...
# n=5, rep=16: fitting Gauss-Legendre parametric prior...
#  12.317866 seconds (310.35 M allocations: 5.418 GiB, 1.86% gc time)
# n=5, rep=16: prior fit done. σ0²=1.2691, ν0=1.19
# n=5, rep=16: computing p-values...
# n=5, rep=16 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=5, rep=17: loading data...
# n=5, rep=17: computing statistics...
# n=5, rep=17: fitting Gauss-Legendre parametric prior...
#  12.167138 seconds (306.27 M allocations: 5.346 GiB, 1.86% gc time)
# n=5, rep=17: prior fit done. σ0²=1.213, ν0=1.113
# n=5, rep=17: computing p-values...
# n=5, rep=17 done → Power=0.01 | FDR=0.0 | TP@100=71
# n=5, rep=18: loading data...
# n=5, rep=18: computing statistics...
# n=5, rep=18: fitting Gauss-Legendre parametric prior...
#  11.888805 seconds (298.99 M allocations: 5.219 GiB, 1.85% gc time)
# n=5, rep=18: prior fit done. σ0²=1.102, ν0=1.105
# n=5, rep=18: computing p-values...
# n=5, rep=18 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=5, rep=19: loading data...
# n=5, rep=19: computing statistics...
# n=5, rep=19: fitting Gauss-Legendre parametric prior...
#  12.640182 seconds (317.75 M allocations: 5.546 GiB, 1.88% gc time)
# n=5, rep=19: prior fit done. σ0²=1.3697, ν0=1.195
# n=5, rep=19: computing p-values...
# n=5, rep=19 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=5, rep=20: loading data...
# n=5, rep=20: computing statistics...
# n=5, rep=20: fitting Gauss-Legendre parametric prior...
#  10.982884 seconds (276.77 M allocations: 4.831 GiB, 1.86% gc time)
# n=5, rep=20: prior fit done. σ0²=1.3366, ν0=1.248
# n=5, rep=20: computing p-values...
# n=5, rep=20 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=5, rep=21: loading data...
# n=5, rep=21: computing statistics...
# n=5, rep=21: fitting Gauss-Legendre parametric prior...
#  11.562025 seconds (291.50 M allocations: 5.088 GiB, 1.86% gc time)
# n=5, rep=21: prior fit done. σ0²=1.2501, ν0=1.139
# n=5, rep=21: computing p-values...
# n=5, rep=21 done → Power=0.009 | FDR=0.0 | TP@100=75
# n=5, rep=22: loading data...
# n=5, rep=22: computing statistics...
# n=5, rep=22: fitting Gauss-Legendre parametric prior...
#  11.713783 seconds (295.29 M allocations: 5.154 GiB, 1.86% gc time)
# n=5, rep=22: prior fit done. σ0²=1.3766, ν0=1.21
# n=5, rep=22: computing p-values...
# n=5, rep=22 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=5, rep=23: loading data...
# n=5, rep=23: computing statistics...
# n=5, rep=23: fitting Gauss-Legendre parametric prior...
#  11.267879 seconds (283.89 M allocations: 4.955 GiB, 1.86% gc time)
# n=5, rep=23: prior fit done. σ0²=1.321, ν0=1.212
# n=5, rep=23: computing p-values...
# n=5, rep=23 done → Power=0.0 | FDR=0.0 | TP@100=72
# n=5, rep=24: loading data...
# n=5, rep=24: computing statistics...
# n=5, rep=24: fitting Gauss-Legendre parametric prior...
#  11.393238 seconds (287.54 M allocations: 5.019 GiB, 1.89% gc time)
# n=5, rep=24: prior fit done. σ0²=1.2774, ν0=1.147
# n=5, rep=24: computing p-values...
# n=5, rep=24 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=5, rep=25: loading data...
# n=5, rep=25: computing statistics...
# n=5, rep=25: fitting Gauss-Legendre parametric prior...
#  12.083281 seconds (306.02 M allocations: 5.341 GiB, 1.89% gc time)
# n=5, rep=25: prior fit done. σ0²=1.3534, ν0=1.111
# n=5, rep=25: computing p-values...
# n=5, rep=25 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=5, rep=26: loading data...
# n=5, rep=26: computing statistics...
# n=5, rep=26: fitting Gauss-Legendre parametric prior...
#  11.550307 seconds (291.05 M allocations: 5.080 GiB, 1.87% gc time)
# n=5, rep=26: prior fit done. σ0²=1.3376, ν0=1.13
# n=5, rep=26: computing p-values...
# n=5, rep=26 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=5, rep=27: loading data...
# n=5, rep=27: computing statistics...
# n=5, rep=27: fitting Gauss-Legendre parametric prior...
#  11.871406 seconds (299.09 M allocations: 5.221 GiB, 1.89% gc time)
# n=5, rep=27: prior fit done. σ0²=1.3088, ν0=1.182
# n=5, rep=27: computing p-values...
# n=5, rep=27 done → Power=0.0 | FDR=0.0 | TP@100=77
# n=5, rep=28: loading data...
# n=5, rep=28: computing statistics...
# n=5, rep=28: fitting Gauss-Legendre parametric prior...
#  11.075387 seconds (280.17 M allocations: 4.890 GiB, 1.89% gc time)
# n=5, rep=28: prior fit done. σ0²=1.3409, ν0=1.153
# n=5, rep=28: computing p-values...
# n=5, rep=28 done → Power=0.05 | FDR=0.0 | TP@100=75
# n=5, rep=29: loading data...
# n=5, rep=29: computing statistics...
# n=5, rep=29: fitting Gauss-Legendre parametric prior...
#  11.999084 seconds (302.89 M allocations: 5.287 GiB, 1.87% gc time)
# n=5, rep=29: prior fit done. σ0²=1.2173, ν0=1.184
# n=5, rep=29: computing p-values...
# n=5, rep=29 done → Power=0.01 | FDR=0.0 | TP@100=66
# n=5, rep=30: loading data...
# n=5, rep=30: computing statistics...
# n=5, rep=30: fitting Gauss-Legendre parametric prior...
#  12.252946 seconds (309.95 M allocations: 5.410 GiB, 1.90% gc time)
# n=5, rep=30: prior fit done. σ0²=1.4183, ν0=1.18
# n=5, rep=30: computing p-values...
# n=5, rep=30 done → Power=0.01 | FDR=0.0 | TP@100=66
# n=5, rep=31: loading data...
# n=5, rep=31: computing statistics...
# n=5, rep=31: fitting Gauss-Legendre parametric prior...
#  11.691545 seconds (295.14 M allocations: 5.152 GiB, 1.88% gc time)
# n=5, rep=31: prior fit done. σ0²=1.058, ν0=1.058
# n=5, rep=31: computing p-values...
# n=5, rep=31 done → Power=0.021 | FDR=0.0 | TP@100=65
# n=5, rep=32: loading data...
# n=5, rep=32: computing statistics...
# n=5, rep=32: fitting Gauss-Legendre parametric prior...
#  11.999819 seconds (302.52 M allocations: 5.280 GiB, 1.88% gc time)
# n=5, rep=32: prior fit done. σ0²=1.286, ν0=1.144
# n=5, rep=32: computing p-values...
# n=5, rep=32 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=5, rep=33: loading data...
# n=5, rep=33: computing statistics...
# n=5, rep=33: fitting Gauss-Legendre parametric prior...
#  13.632663 seconds (343.99 M allocations: 6.005 GiB, 1.87% gc time)
# n=5, rep=33: prior fit done. σ0²=1.2713, ν0=1.185
# n=5, rep=33: computing p-values...
# n=5, rep=33 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=5, rep=34: loading data...
# n=5, rep=34: computing statistics...
# n=5, rep=34: fitting Gauss-Legendre parametric prior...
#  12.101648 seconds (305.77 M allocations: 5.337 GiB, 1.87% gc time)
# n=5, rep=34: prior fit done. σ0²=1.3917, ν0=1.124
# n=5, rep=34: computing p-values...
# n=5, rep=34 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=5, rep=35: loading data...
# n=5, rep=35: computing statistics...
# n=5, rep=35: fitting Gauss-Legendre parametric prior...
#  11.854084 seconds (299.16 M allocations: 5.222 GiB, 1.90% gc time)
# n=5, rep=35: prior fit done. σ0²=1.3677, ν0=1.251
# n=5, rep=35: computing p-values...
# n=5, rep=35 done → Power=0.029 | FDR=0.0 | TP@100=71
# n=5, rep=36: loading data...
# n=5, rep=36: computing statistics...
# n=5, rep=36: fitting Gauss-Legendre parametric prior...
#  11.408982 seconds (287.87 M allocations: 5.025 GiB, 1.91% gc time)
# n=5, rep=36: prior fit done. σ0²=1.2468, ν0=1.182
# n=5, rep=36: computing p-values...
# n=5, rep=36 done → Power=0.042 | FDR=0.0 | TP@100=63
# n=5, rep=37: loading data...
# n=5, rep=37: computing statistics...
# n=5, rep=37: fitting Gauss-Legendre parametric prior...
#  12.582850 seconds (317.48 M allocations: 5.541 GiB, 1.88% gc time)
# n=5, rep=37: prior fit done. σ0²=1.3066, ν0=1.168
# n=5, rep=37: computing p-values...
# n=5, rep=37 done → Power=0.016 | FDR=0.0 | TP@100=86
# n=5, rep=38: loading data...
# n=5, rep=38: computing statistics...
# n=5, rep=38: fitting Gauss-Legendre parametric prior...
#  11.853587 seconds (298.94 M allocations: 5.218 GiB, 1.88% gc time)
# n=5, rep=38: prior fit done. σ0²=1.2607, ν0=1.163
# n=5, rep=38: computing p-values...
# n=5, rep=38 done → Power=0.02 | FDR=0.0 | TP@100=64
# n=5, rep=39: loading data...
# n=5, rep=39: computing statistics...
# n=5, rep=39: fitting Gauss-Legendre parametric prior...
#  13.010461 seconds (328.69 M allocations: 5.737 GiB, 1.90% gc time)
# n=5, rep=39: prior fit done. σ0²=1.4337, ν0=1.192
# n=5, rep=39: computing p-values...
# n=5, rep=39 done → Power=0.0 | FDR=0.0 | TP@100=75
# n=5, rep=40: loading data...
# n=5, rep=40: computing statistics...
# n=5, rep=40: fitting Gauss-Legendre parametric prior...
#  13.602780 seconds (343.61 M allocations: 5.998 GiB, 1.89% gc time)
# n=5, rep=40: prior fit done. σ0²=1.4785, ν0=1.21
# n=5, rep=40: computing p-values...
# n=5, rep=40 done → Power=0.021 | FDR=0.0 | TP@100=68
# n=5, rep=41: loading data...
# n=5, rep=41: computing statistics...
# n=5, rep=41: fitting Gauss-Legendre parametric prior...
#  11.693350 seconds (295.07 M allocations: 5.150 GiB, 1.90% gc time)
# n=5, rep=41: prior fit done. σ0²=1.2327, ν0=1.15
# n=5, rep=41: computing p-values...
# n=5, rep=41 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=5, rep=42: loading data...
# n=5, rep=42: computing statistics...
# n=5, rep=42: fitting Gauss-Legendre parametric prior...
#  11.638732 seconds (294.67 M allocations: 5.143 GiB, 1.91% gc time)
# n=5, rep=42: prior fit done. σ0²=1.2473, ν0=1.075
# n=5, rep=42: computing p-values...
# n=5, rep=42 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=5, rep=43: loading data...
# n=5, rep=43: computing statistics...
# n=5, rep=43: fitting Gauss-Legendre parametric prior...
#  12.270578 seconds (309.87 M allocations: 5.409 GiB, 1.90% gc time)
# n=5, rep=43: prior fit done. σ0²=1.2691, ν0=1.117
# n=5, rep=43: computing p-values...
# n=5, rep=43 done → Power=0.011 | FDR=0.0 | TP@100=60
# n=5, rep=44: loading data...
# n=5, rep=44: computing statistics...
# n=5, rep=44: fitting Gauss-Legendre parametric prior...
#  11.975239 seconds (302.49 M allocations: 5.280 GiB, 1.89% gc time)
# n=5, rep=44: prior fit done. σ0²=1.5971, ν0=1.236
# n=5, rep=44: computing p-values...
# n=5, rep=44 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=5, rep=45: loading data...
# n=5, rep=45: computing statistics...
# n=5, rep=45: fitting Gauss-Legendre parametric prior...
#  13.445878 seconds (339.53 M allocations: 5.926 GiB, 1.89% gc time)
# n=5, rep=45: prior fit done. σ0²=1.4693, ν0=1.155
# n=5, rep=45: computing p-values...
# n=5, rep=45 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=5, rep=46: loading data...
# n=5, rep=46: computing statistics...
# n=5, rep=46: fitting Gauss-Legendre parametric prior...
#  12.419542 seconds (313.51 M allocations: 5.472 GiB, 1.89% gc time)
# n=5, rep=46: prior fit done. σ0²=1.3433, ν0=1.124
# n=5, rep=46: computing p-values...
# n=5, rep=46 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=5, rep=47: loading data...
# n=5, rep=47: computing statistics...
# n=5, rep=47: fitting Gauss-Legendre parametric prior...
#  11.972194 seconds (302.52 M allocations: 5.280 GiB, 1.92% gc time)
# n=5, rep=47: prior fit done. σ0²=1.2499, ν0=1.142
# ...
# 169.679762 seconds (2.30 G allocations: 36.962 GiB, 1.08% gc time)
# n=40, rep=53: prior fit done. σ0²=3.2755, ν0=2.485
# n=40, rep=53: computing p-values...
# n=40, rep=53 done → Power=0.28 | FDR=0.034 | TP@100=49
# n=40, rep=54: loading data...
# n=40, rep=54: computing statistics...
# n=40, rep=54: fitting Gauss-Legendre parametric prior...
# 168.043946 seconds (2.28 G allocations: 36.559 GiB, 1.07% gc time)
# n=40, rep=54: prior fit done. σ0²=3.2173, ν0=2.558
# n=40, rep=54: computing p-values...
# n=40, rep=54 done → Power=0.234 | FDR=0.071 | TP@100=48
# n=40, rep=55: loading data...
# n=40, rep=55: computing statistics...
# n=40, rep=55: fitting Gauss-Legendre parametric prior...
# 165.096557 seconds (2.25 G allocations: 36.031 GiB, 1.08% gc time)
# n=40, rep=55: prior fit done. σ0²=3.2886, ν0=2.512
# n=40, rep=55: computing p-values...
# n=40, rep=55 done → Power=0.195 | FDR=0.118 | TP@100=29
# n=40, rep=56: loading data...
# n=40, rep=56: computing statistics...
# n=40, rep=56: fitting Gauss-Legendre parametric prior...
# 165.881351 seconds (2.26 G allocations: 36.320 GiB, 1.07% gc time)
# n=40, rep=56: prior fit done. σ0²=3.1089, ν0=2.124
# n=40, rep=56: computing p-values...
# n=40, rep=56 done → Power=0.326 | FDR=0.067 | TP@100=42
# n=40, rep=57: loading data...
# n=40, rep=57: computing statistics...
# n=40, rep=57: fitting Gauss-Legendre parametric prior...
# 172.665404 seconds (2.36 G allocations: 37.791 GiB, 1.08% gc time)
# n=40, rep=57: prior fit done. σ0²=3.3709, ν0=2.441
# n=40, rep=57: computing p-values...
# n=40, rep=57 done → Power=0.271 | FDR=0.071 | TP@100=41
# n=40, rep=58: loading data...
# n=40, rep=58: computing statistics...
# n=40, rep=58: fitting Gauss-Legendre parametric prior...
# 173.214425 seconds (2.35 G allocations: 37.758 GiB, 1.11% gc time)
# n=40, rep=58: prior fit done. σ0²=3.118, ν0=2.236
# n=40, rep=58: computing p-values...
# n=40, rep=58 done → Power=0.15 | FDR=0.0 | TP@100=42
# n=40, rep=59: loading data...
# n=40, rep=59: computing statistics...
# n=40, rep=59: fitting Gauss-Legendre parametric prior...
# 168.365562 seconds (2.28 G allocations: 36.545 GiB, 1.12% gc time)
# n=40, rep=59: prior fit done. σ0²=3.0681, ν0=2.42
# n=40, rep=59: computing p-values...
# n=40, rep=59 done → Power=0.278 | FDR=0.12 | TP@100=37
# n=40, rep=60: loading data...
# n=40, rep=60: computing statistics...
# n=40, rep=60: fitting Gauss-Legendre parametric prior...
# 164.901485 seconds (2.24 G allocations: 36.001 GiB, 1.07% gc time)
# n=40, rep=60: prior fit done. σ0²=3.1431, ν0=2.345
# n=40, rep=60: computing p-values...
# n=40, rep=60 done → Power=0.313 | FDR=0.031 | TP@100=45
# n=40, rep=61: loading data...
# n=40, rep=61: computing statistics...
# n=40, rep=61: fitting Gauss-Legendre parametric prior...
# 165.563306 seconds (2.25 G allocations: 36.059 GiB, 1.08% gc time)
# n=40, rep=61: prior fit done. σ0²=3.1141, ν0=2.416
# n=40, rep=61: computing p-values...
# n=40, rep=61 done → Power=0.284 | FDR=0.061 | TP@100=46
# n=40, rep=62: loading data...
# n=40, rep=62: computing statistics...
# n=40, rep=62: fitting Gauss-Legendre parametric prior...
# 160.705214 seconds (2.19 G allocations: 35.073 GiB, 1.07% gc time)
# n=40, rep=62: prior fit done. σ0²=3.083, ν0=2.288
# n=40, rep=62: computing p-values...
# n=40, rep=62 done → Power=0.153 | FDR=0.071 | TP@100=42
# n=40, rep=63: loading data...
# n=40, rep=63: computing statistics...
# n=40, rep=63: fitting Gauss-Legendre parametric prior...
# 167.124620 seconds (2.27 G allocations: 36.459 GiB, 1.08% gc time)
# n=40, rep=63: prior fit done. σ0²=3.1402, ν0=2.366
# n=40, rep=63: computing p-values...
# n=40, rep=63 done → Power=0.265 | FDR=0.103 | TP@100=43
# n=40, rep=64: loading data...
# n=40, rep=64: computing statistics...
# n=40, rep=64: fitting Gauss-Legendre parametric prior...
# 171.583305 seconds (2.33 G allocations: 37.420 GiB, 1.08% gc time)
# n=40, rep=64: prior fit done. σ0²=3.0985, ν0=2.319
# n=40, rep=64: computing p-values...
# n=40, rep=64 done → Power=0.309 | FDR=0.171 | TP@100=45
# n=40, rep=65: loading data...
# n=40, rep=65: computing statistics...
# n=40, rep=65: fitting Gauss-Legendre parametric prior...
# 171.948292 seconds (2.33 G allocations: 37.372 GiB, 1.09% gc time)
# n=40, rep=65: prior fit done. σ0²=2.9139, ν0=2.176
# n=40, rep=65: computing p-values...
# n=40, rep=65 done → Power=0.316 | FDR=0.118 | TP@100=44
# n=40, rep=66: loading data...
# n=40, rep=66: computing statistics...
# n=40, rep=66: fitting Gauss-Legendre parametric prior...
# 169.024231 seconds (2.30 G allocations: 36.941 GiB, 1.07% gc time)
# n=40, rep=66: prior fit done. σ0²=3.371, ν0=2.55
# n=40, rep=66: computing p-values...
# n=40, rep=66 done → Power=0.154 | FDR=0.125 | TP@100=37
# n=40, rep=67: loading data...
# n=40, rep=67: computing statistics...
# n=40, rep=67: fitting Gauss-Legendre parametric prior...
# 176.079509 seconds (2.39 G allocations: 38.373 GiB, 1.07% gc time)
# n=40, rep=67: prior fit done. σ0²=3.1771, ν0=2.473
# n=40, rep=67: computing p-values...
# n=40, rep=67 done → Power=0.242 | FDR=0.0 | TP@100=37
# n=40, rep=68: loading data...
# n=40, rep=68: computing statistics...
# n=40, rep=68: fitting Gauss-Legendre parametric prior...
# 169.518575 seconds (2.30 G allocations: 36.965 GiB, 1.08% gc time)
# n=40, rep=68: prior fit done. σ0²=3.1137, ν0=2.371
# n=40, rep=68: computing p-values...
# n=40, rep=68 done → Power=0.212 | FDR=0.045 | TP@100=37
# n=40, rep=69: loading data...
# n=40, rep=69: computing statistics...
# n=40, rep=69: fitting Gauss-Legendre parametric prior...
# 170.657895 seconds (2.33 G allocations: 37.365 GiB, 1.08% gc time)
# n=40, rep=69: prior fit done. σ0²=3.4612, ν0=2.566
# n=40, rep=69: computing p-values...
# n=40, rep=69 done → Power=0.369 | FDR=0.062 | TP@100=54
# n=40, rep=70: loading data...
# n=40, rep=70: computing statistics...
# n=40, rep=70: fitting Gauss-Legendre parametric prior...
# 174.250695 seconds (2.36 G allocations: 37.916 GiB, 1.08% gc time)
# n=40, rep=70: prior fit done. σ0²=3.1001, ν0=2.436
# n=40, rep=70: computing p-values...
# n=40, rep=70 done → Power=0.147 | FDR=0.2 | TP@100=41
# n=40, rep=71: loading data...
# n=40, rep=71: computing statistics...
# n=40, rep=71: fitting Gauss-Legendre parametric prior...
# 178.130211 seconds (2.42 G allocations: 38.840 GiB, 1.08% gc time)
# n=40, rep=71: prior fit done. σ0²=3.1809, ν0=2.457
# n=40, rep=71: computing p-values...
# n=40, rep=71 done → Power=0.24 | FDR=0.042 | TP@100=43
# n=40, rep=72: loading data...
# n=40, rep=72: computing statistics...
# n=40, rep=72: fitting Gauss-Legendre parametric prior...
# 169.925753 seconds (2.30 G allocations: 36.973 GiB, 1.24% gc time)
# n=40, rep=72: prior fit done. σ0²=3.2023, ν0=2.45
# n=40, rep=72: computing p-values...
# n=40, rep=72 done → Power=0.323 | FDR=0.032 | TP@100=47
# n=40, rep=73: loading data...
# n=40, rep=73: computing statistics...
# n=40, rep=73: fitting Gauss-Legendre parametric prior...
# 169.514809 seconds (2.31 G allocations: 36.997 GiB, 1.08% gc time)
# n=40, rep=73: prior fit done. σ0²=3.2858, ν0=2.57
# n=40, rep=73: computing p-values...
# n=40, rep=73 done → Power=0.24 | FDR=0.0 | TP@100=38
# n=40, rep=74: loading data...
# n=40, rep=74: computing statistics...
# n=40, rep=74: fitting Gauss-Legendre parametric prior...
# 171.334523 seconds (2.33 G allocations: 37.414 GiB, 1.07% gc time)
# n=40, rep=74: prior fit done. σ0²=3.2634, ν0=2.487
# n=40, rep=74: computing p-values...
# n=40, rep=74 done → Power=0.309 | FDR=0.0 | TP@100=46
# n=40, rep=75: loading data...
# n=40, rep=75: computing statistics...
# n=40, rep=75: fitting Gauss-Legendre parametric prior...
# 171.989058 seconds (2.33 G allocations: 37.313 GiB, 1.09% gc time)
# n=40, rep=75: prior fit done. σ0²=3.1349, ν0=2.25
# n=40, rep=75: computing p-values...
# n=40, rep=75 done → Power=0.194 | FDR=0.0 | TP@100=38
# n=40, rep=76: loading data...
# n=40, rep=76: computing statistics...
# n=40, rep=76: fitting Gauss-Legendre parametric prior...
# 173.007418 seconds (2.36 G allocations: 37.822 GiB, 1.07% gc time)
# n=40, rep=76: prior fit done. σ0²=3.2531, ν0=2.414
# n=40, rep=76: computing p-values...
# n=40, rep=76 done → Power=0.207 | FDR=0.05 | TP@100=43
# n=40, rep=77: loading data...
# n=40, rep=77: computing statistics...
# n=40, rep=77: fitting Gauss-Legendre parametric prior...
# 165.569550 seconds (2.25 G allocations: 36.083 GiB, 1.08% gc time)
# n=40, rep=77: prior fit done. σ0²=3.2135, ν0=2.518
# n=40, rep=77: computing p-values...
# n=40, rep=77 done → Power=0.27 | FDR=0.036 | TP@100=51
# n=40, rep=78: loading data...
# n=40, rep=78: computing statistics...
# n=40, rep=78: fitting Gauss-Legendre parametric prior...
# 171.470822 seconds (2.33 G allocations: 37.384 GiB, 1.09% gc time)
# n=40, rep=78: prior fit done. σ0²=3.0948, ν0=2.284
# n=40, rep=78: computing p-values...
# n=40, rep=78 done → Power=0.283 | FDR=0.097 | TP@100=43
# n=40, rep=79: loading data...
# n=40, rep=79: computing statistics...
# n=40, rep=79: fitting Gauss-Legendre parametric prior...
# 171.758838 seconds (2.34 G allocations: 37.484 GiB, 1.07% gc time)
# n=40, rep=79: prior fit done. σ0²=3.3298, ν0=2.64
# n=40, rep=79: computing p-values...
# n=40, rep=79 done → Power=0.273 | FDR=0.069 | TP@100=41
# n=40, rep=80: loading data...
# n=40, rep=80: computing statistics...
# n=40, rep=80: fitting Gauss-Legendre parametric prior...
# 169.525514 seconds (2.32 G allocations: 37.236 GiB, 1.07% gc time)
# n=40, rep=80: prior fit done. σ0²=3.3989, ν0=2.329
# n=40, rep=80: computing p-values...
# n=40, rep=80 done → Power=0.26 | FDR=0.138 | TP@100=44
# n=40, rep=81: loading data...
# n=40, rep=81: computing statistics...
# n=40, rep=81: fitting Gauss-Legendre parametric prior...
# 165.908030 seconds (2.27 G allocations: 36.375 GiB, 1.07% gc time)
# n=40, rep=81: prior fit done. σ0²=3.2968, ν0=2.326
# n=40, rep=81: computing p-values...
# n=40, rep=81 done → Power=0.3 | FDR=0.083 | TP@100=52
# n=40, rep=82: loading data...
# n=40, rep=82: computing statistics...
# n=40, rep=82: fitting Gauss-Legendre parametric prior...
# 165.928024 seconds (2.27 G allocations: 36.387 GiB, 1.08% gc time)
# n=40, rep=82: prior fit done. σ0²=3.332, ν0=2.344
# n=40, rep=82: computing p-values...
# n=40, rep=82 done → Power=0.175 | FDR=0.125 | TP@100=34
# n=40, rep=83: loading data...
# n=40, rep=83: computing statistics...
# n=40, rep=83: fitting Gauss-Legendre parametric prior...
# 164.734954 seconds (2.24 G allocations: 36.012 GiB, 1.08% gc time)
# n=40, rep=83: prior fit done. σ0²=3.2542, ν0=2.413
# n=40, rep=83: computing p-values...
# n=40, rep=83 done → Power=0.288 | FDR=0.179 | TP@100=41
# n=40, rep=84: loading data...
# n=40, rep=84: computing statistics...
# n=40, rep=84: fitting Gauss-Legendre parametric prior...
# 167.276189 seconds (2.28 G allocations: 36.512 GiB, 1.10% gc time)
# n=40, rep=84: prior fit done. σ0²=3.3649, ν0=2.603
# n=40, rep=84: computing p-values...
# n=40, rep=84 done → Power=0.186 | FDR=0.136 | TP@100=44
# n=40, rep=85: loading data...
# n=40, rep=85: computing statistics...
# n=40, rep=85: fitting Gauss-Legendre parametric prior...
# 163.249152 seconds (2.24 G allocations: 35.878 GiB, 1.10% gc time)
# n=40, rep=85: prior fit done. σ0²=3.5579, ν0=2.453
# n=40, rep=85: computing p-values...
# n=40, rep=85 done → Power=0.135 | FDR=0.071 | TP@100=31
# n=40, rep=86: loading data...
# n=40, rep=86: computing statistics...
# n=40, rep=86: fitting Gauss-Legendre parametric prior...
# 160.375058 seconds (2.19 G allocations: 35.072 GiB, 1.08% gc time)
# n=40, rep=86: prior fit done. σ0²=3.2976, ν0=2.453
# n=40, rep=86: computing p-values...
# n=40, rep=86 done → Power=0.366 | FDR=0.109 | TP@100=58
# n=40, rep=87: loading data...
# n=40, rep=87: computing statistics...
# n=40, rep=87: fitting Gauss-Legendre parametric prior...
# 176.406980 seconds (2.40 G allocations: 38.453 GiB, 1.07% gc time)
# n=40, rep=87: prior fit done. σ0²=3.3381, ν0=2.707
# n=40, rep=87: computing p-values...
# n=40, rep=87 done → Power=0.3 | FDR=0.062 | TP@100=46
# n=40, rep=88: loading data...
# n=40, rep=88: computing statistics...
# n=40, rep=88: fitting Gauss-Legendre parametric prior...
# 178.360695 seconds (2.42 G allocations: 38.828 GiB, 1.08% gc time)
# n=40, rep=88: prior fit done. σ0²=3.2813, ν0=2.552
# n=40, rep=88: computing p-values...
# n=40, rep=88 done → Power=0.24 | FDR=0.233 | TP@100=40
# n=40, rep=89: loading data...
# n=40, rep=89: computing statistics...
# n=40, rep=89: fitting Gauss-Legendre parametric prior...
# 163.283870 seconds (2.22 G allocations: 35.561 GiB, 1.10% gc time)
# n=40, rep=89: prior fit done. σ0²=3.1896, ν0=2.391
# n=40, rep=89: computing p-values...
# n=40, rep=89 done → Power=0.172 | FDR=0.154 | TP@100=43
# n=40, rep=90: loading data...
# n=40, rep=90: computing statistics...
# n=40, rep=90: fitting Gauss-Legendre parametric prior...
# 171.885410 seconds (2.33 G allocations: 37.462 GiB, 1.07% gc time)
# n=40, rep=90: prior fit done. σ0²=3.2067, ν0=2.519
# n=40, rep=90: computing p-values...
# n=40, rep=90 done → Power=0.257 | FDR=0.0 | TP@100=45
# n=40, rep=91: loading data...
# n=40, rep=91: computing statistics...
# n=40, rep=91: fitting Gauss-Legendre parametric prior...
# 166.416257 seconds (2.25 G allocations: 36.067 GiB, 1.09% gc time)
# n=40, rep=91: prior fit done. σ0²=3.0718, ν0=2.389
# n=40, rep=91: computing p-values...
# n=40, rep=91 done → Power=0.28 | FDR=0.097 | TP@100=48
# n=40, rep=92: loading data...
# n=40, rep=92: computing statistics...
# n=40, rep=92: fitting Gauss-Legendre parametric prior...
# 169.874920 seconds (2.30 G allocations: 36.847 GiB, 1.10% gc time)
# n=40, rep=92: prior fit done. σ0²=3.3139, ν0=2.352
# n=40, rep=92: computing p-values...
# n=40, rep=92 done → Power=0.262 | FDR=0.097 | TP@100=46
# n=40, rep=93: loading data...
# n=40, rep=93: computing statistics...
# n=40, rep=93: fitting Gauss-Legendre parametric prior...
# 174.824001 seconds (2.36 G allocations: 37.881 GiB, 1.08% gc time)
# n=40, rep=93: prior fit done. σ0²=3.1766, ν0=2.427
# n=40, rep=93: computing p-values...
# n=40, rep=93 done → Power=0.238 | FDR=0.074 | TP@100=42
# n=40, rep=94: loading data...
# n=40, rep=94: computing statistics...
# n=40, rep=94: fitting Gauss-Legendre parametric prior...
# 167.776128 seconds (2.27 G allocations: 36.419 GiB, 1.08% gc time)
# n=40, rep=94: prior fit done. σ0²=3.0734, ν0=2.247
# n=40, rep=94: computing p-values...
# n=40, rep=94 done → Power=0.159 | FDR=0.0 | TP@100=40
# n=40, rep=95: loading data...
# n=40, rep=95: computing statistics...
# n=40, rep=95: fitting Gauss-Legendre parametric prior...
# 160.604552 seconds (2.18 G allocations: 35.040 GiB, 1.07% gc time)
# n=40, rep=95: prior fit done. σ0²=3.1723, ν0=2.301
# n=40, rep=95: computing p-values...
# n=40, rep=95 done → Power=0.262 | FDR=0.097 | TP@100=44
# n=40, rep=96: loading data...
# n=40, rep=96: computing statistics...
# n=40, rep=96: fitting Gauss-Legendre parametric prior...
# 174.374181 seconds (2.36 G allocations: 37.924 GiB, 1.08% gc time)
# n=40, rep=96: prior fit done. σ0²=3.2129, ν0=2.505
# n=40, rep=96: computing p-values...
# n=40, rep=96 done → Power=0.16 | FDR=0.0 | TP@100=46
# n=40, rep=97: loading data...
# n=40, rep=97: computing statistics...
# n=40, rep=97: fitting Gauss-Legendre parametric prior...
# 169.536406 seconds (2.30 G allocations: 36.970 GiB, 1.07% gc time)
# n=40, rep=97: prior fit done. σ0²=3.0977, ν0=2.361
# n=40, rep=97: computing p-values...
# n=40, rep=97 done → Power=0.316 | FDR=0.038 | TP@100=39
# n=40, rep=98: loading data...
# n=40, rep=98: computing statistics...
# n=40, rep=98: fitting Gauss-Legendre parametric prior...
# 172.821369 seconds (2.36 G allocations: 37.803 GiB, 1.07% gc time)
# n=40, rep=98: prior fit done. σ0²=3.2122, ν0=2.342
# n=40, rep=98: computing p-values...
# n=40, rep=98 done → Power=0.28 | FDR=0.097 | TP@100=38
# n=40, rep=99: loading data...
# n=40, rep=99: computing statistics...
# n=40, rep=99: fitting Gauss-Legendre parametric prior...
# 167.409421 seconds (2.27 G allocations: 36.469 GiB, 1.10% gc time)
# n=40, rep=99: prior fit done. σ0²=3.2447, ν0=2.435
# n=40, rep=99: computing p-values...
# n=40, rep=99 done → Power=0.267 | FDR=0.148 | TP@100=37
# n=40, rep=100: loading data...
# n=40, rep=100: computing statistics...
# n=40, rep=100: fitting Gauss-Legendre parametric prior...
# 163.387890 seconds (2.22 G allocations: 35.613 GiB, 1.07% gc time)
# n=40, rep=100: prior fit done. σ0²=3.0941, ν0=2.422
# n=40, rep=100: computing p-values...
# n=40, rep=100 done → Power=0.253 | FDR=0.04 | TP@100=40
# ✅ Done n=40 → Power=0.245 | FDR=0.078 | TP=24.5 | FP=2.3 | TP@100=43.1

# %%
mad_param_gl_summary
# Out:
# Dict{String, Vector} with 6 entries:
#   "TP"        => [0.06, 0.66, 2.64, 8.17, 11.19, 17.32, 19.73, 24.48]
#   "FDR"       => [0.0, 0.0, 0.0, 0.0005, 0.0, 0.00140873, 0.0129521, 0.0783311]
#   "TP_top100" => [68.68, 68.15, 66.82, 64.8, 63.36, 54.08, 46.6, 43.1]
#   "Power"     => [0.000604446, 0.00645401, 0.0269555, 0.0800812, 0.110765, 0.17…
#   "FP"        => [0.0, 0.0, 0.0, 0.01, 0.0, 0.03, 0.3, 2.34]
#   "n"         => [4, 5, 6, 8, 10, 20, 30, 40]

# %%
# =========================================================
# Final summary
# =========================================================
println(
    "\n========== MAD NP SUMMARY ACROSS SAMPLE SIZES =========="
)

for i in eachindex(mad_param_gl_prior_summary["n"])

    println(
        "n = $(mad_param_gl_summary["n"][i]) → " *
        "TP=$(round(mad_param_gl_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_param_gl_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_param_gl_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_param_gl_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(mad_param_gl_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== MAD NP SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=0.06, FP=0.0, Power=0.0006, FDR=0.0, TP@100=68.68
# n = 5 → TP=0.66, FP=0.0, Power=0.00645, FDR=0.0, TP@100=68.15
# n = 6 → TP=2.64, FP=0.0, Power=0.02696, FDR=0.0, TP@100=66.82
# n = 8 → TP=8.17, FP=0.01, Power=0.08008, FDR=0.0005, TP@100=64.8
# n = 10 → TP=11.19, FP=0.0, Power=0.11076, FDR=0.0, TP@100=63.36
# n = 20 → TP=17.32, FP=0.03, Power=0.17141, FDR=0.00141, TP@100=54.08
# n = 30 → TP=19.73, FP=0.3, Power=0.20016, FDR=0.01295, TP@100=46.6
# n = 40 → TP=24.48, FP=2.34, Power=0.24549, FDR=0.07833, TP@100=43.1

# %% [markdown]
# ## MAD Np

# %%
using Distributions, ApproxFun, SpecialFunctions, QuadGK

# ---- distribution type ----
struct MADDistribution{T<:Real,S<:Integer} <: ContinuousUnivariateDistribution
    σ::T
    n::S
end

# ---- import functions we will EXTEND from Distributions ----
import Distributions: pdf, logpdf, insupport, minimum, maximum

# ---- your helpers (unchanged) ----
function G_recursive(max_r::Int; a=0.0, b=100)
    d = Interval(a, b)
    G = Vector{Fun}(undef, max_r+1)
    G[1] = Fun(x -> 1.0, d)
    for r in 1:max_r
        integrand = Fun(x -> exp(-(x^2)/(2r*(r+1))), d) * G[r]
        G[r+1] = cumsum(integrand)
    end
    return G
end

const _Gcache = Dict{Int,Vector{Fun}}()
_getG(n) = get!(_Gcache, n) do; G_recursive(n) end

function _pdf_sigma1(n::Int, m::Real)
    m < 0 && return zero(float(m))          # support m ≥ 0
    z   = n*m/2
    cst = n^(3/2) / (2^((n+1)/2) * π^((n-1)/2))
    G   = _getG(n)
    s   = 0.0
    @inbounds for k in 1:(n-1)
        s += binomial(n,k) * exp(-(m^2 * n^3)/(8k*(n-k))) * G[k](z) * G[n-k](z)
    end
    return cst*s
end

# ---- extend Distributions API ----
# support (MAD ≥ 0)
insupport(::MADDistribution, x::Real) = x ≥ 0
minimum(::MADDistribution) = 0.0
maximum(::MADDistribution) = Inf

# pdf / logpdf (general σ via scaling)
pdf(d::MADDistribution, m::Real) =
    m < 0 ? 0.0 : (1 / d.σ) * _pdf_sigma1(d.n, m / d.σ)

# logpdf(d::MADDistribution, m::Real) =
#     m < 0 ? -Inf : log(pdf(d, m))


# optional convenience
Base.:*(d::MADDistribution, s::Real) = MADDistribution(d.σ * s, d.n)
Base.:*(s::Real, d::MADDistribution) = d * s

using StatsFuns: logsumexp  # you may need to `Pkg.add("StatsFuns")`

function logpdf(d::MADDistribution, m::Real)
    m < 0 && return -Inf
    σ, n = d.σ, d.n

    # Constants
    z   = n * m / (2σ)
    logC = (3/2)*log(n) - ((n+1)/2)*log(2) - ((n-1)/2)*log(π)
    G = _getG(n)

    # Compute all log-terms (inside the sum)
    logs = Float64[]
    for k in 1:(n-1)
        val1 = G[k](z)
        val2 = G[n-k](z)
        if val1 > 0 && val2 > 0
            logterm = log(binomial(n,k)) -
                      (m^2 * n^3)/(8σ^2 * k*(n-k)) +
                      log(val1) + log(val2)
            push!(logs, logterm)
        end
    end

    # Combine safely
    logsum = isempty(logs) ? -Inf : logsumexp(logs)
    return -log(σ) + logC + logsum
end

using Empirikos, Distributions

# 1) evidence type — must subtype EBayesSample
struct MADSample{T,S} <: Empirikos.EBayesSample{T}
    Z::T   # observed MAD
    n::S   # sample size
end

# 2) likelihood at a given σ (must return a Distributions.jl object)
Empirikos.likelihood_distribution(Z::MADSample, σ) = MADDistribution(σ, Z.n)
# Ensure MADDistribution(σ, n) implements pdf/logpdf

# 3) components() for convex prior machinery (vector of likelihoods over σ-support)
Empirikos.components(convexclass::Empirikos.DiscretePriorClass, Z::MADSample) =
    Empirikos.likelihood_distribution.(Ref(Z), Empirikos.support(convexclass))



# limma-style p-value averaged over the posterior on σ
function Empirikos.limma_pvalue(β̂, Z::MADSample, prior::Empirikos.DiscreteNonParametric)
    post = Empirikos.posterior(Z, prior)
    # println("finish post: ")
    # print(post)

    # println(post)
    σs   = Empirikos.support(post)
    # println("finish σs")
    πs   = Empirikos.probs(post)
    # println("finish πs")
    tails = 2 .* ccdf.(Normal.(0, σs), abs(β̂))
    # println("finish tails")
    dot(tails, πs)
    # println("finish dot")
end
# Out:
# WARNING: redefinition of constant Main._Gcache. This may fail, cause incorrect answers, or produce other errors.

# %%
# =========================================================
# Storage for summary results
# =========================================================
mad_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full raw p-values for every successful replicate
mad_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level TP@100
mad_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running MAD (NP) simulation for n = $n ==========")

    tp_vals     = Float64[]
    fp_vals     = Float64[]
    power_vals  = Float64[]
    fdr_vals    = Float64[]
    top100_vals = Float64[]


    for r in 1:R

        try
            # -------------------------------------------------
            # Get simulated dataset
            # -------------------------------------------------
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ


            # -------------------------------------------------
            # Compute statistics
            # -------------------------------------------------
            β_hat = [
                mean(Y[i])
                for i in 1:G
            ]

            mad_obs = [
                mean(abs.(Y[i] .- β_hat[i]))
                for i in 1:G
            ]

            β_tilde = sqrt(n) .* β_hat


            # -------------------------------------------------
            # Fit NPMLE prior from MAD samples
            # -------------------------------------------------
            Zs_mad = [
                MADSample(mad_obs[i], n)
                for i in 1:G
            ]


            # Grid based on observed MAD values
            σ_grid_raw = sort(unique(mad_obs))

            n_grid = 200

            σ_grid = quantile(
                σ_grid_raw,
                range(0, 1; length=n_grid)
            )

            prior_class =
                Empirikos.DiscretePriorClass(σ_grid)

            npmle = Empirikos.NPMLE(
                prior_class,
                Hypatia.Optimizer
            )

            fitres = Empirikos.fit(
                npmle,
                Zs_mad
            )

            prior_hat =
                Empirikos.clean(fitres.prior)


            # -------------------------------------------------
            # Compute RAW MAD p-values
            # -------------------------------------------------
            pvals = [
                Empirikos.limma_pvalue(
                    β_tilde[i],
                    Zs_mad[i],
                    prior_hat
                )
                for i in 1:G
            ]


            # =================================================
            # SAVE RAW P-VALUES
            # =================================================
            mad_pvals_store[(n,r)] = copy(pvals)


            # -------------------------------------------------
            # BH adjustment for rejection-based analysis
            # -------------------------------------------------
            adj_p = adjust(
                pvals,
                BenjaminiHochberg()
            )

            rej = adj_p .<= 0.05


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej .& is_DE)
            FP = sum(rej .& .!is_DE)

            power =
                TP / max(sum(is_DE), 1)

            fdr =
                FP / max(sum(rej), 1)


            # =================================================
            # Ranking metric:
            # true DE genes among 100 smallest RAW p-values
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level ranking result
            mad_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            if r % 10 == 0

                println(
                    "Rep $r → " *
                    "Power=$(round(power, digits=3)) | " *
                    "FDR=$(round(fdr, digits=3)) | " *
                    "TP@100=$TP_top100"
                )

            end


        catch e

            @warn "Skipping Rep $r for n=$n due to error: $e"

            continue
        end
    end


    # =========================================================
    # Summarize for this n
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(mad_summary["n"], n)

    push!(mad_summary["TP"], mean_TP)
    push!(mad_summary["FP"], mean_FP)

    push!(mad_summary["Power"], mean_power)
    push!(mad_summary["FDR"], mean_fdr)

    push!(
        mad_summary["TP_top100"],
        mean_top100
    )


    println(
        "✅ Done n=$n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println(
    "\n========== MAD NP SUMMARY ACROSS SAMPLE SIZES =========="
)

for i in eachindex(mad_summary["n"])

    println(
        "n = $(mad_summary["n"][i]) → " *
        "TP=$(round(mad_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(mad_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running MAD (NP) simulation for n = 4 ==========
#
#  iter        p_obj        d_obj |  abs_gap    x_feas    z_feas |      tau       kap        mu | dir_res     prox  step     alpha
#     0   3.2373e-02  -2.6304e+02 | 2.20e+03  1.16e+02  3.25e+00 | 1.00e+00  1.00e+00  1.00e+00 |
#     1  -5.8050e-01  -2.6742e+02 | 2.09e+03  1.18e+02  3.30e+00 | 9.36e-01  1.02e+00  9.50e-01 | 2.3e-12  9.1e-02  co-a  5.00e-02
#     2  -1.4904e+00  -2.6982e+02 | 1.99e+03  1.19e+02  3.32e+00 | 8.84e-01  1.02e+00  9.03e-01 | 6.3e-13  1.5e-01  co-a  5.00e-02
#     3  -4.4019e+00  -2.7342e+02 | 1.79e+03  1.19e+02  3.33e+00 | 7.94e-01  1.02e+00  8.12e-01 | 7.7e-13  4.2e-01  co-a  1.00e-01
#     4  -1.0182e+01  -2.8004e+02 | 1.61e+03  1.19e+02  3.34e+00 | 7.12e-01  1.03e+00  7.31e-01 | 4.1e-12  1.1e-01  co-a  1.00e-01
#     5  -2.0474e+01  -2.9035e+02 | 1.45e+03  1.19e+02  3.35e+00 | 6.40e-01  1.03e+00  6.58e-01 | 2.1e-12  6.7e-02  co-a  1.00e-01
#     6  -3.5731e+01  -3.0544e+02 | 1.30e+03  1.19e+02  3.35e+00 | 5.76e-01  1.03e+00  5.92e-01 | 3.4e-13  7.9e-02  co-a  1.00e-01
#     7  -5.5659e+01  -3.2509e+02 | 1.17e+03  1.19e+02  3.35e+00 | 5.19e-01  1.03e+00  5.33e-01 | 8.2e-13  3.1e-02  co-a  1.00e-01
#     8  -8.0393e+01  -3.4945e+02 | 1.06e+03  1.19e+02  3.34e+00 | 4.67e-01  1.03e+00  4.80e-01 | 4.7e-12  2.5e-02  co-a  1.00e-01
#     9  -2.0152e+02  -4.6860e+02 | 7.39e+02  1.19e+02  3.33e+00 | 3.28e-01  1.02e+00  3.36e-01 | 4.2e-12  8.5e-01  co-a  3.00e-01
#    10  -3.8326e+02  -6.4537e+02 | 5.17e+02  1.17e+02  3.28e+00 | 2.33e-01  1.01e+00  2.35e-01 | 3.1e-12  3.4e-01  co-a  3.00e-01
#    83  -5.5542e+00  -5.5556e+00 | 4.71e-03  5.95e-04  1.52e-05 | 4.45e-01  4.82e-06  2.14e-06 | 1.2e-10  9.7e-01  co-a  1.00e-01
#    84  -5.5520e+00  -5.5533e+00 | 4.24e-03  5.36e-04  1.36e-05 | 4.45e-01  4.33e-06  1.93e-06 | 1.8e-11  5.1e-01  co-a  1.00e-01
#    85  -5.5422e+00  -5.5428e+00 | 2.12e-03  2.68e-04  6.82e-06 | 4.45e-01  2.17e-06  9.63e-07 | 5.1e-12  8.0e-01  co-a  5.00e-01
# Excessive output truncated after 524312 bytes.

# %%
# =========================================================
# Final summary
# =========================================================
println(
    "\n========== MAD NP SUMMARY ACROSS SAMPLE SIZES =========="
)

for i in eachindex(mad_summary["n"])

    println(
        "n = $(mad_summary["n"][i]) → " *
        "TP=$(round(mad_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(mad_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== MAD NP SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=0.04, FP=0.0, Power=0.0004, FDR=0.0, TP@100=67.73
# n = 5 → TP=0.374, FP=0.0, Power=0.00363, FDR=0.0, TP@100=67.505
# n = 6 → TP=2.46, FP=0.0, Power=0.02514, FDR=0.0, TP@100=66.34
# n = 8 → TP=8.082, FP=0.02, Power=0.07924, FDR=0.00127, TP@100=64.653
# n = 10 → TP=11.434, FP=0.0, Power=0.11352, FDR=0.0, TP@100=63.162
# n = 20 → TP=17.31, FP=0.04, Power=0.17122, FDR=0.00206, TP@100=53.75
# n = 30 → TP=20.3, FP=0.47, Power=0.2058, FDR=0.01924, TP@100=46.47
# n = 40 → TP=25.04, FP=3.111, Power=0.25117, FDR=0.10097, TP@100=43.111

# %%
# =========================================================
# Store the true DE status for each dataset
# =========================================================
is_DE_store = Dict{Tuple{Int,Int}, BitVector}()

for n in n_values
    for r in 1:R
        is_DE_store[(n,r)] = BitVector(datasets[(n,r)].is_DE)
    end
end

using JLD2

simulation_params = (
    n_values = n_values,
    G = G,
    R = R,
    p_signal = p_signal,
    β_signal = β_signal,

    s0_sq_true = s0_sq_true,
    d0_true = d0_true,

    error_dist = "Laplace Mixture Scaled",
    eps_contam = eps_mix,
    tau_contam = tau_mix,

    variance_standardized = false,
)
# Out:
# (n_values = [4, 5, 6, 8, 10, 20, 30, 40], G = 1000, R = 100, p_signal = 0.1, β_signal = 4.0, s0_sq_true = 1.0, d0_true = 4.0, error_dist = "Laplace Mixture Scaled", eps_contam = 0.15, tau_contam = 9.0, variance_standardized = false)

# %%
@save "method_pvalues(7.2).jld2" simulation_params limma_summary epb_summary mad_summary mad_param_gl_summary mad_param_gl_prior_summary mad_param_gl_prior_reps limma_pvals_store epb_pvals_store mad_pvals_store mad_param_pvals_store is_DE_store

# %%
# @save "method_pvalues(1).jld2" simulation_params limma_summary epb_summary mad_summary mad_param_gl_summary limma_pvals_store epb_pvals_store mad_pvals_store is_DE_store

# %%
## # eps_contam = 0.1
println("\n========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========")
for i in 1:length(limma_summary["n"])
    println("n = $(limma_summary["n"][i]) → TP=$(round(limma_summary["TP"][i], digits=3)), FP=$(round(limma_summary["FP"][i], digits=3)), Power=$(round(limma_summary["Power"][i], digits=5)), FDR=$(round(limma_summary["FDR"][i], digits=5))")
end


println("\n========== MAD_mean + parametric prior SUMMARY ==========")
for i in eachindex(mad_param_gl_summary["n"])
    println(
        "n = $(mad_param_gl_summary["n"][i]) → " *
        "TP=$(round(mad_param_gl_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_param_gl_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_param_gl_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_param_gl_summary["FDR"][i], digits=5))"
    )
end

# println("\n========== Fitted prior hyperparameters (Gauss-Legendre) ==========")
# for i in eachindex(mad_param_gl_prior_summary["n"])
#     println(
#         "n = $(mad_param_gl_prior_summary["n"][i]) → " *
#         "mean σ0² = $(round(mad_param_gl_prior_summary["sigma0_sq_mean"][i], digits=5)), " *
#         "mean ν0 = $(round(mad_param_gl_prior_summary["nu0_mean"][i], digits=5))"
#     )
# end

#--- Final summary table ---
println("\n========== SD EPB (NPMLE) SUMMARY ==========")
for i in 1:length(epb_summary["n"])
    println("n = $(epb_summary["n"][i]) → TP=$(round(epb_summary["TP"][i], digits=3)), FP=$(round(epb_summary["FP"][i], digits=3)), Power=$(round(epb_summary["Power"][i], digits=5)), FDR=$(round(epb_summary["FDR"][i], digits=5))")
end


# --- Final summary ---
println("\n========== Mean + MAD SUMMARY ==========")
for i in 1:length(mad_summary["n"])
    println("n = $(mad_summary["n"][i]) → TP=$(round(mad_summary["TP"][i], digits=3)), FP=$(round(mad_summary["FP"][i], digits=3)), Power=$(round(mad_summary["Power"][i], digits=5)), FDR=$(round(mad_summary["FDR"][i], digits=5))")
end
# Out:
# ========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=4.32, FP=0.02, Power=0.0424, FDR=0.00106
# n = 5 → TP=19.79, FP=0.08, Power=0.19691, FDR=0.00277
# n = 6 → TP=29.43, FP=0.12, Power=0.29433, FDR=0.00372
# n = 8 → TP=39.0, FP=0.32, Power=0.3898, FDR=0.00751
# n = 10 → TP=42.99, FP=0.27, Power=0.42665, FDR=0.00611
# n = 20 → TP=40.95, FP=0.48, Power=0.40761, FDR=0.01161
# n = 30 → TP=34.92, FP=0.38, Power=0.3546, FDR=0.01001
#
# ========== MAD_mean + parametric prior SUMMARY ==========
# n = 4 → TP=4.06, FP=0.03, Power=0.04005, FDR=0.00177
# n = 5 → TP=21.1, FP=0.09, Power=0.20981, FDR=0.00363
# n = 6 → TP=32.83, FP=0.17, Power=0.32852, FDR=0.00476
# n = 8 → TP=44.66, FP=0.38, Power=0.44658, FDR=0.00783
# n = 10 → TP=50.27, FP=0.45, Power=0.49914, FDR=0.00868
# n = 20 → TP=59.56, FP=1.29, Power=0.59363, FDR=0.02057
# n = 30 → TP=59.31, FP=3.72, Power=0.60293, FDR=0.05739
#
# ========== SD EPB (NPMLE) SUMMARY ==========
# n = 4 → TP=4.778, FP=0.03, Power=0.04641, FDR=0.00173
# n = 5 → TP=20.48, FP=0.08, Power=0.20354, FDR=0.00281
# n = 6 → TP=30.273, FP=0.121, Power=0.30298, FDR=0.00373
# n = 8 → TP=39.57, FP=0.36, Power=0.39563, FDR=0.0085
# n = 10 → TP=43.06, FP=0.32, Power=0.42772, FDR=0.0073
# n = 20 → TP=41.33, FP=0.54, Power=0.41155, FDR=0.01293
# n = 30 → TP=35.33, FP=0.4, Power=0.35887, FDR=0.01062
#
# ========== Mean + MAD SUMMARY ==========
# n = 4 → TP=5.102, FP=0.031, Power=0.05073, FDR=0.00162
# n = 5 → TP=22.37, FP=0.09, Power=0.22216, FDR=0.00359
# n = 6 → TP=32.77, FP=0.17, Power=0.32853, FDR=0.00456
# n = 8 → TP=45.102, FP=0.367, Power=0.45095, FDR=0.00764
# n = 10 → TP=50.418, FP=0.459, Power=0.49978, FDR=0.00891
# n = 20 → TP=59.929, FP=1.347, Power=0.59644, FDR=0.02148
# n = 30 → TP=59.394, FP=4.384, Power=0.60381, FDR=0.06636

# %%
using Plots

# -------------------------------------------------
# 1. Build a common method dictionary
# -------------------------------------------------
method_summaries = Dict(
    "LIMMA" => limma_summary,
    "SD EPB (NP)" => epb_summary,
    "Mean + MAD (NP)" => mad_summary,
    "Mean + MAD(P)" => mad_param_gl_summary
)

# compute max FDR across all methods
max_fdr = maximum(vcat([summ["FDR"] for summ in values(method_summaries)]...))
fdr_upper = max(0.06, 1.05 * max_fdr)

# -------------------------------------------------
# 2. Power plot
# -------------------------------------------------
p_power = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power across sample sizes",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in method_summaries
    plot!(
        p_power,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle
    )
end

# -------------------------------------------------
# 3. FDR plot
# -------------------------------------------------
p_fdr = plot(
    xlabel = "Sample size n",
    ylabel = "FDR",
    title = "FDR across sample sizes",
    legend = :outerbottom,
    lw = 2,
    marker = :circle,
    ylims = (-0.01, fdr_upper)
)

for (method, summ) in method_summaries
    plot!(
        p_fdr,
        summ["n"],
        summ["FDR"];
        label = method,
        lw = 2,
        marker = :circle
    )
end

hline!(
    p_fdr,
    [0.05];
    label = "FDR = 0.05",
    lw = 2,
    ls = :dash,
    color = :black
)

# -------------------------------------------------
# 4. Show side by side
# -------------------------------------------------
plot(
    p_power,
    p_fdr;
    layout = (1, 2),
    size = (900, 450)
)

# %%
using Plots

# -------------------------------------------------
# 1. Split methods into two groups
# -------------------------------------------------
param_methods = Dict(
    "LIMMA" => limma_summary,
    "Mean + MAD(P)" => mad_param_gl_summary
)

nonparam_methods = Dict(
    "SD EPB (NP)" => epb_summary,
    "Mean + MAD (NP)" => mad_summary
)

# -------------------------------------------------
# 2. Shared colors
# -------------------------------------------------
method_colors = Dict(
    "LIMMA" => :blue,
    "SD EPB (NP)" => :blue,
    "Mean + MAD(P)" => :green,
    "Mean + MAD (NP)" => :green
)

# -------------------------------------------------
# 3. Power plot: parametric vs parametric
# -------------------------------------------------
p_power_param = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power: parametric vs parametric",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in param_methods
    plot!(
        p_power_param,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle,
        color = method_colors[method]
    )
end

# -------------------------------------------------
# 4. Power plot: nonparametric vs nonparametric
# -------------------------------------------------
p_power_nonparam = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power: nonparametric vs nonparametric",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in nonparam_methods
    plot!(
        p_power_nonparam,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle,
        color = method_colors[method]
    )
end

# -------------------------------------------------
# 5. Difference plot: Mean+MAD - SD
#    parametric: Mean+MAD(P) - LIMMA
#    nonparametric: Mean+MAD(NP) - SD EPB(NP)
# -------------------------------------------------
n_param = limma_summary["n"]
diff_param = mad_param_gl_summary["Power"] .- limma_summary["Power"]

n_nonparam = epb_summary["n"]
diff_nonparam = mad_summary["Power"] .- epb_summary["Power"]

p_diff = plot(
    xlabel = "Sample size n",
    ylabel = "Δ Power",
    title = "Difference in power (Mean+MAD - SD)",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

plot!(
    p_diff,
    n_param,
    diff_param;
    label = "Parametric: Mean + MAD(P) - LIMMA",
    lw = 2,
    marker = :circle,
    color = :green
)

plot!(
    p_diff,
    n_nonparam,
    diff_nonparam;
    label = "Nonparametric: Mean + MAD(NP) - SD EPB (NP)",
    lw = 2,
    marker = :circle,
    color = :blue
)

hline!(
    p_diff,
    [0.0];
    label = "0",
    lw = 2,
    ls = :dash,
    color = :black
)

# -------------------------------------------------
# 6. Show all three
# -------------------------------------------------
plot(
    p_power_param,
    p_power_nonparam,
    p_diff;
    layout = (1, 3),
    size = (1350, 420)
)
