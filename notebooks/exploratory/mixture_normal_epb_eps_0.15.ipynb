# %% [markdown]
# ## Mixture Normal

# %%
using Distributions, Random, Statistics, MultipleTesting, Empirikos, Hypatia, LinearAlgebra
using Distributions, StatsPlots, Random

# =========================================================
# 1. Draw contaminated-normal errors
# =========================================================
function rand_contaminated_normal(
    rng::AbstractRNG,
    n::Int;
    eps::Float64 = 0.10,
    tau::Float64 = 5.0
)
    z = Vector{Float64}(undef, n)
    @inbounds for j in 1:n
        if rand(rng) < eps
            z[j] = rand(rng, Normal(0, tau))
        else
            z[j] = rand(rng, Normal(0, 1))
        end
    end
    return z
end

# =========================================================
# 2. Generate one gene under contaminated-normal errors
# =========================================================
function simulate_gene_contaminated_normal(
    rng::AbstractRNG,
    n::Int,
    β::Float64,
    σ::Float64;
    eps::Float64 = 0.10,
    tau::Float64 = 5.0
)
    z = rand_contaminated_normal(rng, n; eps=eps, tau=tau)
    return β .+ σ .* z
end

# =========================================================
# 3. Full dataset generation
# =========================================================
Random.seed!(105)

n_values = [4, 5, 6, 8, 10, 20, 30, 40]
G = 1000
R = 100
p_signal = 0.1
β_signal = 4.0

# Correct parametric variance model
s0_sq_true = 1.0
d0_true    = 4.0

# contaminated-normal parameters
eps_contam = 0.15
tau_contam = 9.0

datasets = Dict{Tuple{Int,Int}, Any}()

for n in n_values
    for r in 1:R
        rng = MersenneTwister(10_000 + 100n + r)

        # DE indicators
        is_DE = rand(rng, G) .< p_signal

        # sigma^2 from the correct parametric prior
        σ2 = rand(rng, InverseGamma(d0_true / 2, d0_true * s0_sq_true / 2), G)
        σ  = sqrt.(σ2)
        # data generation with contaminated-normal errors
        Y = Vector{Vector{Float64}}(undef, G)
        
        @inbounds for i in 1:G
            βi = is_DE[i] ? β_signal * σ[i] / sqrt(n) : 0.0
        
            Y[i] = simulate_gene_contaminated_normal(
                rng, n, βi, σ[i];
                eps=eps_contam,
                tau=tau_contam
            )
        end

        # # data generation with contaminated-normal errors
        # Y = Vector{Vector{Float64}}(undef, G)
        # @inbounds for i in 1:G
        #     βi = is_DE[i] ? β_signal * σ[i] : 0.0
        #     Y[i] = simulate_gene_contaminated_normal(
        #         rng, n, βi, σ[i];
        #         eps=eps_contam,
        #         tau=tau_contam
        #     )
        # end

        datasets[(n, r)] = (
            Y = Y,
            is_DE = is_DE,
            σ = σ,
            σ2 = σ2
        )
    end
end

# %%
limma_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full per-gene p-values
limma_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level top-100 results
limma_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running LIMMA simulation for n = $n ==========")

    ν = n - 1

    power_vals  = Float64[]
    fdr_vals    = Float64[]
    tp_vals     = Float64[]
    fp_vals     = Float64[]
    top100_vals = Float64[]

    for r in 1:R

        try
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ

            # -------------------------------------------------
            # Per-gene statistics
            # -------------------------------------------------
            β_hat = [mean(Y[i]) for i in 1:G]

            s_hat = [
                std(Y[i], corrected=true)
                for i in 1:G
            ]

            se_hat_squared = (s_hat .^ 2) ./ n


            # -------------------------------------------------
            # LIMMA samples
            # -------------------------------------------------
            samples = [
                Empirikos.NormalChiSquareSample(
                    β_hat[i],
                    se_hat_squared[i],
                    ν
                )
                for i in 1:G
            ]


            # -------------------------------------------------
            # Fit LIMMA EB test
            # -------------------------------------------------
            test_limma = Empirikos.EmpiricalPartiallyBayesTTest(
                α = 0.05,
                prior = Empirikos.Limma(),
                solver = Hypatia.Optimizer
            )

            res_limma = fit(test_limma, samples)


            # -------------------------------------------------
            # Extract p-values and rejection decisions
            # -------------------------------------------------
            pvals_limma = res_limma.pvalue
            rej_limma   = res_limma.rj_idx


            # =================================================
            # SAVE THE RAW P-VALUES
            # =================================================
            limma_pvals_store[(n,r)] = copy(pvals_limma)


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej_limma .& is_DE)
            FP = sum(rej_limma .& .!is_DE)

            power = TP / max(sum(is_DE), 1)

            fdr = FP / max(sum(rej_limma), 1)


            # =================================================
            # Ranking metric: true signals among top 100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals_limma)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level ranking result
            limma_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


        catch err

            @warn "Skipping Rep $r for n=$n due to numerical error: $err"

            continue
        end
    end


    # =========================================================
    # Average over replicates
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(limma_summary["n"], n)

    push!(limma_summary["TP"], mean_TP)
    push!(limma_summary["FP"], mean_FP)

    push!(limma_summary["Power"], mean_power)
    push!(limma_summary["FDR"], mean_fdr)

    push!(limma_summary["TP_top100"], mean_top100)


    println(
        "n = $n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println("\n========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========")

for i in eachindex(limma_summary["n"])

    println(
        "n = $(limma_summary["n"][i]) → " *
        "Power=$(round(limma_summary["Power"][i], digits=5)), " *
        "FDR=$(round(limma_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(limma_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running LIMMA simulation for n = 4 ==========
# n = 4 → Power=0.0 | FDR=0.0 | TP=0.0 | FP=0.0 | TP@100=64.4
#
# ========== Running LIMMA simulation for n = 5 ==========
# n = 5 → Power=0.002 | FDR=0.0 | TP=0.2 | FP=0.0 | TP@100=63.2
#
# ========== Running LIMMA simulation for n = 6 ==========
# n = 6 → Power=0.002 | FDR=0.0 | TP=0.2 | FP=0.0 | TP@100=60.7
#
# ========== Running LIMMA simulation for n = 8 ==========
# n = 8 → Power=0.008 | FDR=0.0 | TP=0.8 | FP=0.0 | TP@100=58.2
#
# ========== Running LIMMA simulation for n = 10 ==========
# n = 10 → Power=0.014 | FDR=0.0 | TP=1.4 | FP=0.0 | TP@100=55.0
#
# ========== Running LIMMA simulation for n = 20 ==========
# n = 20 → Power=0.014 | FDR=0.0 | TP=1.4 | FP=0.0 | TP@100=44.4
#
# ========== Running LIMMA simulation for n = 30 ==========
# n = 30 → Power=0.006 | FDR=0.0 | TP=0.6 | FP=0.0 | TP@100=37.0
#
# ========== Running LIMMA simulation for n = 40 ==========
# n = 40 → Power=0.003 | FDR=0.0 | TP=0.3 | FP=0.0 | TP@100=34.6
#
# ========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → Power=0.0004, FDR=0.0, TP@100=64.41
# n = 5 → Power=0.00157, FDR=0.0, TP@100=63.18
# n = 6 → Power=0.00237, FDR=0.0, TP@100=60.74
# n = 8 → Power=0.00751, FDR=0.0, TP@100=58.22
# n = 10 → Power=0.01403, FDR=0.0, TP@100=54.98
# n = 20 → Power=0.01387, FDR=0.0, TP@100=44.4
# n = 30 → Power=0.00589, FDR=0.0, TP@100=37.04
# n = 40 → Power=0.00333, FDR=0.0, TP@100=34.65

# %% [markdown]
# ## NP +SD

# %%
R = 100

# =========================================================
# Storage for summary results
# =========================================================
epb_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full raw p-values for every successful replicate
epb_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level TP@100
epb_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running EPB NPMLE simulation for n = $n ==========")

    ν = n - 1

    power_vals  = Float64[]
    fdr_vals    = Float64[]
    tp_vals     = Float64[]
    fp_vals     = Float64[]
    top100_vals = Float64[]

    for r in 1:R

        try
            # -------------------------------------------------
            # Get the same simulated dataset
            # -------------------------------------------------
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ


            # -------------------------------------------------
            # Compute per-gene statistics
            # -------------------------------------------------
            β_hat = [mean(Y[i]) for i in 1:G]

            s_hat = [
                std(Y[i], corrected=true)
                for i in 1:G
            ]

            se_hat_squared = (s_hat .^ 2) ./ n


            # -------------------------------------------------
            # Build Normal-Chi-square samples
            # -------------------------------------------------
            samples = [
                Empirikos.NormalChiSquareSample(
                    β_hat[i],
                    se_hat_squared[i],
                    ν
                )
                for i in 1:G
            ]


            # -------------------------------------------------
            # Fit EPB with nonparametric NPMLE prior
            # -------------------------------------------------
            test_epb = Empirikos.EmpiricalPartiallyBayesTTest(
                α = 0.05,
                solver = Hypatia.Optimizer
            )

            res_epb = fit(test_epb, samples)


            # -------------------------------------------------
            # Extract p-values and rejection decisions
            # -------------------------------------------------
            pvals_epb = res_epb.pvalue
            rej_epb   = res_epb.rj_idx


            # =================================================
            # SAVE RAW P-VALUES
            # =================================================
            epb_pvals_store[(n,r)] = copy(pvals_epb)


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej_epb .& is_DE)
            FP = sum(rej_epb .& .!is_DE)

            power = TP / max(sum(is_DE), 1)

            fdr = FP / max(sum(rej_epb), 1)


            # =================================================
            # Ranking metric: true DE genes among top 100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals_epb)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level TP@100
            epb_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            println(
                "Rep $r → " *
                "Power=$(round(power, digits=3)) | " *
                "FDR=$(round(fdr, digits=3)) | " *
                "Rej=$(sum(rej_epb)) | " *
                "TP@100=$TP_top100"
            )


        catch e

            @warn "Skipping Rep $r for n=$n due to error: $e"

            continue
        end
    end


    # =========================================================
    # Average over successful replicates
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(epb_summary["n"], n)

    push!(epb_summary["TP"], mean_TP)
    push!(epb_summary["FP"], mean_FP)

    push!(epb_summary["Power"], mean_power)
    push!(epb_summary["FDR"], mean_fdr)

    push!(epb_summary["TP_top100"], mean_top100)


    println(
        "n = $n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println("\n========== EPB SUMMARY ACROSS SAMPLE SIZES ==========")

for i in eachindex(epb_summary["n"])

    println(
        "n = $(epb_summary["n"][i]) → " *
        "TP=$(round(epb_summary["TP"][i], digits=3)), " *
        "FP=$(round(epb_summary["FP"][i], digits=3)), " *
        "Power=$(round(epb_summary["Power"][i], digits=5)), " *
        "FDR=$(round(epb_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(epb_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running EPB NPMLE simulation for n = 4 ==========
#
#  iter        p_obj        d_obj |  abs_gap    x_feas    z_feas |      tau       kap        mu | dir_res     prox  step     alpha
#     0   3.2373e-02  -1.8714e+02 | 2.30e+03  1.00e+02  4.28e+00 | 1.00e+00  1.00e+00  1.00e+00 |
#     1  -6
#   109  -5.5970e+00  -5.5970e+00 | 3.78e-05  4.07e-06  1.15e-07 | 4.49e-01  3.65e-08  1.64e-08 | 2.2e-09  9.4e-01  co-a  1.00e-01
#   110  -5.5970e+00  -5.5970e+00 | 2.64e-05  2.85e-06  8.07e-08 | 4.49e-01  2.56e-08  1.15e-08 | 5.6e-10  9.6e-01  co-a  3.00e-01
#   111  -5.5969e+00  -5.5969e+00 | 1.06e-05  1.14e-06  3.23e-08 | 4.49e-01  1.02e-08  4.59e-09 | 1.7e-10  6.7e-01  co-a  6.00e-01
#   112  -5.5969e+00  -5.5969e+00 | 3.17e-06  3.42e-07  9.69e-09 | 4.49e-01  3.07e-09  1.38e-09 | 1.1e-10  7.9e-01  co-a  7.00e-01
#   113  -5.5969e+00  -5.5969e+00 | 1.27e-06  1.37e-07  3.88e-09 | 4.49e-01  1.23e-09  5.51e-10 | 1.6e-10  5.8e-01  co-a  6.00e-01
#   114  -5.5969e+00  -5.5969e+00 | 3.80e-07  4.11e-08  1.16e-09 | 4.49e-01  3.68e-10  1.65e-10 | 4.4e-10  4.0e-01  co-a  7.00e-01
#   115  -5.5969e+00  -5.5969e+00 | 1.52e-07  1.64e-08  4.65e-10 | 4.49e-01  1.47e-10  6.61e-11 | 3.0e-11  4.7e-01  co-a  6.00e-01
#   116  -5.5969e+00  -5.5969e+00 | 6.08e-08  6.57e-09  1.86e-10 | 4.49e-01  5.89e-11  2.64e-11 | 2.5e-12  8.0e-01  co-a  6.00e-01
# optimal solution found; terminating
#
# status is Optimal after 116 iterations and 1.082 seconds
#
# Rep 36 → Power=0.0 | FDR=0.0 | Rej=0 | TP@100=58
#
#  iter        p_obj        d_obj |  abs_gap    x_feas    z_feas |      tau       kap        mu | dir_res     prox  step     alpha
#     0   3.2373e-02  -2.0653e+02 | 2.30e+03  1.05e+02  3.68e+00 | 1.00e+00  1.00e+00  1.00e+00 |
#     1  -7.8375e-01  -2.1025e+02 | 2.19e+03  1.07e+02  3.74e+00 | 9.37e-01  1.02e+00  9.50e-01 | 2.2e-12  9.0e-02  co-a  5.00e-02
#     2  -1.9442e+00  -2.1257e+02 | 2.08e+03  1.08e+02  3.76e+00 | 8.85e-01  1.02e+00  9.03e-01 | 1.3e-12  1.4e-01  co-a  5.00e-02
#     3  -5.3459e+00  -2.1651e+02 | 1.87e+03  1.08e+02  3.77e+00 | 7.94e-01  1.02e+00  8.12e-01 | 8.5e-13  4.0e-01  co-a  1.00e-01
# Excessive output truncated after 524335 bytes.
#     4  -1.0745e+01  -2.2255e+02 | 1.68e+03  1.08e+02  3.79e+00

# %%
# =========================================================
# Final summary
# =========================================================
println("\n========== EPB SUMMARY ACROSS SAMPLE SIZES ==========")

for i in eachindex(epb_summary["n"])

    println(
        "n = $(epb_summary["n"][i]) → " *
        "TP=$(round(epb_summary["TP"][i], digits=3)), " *
        "FP=$(round(epb_summary["FP"][i], digits=3)), " *
        "Power=$(round(epb_summary["Power"][i], digits=5)), " *
        "FDR=$(round(epb_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(epb_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== EPB SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=0.04, FP=0.0, Power=0.0004, FDR=0.0, TP@100=61.84
# n = 5 → TP=0.13, FP=0.0, Power=0.00129, FDR=0.0, TP@100=60.96
# n = 6 → TP=0.14, FP=0.0, Power=0.00146, FDR=0.0, TP@100=58.95
# n = 8 → TP=1.58, FP=0.01, Power=0.01591, FDR=0.00167, TP@100=57.03
# n = 10 → TP=2.697, FP=0.0, Power=0.02665, FDR=0.0, TP@100=53.929
# n = 20 → TP=2.56, FP=0.0, Power=0.02509, FDR=0.0, TP@100=43.94
# n = 30 → TP=1.16, FP=0.0, Power=0.0115, FDR=0.0, TP@100=37.02
# n = 40 → TP=0.55, FP=0.0, Power=0.0054, FDR=0.0, TP@100=34.62

# %% [markdown]
# ## MAD P

# %%
using FastGaussQuadrature
using Distributions
using StatsFuns: logsumexp
using Optim
using MultipleTesting
using Statistics, Random, LinearAlgebra
using ApproxFun, SpecialFunctions

# =========================================================
# 1. Exact MAD-about-mean likelihood
# =========================================================

struct MADDistribution{T<:Real,S<:Integer} <: ContinuousUnivariateDistribution
    σ::T
    n::S
end

import Distributions: pdf, logpdf, insupport, minimum, maximum

function G_recursive(max_r::Int; a=0.0, b=100)
    d = Interval(a, b)
    G = Vector{Fun}(undef, max_r+1)
    G[1] = Fun(x -> 1.0, d)
    for r in 1:max_r
        integrand = Fun(x -> exp(-(x^2)/(2r*(r+1))), d) * G[r]
        G[r+1] = cumsum(integrand)
    end
    return G
end

const _Gcache = Dict{Int,Vector{Fun}}()
_getG(n) = get!(_Gcache, n) do
    G_recursive(n)
end

function _pdf_sigma1(n::Int, m::Real)
    m < 0 && return zero(float(m))
    z   = n * m / 2
    cst = n^(3/2) / (2^((n+1)/2) * π^((n-1)/2))
    G   = _getG(n)
    s   = 0.0
    @inbounds for k in 1:(n-1)
        s += binomial(n, k) * exp(-(m^2 * n^3) / (8k*(n-k))) * G[k](z) * G[n-k](z)
    end
    return cst * s
end

insupport(::MADDistribution, x::Real) = x ≥ 0
minimum(::MADDistribution) = 0.0
maximum(::MADDistribution) = Inf

pdf(d::MADDistribution, m::Real) =
    m < 0 ? 0.0 : (1 / d.σ) * _pdf_sigma1(d.n, m / d.σ)

function logpdf(d::MADDistribution, m::Real)
    m < 0 && return -Inf
    σ, n = d.σ, d.n
    z    = n * m / (2σ)
    logC = (3/2)*log(n) - ((n+1)/2)*log(2) - ((n-1)/2)*log(π)
    G    = _getG(n)

    logs = Float64[]
    @inbounds for k in 1:(n-1)
        val1 = G[k](z)
        val2 = G[n-k](z)
        if val1 > 0 && val2 > 0
            push!(logs,
                log(binomial(n, k)) -
                (m^2 * n^3) / (8σ^2 * k*(n-k)) +
                log(val1) + log(val2)
            )
        end
    end

    return -log(σ) + logC + (isempty(logs) ? -Inf : logsumexp(logs))
end

# =========================================================
# 2. Parametric prior on sigma^2
# =========================================================

struct InverseScaledChiSquare{T,S} <: ContinuousUnivariateDistribution
    σ²::T
    ν::S
end

function Distributions.InverseGamma(d::InverseScaledChiSquare)
    InverseGamma(d.ν / 2, d.ν * d.σ² / 2)
end

Distributions.pdf(d::InverseScaledChiSquare, x::Real) = pdf(InverseGamma(d), x)
Distributions.logpdf(d::InverseScaledChiSquare, x::Real) = logpdf(InverseGamma(d), x)

prior_sigma2(σ0², ν0) = InverseScaledChiSquare(σ0², ν0)

# =========================================================
# 3. Gauss-Legendre quadrature on (0,1)
# =========================================================

function gausslegendre01(K::Int)
    x, w = gausslegendre(K)   # nodes/weights on [-1,1]
    u = (x .+ 1) ./ 2         # map to (0,1)
    w = w ./ 2
    return u, w
end

# =========================================================
# 4. Marginal likelihood by Gauss-Legendre quadrature
#    transform s2 = u/(1-u), u in (0,1)
# =========================================================
function marginal_mad_logdensity_gl(
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    prior = prior_sigma2(σ0², ν0)

    logvals = similar(u_nodes)
    @inbounds for j in eachindex(u_nodes)
        u = clamp(u_nodes[j], 1e-12, 1 - 1e-12)
        s2 = u / (1 - u)
        jac = 1 / (1 - u)^2

        logvals[j] =
            logpdf(MADDistribution(sqrt(s2), n), D) +
            logpdf(prior, s2) +
            log(jac) +
            log(u_weights[j])
    end

    return logsumexp(logvals)
end

# =========================================================
# 5. Negative log marginal likelihood across genes
# =========================================================

function negloglik_mad_parametric_gl(
    par::Vector{Float64},
    mad_obs::Vector{Float64},
    n::Int,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    η, ξ = par
    σ0² = exp(η)
    ν0  = exp(ξ)

    total = 0.0
    @inbounds for D in mad_obs
        total -= marginal_mad_logdensity_gl(D, n, σ0², ν0, u_nodes, u_weights)
    end
    return total
end

# =========================================================
# 6. Fit prior hyperparameters by Gaussian quadrature
# =========================================================

function fit_mad_parametric_prior_gl(
    mad_obs::Vector{Float64},
    n::Int;
    K_quad::Int = 64,
    init_logσ0² = log(max(median(mad_obs)^2, 1e-6)),
    init_logν0  = log(10.0),
    max_iter::Int = 80
)
    u_nodes, u_weights = gausslegendre01(K_quad)

    obj(par) = negloglik_mad_parametric_gl(par, mad_obs, n, u_nodes, u_weights)

    res = optimize(
        obj,
        [init_logσ0², init_logν0],
        NelderMead(),
        Optim.Options(iterations=max_iter, show_trace=false)
    )

    ηhat, ξhat = Optim.minimizer(res)

    return (
        σ0² = exp(ηhat),
        ν0  = exp(ξhat),
        optim = res,
        u_nodes = u_nodes,
        u_weights = u_weights
    )
end

# =========================================================
# 7. Posterior weights on same quadrature nodes
# =========================================================

function posterior_sigma2_weights_mad_gl(
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    prior = prior_sigma2(σ0², ν0)

    logpost = similar(u_nodes)
    s2_nodes = similar(u_nodes)

    @inbounds for j in eachindex(u_nodes)
        u = clamp(u_nodes[j], 1e-12, 1 - 1e-12)
        s2 = u / (1 - u)
        s2_nodes[j] = s2
        jac = 1 / (1 - u)^2

        logpost[j] =
            logpdf(MADDistribution(sqrt(s2), n), D) +
            logpdf(prior, s2) +
            log(jac) +
            log(u_weights[j])
    end

    m = maximum(logpost)
    w = exp.(logpost .- m)
    w ./= sum(w)

    return s2_nodes, w
end

# =========================================================
# 8. Posterior-averaged p-value
# =========================================================

function mad_parametric_pvalue_gl(
    β_tilde::Float64,
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    s2_nodes, w = posterior_sigma2_weights_mad_gl(D, n, σ0², ν0, u_nodes, u_weights)
    σ_nodes = sqrt.(s2_nodes)
    tails = 2 .* ccdf.(Normal.(0, σ_nodes), abs(β_tilde))
    return dot(tails, w)
end
# Out:
# mad_parametric_pvalue_gl (generic function with 1 method)

# %%
# =========================================================
# 9. Simulation loop: MAD_mean + parametric prior
# =========================================================

mad_param_gl_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

mad_param_gl_prior_summary = Dict(
    "n" => Int[],
    "sigma0_sq_mean" => Float64[],
    "nu0_mean" => Float64[]
)

# Store replicate-level results
mad_param_gl_prior_reps = Dict(
    "n" => Int[],
    "rep" => Int[],
    "sigma0_sq_hat" => Float64[],
    "nu0_hat" => Float64[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# NEW: store all raw p-values
mad_param_pvals_store =
    Dict{Tuple{Int,Int}, Vector{Float64}}()

# NEW: store replicate-level TP@100
mad_param_top100_store =
    Dict{Tuple{Int,Int}, Int}()


for n in n_values

    println(
        "\n========== Running MAD_mean + parametric prior " *
        "(Gauss-Legendre) for n = $n =========="
    )

    tp_vals = Float64[]
    fp_vals = Float64[]
    power_vals = Float64[]
    fdr_vals = Float64[]
    top100_vals = Float64[]

    sigma0_sq_vals = Float64[]
    nu0_vals = Float64[]


    for r in 1:R

        try
            println("n=$n, rep=$r: loading data...")

            Y = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ_true = datasets[(n,r)].σ


            # =================================================
            # Compute statistics
            # =================================================
            println("n=$n, rep=$r: computing statistics...")

            β_hat = [
                mean(Y[i])
                for i in 1:G
            ]

            mad_obs = [
                mean(abs.(Y[i] .- β_hat[i]))
                for i in 1:G
            ]

            β_tilde = sqrt(n) .* β_hat

            idx_fit = 1:length(mad_obs)


            # =================================================
            # Fit parametric MAD prior
            # =================================================
            println(
                "n=$n, rep=$r: fitting Gauss-Legendre parametric prior..."
            )

            @time fit_prior =
                fit_mad_parametric_prior_gl(
                    mad_obs[idx_fit],
                    n;
                    K_quad = 100,
                    max_iter = 80
                )

            σ0²_hat = fit_prior.σ0²
            ν0_hat  = fit_prior.ν0

            u_nodes   = fit_prior.u_nodes
            u_weights = fit_prior.u_weights


            push!(sigma0_sq_vals, σ0²_hat)
            push!(nu0_vals, ν0_hat)


            println(
                "n=$n, rep=$r: prior fit done. " *
                "σ0²=$(round(σ0²_hat, digits=4)), " *
                "ν0=$(round(ν0_hat, digits=3))"
            )


            # =================================================
            # Compute RAW p-values
            # =================================================
            println("n=$n, rep=$r: computing p-values...")

            pvals = [
                mad_parametric_pvalue_gl(
                    β_tilde[i],
                    mad_obs[i],
                    n,
                    σ0²_hat,
                    ν0_hat,
                    u_nodes,
                    u_weights
                )
                for i in 1:G
            ]


            # =================================================
            # NEW: store raw p-values
            # =================================================
            mad_param_pvals_store[(n,r)] = copy(pvals)


            # =================================================
            # NEW: ranking metric TP@100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])

            mad_param_top100_store[(n,r)] =
                TP_top100


            # =================================================
            # BH rejection
            # =================================================
            adj_p = adjust(
                pvals,
                BenjaminiHochberg()
            )

            rej = adj_p .<= 0.05


            # =================================================
            # Standard metrics
            # =================================================
            TP = sum(rej .& is_DE)
            FP = sum(rej .& .!is_DE)

            power =
                TP / max(sum(is_DE), 1)

            fdr =
                FP / max(sum(rej), 1)


            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            # =================================================
            # Store replicate-level prior + performance
            # =================================================
            push!(mad_param_gl_prior_reps["n"], n)
            push!(mad_param_gl_prior_reps["rep"], r)

            push!(
                mad_param_gl_prior_reps["sigma0_sq_hat"],
                σ0²_hat
            )

            push!(
                mad_param_gl_prior_reps["nu0_hat"],
                ν0_hat
            )

            push!(mad_param_gl_prior_reps["TP"], TP)
            push!(mad_param_gl_prior_reps["FP"], FP)

            push!(
                mad_param_gl_prior_reps["Power"],
                power
            )

            push!(
                mad_param_gl_prior_reps["FDR"],
                fdr
            )

            push!(
                mad_param_gl_prior_reps["TP_top100"],
                TP_top100
            )


            println(
                "n=$n, rep=$r done → " *
                "Power=$(round(power, digits=3)) | " *
                "FDR=$(round(fdr, digits=3)) | " *
                "TP@100=$TP_top100"
            )


        catch e

            println(
                "⚠️ Skipping Rep $r for n=$n due to error: " *
                "$(typeof(e)) : $e"
            )

            continue
        end
    end


    # =========================================================
    # Summarize over successful replicates
    # =========================================================
    if !isempty(tp_vals)

        mean_TP = mean(tp_vals)
        mean_FP = mean(fp_vals)

        mean_power = mean(power_vals)
        mean_fdr = mean(fdr_vals)

        mean_top100 = mean(top100_vals)


        push!(mad_param_gl_summary["n"], n)

        push!(
            mad_param_gl_summary["TP"],
            mean_TP
        )

        push!(
            mad_param_gl_summary["FP"],
            mean_FP
        )

        push!(
            mad_param_gl_summary["Power"],
            mean_power
        )

        push!(
            mad_param_gl_summary["FDR"],
            mean_fdr
        )

        push!(
            mad_param_gl_summary["TP_top100"],
            mean_top100
        )


        # Prior summary
        push!(
            mad_param_gl_prior_summary["n"],
            n
        )

        push!(
            mad_param_gl_prior_summary["sigma0_sq_mean"],
            mean(sigma0_sq_vals)
        )

        push!(
            mad_param_gl_prior_summary["nu0_mean"],
            mean(nu0_vals)
        )


        println(
            "✅ Done n=$n → " *
            "Power=$(round(mean_power, digits=3)) | " *
            "FDR=$(round(mean_fdr, digits=3)) | " *
            "TP=$(round(mean_TP, digits=1)) | " *
            "FP=$(round(mean_FP, digits=1)) | " *
            "TP@100=$(round(mean_top100, digits=1))"
        )

    else

        println("⚠️ No successful reps for n=$n")

    end
end
# Out:
# ========== Running MAD_mean + parametric prior (Gauss-Legendre) for n = 4 ==========
# n=4, rep=1: loading data...
# n=4, rep=1: computing statistics...
# n=4, rep=1: fitting Gauss-Legendre parametric prior...
#   8.853304 seconds (228.67 M allocations: 4.270 GiB, 2.35% gc time, 5.78% compilation time)
# n=4, rep=1: prior fit done. σ0²=1.5716, ν0=1.103
# n=4, rep=1: computing p-values...
# n=4, rep=1 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=4, rep=2: loading data...
# n=4, rep=2: computing statistics...
# n=4, rep=2: fitting Gauss-Legendre parametric prior...
#   8.303964 seconds (225.92 M allocations: 4.123 GiB, 2.17% gc time)
# n=4, rep=2: prior fit done. σ0²=1.6719, ν0=1.184
# n=4, rep=2: computing p-values...
# n=4, rep=2 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=3: loading data...
# n=4, rep=3: computing statistics...
# n=4, rep=3: fitting Gauss-Legendre parametric prior...
#   8.190459 seconds (223.14 M allocations: 4.073 GiB, 2.04% gc time)
# n=4, rep=3: prior fit done. σ0²=1.5311, ν0=1.166
# n=4, rep=3: computing p-values...
# n=4, rep=3 done → Power=0.0 | FDR=0.0 | TP@100=75
# n=4, rep=4: loading data...
# n=4, rep=4: computing statistics...
# n=4, rep=4: fitting Gauss-Legendre parametric prior...
#   9.787058 seconds (263.01 M allocations: 4.800 GiB, 2.08% gc time)
# n=4, rep=4: prior fit done. σ0²=1.636, ν0=1.163
# n=4, rep=4: computing p-values...
# n=4, rep=4 done → Power=0.0 | FDR=0.0 | TP@100=58
# n=4, rep=5: loading data...
# n=4, rep=5: computing statistics...
# n=4, rep=5: fitting Gauss-Legendre parametric prior...
#   9.090436 seconds (242.97 M allocations: 4.434 GiB, 2.03% gc time)
# n=4, rep=5: prior fit done. σ0²=1.9163, ν0=1.222
# n=4, rep=5: computing p-values...
# n=4, rep=5 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=6: loading data...
# n=4, rep=6: computing statistics...
# n=4, rep=6: fitting Gauss-Legendre parametric prior...
#   8.586334 seconds (228.61 M allocations: 4.172 GiB, 2.11% gc time)
# n=4, rep=6: prior fit done. σ0²=1.865, ν0=1.208
# n=4, rep=6: computing p-values...
# n=4, rep=6 done → Power=0.0 | FDR=0.0 | TP@100=56
# n=4, rep=7: loading data...
# n=4, rep=7: computing statistics...
# n=4, rep=7: fitting Gauss-Legendre parametric prior...
#   8.275989 seconds (220.08 M allocations: 4.016 GiB, 2.07% gc time)
# n=4, rep=7: prior fit done. σ0²=1.5317, ν0=1.112
# n=4, rep=7: computing p-values...
# n=4, rep=7 done → Power=0.0 | FDR=0.0 | TP@100=51
# n=4, rep=8: loading data...
# n=4, rep=8: computing statistics...
# n=4, rep=8: fitting Gauss-Legendre parametric prior...
#   7.453155 seconds (197.46 M allocations: 3.604 GiB, 2.16% gc time)
# n=4, rep=8: prior fit done. σ0²=1.6443, ν0=1.235
# n=4, rep=8: computing p-values...
# n=4, rep=8 done → Power=0.0 | FDR=0.0 | TP@100=80
# n=4, rep=9: loading data...
# n=4, rep=9: computing statistics...
# n=4, rep=9: fitting Gauss-Legendre parametric prior...
#   9.205286 seconds (243.05 M allocations: 4.436 GiB, 2.08% gc time)
# n=4, rep=9: prior fit done. σ0²=1.6237, ν0=1.173
# n=4, rep=9: computing p-values...
# n=4, rep=9 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=10: loading data...
# n=4, rep=10: computing statistics...
# n=4, rep=10: fitting Gauss-Legendre parametric prior...
#   7.991982 seconds (211.72 M allocations: 3.864 GiB, 2.06% gc time)
# n=4, rep=10: prior fit done. σ0²=1.729, ν0=1.26
# n=4, rep=10: computing p-values...
# n=4, rep=10 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=11: loading data...
# n=4, rep=11: computing statistics...
# n=4, rep=11: fitting Gauss-Legendre parametric prior...
#   7.683543 seconds (202.97 M allocations: 3.704 GiB, 2.10% gc time)
# n=4, rep=11: prior fit done. σ0²=1.6126, ν0=1.166
# n=4, rep=11: computing p-values...
# n=4, rep=11 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=4, rep=12: loading data...
# n=4, rep=12: computing statistics...
# n=4, rep=12: fitting Gauss-Legendre parametric prior...
#   8.649795 seconds (225.74 M allocations: 4.120 GiB, 2.25% gc time)
# n=4, rep=12: prior fit done. σ0²=1.8537, ν0=1.189
# n=4, rep=12: computing p-values...
# n=4, rep=12 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=4, rep=13: loading data...
# n=4, rep=13: computing statistics...
# n=4, rep=13: fitting Gauss-Legendre parametric prior...
#   8.085952 seconds (211.63 M allocations: 3.862 GiB, 2.21% gc time)
# n=4, rep=13: prior fit done. σ0²=1.9144, ν0=1.263
# n=4, rep=13: computing p-values...
# n=4, rep=13 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=14: loading data...
# n=4, rep=14: computing statistics...
# n=4, rep=14: fitting Gauss-Legendre parametric prior...
#   8.452664 seconds (220.21 M allocations: 4.019 GiB, 2.25% gc time)
# n=4, rep=14: prior fit done. σ0²=1.5793, ν0=1.18
# n=4, rep=14: computing p-values...
# n=4, rep=14 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=15: loading data...
# n=4, rep=15: computing statistics...
# n=4, rep=15: fitting Gauss-Legendre parametric prior...
#   8.060216 seconds (211.62 M allocations: 3.862 GiB, 2.04% gc time)
# n=4, rep=15: prior fit done. σ0²=1.635, ν0=1.195
# n=4, rep=15: computing p-values...
# n=4, rep=15 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=16: loading data...
# n=4, rep=16: computing statistics...
# n=4, rep=16: fitting Gauss-Legendre parametric prior...
#   8.710897 seconds (228.85 M allocations: 4.177 GiB, 1.98% gc time)
# n=4, rep=16: prior fit done. σ0²=1.8435, ν0=1.243
# n=4, rep=16: computing p-values...
# n=4, rep=16 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=17: loading data...
# n=4, rep=17: computing statistics...
# n=4, rep=17: fitting Gauss-Legendre parametric prior...
#   8.809694 seconds (231.47 M allocations: 4.224 GiB, 2.01% gc time)
# n=4, rep=17: prior fit done. σ0²=1.888, ν0=1.195
# n=4, rep=17: computing p-values...
# n=4, rep=17 done → Power=0.0 | FDR=0.0 | TP@100=58
# n=4, rep=18: loading data...
# n=4, rep=18: computing statistics...
# n=4, rep=18: fitting Gauss-Legendre parametric prior...
#   8.340213 seconds (217.24 M allocations: 3.965 GiB, 2.22% gc time)
# n=4, rep=18: prior fit done. σ0²=1.554, ν0=1.116
# n=4, rep=18: computing p-values...
# n=4, rep=18 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=19: loading data...
# n=4, rep=19: computing statistics...
# n=4, rep=19: fitting Gauss-Legendre parametric prior...
#   8.730283 seconds (228.64 M allocations: 4.173 GiB, 2.05% gc time)
# n=4, rep=19: prior fit done. σ0²=1.5971, ν0=1.142
# n=4, rep=19: computing p-values...
# n=4, rep=19 done → Power=0.0 | FDR=0.0 | TP@100=54
# n=4, rep=20: loading data...
# n=4, rep=20: computing statistics...
# n=4, rep=20: fitting Gauss-Legendre parametric prior...
#   9.487388 seconds (248.83 M allocations: 4.541 GiB, 2.01% gc time)
# n=4, rep=20: prior fit done. σ0²=1.6151, ν0=1.173
# n=4, rep=20: computing p-values...
# n=4, rep=20 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=21: loading data...
# n=4, rep=21: computing statistics...
# n=4, rep=21: fitting Gauss-Legendre parametric prior...
#   9.504336 seconds (248.86 M allocations: 4.542 GiB, 2.00% gc time)
# n=4, rep=21: prior fit done. σ0²=1.6473, ν0=1.187
# n=4, rep=21: computing p-values...
# n=4, rep=21 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=22: loading data...
# n=4, rep=22: computing statistics...
# n=4, rep=22: fitting Gauss-Legendre parametric prior...
#   8.724010 seconds (228.93 M allocations: 4.178 GiB, 2.00% gc time)
# n=4, rep=22: prior fit done. σ0²=1.7327, ν0=1.224
# n=4, rep=22: computing p-values...
# n=4, rep=22 done → Power=0.0 | FDR=0.0 | TP@100=61
# n=4, rep=23: loading data...
# n=4, rep=23: computing statistics...
# n=4, rep=23: fitting Gauss-Legendre parametric prior...
#   8.631103 seconds (226.26 M allocations: 4.130 GiB, 1.97% gc time)
# n=4, rep=23: prior fit done. σ0²=1.4889, ν0=1.242
# n=4, rep=23: computing p-values...
# n=4, rep=23 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=24: loading data...
# n=4, rep=24: computing statistics...
# n=4, rep=24: fitting Gauss-Legendre parametric prior...
#   9.891767 seconds (260.04 M allocations: 4.746 GiB, 2.00% gc time)
# n=4, rep=24: prior fit done. σ0²=1.7587, ν0=1.164
# n=4, rep=24: computing p-values...
# n=4, rep=24 done → Power=0.0 | FDR=0.0 | TP@100=56
# n=4, rep=25: loading data...
# n=4, rep=25: computing statistics...
# n=4, rep=25: fitting Gauss-Legendre parametric prior...
#   8.505152 seconds (223.14 M allocations: 4.073 GiB, 2.00% gc time)
# n=4, rep=25: prior fit done. σ0²=1.6706, ν0=1.208
# n=4, rep=25: computing p-values...
# n=4, rep=25 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=26: loading data...
# n=4, rep=26: computing statistics...
# n=4, rep=26: fitting Gauss-Legendre parametric prior...
#   8.265997 seconds (217.12 M allocations: 3.962 GiB, 2.00% gc time)
# n=4, rep=26: prior fit done. σ0²=1.6778, ν0=1.154
# n=4, rep=26: computing p-values...
# n=4, rep=26 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=27: loading data...
# n=4, rep=27: computing statistics...
# n=4, rep=27: fitting Gauss-Legendre parametric prior...
#   8.509864 seconds (223.27 M allocations: 4.075 GiB, 1.99% gc time)
# n=4, rep=27: prior fit done. σ0²=1.7711, ν0=1.308
# n=4, rep=27: computing p-values...
# n=4, rep=27 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=28: loading data...
# n=4, rep=28: computing statistics...
# n=4, rep=28: fitting Gauss-Legendre parametric prior...
#   8.183589 seconds (214.49 M allocations: 3.915 GiB, 1.97% gc time)
# n=4, rep=28: prior fit done. σ0²=1.8187, ν0=1.238
# n=4, rep=28: computing p-values...
# n=4, rep=28 done → Power=0.0 | FDR=0.0 | TP@100=61
# n=4, rep=29: loading data...
# n=4, rep=29: computing statistics...
# n=4, rep=29: fitting Gauss-Legendre parametric prior...
#   8.050723 seconds (211.35 M allocations: 3.857 GiB, 1.99% gc time)
# n=4, rep=29: prior fit done. σ0²=1.7085, ν0=1.114
# n=4, rep=29: computing p-values...
# n=4, rep=29 done → Power=0.0 | FDR=0.0 | TP@100=75
# n=4, rep=30: loading data...
# n=4, rep=30: computing statistics...
# n=4, rep=30: fitting Gauss-Legendre parametric prior...
#   9.920462 seconds (260.22 M allocations: 4.749 GiB, 1.99% gc time)
# n=4, rep=30: prior fit done. σ0²=1.6331, ν0=1.143
# n=4, rep=30: computing p-values...
# n=4, rep=30 done → Power=0.0 | FDR=0.0 | TP@100=61
# n=4, rep=31: loading data...
# n=4, rep=31: computing statistics...
# n=4, rep=31: fitting Gauss-Legendre parametric prior...
#   9.035259 seconds (237.45 M allocations: 4.334 GiB, 2.00% gc time)
# n=4, rep=31: prior fit done. σ0²=1.7557, ν0=1.226
# n=4, rep=31: computing p-values...
# n=4, rep=31 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=32: loading data...
# n=4, rep=32: computing statistics...
# n=4, rep=32: fitting Gauss-Legendre parametric prior...
#   8.630953 seconds (225.77 M allocations: 4.120 GiB, 2.02% gc time)
# n=4, rep=32: prior fit done. σ0²=1.5763, ν0=1.136
# n=4, rep=32: computing p-values...
# n=4, rep=32 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=33: loading data...
# n=4, rep=33: computing statistics...
# n=4, rep=33: fitting Gauss-Legendre parametric prior...
#   9.361451 seconds (245.86 M allocations: 4.487 GiB, 2.01% gc time)
# n=4, rep=33: prior fit done. σ0²=1.7515, ν0=1.167
# n=4, rep=33: computing p-values...
# n=4, rep=33 done → Power=0.0 | FDR=0.0 | TP@100=61
# n=4, rep=34: loading data...
# n=4, rep=34: computing statistics...
# n=4, rep=34: fitting Gauss-Legendre parametric prior...
#   8.713594 seconds (228.49 M allocations: 4.170 GiB, 2.00% gc time)
# n=4, rep=34: prior fit done. σ0²=1.8479, ν0=1.177
# n=4, rep=34: computing p-values...
# n=4, rep=34 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=35: loading data...
# n=4, rep=35: computing statistics...
# n=4, rep=35: fitting Gauss-Legendre parametric prior...
#   7.974352 seconds (208.77 M allocations: 3.810 GiB, 2.01% gc time)
# n=4, rep=35: prior fit done. σ0²=1.7014, ν0=1.211
# n=4, rep=35: computing p-values...
# n=4, rep=35 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=36: loading data...
# n=4, rep=36: computing statistics...
# n=4, rep=36: fitting Gauss-Legendre parametric prior...
#   8.197500 seconds (214.54 M allocations: 3.916 GiB, 2.03% gc time)
# n=4, rep=36: prior fit done. σ0²=1.6184, ν0=1.197
# n=4, rep=36: computing p-values...
# n=4, rep=36 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=37: loading data...
# n=4, rep=37: computing statistics...
# n=4, rep=37: fitting Gauss-Legendre parametric prior...
#   7.958588 seconds (208.84 M allocations: 3.812 GiB, 2.01% gc time)
# n=4, rep=37: prior fit done. σ0²=1.8698, ν0=1.282
# n=4, rep=37: computing p-values...
# n=4, rep=37 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=38: loading data...
# n=4, rep=38: computing statistics...
# n=4, rep=38: fitting Gauss-Legendre parametric prior...
#   8.181019 seconds (214.43 M allocations: 3.913 GiB, 2.00% gc time)
# n=4, rep=38: prior fit done. σ0²=1.501, ν0=1.129
# n=4, rep=38: computing p-values...
# n=4, rep=38 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=39: loading data...
# n=4, rep=39: computing statistics...
# n=4, rep=39: fitting Gauss-Legendre parametric prior...
#   8.922116 seconds (234.56 M allocations: 4.281 GiB, 2.03% gc time)
# n=4, rep=39: prior fit done. σ0²=1.6509, ν0=1.186
# n=4, rep=39: computing p-values...
# n=4, rep=39 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=40: loading data...
# n=4, rep=40: computing statistics...
# n=4, rep=40: fitting Gauss-Legendre parametric prior...
#   8.061008 seconds (211.37 M allocations: 3.857 GiB, 1.98% gc time)
# n=4, rep=40: prior fit done. σ0²=1.5963, ν0=1.111
# n=4, rep=40: computing p-values...
# n=4, rep=40 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=4, rep=41: loading data...
# n=4, rep=41: computing statistics...
# n=4, rep=41: fitting Gauss-Legendre parametric prior...
#   7.631196 seconds (200.12 M allocations: 3.652 GiB, 2.04% gc time)
# n=4, rep=41: prior fit done. σ0²=1.5766, ν0=1.161
# n=4, rep=41: computing p-values...
# n=4, rep=41 done → Power=0.0 | FDR=0.0 | TP@100=52
# n=4, rep=42: loading data...
# n=4, rep=42: computing statistics...
# n=4, rep=42: fitting Gauss-Legendre parametric prior...
#   8.836235 seconds (231.57 M allocations: 4.226 GiB, 2.00% gc time)
# n=4, rep=42: prior fit done. σ0²=1.719, ν0=1.187
# n=4, rep=42: computing p-values...
# n=4, rep=42 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=4, rep=43: loading data...
# n=4, rep=43: computing statistics...
# n=4, rep=43: fitting Gauss-Legendre parametric prior...
#   8.478071 seconds (222.71 M allocations: 4.064 GiB, 1.99% gc time)
# n=4, rep=43: prior fit done. σ0²=1.687, ν0=1.065
# n=4, rep=43: computing p-values...
# n=4, rep=43 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=44: loading data...
# n=4, rep=44: computing statistics...
# n=4, rep=44: fitting Gauss-Legendre parametric prior...
#   9.164344 seconds (240.15 M allocations: 4.383 GiB, 2.00% gc time)
# n=4, rep=44: prior fit done. σ0²=1.692, ν0=1.167
# n=4, rep=44: computing p-values...
# n=4, rep=44 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=4, rep=45: loading data...
# n=4, rep=45: computing statistics...
# n=4, rep=45: fitting Gauss-Legendre parametric prior...
#   8.840432 seconds (231.88 M allocations: 4.232 GiB, 2.03% gc time)
# n=4, rep=45: prior fit done. σ0²=1.5471, ν0=1.199
# n=4, rep=45: computing p-values...
# n=4, rep=45 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=46: loading data...
# n=4, rep=46: computing statistics...
# n=4, rep=46: fitting Gauss-Legendre parametric prior...
#   8.625277 seconds (226.12 M allocations: 4.127 GiB, 1.98% gc time)
# n=4, rep=46: prior fit done. σ0²=1.6564, ν0=1.25
# n=4, rep=46: computing p-values...
# n=4, rep=46 done → Power=0.0 | FDR=0.0 | TP@100=56
# n=4, rep=47: loading data...
# n=4, rep=47: computing statistics...
# n=4, rep=47: fitting Gauss-Legendre parametric prior...
#   8.281034 seconds (217.45 M allocations: 3.969 GiB, 2.03% gc time)
# n=4, rep=47: prior fit done. σ0²=1.6791, ν0=1.224
# n=4, rep=47: computing p-values...
# n=4, rep=47 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=48: loading data...
# n=4, rep=48: computing statistics...
# n=4, rep=48: fitting Gauss-Legendre parametric prior...
#   8.744306 seconds (228.78 M allocations: 4.175 GiB, 2.00% gc time)
# n=4, rep=48: prior fit done. σ0²=1.7591, ν0=1.212
# n=4, rep=48: computing p-values...
# n=4, rep=48 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=49: loading data...
# n=4, rep=49: computing statistics...
# n=4, rep=49: fitting Gauss-Legendre parametric prior...
#   9.130138 seconds (240.17 M allocations: 4.383 GiB, 1.99% gc time)
# n=4, rep=49: prior fit done. σ0²=1.6896, ν0=1.173
# n=4, rep=49: computing p-values...
# n=4, rep=49 done → Power=0.0 | FDR=0.0 | TP@100=61
# n=4, rep=50: loading data...
# n=4, rep=50: computing statistics...
# n=4, rep=50: fitting Gauss-Legendre parametric prior...
#   9.495230 seconds (248.68 M allocations: 4.538 GiB, 2.02% gc time)
# n=4, rep=50: prior fit done. σ0²=1.7534, ν0=1.164
# n=4, rep=50: computing p-values...
# n=4, rep=50 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=51: loading data...
# n=4, rep=51: computing statistics...
# n=4, rep=51: fitting Gauss-Legendre parametric prior...
#   8.700560 seconds (228.98 M allocations: 4.179 GiB, 2.00% gc time)
# n=4, rep=51: prior fit done. σ0²=1.5711, ν0=1.239
# n=4, rep=51: computing p-values...
# n=4, rep=51 done → Power=0.011 | FDR=0.0 | TP@100=62
# n=4, rep=52: loading data...
# n=4, rep=52: computing statistics...
# n=4, rep=52: fitting Gauss-Legendre parametric prior...
#   8.193784 seconds (214.45 M allocations: 3.914 GiB, 1.97% gc time)
# n=4, rep=52: prior fit done. σ0²=1.7035, ν0=1.194
# n=4, rep=52: computing p-values...
# n=4, rep=52 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=53: loading data...
# n=4, rep=53: computing statistics...
# n=4, rep=53: fitting Gauss-Legendre parametric prior...
#  10.240928 seconds (268.43 M allocations: 4.899 GiB, 2.01% gc time)
# n=4, rep=53: prior fit done. σ0²=1.8077, ν0=1.142
# n=4, rep=53: computing p-values...
# n=4, rep=53 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=54: loading data...
# n=4, rep=54: computing statistics...
# n=4, rep=54: fitting Gauss-Legendre parametric prior...
#   8.618018 seconds (225.88 M allocations: 4.122 GiB, 2.01% gc time)
# n=4, rep=54: prior fit done. σ0²=1.5868, ν0=1.163
# n=4, rep=54: computing p-values...
# n=4, rep=54 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=4, rep=55: loading data...
# n=4, rep=55: computing statistics...
# n=4, rep=55: fitting Gauss-Legendre parametric prior...
#   8.181337 seconds (214.45 M allocations: 3.914 GiB, 1.98% gc time)
# n=4, rep=55: prior fit done. σ0²=1.6464, ν0=1.174
# n=4, rep=55: computing p-values...
# n=4, rep=55 done → Power=0.0 | FDR=0.0 | TP@100=76
# n=4, rep=56: loading data...
# n=4, rep=56: computing statistics...
# n=4, rep=56: fitting Gauss-Legendre parametric prior...
#   8.177582 seconds (214.49 M allocations: 3.915 GiB, 2.01% gc time)
# n=4, rep=56: prior fit done. σ0²=1.8248, ν0=1.235
# n=4, rep=56: computing p-values...
# n=4, rep=56 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=57: loading data...
# n=4, rep=57: computing statistics...
# n=4, rep=57: fitting Gauss-Legendre parametric prior...
#   9.055215 seconds (236.96 M allocations: 4.324 GiB, 2.02% gc time)
# n=4, rep=57: prior fit done. σ0²=1.979, ν0=1.168
# n=4, rep=57: computing p-values...
# n=4, rep=57 done → Power=0.01 | FDR=0.0 | TP@100=69
# n=4, rep=58: loading data...
# n=4, rep=58: computing statistics...
# n=4, rep=58: fitting Gauss-Legendre parametric prior...
#   7.980503 seconds (208.90 M allocations: 3.813 GiB, 2.10% gc time)
# n=4, rep=58: prior fit done. σ0²=1.715, ν0=1.272
# n=4, rep=58: computing p-values...
# n=4, rep=58 done → Power=0.011 | FDR=0.0 | TP@100=67
# n=4, rep=59: loading data...
# n=4, rep=59: computing statistics...
# n=4, rep=59: fitting Gauss-Legendre parametric prior...
#   8.414661 seconds (220.15 M allocations: 4.018 GiB, 2.06% gc time)
# n=4, rep=59: prior fit done. σ0²=1.6912, ν0=1.19
# n=4, rep=59: computing p-values...
# n=4, rep=59 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=60: loading data...
# n=4, rep=60: computing statistics...
# n=4, rep=60: fitting Gauss-Legendre parametric prior...
#   8.200560 seconds (214.61 M allocations: 3.917 GiB, 2.01% gc time)
# n=4, rep=60: prior fit done. σ0²=1.7216, ν0=1.234
# n=4, rep=60: computing p-values...
# n=4, rep=60 done → Power=0.0 | FDR=0.0 | TP@100=58
# n=4, rep=61: loading data...
# n=4, rep=61: computing statistics...
# n=4, rep=61: fitting Gauss-Legendre parametric prior...
#   8.432225 seconds (220.25 M allocations: 4.020 GiB, 1.98% gc time)
# n=4, rep=61: prior fit done. σ0²=1.4952, ν0=1.14
# n=4, rep=61: computing p-values...
# n=4, rep=61 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=62: loading data...
# n=4, rep=62: computing statistics...
# n=4, rep=62: fitting Gauss-Legendre parametric prior...
#   8.630737 seconds (225.88 M allocations: 4.122 GiB, 2.00% gc time)
# n=4, rep=62: prior fit done. σ0²=1.493, ν0=1.134
# n=4, rep=62: computing p-values...
# n=4, rep=62 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=63: loading data...
# n=4, rep=63: computing statistics...
# n=4, rep=63: fitting Gauss-Legendre parametric prior...
#   8.320296 seconds (217.25 M allocations: 3.965 GiB, 2.02% gc time)
# n=4, rep=63: prior fit done. σ0²=1.7599, ν0=1.185
# n=4, rep=63: computing p-values...
# n=4, rep=63 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=64: loading data...
# n=4, rep=64: computing statistics...
# n=4, rep=64: fitting Gauss-Legendre parametric prior...
#   8.308721 seconds (217.52 M allocations: 3.970 GiB, 2.06% gc time)
# n=4, rep=64: prior fit done. σ0²=1.6307, ν0=1.233
# n=4, rep=64: computing p-values...
# n=4, rep=64 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=65: loading data...
# n=4, rep=65: computing statistics...
# n=4, rep=65: fitting Gauss-Legendre parametric prior...
#   9.472339 seconds (248.69 M allocations: 4.539 GiB, 2.06% gc time)
# n=4, rep=65: prior fit done. σ0²=1.7466, ν0=1.166
# n=4, rep=65: computing p-values...
# n=4, rep=65 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=66: loading data...
# n=4, rep=66: computing statistics...
# n=4, rep=66: fitting Gauss-Legendre parametric prior...
#   8.723080 seconds (228.56 M allocations: 4.171 GiB, 2.03% gc time)
# n=4, rep=66: prior fit done. σ0²=1.6326, ν0=1.117
# n=4, rep=66: computing p-values...
# n=4, rep=66 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=67: loading data...
# n=4, rep=67: computing statistics...
# n=4, rep=67: fitting Gauss-Legendre parametric prior...
#   8.200332 seconds (214.54 M allocations: 3.916 GiB, 2.02% gc time)
# n=4, rep=67: prior fit done. σ0²=1.7961, ν0=1.237
# n=4, rep=67: computing p-values...
# n=4, rep=67 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=4, rep=68: loading data...
# n=4, rep=68: computing statistics...
# n=4, rep=68: fitting Gauss-Legendre parametric prior...
#   8.515990 seconds (223.08 M allocations: 4.071 GiB, 2.02% gc time)
# n=4, rep=68: prior fit done. σ0²=1.5689, ν0=1.162
# n=4, rep=68: computing p-values...
# n=4, rep=68 done → Power=0.0 | FDR=0.0 | TP@100=57
# n=4, rep=69: loading data...
# n=4, rep=69: computing statistics...
# n=4, rep=69: fitting Gauss-Legendre parametric prior...
#   8.197139 seconds (214.38 M allocations: 3.912 GiB, 2.01% gc time)
# n=4, rep=69: prior fit done. σ0²=1.6338, ν0=1.156
# n=4, rep=69: computing p-values...
# n=4, rep=69 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=70: loading data...
# n=4, rep=70: computing statistics...
# n=4, rep=70: fitting Gauss-Legendre parametric prior...
#   9.044823 seconds (237.25 M allocations: 4.330 GiB, 2.01% gc time)
# n=4, rep=70: prior fit done. σ0²=1.7179, ν0=1.173
# n=4, rep=70: computing p-values...
# n=4, rep=70 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=71: loading data...
# n=4, rep=71: computing statistics...
# n=4, rep=71: fitting Gauss-Legendre parametric prior...
#  10.364236 seconds (271.46 M allocations: 4.954 GiB, 1.99% gc time)
# n=4, rep=71: prior fit done. σ0²=1.7109, ν0=1.149
# n=4, rep=71: computing p-values...
# n=4, rep=71 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=72: loading data...
# n=4, rep=72: computing statistics...
# n=4, rep=72: fitting Gauss-Legendre parametric prior...
#   7.960793 seconds (208.80 M allocations: 3.811 GiB, 2.06% gc time)
# n=4, rep=72: prior fit done. σ0²=1.7469, ν0=1.244
# n=4, rep=72: computing p-values...
# n=4, rep=72 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=4, rep=73: loading data...
# n=4, rep=73: computing statistics...
# n=4, rep=73: fitting Gauss-Legendre parametric prior...
#   7.852338 seconds (206.03 M allocations: 3.760 GiB, 2.01% gc time)
# n=4, rep=73: prior fit done. σ0²=1.6037, ν0=1.204
# n=4, rep=73: computing p-values...
# n=4, rep=73 done → Power=0.0 | FDR=0.0 | TP@100=58
# n=4, rep=74: loading data...
# n=4, rep=74: computing statistics...
# n=4, rep=74: fitting Gauss-Legendre parametric prior...
#   8.329193 seconds (217.58 M allocations: 3.971 GiB, 2.04% gc time)
# n=4, rep=74: prior fit done. σ0²=1.7256, ν0=1.292
# n=4, rep=74: computing p-values...
# n=4, rep=74 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=75: loading data...
# n=4, rep=75: computing statistics...
# n=4, rep=75: fitting Gauss-Legendre parametric prior...
#   7.860209 seconds (205.96 M allocations: 3.759 GiB, 2.00% gc time)
# n=4, rep=75: prior fit done. σ0²=1.7237, ν0=1.235
# n=4, rep=75: computing p-values...
# n=4, rep=75 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=4, rep=76: loading data...
# n=4, rep=76: computing statistics...
# n=4, rep=76: fitting Gauss-Legendre parametric prior...
#  10.100160 seconds (265.45 M allocations: 4.844 GiB, 2.02% gc time)
# n=4, rep=76: prior fit done. σ0²=1.8741, ν0=1.146
# n=4, rep=76: computing p-values...
# n=4, rep=76 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=4, rep=77: loading data...
# n=4, rep=77: computing statistics...
# n=4, rep=77: fitting Gauss-Legendre parametric prior...
#   7.768956 seconds (203.27 M allocations: 3.710 GiB, 2.02% gc time)
# n=4, rep=77: prior fit done. σ0²=1.5311, ν0=1.206
# n=4, rep=77: computing p-values...
# n=4, rep=77 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=78: loading data...
# n=4, rep=78: computing statistics...
# n=4, rep=78: fitting Gauss-Legendre parametric prior...
#   8.622112 seconds (226.04 M allocations: 4.126 GiB, 2.02% gc time)
# n=4, rep=78: prior fit done. σ0²=1.622, ν0=1.219
# n=4, rep=78: computing p-values...
# n=4, rep=78 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=79: loading data...
# n=4, rep=79: computing statistics...
# n=4, rep=79: fitting Gauss-Legendre parametric prior...
#   8.528143 seconds (223.19 M allocations: 4.074 GiB, 2.02% gc time)
# n=4, rep=79: prior fit done. σ0²=1.8857, ν0=1.292
# n=4, rep=79: computing p-values...
# n=4, rep=79 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=80: loading data...
# n=4, rep=80: computing statistics...
# n=4, rep=80: fitting Gauss-Legendre parametric prior...
#   8.828561 seconds (231.58 M allocations: 4.226 GiB, 2.05% gc time)
# n=4, rep=80: prior fit done. σ0²=1.7478, ν0=1.188
# n=4, rep=80: computing p-values...
# n=4, rep=80 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=81: loading data...
# n=4, rep=81: computing statistics...
# n=4, rep=81: fitting Gauss-Legendre parametric prior...
#   9.507425 seconds (248.57 M allocations: 4.536 GiB, 2.05% gc time)
# n=4, rep=81: prior fit done. σ0²=1.7779, ν0=1.168
# n=4, rep=81: computing p-values...
# n=4, rep=81 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=4, rep=82: loading data...
# n=4, rep=82: computing statistics...
# n=4, rep=82: fitting Gauss-Legendre parametric prior...
#   8.705225 seconds (228.61 M allocations: 4.172 GiB, 2.04% gc time)
# n=4, rep=82: prior fit done. σ0²=1.7475, ν0=1.168
# n=4, rep=82: computing p-values...
# n=4, rep=82 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=83: loading data...
# n=4, rep=83: computing statistics...
# n=4, rep=83: fitting Gauss-Legendre parametric prior...
#   9.274499 seconds (243.00 M allocations: 4.435 GiB, 2.03% gc time)
# n=4, rep=83: prior fit done. σ0²=1.6738, ν0=1.178
# n=4, rep=83: computing p-values...
# n=4, rep=83 done → Power=0.0 | FDR=0.0 | TP@100=57
# n=4, rep=84: loading data...
# n=4, rep=84: computing statistics...
# n=4, rep=84: fitting Gauss-Legendre parametric prior...
#   8.955386 seconds (234.50 M allocations: 4.280 GiB, 2.01% gc time)
# n=4, rep=84: prior fit done. σ0²=1.7033, ν0=1.199
# n=4, rep=84: computing p-values...
# n=4, rep=84 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=85: loading data...
# n=4, rep=85: computing statistics...
# n=4, rep=85: fitting Gauss-Legendre parametric prior...
#   8.615644 seconds (225.91 M allocations: 4.123 GiB, 2.04% gc time)
# n=4, rep=85: prior fit done. σ0²=1.7256, ν0=1.225
# n=4, rep=85: computing p-values...
# n=4, rep=85 done → Power=0.0 | FDR=0.0 | TP@100=59
# n=4, rep=86: loading data...
# n=4, rep=86: computing statistics...
# n=4, rep=86: fitting Gauss-Legendre parametric prior...
#   7.749115 seconds (203.13 M allocations: 3.707 GiB, 2.03% gc time)
# n=4, rep=86: prior fit done. σ0²=1.6047, ν0=1.201
# n=4, rep=86: computing p-values...
# n=4, rep=86 done → Power=0.0 | FDR=0.0 | TP@100=76
# n=4, rep=87: loading data...
# n=4, rep=87: computing statistics...
# n=4, rep=87: fitting Gauss-Legendre parametric prior...
#   8.308400 seconds (217.32 M allocations: 3.966 GiB, 2.03% gc time)
# n=4, rep=87: prior fit done. σ0²=1.4845, ν0=1.142
# n=4, rep=87: computing p-values...
# n=4, rep=87 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=88: loading data...
# n=4, rep=88: computing statistics...
# n=4, rep=88: fitting Gauss-Legendre parametric prior...
#   8.267404 seconds (217.38 M allocations: 3.967 GiB, 2.05% gc time)
# n=4, rep=88: prior fit done. σ0²=1.5748, ν0=1.17
# n=4, rep=88: computing p-values...
# n=4, rep=88 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=89: loading data...
# n=4, rep=89: computing statistics...
# n=4, rep=89: fitting Gauss-Legendre parametric prior...
#   7.638604 seconds (200.27 M allocations: 3.655 GiB, 2.02% gc time)
# n=4, rep=89: prior fit done. σ0²=1.7469, ν0=1.264
# n=4, rep=89: computing p-values...
# n=4, rep=89 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=4, rep=90: loading data...
# n=4, rep=90: computing statistics...
# n=4, rep=90: fitting Gauss-Legendre parametric prior...
#   7.934122 seconds (208.64 M allocations: 3.808 GiB, 2.08% gc time)
# n=4, rep=90: prior fit done. σ0²=1.5387, ν0=1.116
# n=4, rep=90: computing p-values...
# n=4, rep=90 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=91: loading data...
# n=4, rep=91: computing statistics...
# n=4, rep=91: fitting Gauss-Legendre parametric prior...
#   8.288862 seconds (217.25 M allocations: 3.965 GiB, 2.04% gc time)
# n=4, rep=91: prior fit done. σ0²=1.535, ν0=1.129
# n=4, rep=91: computing p-values...
# n=4, rep=91 done → Power=0.0 | FDR=0.0 | TP@100=58
# n=4, rep=92: loading data...
# n=4, rep=92: computing statistics...
# n=4, rep=92: fitting Gauss-Legendre parametric prior...
#   8.901922 seconds (234.25 M allocations: 4.275 GiB, 2.08% gc time)
# n=4, rep=92: prior fit done. σ0²=1.7716, ν0=1.135
# n=4, rep=92: computing p-values...
# n=4, rep=92 done → Power=0.0 | FDR=0.0 | TP@100=58
# n=4, rep=93: loading data...
# n=4, rep=93: computing statistics...
# n=4, rep=93: fitting Gauss-Legendre parametric prior...
#   9.144633 seconds (239.99 M allocations: 4.380 GiB, 2.04% gc time)
# n=4, rep=93: prior fit done. σ0²=1.8573, ν0=1.185
# n=4, rep=93: computing p-values...
# n=4, rep=93 done → Power=0.0 | FDR=0.0 | TP@100=52
# n=4, rep=94: loading data...
# n=4, rep=94: computing statistics...
# n=4, rep=94: fitting Gauss-Legendre parametric prior...
#   9.472172 seconds (248.67 M allocations: 4.538 GiB, 2.07% gc time)
# n=4, rep=94: prior fit done. σ0²=1.6672, ν0=1.141
# n=4, rep=94: computing p-values...
# n=4, rep=94 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=4, rep=95: loading data...
# n=4, rep=95: computing statistics...
# n=4, rep=95: fitting Gauss-Legendre parametric prior...
#   7.847638 seconds (205.89 M allocations: 3.758 GiB, 2.05% gc time)
# n=4, rep=95: prior fit done. σ0²=1.7393, ν0=1.23
# n=4, rep=95: computing p-values...
# n=4, rep=95 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=4, rep=96: loading data...
# n=4, rep=96: computing statistics...
# n=4, rep=96: fitting Gauss-Legendre parametric prior...
#   7.741501 seconds (203.20 M allocations: 3.709 GiB, 2.10% gc time)
# n=4, rep=96: prior fit done. σ0²=1.5625, ν0=1.192
# n=4, rep=96: computing p-values...
# n=4, rep=96 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=4, rep=97: loading data...
# n=4, rep=97: computing statistics...
# n=4, rep=97: fitting Gauss-Legendre parametric prior...
#   8.832697 seconds (231.52 M allocations: 4.225 GiB, 2.05% gc time)
# n=4, rep=97: prior fit done. σ0²=1.8033, ν0=1.2
# n=4, rep=97: computing p-values...
# n=4, rep=97 done → Power=0.0 | FDR=0.0 | TP@100=57
# n=4, rep=98: loading data...
# n=4, rep=98: computing statistics...
# n=4, rep=98: fitting Gauss-Legendre parametric prior...
#   8.588091 seconds (225.84 M allocations: 4.122 GiB, 2.05% gc time)
# n=4, rep=98: prior fit done. σ0²=1.7346, ν0=1.206
# n=4, rep=98: computing p-values...
# n=4, rep=98 done → Power=0.008 | FDR=0.0 | TP@100=70
# n=4, rep=99: loading data...
# n=4, rep=99: computing statistics...
# n=4, rep=99: fitting Gauss-Legendre parametric prior...
#   8.038492 seconds (211.64 M allocations: 3.863 GiB, 2.05% gc time)
# n=4, rep=99: prior fit done. σ0²=1.7005, ν0=1.203
# n=4, rep=99: computing p-values...
# n=4, rep=99 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=4, rep=100: loading data...
# n=4, rep=100: computing statistics...
# n=4, rep=100: fitting Gauss-Legendre parametric prior...
#   8.264875 seconds (217.29 M allocations: 3.966 GiB, 2.09% gc time)
# n=4, rep=100: prior fit done. σ0²=1.5499, ν0=1.128
# n=4, rep=100: computing p-values...
# n=4, rep=100 done → Power=0.0 | FDR=0.0 | TP@100=66
# ✅ Done n=4 → Power=0.0 | FDR=0.0 | TP=0.0 | FP=0.0 | TP@100=64.3
#
# ========== Running MAD_mean + parametric prior (Gauss-Legendre) for n = 5 ==========
# n=5, rep=1: loading data...
# n=5, rep=1: computing statistics...
# n=5, rep=1: fitting Gauss-Legendre parametric prior...
#  11.830691 seconds (294.68 M allocations: 5.143 GiB, 1.85% gc time)
# n=5, rep=1: prior fit done. σ0²=1.9559, ν0=1.288
# n=5, rep=1: computing p-values...
# n=5, rep=1 done → Power=0.0 | FDR=0.0 | TP@100=54
# n=5, rep=2: loading data...
# n=5, rep=2: computing statistics...
# n=5, rep=2: fitting Gauss-Legendre parametric prior...
#  12.399875 seconds (309.41 M allocations: 5.400 GiB, 1.84% gc time)
# n=5, rep=2: prior fit done. σ0²=1.9727, ν0=1.246
# n=5, rep=2: computing p-values...
# n=5, rep=2 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=5, rep=3: loading data...
# n=5, rep=3: computing statistics...
# n=5, rep=3: fitting Gauss-Legendre parametric prior...
#  11.808922 seconds (294.91 M allocations: 5.147 GiB, 1.85% gc time)
# n=5, rep=3: prior fit done. σ0²=1.7929, ν0=1.279
# n=5, rep=3: computing p-values...
# n=5, rep=3 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=5, rep=4: loading data...
# n=5, rep=4: computing statistics...
# n=5, rep=4: fitting Gauss-Legendre parametric prior...
#  12.400868 seconds (309.57 M allocations: 5.403 GiB, 1.84% gc time)
# n=5, rep=4: prior fit done. σ0²=1.9693, ν0=1.274
# n=5, rep=4: computing p-values...
# n=5, rep=4 done → Power=0.0 | FDR=0.0 | TP@100=56
# n=5, rep=5: loading data...
# n=5, rep=5: computing statistics...
# n=5, rep=5: fitting Gauss-Legendre parametric prior...
#  12.508962 seconds (313.00 M allocations: 5.463 GiB, 1.82% gc time)
# n=5, rep=5: prior fit done. σ0²=1.7702, ν0=1.157
# n=5, rep=5: computing p-values...
# n=5, rep=5 done → Power=0.0 | FDR=0.0 | TP@100=55
# n=5, rep=6: loading data...
# n=5, rep=6: computing statistics...
# n=5, rep=6: fitting Gauss-Legendre parametric prior...
#  11.612314 seconds (290.70 M allocations: 5.073 GiB, 1.83% gc time)
# n=5, rep=6: prior fit done. σ0²=2.0588, ν0=1.259
# n=5, rep=6: computing p-values...
# n=5, rep=6 done → Power=0.0 | FDR=0.0 | TP@100=72
# n=5, rep=7: loading data...
# n=5, rep=7: computing statistics...
# n=5, rep=7: fitting Gauss-Legendre parametric prior...
#  12.340125 seconds (309.17 M allocations: 5.396 GiB, 1.85% gc time)
# n=5, rep=7: prior fit done. σ0²=2.0047, ν0=1.199
# n=5, rep=7: computing p-values...
# n=5, rep=7 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=5, rep=8: loading data...
# n=5, rep=8: computing statistics...
# n=5, rep=8: fitting Gauss-Legendre parametric prior...
#  12.982838 seconds (324.37 M allocations: 5.661 GiB, 1.86% gc time)
# n=5, rep=8: prior fit done. σ0²=1.8017, ν0=1.19
# n=5, rep=8: computing p-values...
# n=5, rep=8 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=5, rep=9: loading data...
# n=5, rep=9: computing statistics...
# n=5, rep=9: fitting Gauss-Legendre parametric prior...
#  12.226562 seconds (306.06 M allocations: 5.342 GiB, 1.84% gc time)
# n=5, rep=9: prior fit done. σ0²=1.6054, ν0=1.185
# n=5, rep=9: computing p-values...
# n=5, rep=9 done → Power=0.017 | FDR=0.0 | TP@100=72
# n=5, rep=10: loading data...
# n=5, rep=10: computing statistics...
# n=5, rep=10: fitting Gauss-Legendre parametric prior...
#  12.526599 seconds (313.15 M allocations: 5.465 GiB, 1.86% gc time)
# n=5, rep=10: prior fit done. σ0²=1.8883, ν0=1.222
# n=5, rep=10: computing p-values...
# n=5, rep=10 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=5, rep=11: loading data...
# n=5, rep=11: computing statistics...
# n=5, rep=11: fitting Gauss-Legendre parametric prior...
#  11.644197 seconds (291.11 M allocations: 5.081 GiB, 1.85% gc time)
# n=5, rep=11: prior fit done. σ0²=1.9014, ν0=1.294
# n=5, rep=11: computing p-values...
# n=5, rep=11 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=5, rep=12: loading data...
# n=5, rep=12: computing statistics...
# n=5, rep=12: fitting Gauss-Legendre parametric prior...
#  12.241356 seconds (305.94 M allocations: 5.340 GiB, 1.84% gc time)
# n=5, rep=12: prior fit done. σ0²=2.005, ν0=1.31
# n=5, rep=12: computing p-values...
# n=5, rep=12 done → Power=0.011 | FDR=0.0 | TP@100=61
# n=5, rep=13: loading data...
# n=5, rep=13: computing statistics...
# n=5, rep=13: fitting Gauss-Legendre parametric prior...
#  12.234269 seconds (305.97 M allocations: 5.340 GiB, 1.86% gc time)
# n=5, rep=13: prior fit done. σ0²=1.7615, ν0=1.222
# n=5, rep=13: computing p-values...
# n=5, rep=13 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=5, rep=14: loading data...
# n=5, rep=14: computing statistics...
# n=5, rep=14: fitting Gauss-Legendre parametric prior...
#  12.052825 seconds (302.18 M allocations: 5.274 GiB, 1.86% gc time)
# n=5, rep=14: prior fit done. σ0²=1.9511, ν0=1.316
# n=5, rep=14: computing p-values...
# n=5, rep=14 done → Power=0.0 | FDR=0.0 | TP@100=67
# n=5, rep=15: loading data...
# n=5, rep=15: computing statistics...
# n=5, rep=15: fitting Gauss-Legendre parametric prior...
#  11.515914 seconds (287.31 M allocations: 5.015 GiB, 1.86% gc time)
# n=5, rep=15: prior fit done. σ0²=1.8826, ν0=1.28
# n=5, rep=15: computing p-values...
# n=5, rep=15 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=5, rep=16: loading data...
# n=5, rep=16: computing statistics...
# n=5, rep=16: fitting Gauss-Legendre parametric prior...
#  12.246182 seconds (305.64 M allocations: 5.334 GiB, 1.84% gc time)
# n=5, rep=16: prior fit done. σ0²=1.962, ν0=1.217
# n=5, rep=16: computing p-values...
# n=5, rep=16 done → Power=0.01 | FDR=0.0 | TP@100=63
# n=5, rep=17: loading data...
# n=5, rep=17: computing statistics...
# n=5, rep=17: fitting Gauss-Legendre parametric prior...
#  12.957930 seconds (324.18 M allocations: 5.658 GiB, 1.84% gc time)
# n=5, rep=17: prior fit done. σ0²=1.8977, ν0=1.179
# n=5, rep=17: computing p-values...
# n=5, rep=17 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=5, rep=18: loading data...
# n=5, rep=18: computing statistics...
# n=5, rep=18: fitting Gauss-Legendre parametric prior...
#  12.799619 seconds (320.62 M allocations: 5.596 GiB, 1.89% gc time)
# n=5, rep=18: prior fit done. σ0²=2.0946, ν0=1.288
# n=5, rep=18: computing p-values...
# n=5, rep=18 done → Power=0.0 | FDR=0.0 | TP@100=57
# n=5, rep=19: loading data...
# n=5, rep=19: computing statistics...
# n=5, rep=19: fitting Gauss-Legendre parametric prior...
#  12.096302 seconds (302.21 M allocations: 5.275 GiB, 1.85% gc time)
# n=5, rep=19: prior fit done. σ0²=1.7511, ν0=1.219
# n=5, rep=19: computing p-values...
# n=5, rep=19 done → Power=0.0 | FDR=0.0 | TP@100=57
# n=5, rep=20: loading data...
# n=5, rep=20: computing statistics...
# n=5, rep=20: fitting Gauss-Legendre parametric prior...
#  13.883657 seconds (346.82 M allocations: 6.053 GiB, 1.84% gc time)
# n=5, rep=20: prior fit done. σ0²=2.0437, ν0=1.314
# n=5, rep=20: computing p-values...
# n=5, rep=20 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=5, rep=21: loading data...
# n=5, rep=21: computing statistics...
# n=5, rep=21: fitting Gauss-Legendre parametric prior...
#  11.924552 seconds (298.51 M allocations: 5.210 GiB, 1.87% gc time)
# n=5, rep=21: prior fit done. σ0²=1.8561, ν0=1.259
# n=5, rep=21: computing p-values...
# n=5, rep=21 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=5, rep=22: loading data...
# n=5, rep=22: computing statistics...
# n=5, rep=22: fitting Gauss-Legendre parametric prior...
#  12.041350 seconds (301.99 M allocations: 5.271 GiB, 1.87% gc time)
# n=5, rep=22: prior fit done. σ0²=1.9428, ν0=1.228
# n=5, rep=22: computing p-values...
# n=5, rep=22 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=5, rep=23: loading data...
# n=5, rep=23: computing statistics...
# n=5, rep=23: fitting Gauss-Legendre parametric prior...
#  11.488673 seconds (287.29 M allocations: 5.014 GiB, 1.87% gc time)
# n=5, rep=23: prior fit done. σ0²=2.0358, ν0=1.334
# n=5, rep=23: computing p-values...
# n=5, rep=23 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=5, rep=24: loading data...
# n=5, rep=24: computing statistics...
# n=5, rep=24: fitting Gauss-Legendre parametric prior...
#  11.301787 seconds (283.12 M allocations: 4.941 GiB, 1.89% gc time)
# n=5, rep=24: prior fit done. σ0²=1.8579, ν0=1.183
# n=5, rep=24: computing p-values...
# n=5, rep=24 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=5, rep=25: loading data...
# n=5, rep=25: computing statistics...
# n=5, rep=25: fitting Gauss-Legendre parametric prior...
#  12.647043 seconds (316.91 M allocations: 5.531 GiB, 1.86% gc time)
# n=5, rep=25: prior fit done. σ0²=1.9701, ν0=1.249
# n=5, rep=25: computing p-values...
# n=5, rep=25 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=5, rep=26: loading data...
# n=5, rep=26: computing statistics...
# n=5, rep=26: fitting Gauss-Legendre parametric prior...
#  12.080918 seconds (301.97 M allocations: 5.270 GiB, 1.89% gc time)
# n=5, rep=26: prior fit done. σ0²=2.0123, ν0=1.227
# n=5, rep=26: computing p-values...
# n=5, rep=26 done → Power=0.0 | FDR=0.0 | TP@100=69
# n=5, rep=27: loading data...
# n=5, rep=27: computing statistics...
# n=5, rep=27: fitting Gauss-Legendre parametric prior...
#  11.908414 seconds (298.52 M allocations: 5.210 GiB, 1.88% gc time)
# n=5, rep=27: prior fit done. σ0²=1.7549, ν0=1.225
# n=5, rep=27: computing p-values...
# n=5, rep=27 done → Power=0.0 | FDR=0.0 | TP@100=68
# n=5, rep=28: loading data...
# n=5, rep=28: computing statistics...
# n=5, rep=28: fitting Gauss-Legendre parametric prior...
#  12.497484 seconds (313.00 M allocations: 5.463 GiB, 1.88% gc time)
# n=5, rep=28: prior fit done. σ0²=1.8632, ν0=1.204
# n=5, rep=28: computing p-values...
# n=5, rep=28 done → Power=0.0 | FDR=0.0 | TP@100=72
# n=5, rep=29: loading data...
# n=5, rep=29: computing statistics...
# n=5, rep=29: fitting Gauss-Legendre parametric prior...
#  13.858461 seconds (346.45 M allocations: 6.046 GiB, 1.87% gc time)
# n=5, rep=29: prior fit done. σ0²=2.0668, ν0=1.257
# n=5, rep=29: computing p-values...
# n=5, rep=29 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=5, rep=30: loading data...
# n=5, rep=30: computing statistics...
# n=5, rep=30: fitting Gauss-Legendre parametric prior...
#  12.214914 seconds (305.95 M allocations: 5.340 GiB, 1.88% gc time)
# n=5, rep=30: prior fit done. σ0²=2.0172, ν0=1.326
# n=5, rep=30: computing p-values...
# n=5, rep=30 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=5, rep=31: loading data...
# n=5, rep=31: computing statistics...
# n=5, rep=31: fitting Gauss-Legendre parametric prior...
#  13.237604 seconds (331.42 M allocations: 5.784 GiB, 1.90% gc time)
# n=5, rep=31: prior fit done. σ0²=1.9127, ν0=1.182
# n=5, rep=31: computing p-values...
# n=5, rep=31 done → Power=0.0 | FDR=0.0 | TP@100=62
# n=5, rep=32: loading data...
# n=5, rep=32: computing statistics...
# n=5, rep=32: fitting Gauss-Legendre parametric prior...
#  11.611550 seconds (290.71 M allocations: 5.074 GiB, 1.89% gc time)
# n=5, rep=32: prior fit done. σ0²=1.9443, ν0=1.222
# n=5, rep=32: computing p-values...
# n=5, rep=32 done → Power=0.029 | FDR=0.0 | TP@100=57
# n=5, rep=33: loading data...
# n=5, rep=33: computing statistics...
# n=5, rep=33: fitting Gauss-Legendre parametric prior...
#  12.506756 seconds (313.04 M allocations: 5.463 GiB, 1.87% gc time)
# n=5, rep=33: prior fit done. σ0²=2.0311, ν0=1.237
# n=5, rep=33: computing p-values...
# n=5, rep=33 done → Power=0.0 | FDR=0.0 | TP@100=61
# n=5, rep=34: loading data...
# n=5, rep=34: computing statistics...
# n=5, rep=34: fitting Gauss-Legendre parametric prior...
#  12.331334 seconds (309.19 M allocations: 5.396 GiB, 1.92% gc time)
# n=5, rep=34: prior fit done. σ0²=2.0681, ν0=1.259
# n=5, rep=34: computing p-values...
# n=5, rep=34 done → Power=0.0 | FDR=0.0 | TP@100=74
# n=5, rep=35: loading data...
# n=5, rep=35: computing statistics...
# n=5, rep=35: fitting Gauss-Legendre parametric prior...
#  14.575419 seconds (365.06 M allocations: 6.371 GiB, 1.87% gc time)
# n=5, rep=35: prior fit done. σ0²=2.1015, ν0=1.216
# n=5, rep=35: computing p-values...
# n=5, rep=35 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=5, rep=36: loading data...
# n=5, rep=36: computing statistics...
# n=5, rep=36: fitting Gauss-Legendre parametric prior...
#  12.519539 seconds (313.26 M allocations: 5.467 GiB, 1.89% gc time)
# n=5, rep=36: prior fit done. σ0²=1.7828, ν0=1.194
# n=5, rep=36: computing p-values...
# n=5, rep=36 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=5, rep=37: loading data...
# n=5, rep=37: computing statistics...
# n=5, rep=37: fitting Gauss-Legendre parametric prior...
#  12.189764 seconds (305.88 M allocations: 5.339 GiB, 1.89% gc time)
# n=5, rep=37: prior fit done. σ0²=1.8605, ν0=1.232
# n=5, rep=37: computing p-values...
# n=5, rep=37 done → Power=0.0 | FDR=0.0 | TP@100=73
# n=5, rep=38: loading data...
# n=5, rep=38: computing statistics...
# n=5, rep=38: fitting Gauss-Legendre parametric prior...
#  11.747598 seconds (294.64 M allocations: 5.142 GiB, 1.90% gc time)
# n=5, rep=38: prior fit done. σ0²=1.9376, ν0=1.273
# n=5, rep=38: computing p-values...
# n=5, rep=38 done → Power=0.0 | FDR=0.0 | TP@100=71
# n=5, rep=39: loading data...
# n=5, rep=39: computing statistics...
# n=5, rep=39: fitting Gauss-Legendre parametric prior...
#  11.919169 seconds (298.39 M allocations: 5.208 GiB, 1.90% gc time)
# n=5, rep=39: prior fit done. σ0²=1.9028, ν0=1.245
# n=5, rep=39: computing p-values...
# n=5, rep=39 done → Power=0.0 | FDR=0.0 | TP@100=70
# n=5, rep=40: loading data...
# n=5, rep=40: computing statistics...
# n=5, rep=40: fitting Gauss-Legendre parametric prior...
#  14.262765 seconds (357.64 M allocations: 6.242 GiB, 1.87% gc time)
# n=5, rep=40: prior fit done. σ0²=2.0669, ν0=1.225
# n=5, rep=40: computing p-values...
# n=5, rep=40 done → Power=0.0 | FDR=0.0 | TP@100=66
# n=5, rep=41: loading data...
# n=5, rep=41: computing statistics...
# n=5, rep=41: fitting Gauss-Legendre parametric prior...
#  11.457301 seconds (287.04 M allocations: 5.010 GiB, 1.89% gc time)
# n=5, rep=41: prior fit done. σ0²=1.891, ν0=1.208
# n=5, rep=41: computing p-values...
# n=5, rep=41 done → Power=0.0 | FDR=0.0 | TP@100=65
# n=5, rep=42: loading data...
# n=5, rep=42: computing statistics...
# n=5, rep=42: fitting Gauss-Legendre parametric prior...
#  12.793359 seconds (320.43 M allocations: 5.592 GiB, 1.90% gc time)
# n=5, rep=42: prior fit done. σ0²=1.9265, ν0=1.203
# n=5, rep=42: computing p-values...
# n=5, rep=42 done → Power=0.01 | FDR=0.0 | TP@100=62
# n=5, rep=43: loading data...
# n=5, rep=43: computing statistics...
# n=5, rep=43: fitting Gauss-Legendre parametric prior...
#  12.358575 seconds (309.42 M allocations: 5.400 GiB, 1.89% gc time)
# n=5, rep=43: prior fit done. σ0²=1.8915, ν0=1.236
# n=5, rep=43: computing p-values...
# n=5, rep=43 done → Power=0.0 | FDR=0.0 | TP@100=56
# n=5, rep=44: loading data...
# n=5, rep=44: computing statistics...
# n=5, rep=44: fitting Gauss-Legendre parametric prior...
#  12.226987 seconds (305.86 M allocations: 5.338 GiB, 1.91% gc time)
# n=5, rep=44: prior fit done. σ0²=1.7941, ν0=1.238
# n=5, rep=44: computing p-values...
# n=5, rep=44 done → Power=0.0 | FDR=0.0 | TP@100=60
# n=5, rep=45: loading data...
# n=5, rep=45: computing statistics...
# n=5, rep=45: fitting Gauss-Legendre parametric prior...
#  12.635050 seconds (316.67 M allocations: 5.527 GiB, 1.89% gc time)
# n=5, rep=45: prior fit done. σ0²=2.1018, ν0=1.235
# n=5, rep=45: computing p-values...
# n=5, rep=45 done → Power=0.0 | FDR=0.0 | TP@100=63
# n=5, rep=46: loading data...
# n=5, rep=46: computing statistics...
# n=5, rep=46: fitting Gauss-Legendre parametric prior...
#  12.364565 seconds (309.16 M allocations: 5.396 GiB, 1.88% gc time)
# n=5, rep=46: prior fit done. σ0²=2.2131, ν0=1.272
# n=5, rep=46: computing p-values...
# n=5, rep=46 done → Power=0.0 | FDR=0.0 | TP@100=64
# n=5, rep=47: loading data...
# n=5, rep=47: computing statistics...
# n=5, rep=47: fitting Gauss-Legendre parametric prior...
#  11.753446 seconds (294.61 M allocations: 5.142 GiB, 1.90% gc time)
# n=5, rep=47: prior fit done. σ0²=1.8143, ν0=1.231
# ...
# 175.062147 seconds (2.35 G allocations: 37.615 GiB, 1.09% gc time)
# n=40, rep=53: prior fit done. σ0²=4.2433, ν0=2.835
# n=40, rep=53: computing p-values...
# n=40, rep=53 done → Power=0.24 | FDR=0.143 | TP@100=41
# n=40, rep=54: loading data...
# n=40, rep=54: computing statistics...
# n=40, rep=54: fitting Gauss-Legendre parametric prior...
# 179.367753 seconds (2.38 G allocations: 38.112 GiB, 1.08% gc time)
# n=40, rep=54: prior fit done. σ0²=4.2726, ν0=2.963
# n=40, rep=54: computing p-values...
# n=40, rep=54 done → Power=0.162 | FDR=0.0 | TP@100=39
# n=40, rep=55: loading data...
# n=40, rep=55: computing statistics...
# n=40, rep=55: fitting Gauss-Legendre parametric prior...
# 181.791074 seconds (2.34 G allocations: 37.550 GiB, 1.09% gc time)
# n=40, rep=55: prior fit done. σ0²=4.2034, ν0=2.699
# n=40, rep=55: computing p-values...
# n=40, rep=55 done → Power=0.208 | FDR=0.2 | TP@100=33
# n=40, rep=56: loading data...
# n=40, rep=56: computing statistics...
# n=40, rep=56: fitting Gauss-Legendre parametric prior...
# 174.575834 seconds (2.25 G allocations: 36.109 GiB, 1.08% gc time)
# n=40, rep=56: prior fit done. σ0²=4.5114, ν0=2.816
# n=40, rep=56: computing p-values...
# n=40, rep=56 done → Power=0.186 | FDR=0.059 | TP@100=32
# n=40, rep=57: loading data...
# n=40, rep=57: computing statistics...
# n=40, rep=57: fitting Gauss-Legendre parametric prior...
# 177.738680 seconds (2.37 G allocations: 37.902 GiB, 1.08% gc time)
# n=40, rep=57: prior fit done. σ0²=4.3138, ν0=2.604
# n=40, rep=57: computing p-values...
# n=40, rep=57 done → Power=0.052 | FDR=0.0 | TP@100=33
# n=40, rep=58: loading data...
# n=40, rep=58: computing statistics...
# n=40, rep=58: fitting Gauss-Legendre parametric prior...
# 173.787248 seconds (2.31 G allocations: 37.067 GiB, 1.09% gc time)
# n=40, rep=58: prior fit done. σ0²=4.2009, ν0=2.638
# n=40, rep=58: computing p-values...
# n=40, rep=58 done → Power=0.075 | FDR=0.0 | TP@100=35
# n=40, rep=59: loading data...
# n=40, rep=59: computing statistics...
# n=40, rep=59: fitting Gauss-Legendre parametric prior...
# 166.223219 seconds (2.26 G allocations: 36.199 GiB, 1.07% gc time)
# n=40, rep=59: prior fit done. σ0²=4.1534, ν0=2.708
# n=40, rep=59: computing p-values...
# n=40, rep=59 done → Power=0.101 | FDR=0.0 | TP@100=33
# n=40, rep=60: loading data...
# n=40, rep=60: computing statistics...
# n=40, rep=60: fitting Gauss-Legendre parametric prior...
# 157.119964 seconds (2.15 G allocations: 34.433 GiB, 1.07% gc time)
# n=40, rep=60: prior fit done. σ0²=4.1107, ν0=2.796
# n=40, rep=60: computing p-values...
# n=40, rep=60 done → Power=0.111 | FDR=0.0 | TP@100=36
# n=40, rep=61: loading data...
# n=40, rep=61: computing statistics...
# n=40, rep=61: fitting Gauss-Legendre parametric prior...
# 164.983764 seconds (2.26 G allocations: 36.260 GiB, 1.08% gc time)
# n=40, rep=61: prior fit done. σ0²=4.2277, ν0=2.868
# n=40, rep=61: computing p-values...
# n=40, rep=61 done → Power=0.156 | FDR=0.056 | TP@100=36
# n=40, rep=62: loading data...
# n=40, rep=62: computing statistics...
# n=40, rep=62: fitting Gauss-Legendre parametric prior...
# 155.292192 seconds (2.14 G allocations: 34.331 GiB, 1.08% gc time)
# n=40, rep=62: prior fit done. σ0²=4.4313, ν0=2.844
# n=40, rep=62: computing p-values...
# n=40, rep=62 done → Power=0.059 | FDR=0.0 | TP@100=32
# n=40, rep=63: loading data...
# n=40, rep=63: computing statistics...
# n=40, rep=63: fitting Gauss-Legendre parametric prior...
# 150.568101 seconds (2.08 G allocations: 33.339 GiB, 1.09% gc time)
# n=40, rep=63: prior fit done. σ0²=4.1022, ν0=2.46
# n=40, rep=63: computing p-values...
# n=40, rep=63 done → Power=0.102 | FDR=0.0 | TP@100=30
# n=40, rep=64: loading data...
# n=40, rep=64: computing statistics...
# n=40, rep=64: fitting Gauss-Legendre parametric prior...
# 165.914650 seconds (2.29 G allocations: 36.674 GiB, 1.08% gc time)
# n=40, rep=64: prior fit done. σ0²=4.2772, ν0=2.828
# n=40, rep=64: computing p-values...
# n=40, rep=64 done → Power=0.255 | FDR=0.067 | TP@100=45
# n=40, rep=65: loading data...
# n=40, rep=65: computing statistics...
# n=40, rep=65: fitting Gauss-Legendre parametric prior...
# 167.341386 seconds (2.31 G allocations: 37.063 GiB, 1.08% gc time)
# n=40, rep=65: prior fit done. σ0²=4.1789, ν0=2.633
# n=40, rep=65: computing p-values...
# n=40, rep=65 done → Power=0.147 | FDR=0.067 | TP@100=32
# n=40, rep=66: loading data...
# n=40, rep=66: computing statistics...
# n=40, rep=66: fitting Gauss-Legendre parametric prior...
# 161.822496 seconds (2.25 G allocations: 36.039 GiB, 1.09% gc time)
# n=40, rep=66: prior fit done. σ0²=4.562, ν0=2.727
# n=40, rep=66: computing p-values...
# n=40, rep=66 done → Power=0.088 | FDR=0.0 | TP@100=35
# n=40, rep=67: loading data...
# n=40, rep=67: computing statistics...
# n=40, rep=67: fitting Gauss-Legendre parametric prior...
# 157.393513 seconds (2.17 G allocations: 34.822 GiB, 1.08% gc time)
# n=40, rep=67: prior fit done. σ0²=4.0304, ν0=2.579
# n=40, rep=67: computing p-values...
# n=40, rep=67 done → Power=0.121 | FDR=0.083 | TP@100=31
# n=40, rep=68: loading data...
# n=40, rep=68: computing statistics...
# n=40, rep=68: fitting Gauss-Legendre parametric prior...
# 153.327253 seconds (2.12 G allocations: 33.932 GiB, 1.08% gc time)
# n=40, rep=68: prior fit done. σ0²=4.2134, ν0=2.79
# n=40, rep=68: computing p-values...
# n=40, rep=68 done → Power=0.101 | FDR=0.0 | TP@100=35
# n=40, rep=69: loading data...
# n=40, rep=69: computing statistics...
# n=40, rep=69: fitting Gauss-Legendre parametric prior...
# 166.801259 seconds (2.31 G allocations: 37.021 GiB, 1.09% gc time)
# n=40, rep=69: prior fit done. σ0²=4.2168, ν0=2.588
# n=40, rep=69: computing p-values...
# n=40, rep=69 done → Power=0.172 | FDR=0.0 | TP@100=41
# n=40, rep=70: loading data...
# n=40, rep=70: computing statistics...
# n=40, rep=70: fitting Gauss-Legendre parametric prior...
# 165.068149 seconds (2.28 G allocations: 36.615 GiB, 1.09% gc time)
# n=40, rep=70: prior fit done. σ0²=4.2333, ν0=2.677
# n=40, rep=70: computing p-values...
# n=40, rep=70 done → Power=0.138 | FDR=0.211 | TP@100=40
# n=40, rep=71: loading data...
# n=40, rep=71: computing statistics...
# n=40, rep=71: fitting Gauss-Legendre parametric prior...
# 154.223473 seconds (2.12 G allocations: 34.018 GiB, 1.08% gc time)
# n=40, rep=71: prior fit done. σ0²=4.1034, ν0=2.902
# n=40, rep=71: computing p-values...
# n=40, rep=71 done → Power=0.188 | FDR=0.053 | TP@100=42
# n=40, rep=72: loading data...
# n=40, rep=72: computing statistics...
# n=40, rep=72: fitting Gauss-Legendre parametric prior...
# 161.613839 seconds (2.23 G allocations: 35.764 GiB, 1.08% gc time)
# n=40, rep=72: prior fit done. σ0²=4.1922, ν0=2.783
# n=40, rep=72: computing p-values...
# n=40, rep=72 done → Power=0.086 | FDR=0.0 | TP@100=42
# n=40, rep=73: loading data...
# n=40, rep=73: computing statistics...
# n=40, rep=73: fitting Gauss-Legendre parametric prior...
# 167.035850 seconds (2.31 G allocations: 37.055 GiB, 1.09% gc time)
# n=40, rep=73: prior fit done. σ0²=4.2612, ν0=2.651
# n=40, rep=73: computing p-values...
# n=40, rep=73 done → Power=0.09 | FDR=0.1 | TP@100=38
# n=40, rep=74: loading data...
# n=40, rep=74: computing statistics...
# n=40, rep=74: fitting Gauss-Legendre parametric prior...
# 165.049362 seconds (2.28 G allocations: 36.620 GiB, 1.09% gc time)
# n=40, rep=74: prior fit done. σ0²=4.3579, ν0=2.787
# n=40, rep=74: computing p-values...
# n=40, rep=74 done → Power=0.106 | FDR=0.0 | TP@100=34
# n=40, rep=75: loading data...
# n=40, rep=75: computing statistics...
# n=40, rep=75: fitting Gauss-Legendre parametric prior...
# 164.802067 seconds (2.28 G allocations: 36.598 GiB, 1.09% gc time)
# n=40, rep=75: prior fit done. σ0²=4.3734, ν0=2.77
# n=40, rep=75: computing p-values...
# n=40, rep=75 done → Power=0.108 | FDR=0.091 | TP@100=38
# n=40, rep=76: loading data...
# n=40, rep=76: computing statistics...
# n=40, rep=76: fitting Gauss-Legendre parametric prior...
# 166.498512 seconds (2.31 G allocations: 37.017 GiB, 1.09% gc time)
# n=40, rep=76: prior fit done. σ0²=4.3333, ν0=2.658
# n=40, rep=76: computing p-values...
# n=40, rep=76 done → Power=0.152 | FDR=0.0 | TP@100=42
# n=40, rep=77: loading data...
# n=40, rep=77: computing statistics...
# n=40, rep=77: fitting Gauss-Legendre parametric prior...
# 165.347010 seconds (2.29 G allocations: 36.645 GiB, 1.09% gc time)
# n=40, rep=77: prior fit done. σ0²=4.2922, ν0=2.799
# n=40, rep=77: computing p-values...
# n=40, rep=77 done → Power=0.17 | FDR=0.19 | TP@100=38
# n=40, rep=78: loading data...
# n=40, rep=78: computing statistics...
# n=40, rep=78: fitting Gauss-Legendre parametric prior...
# 171.352830 seconds (2.37 G allocations: 38.011 GiB, 1.09% gc time)
# n=40, rep=78: prior fit done. σ0²=4.241, ν0=2.688
# n=40, rep=78: computing p-values...
# n=40, rep=78 done → Power=0.162 | FDR=0.111 | TP@100=33
# n=40, rep=79: loading data...
# n=40, rep=79: computing statistics...
# n=40, rep=79: fitting Gauss-Legendre parametric prior...
# 170.166320 seconds (2.35 G allocations: 37.639 GiB, 1.08% gc time)
# n=40, rep=79: prior fit done. σ0²=4.1183, ν0=2.763
# n=40, rep=79: computing p-values...
# n=40, rep=79 done → Power=0.141 | FDR=0.125 | TP@100=43
# n=40, rep=80: loading data...
# n=40, rep=80: computing statistics...
# n=40, rep=80: fitting Gauss-Legendre parametric prior...
# 169.731225 seconds (2.36 G allocations: 37.841 GiB, 1.09% gc time)
# n=40, rep=80: prior fit done. σ0²=4.4765, ν0=2.627
# n=40, rep=80: computing p-values...
# n=40, rep=80 done → Power=0.052 | FDR=0.0 | TP@100=36
# n=40, rep=81: loading data...
# n=40, rep=81: computing statistics...
# n=40, rep=81: fitting Gauss-Legendre parametric prior...
# 162.322272 seconds (2.25 G allocations: 36.089 GiB, 1.09% gc time)
# n=40, rep=81: prior fit done. σ0²=4.28, ν0=2.611
# n=40, rep=81: computing p-values...
# n=40, rep=81 done → Power=0.127 | FDR=0.067 | TP@100=42
# n=40, rep=82: loading data...
# n=40, rep=82: computing statistics...
# n=40, rep=82: fitting Gauss-Legendre parametric prior...
# 164.041463 seconds (2.28 G allocations: 36.522 GiB, 1.09% gc time)
# n=40, rep=82: prior fit done. σ0²=4.3806, ν0=2.638
# n=40, rep=82: computing p-values...
# n=40, rep=82 done → Power=0.138 | FDR=0.0 | TP@100=23
# n=40, rep=83: loading data...
# n=40, rep=83: computing statistics...
# n=40, rep=83: fitting Gauss-Legendre parametric prior...
# 172.841037 seconds (2.40 G allocations: 38.424 GiB, 1.09% gc time)
# n=40, rep=83: prior fit done. σ0²=4.452, ν0=2.822
# n=40, rep=83: computing p-values...
# n=40, rep=83 done → Power=0.297 | FDR=0.108 | TP@100=50
# n=40, rep=84: loading data...
# n=40, rep=84: computing statistics...
# n=40, rep=84: fitting Gauss-Legendre parametric prior...
# 165.856075 seconds (2.29 G allocations: 36.705 GiB, 1.08% gc time)
# n=40, rep=84: prior fit done. σ0²=4.2124, ν0=2.855
# n=40, rep=84: computing p-values...
# n=40, rep=84 done → Power=0.069 | FDR=0.0 | TP@100=34
# n=40, rep=85: loading data...
# n=40, rep=85: computing statistics...
# n=40, rep=85: fitting Gauss-Legendre parametric prior...
# 161.511604 seconds (2.25 G allocations: 36.025 GiB, 1.09% gc time)
# n=40, rep=85: prior fit done. σ0²=4.5227, ν0=2.654
# n=40, rep=85: computing p-values...
# n=40, rep=85 done → Power=0.094 | FDR=0.182 | TP@100=31
# n=40, rep=86: loading data...
# n=40, rep=86: computing statistics...
# n=40, rep=86: fitting Gauss-Legendre parametric prior...
# 165.803959 seconds (2.29 G allocations: 36.684 GiB, 1.08% gc time)
# n=40, rep=86: prior fit done. σ0²=4.0315, ν0=2.633
# n=40, rep=86: computing p-values...
# n=40, rep=86 done → Power=0.152 | FDR=0.292 | TP@100=35
# n=40, rep=87: loading data...
# n=40, rep=87: computing statistics...
# n=40, rep=87: fitting Gauss-Legendre parametric prior...
# 171.916427 seconds (2.38 G allocations: 38.090 GiB, 1.08% gc time)
# n=40, rep=87: prior fit done. σ0²=4.3986, ν0=3.02
# n=40, rep=87: computing p-values...
# n=40, rep=87 done → Power=0.14 | FDR=0.125 | TP@100=39
# n=40, rep=88: loading data...
# n=40, rep=88: computing statistics...
# n=40, rep=88: fitting Gauss-Legendre parametric prior...
# 165.012264 seconds (2.29 G allocations: 36.623 GiB, 1.09% gc time)
# n=40, rep=88: prior fit done. σ0²=4.3088, ν0=2.755
# n=40, rep=88: computing p-values...
# n=40, rep=88 done → Power=0.135 | FDR=0.071 | TP@100=32
# n=40, rep=89: loading data...
# n=40, rep=89: computing statistics...
# n=40, rep=89: fitting Gauss-Legendre parametric prior...
# 166.943177 seconds (2.31 G allocations: 37.079 GiB, 1.09% gc time)
# n=40, rep=89: prior fit done. σ0²=4.4043, ν0=2.833
# n=40, rep=89: computing p-values...
# n=40, rep=89 done → Power=0.109 | FDR=0.0 | TP@100=44
# n=40, rep=90: loading data...
# n=40, rep=90: computing statistics...
# n=40, rep=90: fitting Gauss-Legendre parametric prior...
# 164.944384 seconds (2.29 G allocations: 36.629 GiB, 1.09% gc time)
# n=40, rep=90: prior fit done. σ0²=4.3194, ν0=2.731
# n=40, rep=90: computing p-values...
# n=40, rep=90 done → Power=0.04 | FDR=0.0 | TP@100=34
# n=40, rep=91: loading data...
# n=40, rep=91: computing statistics...
# n=40, rep=91: fitting Gauss-Legendre parametric prior...
# 159.705208 seconds (2.20 G allocations: 35.340 GiB, 1.09% gc time)
# n=40, rep=91: prior fit done. σ0²=4.2505, ν0=2.882
# n=40, rep=91: computing p-values...
# n=40, rep=91 done → Power=0.1 | FDR=0.091 | TP@100=39
# n=40, rep=92: loading data...
# n=40, rep=92: computing statistics...
# n=40, rep=92: fitting Gauss-Legendre parametric prior...
# 159.916098 seconds (2.22 G allocations: 35.576 GiB, 1.10% gc time)
# n=40, rep=92: prior fit done. σ0²=4.3271, ν0=2.516
# n=40, rep=92: computing p-values...
# n=40, rep=92 done → Power=0.103 | FDR=0.0 | TP@100=44
# n=40, rep=93: loading data...
# n=40, rep=93: computing statistics...
# n=40, rep=93: fitting Gauss-Legendre parametric prior...
# 167.809407 seconds (2.29 G allocations: 36.642 GiB, 1.10% gc time)
# n=40, rep=93: prior fit done. σ0²=4.1933, ν0=2.698
# n=40, rep=93: computing p-values...
# n=40, rep=93 done → Power=0.152 | FDR=0.0 | TP@100=45
# n=40, rep=94: loading data...
# n=40, rep=94: computing statistics...
# n=40, rep=94: fitting Gauss-Legendre parametric prior...
# 177.552829 seconds (2.37 G allocations: 37.993 GiB, 1.09% gc time)
# n=40, rep=94: prior fit done. σ0²=4.053, ν0=2.558
# n=40, rep=94: computing p-values...
# n=40, rep=94 done → Power=0.159 | FDR=0.0 | TP@100=42
# n=40, rep=95: loading data...
# n=40, rep=95: computing statistics...
# n=40, rep=95: fitting Gauss-Legendre parametric prior...
# 173.351005 seconds (2.37 G allocations: 37.983 GiB, 1.11% gc time)
# n=40, rep=95: prior fit done. σ0²=4.0952, ν0=2.571
# n=40, rep=95: computing p-values...
# n=40, rep=95 done → Power=0.14 | FDR=0.211 | TP@100=44
# n=40, rep=96: loading data...
# n=40, rep=96: computing statistics...
# n=40, rep=96: fitting Gauss-Legendre parametric prior...
# 168.734439 seconds (2.31 G allocations: 37.090 GiB, 1.09% gc time)
# n=40, rep=96: prior fit done. σ0²=4.4005, ν0=2.838
# n=40, rep=96: computing p-values...
# n=40, rep=96 done → Power=0.09 | FDR=0.0 | TP@100=31
# n=40, rep=97: loading data...
# n=40, rep=97: computing statistics...
# n=40, rep=97: fitting Gauss-Legendre parametric prior...
# 168.321919 seconds (2.29 G allocations: 36.654 GiB, 1.10% gc time)
# n=40, rep=97: prior fit done. σ0²=4.1619, ν0=2.685
# n=40, rep=97: computing p-values...
# n=40, rep=97 done → Power=0.063 | FDR=0.167 | TP@100=26
# n=40, rep=98: loading data...
# n=40, rep=98: computing statistics...
# n=40, rep=98: fitting Gauss-Legendre parametric prior...
# 174.609228 seconds (2.34 G allocations: 37.455 GiB, 1.11% gc time)
# n=40, rep=98: prior fit done. σ0²=4.443, ν0=2.716
# n=40, rep=98: computing p-values...
# n=40, rep=98 done → Power=0.06 | FDR=0.0 | TP@100=31
# n=40, rep=99: loading data...
# n=40, rep=99: computing statistics...
# n=40, rep=99: fitting Gauss-Legendre parametric prior...
# 163.916521 seconds (2.23 G allocations: 35.732 GiB, 1.11% gc time)
# n=40, rep=99: prior fit done. σ0²=4.3267, ν0=2.805
# n=40, rep=99: computing p-values...
# n=40, rep=99 done → Power=0.128 | FDR=0.083 | TP@100=31
# n=40, rep=100: loading data...
# n=40, rep=100: computing statistics...
# n=40, rep=100: fitting Gauss-Legendre parametric prior...
# 165.296371 seconds (2.23 G allocations: 35.734 GiB, 1.10% gc time)
# n=40, rep=100: prior fit done. σ0²=4.235, ν0=2.746
# n=40, rep=100: computing p-values...
# n=40, rep=100 done → Power=0.168 | FDR=0.0 | TP@100=32
# ✅ Done n=40 → Power=0.135 | FDR=0.076 | TP=13.5 | FP=1.5 | TP@100=37.0

# %%
mad_param_gl_summary
# Out:
# Dict{String, Vector} with 6 entries:
#   "TP"        => [0.04, 0.15, 0.3, 1.67, 2.25, 6.48, 10.26, 13.5]
#   "FDR"       => [0.0, 0.0, 0.0, 0.000833333, 0.0, 0.00258824, 0.0128471, 0.075…
#   "TP_top100" => [64.34, 63.7, 62.52, 60.65, 57.85, 46.97, 39.8, 37.01]
#   "Power"     => [0.000395494, 0.00149544, 0.00306996, 0.0167092, 0.0223878, 0.…
#   "FP"        => [0.0, 0.0, 0.0, 0.01, 0.0, 0.02, 0.22, 1.47]
#   "n"         => [4, 5, 6, 8, 10, 20, 30, 40]

# %% [markdown]
# ## MAD Np

# %%
using Distributions, ApproxFun, SpecialFunctions, QuadGK

# ---- distribution type ----
struct MADDistribution{T<:Real,S<:Integer} <: ContinuousUnivariateDistribution
    σ::T
    n::S
end

# ---- import functions we will EXTEND from Distributions ----
import Distributions: pdf, logpdf, insupport, minimum, maximum

# ---- your helpers (unchanged) ----
function G_recursive(max_r::Int; a=0.0, b=100)
    d = Interval(a, b)
    G = Vector{Fun}(undef, max_r+1)
    G[1] = Fun(x -> 1.0, d)
    for r in 1:max_r
        integrand = Fun(x -> exp(-(x^2)/(2r*(r+1))), d) * G[r]
        G[r+1] = cumsum(integrand)
    end
    return G
end

const _Gcache = Dict{Int,Vector{Fun}}()
_getG(n) = get!(_Gcache, n) do; G_recursive(n) end

function _pdf_sigma1(n::Int, m::Real)
    m < 0 && return zero(float(m))          # support m ≥ 0
    z   = n*m/2
    cst = n^(3/2) / (2^((n+1)/2) * π^((n-1)/2))
    G   = _getG(n)
    s   = 0.0
    @inbounds for k in 1:(n-1)
        s += binomial(n,k) * exp(-(m^2 * n^3)/(8k*(n-k))) * G[k](z) * G[n-k](z)
    end
    return cst*s
end

# ---- extend Distributions API ----
# support (MAD ≥ 0)
insupport(::MADDistribution, x::Real) = x ≥ 0
minimum(::MADDistribution) = 0.0
maximum(::MADDistribution) = Inf

# pdf / logpdf (general σ via scaling)
pdf(d::MADDistribution, m::Real) =
    m < 0 ? 0.0 : (1 / d.σ) * _pdf_sigma1(d.n, m / d.σ)

# logpdf(d::MADDistribution, m::Real) =
#     m < 0 ? -Inf : log(pdf(d, m))


# optional convenience
Base.:*(d::MADDistribution, s::Real) = MADDistribution(d.σ * s, d.n)
Base.:*(s::Real, d::MADDistribution) = d * s

using StatsFuns: logsumexp  # you may need to `Pkg.add("StatsFuns")`

function logpdf(d::MADDistribution, m::Real)
    m < 0 && return -Inf
    σ, n = d.σ, d.n

    # Constants
    z   = n * m / (2σ)
    logC = (3/2)*log(n) - ((n+1)/2)*log(2) - ((n-1)/2)*log(π)
    G = _getG(n)

    # Compute all log-terms (inside the sum)
    logs = Float64[]
    for k in 1:(n-1)
        val1 = G[k](z)
        val2 = G[n-k](z)
        if val1 > 0 && val2 > 0
            logterm = log(binomial(n,k)) -
                      (m^2 * n^3)/(8σ^2 * k*(n-k)) +
                      log(val1) + log(val2)
            push!(logs, logterm)
        end
    end

    # Combine safely
    logsum = isempty(logs) ? -Inf : logsumexp(logs)
    return -log(σ) + logC + logsum
end

using Empirikos, Distributions

# 1) evidence type — must subtype EBayesSample
struct MADSample{T,S} <: Empirikos.EBayesSample{T}
    Z::T   # observed MAD
    n::S   # sample size
end

# 2) likelihood at a given σ (must return a Distributions.jl object)
Empirikos.likelihood_distribution(Z::MADSample, σ) = MADDistribution(σ, Z.n)
# Ensure MADDistribution(σ, n) implements pdf/logpdf

# 3) components() for convex prior machinery (vector of likelihoods over σ-support)
Empirikos.components(convexclass::Empirikos.DiscretePriorClass, Z::MADSample) =
    Empirikos.likelihood_distribution.(Ref(Z), Empirikos.support(convexclass))



# limma-style p-value averaged over the posterior on σ
function Empirikos.limma_pvalue(β̂, Z::MADSample, prior::Empirikos.DiscreteNonParametric)
    post = Empirikos.posterior(Z, prior)
    # println("finish post: ")
    # print(post)

    # println(post)
    σs   = Empirikos.support(post)
    # println("finish σs")
    πs   = Empirikos.probs(post)
    # println("finish πs")
    tails = 2 .* ccdf.(Normal.(0, σs), abs(β̂))
    # println("finish tails")
    dot(tails, πs)
    # println("finish dot")
end
# Out:
# WARNING: redefinition of constant Main._Gcache. This may fail, cause incorrect answers, or produce other errors.

# %%
# =========================================================
# Storage for summary results
# =========================================================
mad_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full raw p-values for every successful replicate
mad_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level TP@100
mad_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running MAD (NP) simulation for n = $n ==========")

    tp_vals     = Float64[]
    fp_vals     = Float64[]
    power_vals  = Float64[]
    fdr_vals    = Float64[]
    top100_vals = Float64[]


    for r in 1:R

        try
            # -------------------------------------------------
            # Get simulated dataset
            # -------------------------------------------------
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ


            # -------------------------------------------------
            # Compute statistics
            # -------------------------------------------------
            β_hat = [
                mean(Y[i])
                for i in 1:G
            ]

            mad_obs = [
                mean(abs.(Y[i] .- β_hat[i]))
                for i in 1:G
            ]

            β_tilde = sqrt(n) .* β_hat


            # -------------------------------------------------
            # Fit NPMLE prior from MAD samples
            # -------------------------------------------------
            Zs_mad = [
                MADSample(mad_obs[i], n)
                for i in 1:G
            ]


            # Grid based on observed MAD values
            σ_grid_raw = sort(unique(mad_obs))

            n_grid = 200

            σ_grid = quantile(
                σ_grid_raw,
                range(0, 1; length=n_grid)
            )

            prior_class =
                Empirikos.DiscretePriorClass(σ_grid)

            npmle = Empirikos.NPMLE(
                prior_class,
                Hypatia.Optimizer
            )

            fitres = Empirikos.fit(
                npmle,
                Zs_mad
            )

            prior_hat =
                Empirikos.clean(fitres.prior)


            # -------------------------------------------------
            # Compute RAW MAD p-values
            # -------------------------------------------------
            pvals = [
                Empirikos.limma_pvalue(
                    β_tilde[i],
                    Zs_mad[i],
                    prior_hat
                )
                for i in 1:G
            ]


            # =================================================
            # SAVE RAW P-VALUES
            # =================================================
            mad_pvals_store[(n,r)] = copy(pvals)


            # -------------------------------------------------
            # BH adjustment for rejection-based analysis
            # -------------------------------------------------
            adj_p = adjust(
                pvals,
                BenjaminiHochberg()
            )

            rej = adj_p .<= 0.05


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej .& is_DE)
            FP = sum(rej .& .!is_DE)

            power =
                TP / max(sum(is_DE), 1)

            fdr =
                FP / max(sum(rej), 1)


            # =================================================
            # Ranking metric:
            # true DE genes among 100 smallest RAW p-values
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level ranking result
            mad_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            if r % 10 == 0

                println(
                    "Rep $r → " *
                    "Power=$(round(power, digits=3)) | " *
                    "FDR=$(round(fdr, digits=3)) | " *
                    "TP@100=$TP_top100"
                )

            end


        catch e

            @warn "Skipping Rep $r for n=$n due to error: $e"

            continue
        end
    end


    # =========================================================
    # Summarize for this n
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(mad_summary["n"], n)

    push!(mad_summary["TP"], mean_TP)
    push!(mad_summary["FP"], mean_FP)

    push!(mad_summary["Power"], mean_power)
    push!(mad_summary["FDR"], mean_fdr)

    push!(
        mad_summary["TP_top100"],
        mean_top100
    )


    println(
        "✅ Done n=$n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println(
    "\n========== MAD NP SUMMARY ACROSS SAMPLE SIZES =========="
)

for i in eachindex(mad_summary["n"])

    println(
        "n = $(mad_summary["n"][i]) → " *
        "TP=$(round(mad_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(mad_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running MAD (NP) simulation for n = 4 ==========
#
#  iter        p_obj        d_obj |  abs_gap    x_feas    z_feas |      tau       kap        mu | dir_res     prox  step     alpha
#     0   3.2373e-02  -2.7132e+02 | 2.20e+03  1.22e+02  2.87e+00 | 1.00e+00  1.00e+00  1.00e+00 |
#     1  -5.3131e-01  -2.7579e+02 | 2.09e+03  1.24e+02  2.91e+00 | 9.36e-01  1.02e+00  9.50e-01 | 2.5e-12  9.0e-02  co-a  5.00e-02
#     2  -1.3194e+00  -2.7812e+02 | 1.99e+03  1.25e+02  2.93e+00 | 8.84e-01  1.02e+00  9.03e-01 | 1.6e-12  1.5e-01  co-a  5.00e-02
#     3  -3.6531e+00  -2.8119e+02 | 1.79e+03  1.25e+02  2.94e+00 | 7.93e-01  1.02e+00  8.12e-01 | 6.7e-13  4.3e-01  co-a  1.00e-01
#     4  -7.6967e+00  -2.8613e+02 | 1.61e+03  1.26e+02  2.95e+00 | 7.11e-01  1.03e+00  7.31e-01 | 2.9e-12  9.4e-02  co-a  1.00e-01
#     5  -1.4458e+01  -2.9297e+02 | 1.45e+03  1.26e+02  2.95e+00 | 6.40e-01  1.03e+00  6.58e-01 | 1.2e-12  6.7e-02  co-a  1.00e-01
#     6  -2.5458e+01  -3.0385e+02 | 1.30e+03  1.26e+02  2.95e+00 | 5.76e-01  1.03e+00  5.92e-01 | 1.0e-12  6.7e-02  co-a  1.00e-01
#     7  -4.1478e+01  -3.1964e+02 | 1.17e+03  1.26e+02  2.95e+00 | 5.18e-01  1.03e+00  5.33e-01 | 3
#    17  -1.8584e+02  -2.3064e+02 | 1.92e+02  2.02e+01  5.35e-01 | 5.34e-01  1.88e-01  8.74e-02 | 1.1e-11  8.1e-01  co-a  3.00e-01
# Excessive output truncated after 524300 bytes.
#    18  -1.7217e+02  -2.1108e+02 | 1.73e+02  1.75e+01  4.64e-01

# %%
# =========================================================
# Final summary
# =========================================================
println(
    "\n========== MAD NP SUMMARY ACROSS SAMPLE SIZES =========="
)

for i in eachindex(mad_summary["n"])

    println(
        "n = $(mad_summary["n"][i]) → " *
        "TP=$(round(mad_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(mad_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== MAD NP SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=0.03, FP=0.0, Power=0.00029, FDR=0.0, TP@100=62.29
# n = 5 → TP=0.092, FP=0.0, Power=0.00094, FDR=0.0, TP@100=62.408
# n = 6 → TP=0.21, FP=0.0, Power=0.00216, FDR=0.0, TP@100=61.32
# n = 8 → TP=1.364, FP=0.02, Power=0.01356, FDR=0.0028, TP@100=59.96
# n = 10 → TP=2.306, FP=0.01, Power=0.02281, FDR=0.00146, TP@100=57.367
# n = 20 → TP=6.69, FP=0.0, Power=0.06605, FDR=0.0, TP@100=46.83
# n = 30 → TP=11.212, FP=0.434, Power=0.11253, FDR=0.02584, TP@100=39.879
# n = 40 → TP=13.636, FP=1.717, Power=0.1364, FDR=0.08458, TP@100=37.01

# %%
# =========================================================
# Store the true DE status for each dataset
# =========================================================
is_DE_store = Dict{Tuple{Int,Int}, BitVector}()

for n in n_values
    for r in 1:R
        is_DE_store[(n,r)] = BitVector(datasets[(n,r)].is_DE)
    end
end

using JLD2

# simulation_params = (
#     n_values = n_values,
#     G = G,
#     R = R,
#     p_signal = p_signal,
#     β_signal = β_signal,

#     s0_sq_true = s0_sq_true,
#     d0_true = d0_true,

#     error_dist = "Laplace Mixture Scaled",
#     eps_contam = eps_mix,
#     tau_contam = tau_mix,

#     variance_standardized = false,
# )
simulation_params = (
    n_values = n_values,
    G = G,
    R = R,
    p_signal = p_signal,
    β_signal = β_signal,

    s0_sq_true = s0_sq_true,
    d0_true = d0_true,

    error_dist = "Normal Mixture Scaled",
    eps_contam = eps_contam,
    tau_contam = tau_contam,

    variance_standardized = false,
)
# Out:
# (n_values = [4, 5, 6, 8, 10, 20, 30, 40], G = 1000, R = 100, p_signal = 0.1, β_signal = 4.0, s0_sq_true = 1.0, d0_true = 4.0, error_dist = "Normal Mixture Scaled", eps_contam = 0.15, tau_contam = 9.0, variance_standardized = false)

# %%
@save "method_pvalues(8.2).jld2" simulation_params limma_summary epb_summary mad_summary mad_param_gl_summary mad_param_gl_prior_summary mad_param_gl_prior_reps limma_pvals_store epb_pvals_store mad_pvals_store mad_param_pvals_store is_DE_store

# %%
## # eps_contam = 0.1
println("\n========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========")
for i in 1:length(limma_summary["n"])
    println("n = $(limma_summary["n"][i]) → TP=$(round(limma_summary["TP"][i], digits=3)), FP=$(round(limma_summary["FP"][i], digits=3)), Power=$(round(limma_summary["Power"][i], digits=5)), FDR=$(round(limma_summary["FDR"][i], digits=5))")
end


println("\n========== MAD_mean + parametric prior SUMMARY ==========")
for i in eachindex(mad_param_gl_summary["n"])
    println(
        "n = $(mad_param_gl_summary["n"][i]) → " *
        "TP=$(round(mad_param_gl_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_param_gl_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_param_gl_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_param_gl_summary["FDR"][i], digits=5))"
    )
end

# println("\n========== Fitted prior hyperparameters (Gauss-Legendre) ==========")
# for i in eachindex(mad_param_gl_prior_summary["n"])
#     println(
#         "n = $(mad_param_gl_prior_summary["n"][i]) → " *
#         "mean σ0² = $(round(mad_param_gl_prior_summary["sigma0_sq_mean"][i], digits=5)), " *
#         "mean ν0 = $(round(mad_param_gl_prior_summary["nu0_mean"][i], digits=5))"
#     )
# end

#--- Final summary table ---
println("\n========== SD EPB (NPMLE) SUMMARY ==========")
for i in 1:length(epb_summary["n"])
    println("n = $(epb_summary["n"][i]) → TP=$(round(epb_summary["TP"][i], digits=3)), FP=$(round(epb_summary["FP"][i], digits=3)), Power=$(round(epb_summary["Power"][i], digits=5)), FDR=$(round(epb_summary["FDR"][i], digits=5))")
end


# --- Final summary ---
println("\n========== Mean + MAD SUMMARY ==========")
for i in 1:length(mad_summary["n"])
    println("n = $(mad_summary["n"][i]) → TP=$(round(mad_summary["TP"][i], digits=3)), FP=$(round(mad_summary["FP"][i], digits=3)), Power=$(round(mad_summary["Power"][i], digits=5)), FDR=$(round(mad_summary["FDR"][i], digits=5))")
end
# Out:
# ========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=0.04, FP=0.0, Power=0.0004, FDR=0.0
# n = 5 → TP=0.16, FP=0.0, Power=0.00157, FDR=0.0
# n = 6 → TP=0.23, FP=0.0, Power=0.00237, FDR=0.0
# n = 8 → TP=0.75, FP=0.0, Power=0.00751, FDR=0.0
# n = 10 → TP=1.41, FP=0.0, Power=0.01403, FDR=0.0
# n = 20 → TP=1.42, FP=0.0, Power=0.01387, FDR=0.0
# n = 30 → TP=0.6, FP=0.0, Power=0.00589, FDR=0.0
# n = 40 → TP=0.34, FP=0.0, Power=0.00333, FDR=0.0
#
# ========== MAD_mean + parametric prior SUMMARY ==========
# n = 4 → TP=0.04, FP=0.0, Power=0.0004, FDR=0.0
# n = 5 → TP=0.15, FP=0.0, Power=0.0015, FDR=0.0
# n = 6 → TP=0.3, FP=0.0, Power=0.00307, FDR=0.0
# n = 8 → TP=1.67, FP=0.01, Power=0.01671, FDR=0.00083
# n = 10 → TP=2.25, FP=0.0, Power=0.02239, FDR=0.0
# n = 20 → TP=6.48, FP=0.02, Power=0.06394, FDR=0.00259
# n = 30 → TP=10.26, FP=0.22, Power=0.10284, FDR=0.01285
# n = 40 → TP=13.5, FP=1.47, Power=0.13467, FDR=0.07563
#
# ========== SD EPB (NPMLE) SUMMARY ==========
# n = 4 → TP=0.04, FP=0.0, Power=0.0004, FDR=0.0
# n = 5 → TP=0.13, FP=0.0, Power=0.00129, FDR=0.0
# n = 6 → TP=0.14, FP=0.0, Power=0.00146, FDR=0.0
# n = 8 → TP=1.58, FP=0.01, Power=0.01591, FDR=0.00167
# n = 10 → TP=2.697, FP=0.0, Power=0.02665, FDR=0.0
# n = 20 → TP=2.56, FP=0.0, Power=0.02509, FDR=0.0
# n = 30 → TP=1.16, FP=0.0, Power=0.0115, FDR=0.0
# n = 40 → TP=0.55, FP=0.0, Power=0.0054, FDR=0.0
#
# ========== Mean + MAD SUMMARY ==========
# n = 4 → TP=0.03, FP=0.0, Power=0.00029, FDR=0.0
# n = 5 → TP=0.092, FP=0.0, Power=0.00094, FDR=0.0
# n = 6 → TP=0.21, FP=0.0, Power=0.00216, FDR=0.0
# n = 8 → TP=1.364, FP=0.02, Power=0.01356, FDR=0.0028
# n = 10 → TP=2.306, FP=0.01, Power=0.02281, FDR=0.00146
# n = 20 → TP=6.69, FP=0.0, Power=0.06605, FDR=0.0
# n = 30 → TP=11.212, FP=0.434, Power=0.11253, FDR=0.02584
# n = 40 → TP=13.636, FP=1.717, Power=0.1364, FDR=0.08458

# %%
using Plots

# -------------------------------------------------
# 1. Build a common method dictionary
# -------------------------------------------------
method_summaries = Dict(
    "LIMMA" => limma_summary,
    "SD EPB (NP)" => epb_summary,
    "Mean + MAD (NP)" => mad_summary,
    "Mean + MAD(P)" => mad_param_gl_summary
)

# compute max FDR across all methods
max_fdr = maximum(vcat([summ["FDR"] for summ in values(method_summaries)]...))
fdr_upper = max(0.06, 1.05 * max_fdr)

# -------------------------------------------------
# 2. Power plot
# -------------------------------------------------
p_power = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power across sample sizes",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in method_summaries
    plot!(
        p_power,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle
    )
end

# -------------------------------------------------
# 3. FDR plot
# -------------------------------------------------
p_fdr = plot(
    xlabel = "Sample size n",
    ylabel = "FDR",
    title = "FDR across sample sizes",
    legend = :outerbottom,
    lw = 2,
    marker = :circle,
    ylims = (-0.01, fdr_upper)
)

for (method, summ) in method_summaries
    plot!(
        p_fdr,
        summ["n"],
        summ["FDR"];
        label = method,
        lw = 2,
        marker = :circle
    )
end

hline!(
    p_fdr,
    [0.05];
    label = "FDR = 0.05",
    lw = 2,
    ls = :dash,
    color = :black
)

# -------------------------------------------------
# 4. Show side by side
# -------------------------------------------------
plot(
    p_power,
    p_fdr;
    layout = (1, 2),
    size = (900, 450)
)

# %%
using Plots

# -------------------------------------------------
# 1. Split methods into two groups
# -------------------------------------------------
param_methods = Dict(
    "LIMMA" => limma_summary,
    "Mean + MAD(P)" => mad_param_gl_summary
)

nonparam_methods = Dict(
    "SD EPB (NP)" => epb_summary,
    "Mean + MAD (NP)" => mad_summary
)

# -------------------------------------------------
# 2. Shared colors
# -------------------------------------------------
method_colors = Dict(
    "LIMMA" => :blue,
    "SD EPB (NP)" => :blue,
    "Mean + MAD(P)" => :green,
    "Mean + MAD (NP)" => :green
)

# -------------------------------------------------
# 3. Power plot: parametric vs parametric
# -------------------------------------------------
p_power_param = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power: parametric vs parametric",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in param_methods
    plot!(
        p_power_param,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle,
        color = method_colors[method]
    )
end

# -------------------------------------------------
# 4. Power plot: nonparametric vs nonparametric
# -------------------------------------------------
p_power_nonparam = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power: nonparametric vs nonparametric",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in nonparam_methods
    plot!(
        p_power_nonparam,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle,
        color = method_colors[method]
    )
end

# -------------------------------------------------
# 5. Difference plot: Mean+MAD - SD
#    parametric: Mean+MAD(P) - LIMMA
#    nonparametric: Mean+MAD(NP) - SD EPB(NP)
# -------------------------------------------------
n_param = limma_summary["n"]
diff_param = mad_param_gl_summary["Power"] .- limma_summary["Power"]

n_nonparam = epb_summary["n"]
diff_nonparam = mad_summary["Power"] .- epb_summary["Power"]

p_diff = plot(
    xlabel = "Sample size n",
    ylabel = "Δ Power",
    title = "Difference in power (Mean+MAD - SD)",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

plot!(
    p_diff,
    n_param,
    diff_param;
    label = "Parametric: Mean + MAD(P) - LIMMA",
    lw = 2,
    marker = :circle,
    color = :green
)

plot!(
    p_diff,
    n_nonparam,
    diff_nonparam;
    label = "Nonparametric: Mean + MAD(NP) - SD EPB (NP)",
    lw = 2,
    marker = :circle,
    color = :blue
)

hline!(
    p_diff,
    [0.0];
    label = "0",
    lw = 2,
    ls = :dash,
    color = :black
)

# -------------------------------------------------
# 6. Show all three
# -------------------------------------------------
plot(
    p_power_param,
    p_power_nonparam,
    p_diff;
    layout = (1, 3),
    size = (1350, 420)
)
