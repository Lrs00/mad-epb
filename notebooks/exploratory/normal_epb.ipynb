# %% [markdown]
# ## Normal Scaled

# %%
using Distributions, Random, Statistics, MultipleTesting, Empirikos, Hypatia, LinearAlgebra
using Distributions, StatsPlots, Random

Random.seed!(105)
n_values = [4, 5, 6, 8, 10, 20, 30, 40]
G = 1000
R = 100
p_signal = 0.1
β_signal = 4.0

# parametric variance model
s0_sq_true = 1.0
d0_true    = 4.0

datasets = Dict{Tuple{Int,Int}, Any}()

for n in n_values
    for r in 1:R
        rng = MersenneTwister(10_000 + 100n + r)

        is_DE = rand(rng, G) .< p_signal

        # sigma^2 from the correct parametric prior
        σ2 = rand(rng, InverseGamma(d0_true / 2, d0_true * s0_sq_true / 2), G)
        σ  = sqrt.(σ2)

        # data generation
        Y = [
            rand(rng, Normal(is_DE[i] ? β_signal * σ[i]/ sqrt(n) : 0.0, σ[i]), n)
            for i in 1:G
        ]

        datasets[(n, r)] = (
            Y = Y,
            is_DE = is_DE,
            σ = σ,
            σ2 = σ2
        )
    end
end

# %%
datasets
# Out:
# Dict{Tuple{Int64, Int64}, Any} with 800 entries:
#   (10, 79) => (Y = [[2.83205, 0.315565, -1.8768, -0.316528, 1.1283, 1.32902, 2.…
#   (30, 68) => (Y = [[0.0165074, 0.0571174, 0.459991, -0.424326, 0.749755, 1.050…
#   (40, 28) => (Y = [[-0.313257, -1.08093, -0.529138, -0.430393, -0.616867, -0.9…
#   (10, 17) => (Y = [[-0.856933, -1.63848, -0.163199, 0.833631, -0.354057, -0.44…
#   (30, 41) => (Y = [[0.528572, -0.482191, -1.62712, 1.67789, -0.123802, 3.12464…
#   (40, 65) => (Y = [[0.0815584, -0.154493, -1.03143, 0.359565, -1.2862, -0.4722…
#   (20, 26) => (Y = [[2.18778, 1.88097, -0.65084, 1.33329, 1.16489, -0.0135252, …
#   (30, 23) => (Y = [[1.22417, 1.38679, -0.728215, -1.73403, -0.952736, 2.51345,…
#   (8, 91)  => (Y = [[0.401725, 0.433981, -0.0790698, -1.1257, 0.478835, 0.92107…
#   (10, 59) => (Y = [[0.459849, 0.851058, -0.500595, 0.131807, 0.14367, -0.14342…
#   (6, 29)  => (Y = [[2.05688, 1.0874, -0.189153, -0.522503, 1.11596, 1.25187], …
#   (6, 75)  => (Y = [[0.477434, -0.174208, 0.679352, 0.965212, 0.87455, 0.379824…
#   (4, 68)  => (Y = [[-2.5527, -0.79761, -4.03402, -3.17372], [3.9169, 2.90339, …
#   (8, 63)  => (Y = [[-0.152784, 2.09222, -0.121344, -0.185706, 2.43887, -0.7296…
#   (30, 74) => (Y = [[-0.0954385, -1.62205, -0.523062, -3.27544, -0.0777664, -1.…
#   (4, 41)  => (Y = [[0.774336, 0.739753, -0.158442, 1.34631], [-0.987998, 0.241…
#   (10, 32) => (Y = [[0.376739, 0.853327, -0.195005, 0.0259096, -0.0594457, -2.0…
#   (4, 23)  => (Y = [[-0.910689, 0.0187097, -0.532863, -1.36348], [0.125793, 1.6…
#   (20, 71) => (Y = [[-1.12092, 1.47794, -0.00666642, 1.03115, 0.726952, 0.06980…
#   (6, 31)  => (Y = [[1.73592, -1.04194, -0.846122, -1.70491, 1.10428, -0.494171…
#   (10, 77) => (Y = [[-0.416869, 1.22798, 0.432322, 1.01913, -1.29169, 0.833163,…
#   (6, 44)  => (Y = [[0.112835, -0.463682, -0.834965, 0.890067, -0.0364769, -0.3…
#   (4, 74)  => (Y = [[-3.67572, -0.414683, 0.847903, -2.91129], [-0.141337, -0.9…
#   (6, 19)  => (Y = [[-1.53201, -0.26905, -0.507904, -2.54082, 1.53092, -0.80928…
#   (30, 86) => (Y = [[1.3318, -0.741286, -0.283916, -0.709931, -1.54392, 1.07019…
#   ⋮        => ⋮

# %%
limma_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full per-gene p-values
limma_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level top-100 results
limma_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running LIMMA simulation for n = $n ==========")

    ν = n - 1

    power_vals  = Float64[]
    fdr_vals    = Float64[]
    tp_vals     = Float64[]
    fp_vals     = Float64[]
    top100_vals = Float64[]

    for r in 1:R

        try
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ

            # -------------------------------------------------
            # Per-gene statistics
            # -------------------------------------------------
            β_hat = [mean(Y[i]) for i in 1:G]

            s_hat = [
                std(Y[i], corrected=true)
                for i in 1:G
            ]

            se_hat_squared = (s_hat .^ 2) ./ n


            # -------------------------------------------------
            # LIMMA samples
            # -------------------------------------------------
            samples = [
                Empirikos.NormalChiSquareSample(
                    β_hat[i],
                    se_hat_squared[i],
                    ν
                )
                for i in 1:G
            ]


            # -------------------------------------------------
            # Fit LIMMA EB test
            # -------------------------------------------------
            test_limma = Empirikos.EmpiricalPartiallyBayesTTest(
                α = 0.05,
                prior = Empirikos.Limma(),
                solver = Hypatia.Optimizer
            )

            res_limma = fit(test_limma, samples)


            # -------------------------------------------------
            # Extract p-values and rejection decisions
            # -------------------------------------------------
            pvals_limma = res_limma.pvalue
            rej_limma   = res_limma.rj_idx


            # =================================================
            # SAVE THE RAW P-VALUES
            # =================================================
            limma_pvals_store[(n,r)] = copy(pvals_limma)


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej_limma .& is_DE)
            FP = sum(rej_limma .& .!is_DE)

            power = TP / max(sum(is_DE), 1)

            fdr = FP / max(sum(rej_limma), 1)


            # =================================================
            # Ranking metric: true signals among top 100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals_limma)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level ranking result
            limma_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


        catch err

            @warn "Skipping Rep $r for n=$n due to numerical error: $err"

            continue
        end
    end


    # =========================================================
    # Average over replicates
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(limma_summary["n"], n)

    push!(limma_summary["TP"], mean_TP)
    push!(limma_summary["FP"], mean_FP)

    push!(limma_summary["Power"], mean_power)
    push!(limma_summary["FDR"], mean_fdr)

    push!(limma_summary["TP_top100"], mean_top100)


    println(
        "n = $n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println("\n========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========")

for i in eachindex(limma_summary["n"])

    println(
        "n = $(limma_summary["n"][i]) → " *
        "Power=$(round(limma_summary["Power"][i], digits=5)), " *
        "FDR=$(round(limma_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(limma_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running LIMMA simulation for n = 4 ==========
# n = 4 → Power=0.346 | FDR=0.042 | TP=34.7 | FP=1.7 | TP@100=80.6
#
# ========== Running LIMMA simulation for n = 5 ==========
# n = 5 → Power=0.435 | FDR=0.049 | TP=43.8 | FP=2.3 | TP@100=82.3
#
# ========== Running LIMMA simulation for n = 6 ==========
# n = 6 → Power=0.505 | FDR=0.052 | TP=50.6 | FP=2.8 | TP@100=82.9
#
# ========== Running LIMMA simulation for n = 8 ==========
# n = 8 → Power=0.598 | FDR=0.043 | TP=60.0 | FP=2.8 | TP@100=84.8
#
# ========== Running LIMMA simulation for n = 10 ==========
# n = 10 → Power=0.665 | FDR=0.044 | TP=66.9 | FP=3.2 | TP@100=85.9
#
# ========== Running LIMMA simulation for n = 20 ==========
# n = 20 → Power=0.765 | FDR=0.045 | TP=76.8 | FP=3.7 | TP@100=87.8
#
# ========== Running LIMMA simulation for n = 30 ==========
# n = 30 → Power=0.812 | FDR=0.045 | TP=80.0 | FP=3.9 | TP@100=88.5
#
# ========== Running LIMMA simulation for n = 40 ==========
# n = 40 → Power=0.83 | FDR=0.046 | TP=82.8 | FP=4.0 | TP@100=89.2
#
# ========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → Power=0.34649, FDR=0.04169, TP@100=80.58
# n = 5 → Power=0.43545, FDR=0.04871, TP@100=82.31
# n = 6 → Power=0.50459, FDR=0.05212, TP@100=82.91
# n = 8 → Power=0.59826, FDR=0.04345, TP@100=84.82
# n = 10 → Power=0.66482, FDR=0.04411, TP@100=85.91
# n = 20 → Power=0.76542, FDR=0.04468, TP@100=87.82
# n = 30 → Power=0.81162, FDR=0.045, TP@100=88.46
# n = 40 → Power=0.83021, FDR=0.04594, TP@100=89.16

# %% [markdown]
# ## NP +SD

# %%
R = 100

# =========================================================
# Storage for summary results
# =========================================================
epb_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full raw p-values for every successful replicate
epb_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level TP@100
epb_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running EPB NPMLE simulation for n = $n ==========")

    ν = n - 1

    power_vals  = Float64[]
    fdr_vals    = Float64[]
    tp_vals     = Float64[]
    fp_vals     = Float64[]
    top100_vals = Float64[]

    for r in 1:R

        try
            # -------------------------------------------------
            # Get the same simulated dataset
            # -------------------------------------------------
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ


            # -------------------------------------------------
            # Compute per-gene statistics
            # -------------------------------------------------
            β_hat = [mean(Y[i]) for i in 1:G]

            s_hat = [
                std(Y[i], corrected=true)
                for i in 1:G
            ]

            se_hat_squared = (s_hat .^ 2) ./ n


            # -------------------------------------------------
            # Build Normal-Chi-square samples
            # -------------------------------------------------
            samples = [
                Empirikos.NormalChiSquareSample(
                    β_hat[i],
                    se_hat_squared[i],
                    ν
                )
                for i in 1:G
            ]


            # -------------------------------------------------
            # Fit EPB with nonparametric NPMLE prior
            # -------------------------------------------------
            test_epb = Empirikos.EmpiricalPartiallyBayesTTest(
                α = 0.05,
                solver = Hypatia.Optimizer
            )

            res_epb = fit(test_epb, samples)


            # -------------------------------------------------
            # Extract p-values and rejection decisions
            # -------------------------------------------------
            pvals_epb = res_epb.pvalue
            rej_epb   = res_epb.rj_idx


            # =================================================
            # SAVE RAW P-VALUES
            # =================================================
            epb_pvals_store[(n,r)] = copy(pvals_epb)


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej_epb .& is_DE)
            FP = sum(rej_epb .& .!is_DE)

            power = TP / max(sum(is_DE), 1)

            fdr = FP / max(sum(rej_epb), 1)


            # =================================================
            # Ranking metric: true DE genes among top 100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals_epb)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level TP@100
            epb_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            println(
                "Rep $r → " *
                "Power=$(round(power, digits=3)) | " *
                "FDR=$(round(fdr, digits=3)) | " *
                "Rej=$(sum(rej_epb)) | " *
                "TP@100=$TP_top100"
            )


        catch e

            @warn "Skipping Rep $r for n=$n due to error: $e"

            continue
        end
    end


    # =========================================================
    # Average over successful replicates
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(epb_summary["n"], n)

    push!(epb_summary["TP"], mean_TP)
    push!(epb_summary["FP"], mean_FP)

    push!(epb_summary["Power"], mean_power)
    push!(epb_summary["FDR"], mean_fdr)

    push!(epb_summary["TP_top100"], mean_top100)


    println(
        "n = $n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println("\n========== EPB SUMMARY ACROSS SAMPLE SIZES ==========")

for i in eachindex(epb_summary["n"])

    println(
        "n = $(epb_summary["n"][i]) → " *
        "TP=$(round(epb_summary["TP"][i], digits=3)), " *
        "FP=$(round(epb_summary["FP"][i], digits=3)), " *
        "Power=$(round(epb_summary["Power"][i], digits=5)), " *
        "FDR=$(round(epb_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(epb_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running EPB NPMLE simulation for n = 4 ==========
#
#  iter        p_obj        d_obj |  abs_gap    x_feas    z_feas |      tau       kap        mu | dir_res     prox  step     alpha
#     0   3.2373e-02  -2.6562e+02 | 2.30e+03  1.74e+02  3.17e+00 | 1.00e+00  1.00e+00  1.00e+00 |
#     1  -5.6432e-01  -2.7008e+02 | 2.19e+03  1.77e+02  3.21e+00 | 9.36e-01  1.02e+00  9.50e-01 | 3.3e-12  8.9e-02  co-a  5.00e-02
#     2  -1.4129e+00  -2.7243e+02 | 2.08e+03  1.78e+02  3.23e+00 | 8.84e-01  1.02e+00  9.03e-01 | 7.4e-13  1.5e-01  co-a  5.00e-02
#     3  -3.9967e+00  -2.7572e+02 | 1.87e+03  1.78e+02  3.24e+00 | 7.93e-01  1.02e+00  8.12e-01 | 2.1e-12  4.4e-01  co-a  1.00e-01
#     4  -8.4025e+00  -2.8102e+02 | 1.68e+03  1.79e+02  3.25e+00 | 7.11e-01  1.03e+00  7.31e-01 | 3.7e-13  9.3e-02  co-a  1.00e-01
#     5  -1.4877e+01  -2.8759e+02 | 1.51e+03  1.79e+02  3.26e+00 | 6.40e-01  1.03e+00  6.58e-01 | 1
UMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=35.556, FP=1.869, Power=0.35516, FDR=0.04589, TP@100=80.424
# n = 5 → TP=45.01, FP=2.49, Power=0.44744, FDR=0.05073, TP@100=82.25
# n = 6 → TP=50.99, FP=3.051, Power=0.50943, FDR=0.05549, TP@100=82.848
# n = 8 → TP=60.48, FP=2.89, Power=0.60328, FDR=0.04386, TP@100=84.61
# n = 10 → TP=67.14, FP=3.26, Power=0.66697, FDR=0.0453, TP@100=85.87
# n = 20 → TP=77.03, FP=3.68, Power=0.76835, FDR=0.04462, TP@100=87.84
# n = 30 → TP=80.222, FP=3.909, Power=0.81396, FDR=0.04547, TP@100=88.444
# n = 40 → TP=82.67, FP=4.13, Power=0.82891, FDR=0.04685, TP@100=89.15

# %% [markdown]
# ## MAD P

# %%
using FastGaussQuadrature
using Distributions
using StatsFuns: logsumexp
using Optim
using MultipleTesting
using Statistics, Random, LinearAlgebra
using ApproxFun, SpecialFunctions

# =========================================================
# 1. Exact MAD-about-mean likelihood
# =========================================================

struct MADDistribution{T<:Real,S<:Integer} <: ContinuousUnivariateDistribution
    σ::T
    n::S
end

import Distributions: pdf, logpdf, insupport, minimum, maximum

function G_recursive(max_r::Int; a=0.0, b=100)
    d = Interval(a, b)
    G = Vector{Fun}(undef, max_r+1)
    G[1] = Fun(x -> 1.0, d)
    for r in 1:max_r
        integrand = Fun(x -> exp(-(x^2)/(2r*(r+1))), d) * G[r]
        G[r+1] = cumsum(integrand)
    end
    return G
end

const _Gcache = Dict{Int,Vector{Fun}}()
_getG(n) = get!(_Gcache, n) do
    G_recursive(n)
end

function _pdf_sigma1(n::Int, m::Real)
    m < 0 && return zero(float(m))
    z   = n * m / 2
    cst = n^(3/2) / (2^((n+1)/2) * π^((n-1)/2))
    G   = _getG(n)
    s   = 0.0
    @inbounds for k in 1:(n-1)
        s += binomial(n, k) * exp(-(m^2 * n^3) / (8k*(n-k))) * G[k](z) * G[n-k](z)
    end
    return cst * s
end

insupport(::MADDistribution, x::Real) = x ≥ 0
minimum(::MADDistribution) = 0.0
maximum(::MADDistribution) = Inf

pdf(d::MADDistribution, m::Real) =
    m < 0 ? 0.0 : (1 / d.σ) * _pdf_sigma1(d.n, m / d.σ)

function logpdf(d::MADDistribution, m::Real)
    m < 0 && return -Inf
    σ, n = d.σ, d.n
    z    = n * m / (2σ)
    logC = (3/2)*log(n) - ((n+1)/2)*log(2) - ((n-1)/2)*log(π)
    G    = _getG(n)

    logs = Float64[]
    @inbounds for k in 1:(n-1)
        val1 = G[k](z)
        val2 = G[n-k](z)
        if val1 > 0 && val2 > 0
            push!(logs,
                log(binomial(n, k)) -
                (m^2 * n^3) / (8σ^2 * k*(n-k)) +
                log(val1) + log(val2)
            )
        end
    end

    return -log(σ) + logC + (isempty(logs) ? -Inf : logsumexp(logs))
end

# =========================================================
# 2. Parametric prior on sigma^2
# =========================================================

struct InverseScaledChiSquare{T,S} <: ContinuousUnivariateDistribution
    σ²::T
    ν::S
end

function Distributions.InverseGamma(d::InverseScaledChiSquare)
    InverseGamma(d.ν / 2, d.ν * d.σ² / 2)
end

Distributions.pdf(d::InverseScaledChiSquare, x::Real) = pdf(InverseGamma(d), x)
Distributions.logpdf(d::InverseScaledChiSquare, x::Real) = logpdf(InverseGamma(d), x)

prior_sigma2(σ0², ν0) = InverseScaledChiSquare(σ0², ν0)

# =========================================================
# 3. Gauss-Legendre quadrature on (0,1)
# =========================================================

function gausslegendre01(K::Int)
    x, w = gausslegendre(K)   # nodes/weights on [-1,1]
    u = (x .+ 1) ./ 2         # map to (0,1)
    w = w ./ 2
    return u, w
end

# =========================================================
# 4. Marginal likelihood by Gauss-Legendre quadrature
#    transform s2 = u/(1-u), u in (0,1)
# =========================================================
function marginal_mad_logdensity_gl(
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    prior = prior_sigma2(σ0², ν0)

    logvals = similar(u_nodes)
    @inbounds for j in eachindex(u_nodes)
        u = clamp(u_nodes[j], 1e-12, 1 - 1e-12)
        s2 = u / (1 - u)
        jac = 1 / (1 - u)^2

        logvals[j] =
            logpdf(MADDistribution(sqrt(s2), n), D) +
            logpdf(prior, s2) +
            log(jac) +
            log(u_weights[j])
    end

    return logsumexp(logvals)
end

# =========================================================
# 5. Negative log marginal likelihood across genes
# =========================================================

function negloglik_mad_parametric_gl(
    par::Vector{Float64},
    mad_obs::Vector{Float64},
    n::Int,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    η, ξ = par
    σ0² = exp(η)
    ν0  = exp(ξ)

    total = 0.0
    @inbounds for D in mad_obs
        total -= marginal_mad_logdensity_gl(D, n, σ0², ν0, u_nodes, u_weights)
    end
    return total
end

# =========================================================
# 6. Fit prior hyperparameters by Gaussian quadrature
# =========================================================

function fit_mad_parametric_prior_gl(
    mad_obs::Vector{Float64},
    n::Int;
    K_quad::Int = 64,
    init_logσ0² = log(max(median(mad_obs)^2, 1e-6)),
    init_logν0  = log(10.0),
    max_iter::Int = 80
)
    u_nodes, u_weights = gausslegendre01(K_quad)

    obj(par) = negloglik_mad_parametric_gl(par, mad_obs, n, u_nodes, u_weights)

    res = optimize(
        obj,
        [init_logσ0², init_logν0],
        NelderMead(),
        Optim.Options(iterations=max_iter, show_trace=false)
    )

    ηhat, ξhat = Optim.minimizer(res)

    return (
        σ0² = exp(ηhat),
        ν0  = exp(ξhat),
        optim = res,
        u_nodes = u_nodes,
        u_weights = u_weights
    )
end

# =========================================================
# 7. Posterior weights on same quadrature nodes
# =========================================================

function posterior_sigma2_weights_mad_gl(
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    prior = prior_sigma2(σ0², ν0)

    logpost = similar(u_nodes)
    s2_nodes = similar(u_nodes)

    @inbounds for j in eachindex(u_nodes)
        u = clamp(u_nodes[j], 1e-12, 1 - 1e-12)
        s2 = u / (1 - u)
        s2_nodes[j] = s2
        jac = 1 / (1 - u)^2

        logpost[j] =
            logpdf(MADDistribution(sqrt(s2), n), D) +
            logpdf(prior, s2) +
            log(jac) +
            log(u_weights[j])
    end

    m = maximum(logpost)
    w = exp.(logpost .- m)
    w ./= sum(w)

    return s2_nodes, w
end

# =========================================================
# 8. Posterior-averaged p-value
# =========================================================

function mad_parametric_pvalue_gl(
    β_tilde::Float64,
    D::Float64,
    n::Int,
    σ0²::Float64,
    ν0::Float64,
    u_nodes::Vector{Float64},
    u_weights::Vector{Float64}
)
    s2_nodes, w = posterior_sigma2_weights_mad_gl(D, n, σ0², ν0, u_nodes, u_weights)
    σ_nodes = sqrt.(s2_nodes)
    tails = 2 .* ccdf.(Normal.(0, σ_nodes), abs(β_tilde))
    return dot(tails, w)
end
# Out:
# WARNING: redefinition of constant Main._Gcache. This may fail, cause incorrect answers, or produce other errors.
# mad_parametric_pvalue_gl (generic function with 1 method)

# %%
# =========================================================
# 9. Simulation loop: MAD_mean + parametric prior
# =========================================================

mad_param_gl_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

mad_param_gl_prior_summary = Dict(
    "n" => Int[],
    "sigma0_sq_mean" => Float64[],
    "nu0_mean" => Float64[]
)

# Store replicate-level results
mad_param_gl_prior_reps = Dict(
    "n" => Int[],
    "rep" => Int[],
    "sigma0_sq_hat" => Float64[],
    "nu0_hat" => Float64[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# NEW: store all raw p-values
mad_param_pvals_store =
    Dict{Tuple{Int,Int}, Vector{Float64}}()

# NEW: store replicate-level TP@100
mad_param_top100_store =
    Dict{Tuple{Int,Int}, Int}()


for n in n_values

    println(
        "\n========== Running MAD_mean + parametric prior " *
        "(Gauss-Legendre) for n = $n =========="
    )

    tp_vals = Float64[]
    fp_vals = Float64[]
    power_vals = Float64[]
    fdr_vals = Float64[]
    top100_vals = Float64[]

    sigma0_sq_vals = Float64[]
    nu0_vals = Float64[]


    for r in 1:R

        try
            println("n=$n, rep=$r: loading data...")

            Y = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ_true = datasets[(n,r)].σ


            # =================================================
            # Compute statistics
            # =================================================
            println("n=$n, rep=$r: computing statistics...")

            β_hat = [
                mean(Y[i])
                for i in 1:G
            ]

            mad_obs = [
                mean(abs.(Y[i] .- β_hat[i]))
                for i in 1:G
            ]

            β_tilde = sqrt(n) .* β_hat

            idx_fit = 1:length(mad_obs)


            # =================================================
            # Fit parametric MAD prior
            # =================================================
            println(
                "n=$n, rep=$r: fitting Gauss-Legendre parametric prior..."
            )

            @time fit_prior =
                fit_mad_parametric_prior_gl(
                    mad_obs[idx_fit],
                    n;
                    K_quad = 100,
                    max_iter = 80
                )

            σ0²_hat = fit_prior.σ0²
            ν0_hat  = fit_prior.ν0

            u_nodes   = fit_prior.u_nodes
            u_weights = fit_prior.u_weights


            push!(sigma0_sq_vals, σ0²_hat)
            push!(nu0_vals, ν0_hat)


            println(
                "n=$n, rep=$r: prior fit done. " *
                "σ0²=$(round(σ0²_hat, digits=4)), " *
                "ν0=$(round(ν0_hat, digits=3))"
            )


            # =================================================
            # Compute RAW p-values
            # =================================================
            println("n=$n, rep=$r: computing p-values...")

            pvals = [
                mad_parametric_pvalue_gl(
                    β_tilde[i],
                    mad_obs[i],
                    n,
                    σ0²_hat,
                    ν0_hat,
                    u_nodes,
                    u_weights
                )
                for i in 1:G
            ]


            # =================================================
            # NEW: store raw p-values
            # =================================================
            mad_param_pvals_store[(n,r)] = copy(pvals)


            # =================================================
            # NEW: ranking metric TP@100
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])

            mad_param_top100_store[(n,r)] =
                TP_top100


            # =================================================
            # BH rejection
            # =================================================
            adj_p = adjust(
                pvals,
                BenjaminiHochberg()
            )

            rej = adj_p .<= 0.05


            # =================================================
            # Standard metrics
            # =================================================
            TP = sum(rej .& is_DE)
            FP = sum(rej .& .!is_DE)

            power =
                TP / max(sum(is_DE), 1)

            fdr =
                FP / max(sum(rej), 1)


            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            # =================================================
            # Store replicate-level prior + performance
            # =================================================
            push!(mad_param_gl_prior_reps["n"], n)
            push!(mad_param_gl_prior_reps["rep"], r)

            push!(
                mad_param_gl_prior_reps["sigma0_sq_hat"],
                σ0²_hat
            )

            push!(
                mad_param_gl_prior_reps["nu0_hat"],
                ν0_hat
            )

            push!(mad_param_gl_prior_reps["TP"], TP)
            push!(mad_param_gl_prior_reps["FP"], FP)

            push!(
                mad_param_gl_prior_reps["Power"],
                power
            )

            push!(
                mad_param_gl_prior_reps["FDR"],
                fdr
            )

            push!(
                mad_param_gl_prior_reps["TP_top100"],
                TP_top100
            )


            println(
                "n=$n, rep=$r done → " *
                "Power=$(round(power, digits=3)) | " *
                "FDR=$(round(fdr, digits=3)) | " *
                "TP@100=$TP_top100"
            )


        catch e

            println(
                "⚠️ Skipping Rep $r for n=$n due to error: " *
                "$(typeof(e)) : $e"
            )

            continue
        end
    end


    # =========================================================
    # Summarize over successful replicates
    # =========================================================
    if !isempty(tp_vals)

        mean_TP = mean(tp_vals)
        mean_FP = mean(fp_vals)

        mean_power = mean(power_vals)
        mean_fdr = mean(fdr_vals)

        mean_top100 = mean(top100_vals)


        push!(mad_param_gl_summary["n"], n)

        push!(
            mad_param_gl_summary["TP"],
            mean_TP
        )

        push!(
            mad_param_gl_summary["FP"],
            mean_FP
        )

        push!(
            mad_param_gl_summary["Power"],
            mean_power
        )

        push!(
            mad_param_gl_summary["FDR"],
            mean_fdr
        )

        push!(
            mad_param_gl_summary["TP_top100"],
            mean_top100
        )


        # Prior summary
        push!(
            mad_param_gl_prior_summary["n"],
            n
        )

        push!(
            mad_param_gl_prior_summary["sigma0_sq_mean"],
            mean(sigma0_sq_vals)
        )

        push!(
            mad_param_gl_prior_summary["nu0_mean"],
            mean(nu0_vals)
        )


        println(
            "✅ Done n=$n → " *
            "Power=$(round(mean_power, digits=3)) | " *
            "FDR=$(round(mean_fdr, digits=3)) | " *
            "TP=$(round(mean_TP, digits=1)) | " *
            "FP=$(round(mean_FP, digits=1)) | " *
            "TP@100=$(round(mean_top100, digits=1))"
        )

    else

        println("⚠️ No successful reps for n=$n")

    end
end
# Out:
# ========== Running MAD_mean + parametric prior (Gauss-Legendre) for n = 4 ==========
# n=4, rep=1: loading data...
# n=4, rep=1: computing statistics...
# n=4, rep=1: fitting Gauss-Legendre parametric prior...
#   9.237016 seconds (234.64 M allocations: 4.398 GiB, 3.15% gc time, 7.27% compilation time)
# n=4, rep=1: prior fit done. σ0²=0.9832, ν0=4.142
# n=4, rep=1: computing p-values...
# n=4, rep=1 done → Power=0.431 | FDR=0.083 | TP@100=79
# n=4, rep=2: loading data...
# n=4, rep=2: computing statistics...
# n=4, rep=2: fitting Gauss-Legendre parametric prior...
#   8.609815 seconds (233.98 M allocations: 4.273 GiB, 2.24% gc time)
# n=4, rep=2: prior fit done. σ0²=1.0702, ν0=4.527
# n=4, rep=2: computing p-values...
# n=4, rep=2 done → Power=0.452 | FDR=0.045 | TP@100=75
# n=4, rep=3: loading data...
# n=4, rep=3: computing statistics...
# n=4, rep=3: fitting Gauss-Legendre parametric prior...
#   9.152954 seconds (248.47 M allocations: 4.538 GiB, 2.16% gc time)
# n=4, rep=3: prior fit done. σ0²=1.0274, ν0=4.466
# n=4, rep=3: computing p-values...
# n=4, rep=3 done → Power=0.487 | FDR=0.097 | TP@100=86
# n=4, rep=4: loading data...
# n=4, rep=4: computing statistics...
# n=4, rep=4: fitting Gauss-Legendre parametric prior...
#   8.616347 seconds (234.00 M allocations: 4.274 GiB, 2.11% gc time)
# n=4, rep=4: prior fit done. σ0²=0.9919, ν0=4.0
# n=4, rep=4: computing p-values...
# n=4, rep=4 done → Power=0.131 | FDR=0.071 | TP@100=77
# n=4, rep=5: loading data...
# n=4, rep=5: computing statistics...
# n=4, rep=5: fitting Gauss-Legendre parametric prior...
#   8.816752 seconds (239.78 M allocations: 4.379 GiB, 2.17% gc time)
# n=4, rep=5: prior fit done. σ0²=1.0069, ν0=4.126
# n=4, rep=5: computing p-values...
# n=4, rep=5 done → Power=0.402 | FDR=0.065 | TP@100=85
# n=4, rep=6: loading data...
# n=4, rep=6: computing statistics...
# n=4, rep=6: fitting Gauss-Legendre parametric prior...
#   8.607497 seconds (233.99 M allocations: 4.274 GiB, 2.14% gc time)
# n=4, rep=6: prior fit done. σ0²=0.9886, ν0=4.001
# n=4, rep=6: computing p-values...
# n=4, rep=6 done → Power=0.155 | FDR=0.0 | TP@100=78
# n=4, rep=7: loading data...
# n=4, rep=7: computing statistics...
# n=4, rep=7: fitting Gauss-Legendre parametric prior...
#   8.743810 seconds (236.90 M allocations: 4.327 GiB, 2.18% gc time)
# n=4, rep=7: prior fit done. σ0²=1.0238, ν0=4.63
# n=4, rep=7: computing p-values...
# n=4, rep=7 done → Power=0.247 | FDR=0.095 | TP@100=68
# n=4, rep=8: loading data...
# n=4, rep=8: computing statistics...
# n=4, rep=8: fitting Gauss-Legendre parametric prior...
#   8.523703 seconds (231.09 M allocations: 4.221 GiB, 2.13% gc time)
# n=4, rep=8: prior fit done. σ0²=1.0294, ν0=3.929
# n=4, rep=8: computing p-values...
# n=4, rep=8 done → Power=0.403 | FDR=0.059 | TP@100=89
# n=4, rep=9: loading data...
# n=4, rep=9: computing statistics...
# n=4, rep=9: fitting Gauss-Legendre parametric prior...
#   9.237039 seconds (251.28 M allocations: 4.589 GiB, 2.15% gc time)
# n=4, rep=9: prior fit done. σ0²=1.0673, ν0=4.105
# n=4, rep=9: computing p-values...
# n=4, rep=9 done → Power=0.255 | FDR=0.0 | TP@100=82
# n=4, rep=10: loading data...
# n=4, rep=10: computing statistics...
# n=4, rep=10: fitting Gauss-Legendre parametric prior...
#   8.821016 seconds (239.76 M allocations: 4.379 GiB, 2.16% gc time)
# n=4, rep=10: prior fit done. σ0²=1.0476, ν0=4.334
# n=4, rep=10: computing p-values...
# n=4, rep=10 done → Power=0.393 | FDR=0.022 | TP@100=88
# n=4, rep=11: loading data...
# n=4, rep=11: computing statistics...
# n=4, rep=11: fitting Gauss-Legendre parametric prior...
#   8.818137 seconds (239.82 M allocations: 4.380 GiB, 2.15% gc time)
# n=4, rep=11: prior fit done. σ0²=1.0113, ν0=4.457
# n=4, rep=11: computing p-values...
# n=4, rep=11 done → Power=0.402 | FDR=0.0 | TP@100=79
# n=4, rep=12: loading data...
# n=4, rep=12: computing statistics...
# n=4, rep=12: fitting Gauss-Legendre parametric prior...
#   8.829942 seconds (239.78 M allocations: 4.379 GiB, 2.15% gc time)
# n=4, rep=12: prior fit done. σ0²=0.9614, ν0=3.798
# n=4, rep=12: computing p-values...
# n=4, rep=12 done → Power=0.45 | FDR=0.039 | TP@100=83
# n=4, rep=13: loading data...
# n=4, rep=13: computing statistics...
# n=4, rep=13: fitting Gauss-Legendre parametric prior...
#   8.824266 seconds (239.70 M allocations: 4.378 GiB, 2.15% gc time)
# n=4, rep=13: prior fit done. σ0²=1.0589, ν0=3.739
# n=4, rep=13: computing p-values...
# n=4, rep=13 done → Power=0.327 | FDR=0.059 | TP@100=81
# n=4, rep=14: loading data...
# n=4, rep=14: computing statistics...
# n=4, rep=14: fitting Gauss-Legendre parametric prior...
#   8.962525 seconds (242.66 M allocations: 4.432 GiB, 2.15% gc time)
# n=4, rep=14: prior fit done. σ0²=1.0873, ν0=4.594
# n=4, rep=14: computing p-values...
# n=4, rep=14 done → Power=0.244 | FDR=0.0 | TP@100=77
# n=4, rep=15: loading data...
# n=4, rep=15: computing statistics...
# n=4, rep=15: fitting Gauss-Legendre parametric prior...
#   8.775384 seconds (236.89 M allocations: 4.327 GiB, 2.12% gc time)
# n=4, rep=15: prior fit done. σ0²=1.0086, ν0=4.245
# n=4, rep=15: computing p-values...
# n=4, rep=15 done → Power=0.363 | FDR=0.057 | TP@100=79
# n=4, rep=16: loading data...
# n=4, rep=16: computing statistics...
# n=4, rep=16: fitting Gauss-Legendre parametric prior...
#   8.797032 seconds (236.87 M allocations: 4.326 GiB, 2.14% gc time)
# n=4, rep=16: prior fit done. σ0²=0.9485, ν0=3.447
# n=4, rep=16: computing p-values...
# n=4, rep=16 done → Power=0.28 | FDR=0.0 | TP@100=83
# n=4, rep=17: loading data...
# n=4, rep=17: computing statistics...
# n=4, rep=17: fitting Gauss-Legendre parametric prior...
#   8.819264 seconds (236.85 M allocations: 4.326 GiB, 2.13% gc time)
# n=4, rep=17: prior fit done. σ0²=1.1027, ν0=4.41
# n=4, rep=17: computing p-values...
# n=4, rep=17 done → Power=0.309 | FDR=0.032 | TP@100=80
# n=4, rep=18: loading data...
# n=4, rep=18: computing statistics...
# n=4, rep=18: fitting Gauss-Legendre parametric prior...
#   8.829985 seconds (236.85 M allocations: 4.326 GiB, 2.15% gc time)
# n=4, rep=18: prior fit done. σ0²=1.0383, ν0=3.989
# n=4, rep=18: computing p-values...
# n=4, rep=18 done → Power=0.261 | FDR=0.0 | TP@100=82
# n=4, rep=19: loading data...
# n=4, rep=19: computing statistics...
# n=4, rep=19: fitting Gauss-Legendre parametric prior...
#   8.752068 seconds (234.02 M allocations: 4.274 GiB, 2.13% gc time)
# n=4, rep=19: prior fit done. σ0²=0.9802, ν0=4.084
# n=4, rep=19: computing p-values...
# n=4, rep=19 done → Power=0.356 | FDR=0.059 | TP@100=77
# n=4, rep=20: loading data...
# n=4, rep=20: computing statistics...
# n=4, rep=20: fitting Gauss-Legendre parametric prior...
#   8.632850 seconds (231.12 M allocations: 4.221 GiB, 2.11% gc time)
# n=4, rep=20: prior fit done. σ0²=0.9903, ν0=3.943
# n=4, rep=20: computing p-values...
# n=4, rep=20 done → Power=0.341 | FDR=0.031 | TP@100=81
# n=4, rep=21: loading data...
# n=4, rep=21: computing statistics...
# n=4, rep=21: fitting Gauss-Legendre parametric prior...
#   9.337583 seconds (248.50 M allocations: 4.539 GiB, 2.15% gc time)
# n=4, rep=21: prior fit done. σ0²=1.0326, ν0=4.959
# n=4, rep=21: computing p-values...
# n=4, rep=21 done → Power=0.549 | FDR=0.0 | TP@100=82
# n=4, rep=22: loading data...
# n=4, rep=22: computing statistics...
# n=4, rep=22: fitting Gauss-Legendre parametric prior...
#   8.904886 seconds (236.87 M allocations: 4.326 GiB, 2.16% gc time)
# n=4, rep=22: prior fit done. σ0²=1.0313, ν0=4.147
# n=4, rep=22: computing p-values...
# n=4, rep=22 done → Power=0.305 | FDR=0.0 | TP@100=81
# n=4, rep=23: loading data...
# n=4, rep=23: computing statistics...
# n=4, rep=23: fitting Gauss-Legendre parametric prior...
#   9.017527 seconds (239.80 M allocations: 4.380 GiB, 2.10% gc time)
# n=4, rep=23: prior fit done. σ0²=0.9519, ν0=4.069
# n=4, rep=23: computing p-values...
# n=4, rep=23 done → Power=0.333 | FDR=0.059 | TP@100=75
# n=4, rep=24: loading data...
# n=4, rep=24: computing statistics...
# n=4, rep=24: fitting Gauss-Legendre parametric prior...
#   7.518953 seconds (199.36 M allocations: 3.641 GiB, 2.14% gc time)
# n=4, rep=24: prior fit done. σ0²=0.9817, ν0=4.145
# n=4, rep=24: computing p-values...
# n=4, rep=24 done → Power=0.266 | FDR=0.0 | TP@100=77
# n=4, rep=25: loading data...
# n=4, rep=25: computing statistics...
# n=4, rep=25: fitting Gauss-Legendre parametric prior...
#   8.939533 seconds (236.90 M allocations: 4.327 GiB, 2.11% gc time)
# n=4, rep=25: prior fit done. σ0²=1.0129, ν0=4.173
# n=4, rep=25: computing p-values...
# n=4, rep=25 done → Power=0.495 | FDR=0.093 | TP@100=85
# n=4, rep=26: loading data...
# n=4, rep=26: computing statistics...
# n=4, rep=26: fitting Gauss-Legendre parametric prior...
#   8.935871 seconds (236.89 M allocations: 4.326 GiB, 2.14% gc time)
# n=4, rep=26: prior fit done. σ0²=1.0499, ν0=4.459
# n=4, rep=26: computing p-values...
# n=4, rep=26 done → Power=0.413 | FDR=0.023 | TP@100=84
# n=4, rep=27: loading data...
# n=4, rep=27: computing statistics...
# n=4, rep=27: fitting Gauss-Legendre parametric prior...
#   9.375751 seconds (248.41 M allocations: 4.537 GiB, 2.11% gc time)
# n=4, rep=27: prior fit done. σ0²=1.0015, ν0=3.726
# n=4, rep=27: computing p-values...
# n=4, rep=27 done → Power=0.435 | FDR=0.041 | TP@100=87
# n=4, rep=28: loading data...
# n=4, rep=28: computing statistics...
# n=4, rep=28: fitting Gauss-Legendre parametric prior...
#   9.503678 seconds (251.32 M allocations: 4.590 GiB, 2.12% gc time)
# n=4, rep=28: prior fit done. σ0²=1.014, ν0=3.821
# n=4, rep=28: computing p-values...
# n=4, rep=28 done → Power=0.051 | FDR=0.0 | TP@100=83
# n=4, rep=29: loading data...
# n=4, rep=29: computing statistics...
# n=4, rep=29: fitting Gauss-Legendre parametric prior...
#   8.739719 seconds (231.10 M allocations: 4.221 GiB, 2.14% gc time)
# n=4, rep=29: prior fit done. σ0²=1.0015, ν0=3.805
# n=4, rep=29: computing p-values...
# n=4, rep=29 done → Power=0.319 | FDR=0.027 | TP@100=81
# n=4, rep=30: loading data...
# n=4, rep=30: computing statistics...
# n=4, rep=30: fitting Gauss-Legendre parametric prior...
#   9.199270 seconds (242.70 M allocations: 4.433 GiB, 2.12% gc time)
# n=4, rep=30: prior fit done. σ0²=0.988, ν0=4.108
# n=4, rep=30: computing p-values...
# n=4, rep=30 done → Power=0.327 | FDR=0.0 | TP@100=80
# n=4, rep=31: loading data...
# n=4, rep=31: computing statistics...
# n=4, rep=31: fitting Gauss-Legendre parametric prior...
#   8.870698 seconds (233.99 M allocations: 4.274 GiB, 2.12% gc time)
# n=4, rep=31: prior fit done. σ0²=0.9854, ν0=3.887
# n=4, rep=31: computing p-values...
# n=4, rep=31 done → Power=0.418 | FDR=0.068 | TP@100=81
# n=4, rep=32: loading data...
# n=4, rep=32: computing statistics...
# n=4, rep=32: fitting Gauss-Legendre parametric prior...
#   9.196800 seconds (242.72 M allocations: 4.433 GiB, 2.12% gc time)
# n=4, rep=32: prior fit done. σ0²=0.9751, ν0=4.184
# n=4, rep=32: computing p-values...
# n=4, rep=32 done → Power=0.359 | FDR=0.026 | TP@100=85
# n=4, rep=33: loading data...
# n=4, rep=33: computing statistics...
# n=4, rep=33: fitting Gauss-Legendre parametric prior...
#   8.118968 seconds (210.89 M allocations: 3.852 GiB, 2.38% gc time)
# n=4, rep=33: prior fit done. σ0²=1.1108, ν0=5.074
# n=4, rep=33: computing p-values...
# n=4, rep=33 done → Power=0.404 | FDR=0.083 | TP@100=83
# n=4, rep=34: loading data...
# n=4, rep=34: computing statistics...
# n=4, rep=34: fitting Gauss-Legendre parametric prior...
#   8.892695 seconds (233.98 M allocations: 4.273 GiB, 2.12% gc time)
# n=4, rep=34: prior fit done. σ0²=0.9833, ν0=3.627
# n=4, rep=34: computing p-values...
# n=4, rep=34 done → Power=0.292 | FDR=0.034 | TP@100=84
# n=4, rep=35: loading data...
# n=4, rep=35: computing statistics...
# n=4, rep=35: fitting Gauss-Legendre parametric prior...
#   8.926297 seconds (233.97 M allocations: 4.273 GiB, 2.11% gc time)
# n=4, rep=35: prior fit done. σ0²=1.0816, ν0=4.178
# n=4, rep=35: computing p-values...
# n=4, rep=35 done → Power=0.346 | FDR=0.0 | TP@100=85
# n=4, rep=36: loading data...
# n=4, rep=36: computing statistics...
# n=4, rep=36: fitting Gauss-Legendre parametric prior...
#   9.029658 seconds (236.93 M allocations: 4.327 GiB, 2.10% gc time)
# n=4, rep=36: prior fit done. σ0²=0.9387, ν0=4.019
# n=4, rep=36: computing p-values...
# n=4, rep=36 done → Power=0.154 | FDR=0.067 | TP@100=77
# n=4, rep=37: loading data...
# n=4, rep=37: computing statistics...
# n=4, rep=37: fitting Gauss-Legendre parametric prior...
#   9.169404 seconds (239.76 M allocations: 4.379 GiB, 2.10% gc time)
# n=4, rep=37: prior fit done. σ0²=0.9408, ν0=3.723
# n=4, rep=37: computing p-values...
# n=4, rep=37 done → Power=0.29 | FDR=0.069 | TP@100=80
# n=4, rep=38: loading data...
# n=4, rep=38: computing statistics...
# n=4, rep=38: fitting Gauss-Legendre parametric prior...
#   8.628257 seconds (225.37 M allocations: 4.116 GiB, 2.09% gc time)
# n=4, rep=38: prior fit done. σ0²=0.9839, ν0=4.385
# n=4, rep=38: computing p-values...
# n=4, rep=38 done → Power=0.326 | FDR=0.091 | TP@100=79
# n=4, rep=39: loading data...
# n=4, rep=39: computing statistics...
# n=4, rep=39: fitting Gauss-Legendre parametric prior...
#   9.266973 seconds (242.69 M allocations: 4.433 GiB, 2.09% gc time)
# n=4, rep=39: prior fit done. σ0²=0.929, ν0=3.75
# n=4, rep=39: computing p-values...
# n=4, rep=39 done → Power=0.418 | FDR=0.073 | TP@100=83
# n=4, rep=40: loading data...
# n=4, rep=40: computing statistics...
# n=4, rep=40: fitting Gauss-Legendre parametric prior...
#   8.944451 seconds (234.01 M allocations: 4.274 GiB, 2.11% gc time)
# n=4, rep=40: prior fit done. σ0²=0.9841, ν0=4.069
# n=4, rep=40: computing p-values...
# n=4, rep=40 done → Power=0.327 | FDR=0.1 | TP@100=81
# n=4, rep=41: loading data...
# n=4, rep=41: computing statistics...
# n=4, rep=41: fitting Gauss-Legendre parametric prior...
#   8.930844 seconds (233.93 M allocations: 4.272 GiB, 2.07% gc time)
# n=4, rep=41: prior fit done. σ0²=1.0819, ν0=3.81
# n=4, rep=41: computing p-values...
# n=4, rep=41 done → Power=0.227 | FDR=0.048 | TP@100=79
# n=4, rep=42: loading data...
# n=4, rep=42: computing statistics...
# n=4, rep=42: fitting Gauss-Legendre parametric prior...
#   9.177155 seconds (239.78 M allocations: 4.379 GiB, 2.11% gc time)
# n=4, rep=42: prior fit done. σ0²=1.0079, ν0=3.99
# n=4, rep=42: computing p-values...
# n=4, rep=42 done → Power=0.284 | FDR=0.033 | TP@100=81
# n=4, rep=43: loading data...
# n=4, rep=43: computing statistics...
# n=4, rep=43: fitting Gauss-Legendre parametric prior...
#   9.174037 seconds (239.77 M allocations: 4.379 GiB, 2.08% gc time)
# n=4, rep=43: prior fit done. σ0²=0.9969, ν0=4.059
# n=4, rep=43: computing p-values...
# n=4, rep=43 done → Power=0.34 | FDR=0.054 | TP@100=81
# n=4, rep=44: loading data...
# n=4, rep=44: computing statistics...
# n=4, rep=44: fitting Gauss-Legendre parametric prior...
#   9.064851 seconds (236.89 M allocations: 4.327 GiB, 2.11% gc time)
# n=4, rep=44: prior fit done. σ0²=1.0915, ν0=4.88
# n=4, rep=44: computing p-values...
# n=4, rep=44 done → Power=0.462 | FDR=0.109 | TP@100=81
# n=4, rep=45: loading data...
# n=4, rep=45: computing statistics...
# n=4, rep=45: fitting Gauss-Legendre parametric prior...
#   9.096373 seconds (236.96 M allocations: 4.328 GiB, 2.07% gc time)
# n=4, rep=45: prior fit done. σ0²=0.9785, ν0=4.677
# n=4, rep=45: computing p-values...
# n=4, rep=45 done → Power=0.412 | FDR=0.067 | TP@100=81
# n=4, rep=46: loading data...
# n=4, rep=46: computing statistics...
# n=4, rep=46: fitting Gauss-Legendre parametric prior...
#   8.979417 seconds (234.07 M allocations: 4.275 GiB, 2.11% gc time)
# n=4, rep=46: prior fit done. σ0²=1.0034, ν0=4.835
# n=4, rep=46: computing p-values...
# n=4, rep=46 done → Power=0.364 | FDR=0.03 | TP@100=75
# n=4, rep=47: loading data...
# n=4, rep=47: computing statistics...
# n=4, rep=47: fitting Gauss-Legendre parametric prior...
#   9.214245 seconds (239.79 M allocations: 4.380 GiB, 2.17% gc time)
# n=4, rep=47: prior fit done. σ0²=1.0027, ν0=4.433
# n=4, rep=47: computing p-values...
# n=4, rep=47 done → Power=0.351 | FDR=0.029 | TP@100=80
# n=4, rep=48: loading data...
# n=4, rep=48: computing statistics...
# n=4, rep=48: fitting Gauss-Legendre parametric prior...
#   8.867790 seconds (231.07 M allocations: 4.220 GiB, 2.10% gc time)
# n=4, rep=48: prior fit done. σ0²=0.9824, ν0=3.567
# n=4, rep=48: computing p-values...
# n=4, rep=48 done → Power=0.271 | FDR=0.037 | TP@100=81
# n=4, rep=49: loading data...
# n=4, rep=49: computing statistics...
# n=4, rep=49: fitting Gauss-Legendre parametric prior...
#   8.894659 seconds (231.11 M allocations: 4.221 GiB, 2.12% gc time)
# n=4, rep=49: prior fit done. σ0²=1.1339, ν0=5.358
# n=4, rep=49: computing p-values...
# n=4, rep=49 done → Power=0.531 | FDR=0.055 | TP@100=87
# n=4, rep=50: loading data...
# n=4, rep=50: computing statistics...
# n=4, rep=50: fitting Gauss-Legendre parametric prior...
#   9.121688 seconds (236.92 M allocations: 4.327 GiB, 2.08% gc time)
# n=4, rep=50: prior fit done. σ0²=0.9556, ν0=4.071
# n=4, rep=50: computing p-values...
# n=4, rep=50 done → Power=0.573 | FDR=0.048 | TP@100=83
# n=4, rep=51: loading data...
# n=4, rep=51: computing statistics...
# n=4, rep=51: fitting Gauss-Legendre parametric prior...
#   9.447843 seconds (245.61 M allocations: 4.486 GiB, 2.12% gc time)
# n=4, rep=51: prior fit done. σ0²=0.9563, ν0=4.201
# n=4, rep=51: computing p-values...
# n=4, rep=51 done → Power=0.359 | FDR=0.108 | TP@100=78
# n=4, rep=52: loading data...
# n=4, rep=52: computing statistics...
# n=4, rep=52: fitting Gauss-Legendre parametric prior...
#   9.248259 seconds (239.72 M allocations: 4.378 GiB, 2.09% gc time)
# n=4, rep=52: prior fit done. σ0²=1.0109, ν0=3.704
# n=4, rep=52: computing p-values...
# n=4, rep=52 done → Power=0.255 | FDR=0.038 | TP@100=78
# n=4, rep=53: loading data...
# n=4, rep=53: computing statistics...
# n=4, rep=53: fitting Gauss-Legendre parametric prior...
#   9.327931 seconds (242.64 M allocations: 4.431 GiB, 2.10% gc time)
# n=4, rep=53: prior fit done. σ0²=1.029, ν0=3.836
# n=4, rep=53: computing p-values...
# n=4, rep=53 done → Power=0.34 | FDR=0.0 | TP@100=82
# n=4, rep=54: loading data...
# n=4, rep=54: computing statistics...
# n=4, rep=54: fitting Gauss-Legendre parametric prior...
#   9.796425 seconds (254.22 M allocations: 4.643 GiB, 2.09% gc time)
# n=4, rep=54: prior fit done. σ0²=0.96, ν0=3.763
# n=4, rep=54: computing p-values...
# n=4, rep=54 done → Power=0.423 | FDR=0.024 | TP@100=87
# n=4, rep=55: loading data...
# n=4, rep=55: computing statistics...
# n=4, rep=55: fitting Gauss-Legendre parametric prior...
#   8.804578 seconds (228.23 M allocations: 4.168 GiB, 2.09% gc time)
# n=4, rep=55: prior fit done. σ0²=0.9984, ν0=3.947
# n=4, rep=55: computing p-values...
# n=4, rep=55 done → Power=0.36 | FDR=0.048 | TP@100=87
# n=4, rep=56: loading data...
# n=4, rep=56: computing statistics...
# n=4, rep=56: fitting Gauss-Legendre parametric prior...
#   9.448219 seconds (245.45 M allocations: 4.483 GiB, 2.12% gc time)
# n=4, rep=56: prior fit done. σ0²=1.1067, ν0=4.031
# n=4, rep=56: computing p-values...
# n=4, rep=56 done → Power=0.198 | FDR=0.0 | TP@100=70
# n=4, rep=57: loading data...
# n=4, rep=57: computing statistics...
# n=4, rep=57: fitting Gauss-Legendre parametric prior...
#   8.929974 seconds (231.04 M allocations: 4.220 GiB, 2.12% gc time)
# n=4, rep=57: prior fit done. σ0²=1.0757, ν0=3.961
# n=4, rep=57: computing p-values...
# n=4, rep=57 done → Power=0.381 | FDR=0.0 | TP@100=84
# n=4, rep=58: loading data...
# n=4, rep=58: computing statistics...
# n=4, rep=58: fitting Gauss-Legendre parametric prior...
#   8.817218 seconds (228.27 M allocations: 4.169 GiB, 2.12% gc time)
# n=4, rep=58: prior fit done. σ0²=0.9865, ν0=4.529
# n=4, rep=58: computing p-values...
# n=4, rep=58 done → Power=0.441 | FDR=0.024 | TP@100=75
# n=4, rep=59: loading data...
# n=4, rep=59: computing statistics...
# n=4, rep=59: fitting Gauss-Legendre parametric prior...
#   9.150232 seconds (236.89 M allocations: 4.327 GiB, 2.11% gc time)
# n=4, rep=59: prior fit done. σ0²=1.0064, ν0=4.176
# n=4, rep=59: computing p-values...
# n=4, rep=59 done → Power=0.304 | FDR=0.088 | TP@100=83
# n=4, rep=60: loading data...
# n=4, rep=60: computing statistics...
# n=4, rep=60: fitting Gauss-Legendre parametric prior...
#   9.299303 seconds (239.79 M allocations: 4.379 GiB, 2.10% gc time)
# n=4, rep=60: prior fit done. σ0²=1.0379, ν0=4.175
# n=4, rep=60: computing p-values...
# n=4, rep=60 done → Power=0.382 | FDR=0.0 | TP@100=75
# n=4, rep=61: loading data...
# n=4, rep=61: computing statistics...
# n=4, rep=61: fitting Gauss-Legendre parametric prior...
#   9.377243 seconds (242.72 M allocations: 4.433 GiB, 2.13% gc time)
# n=4, rep=61: prior fit done. σ0²=0.9188, ν0=3.89
# n=4, rep=61: computing p-values...
# n=4, rep=61 done → Power=0.172 | FDR=0.062 | TP@100=76
# n=4, rep=62: loading data...
# n=4, rep=62: computing statistics...
# n=4, rep=62: fitting Gauss-Legendre parametric prior...
#   9.055247 seconds (233.99 M allocations: 4.274 GiB, 2.11% gc time)
# n=4, rep=62: prior fit done. σ0²=1.0044, ν0=3.971
# n=4, rep=62: computing p-values...
# n=4, rep=62 done → Power=0.303 | FDR=0.036 | TP@100=79
# n=4, rep=63: loading data...
# n=4, rep=63: computing statistics...
# n=4, rep=63: fitting Gauss-Legendre parametric prior...
#   9.403213 seconds (242.67 M allocations: 4.432 GiB, 2.13% gc time)
# n=4, rep=63: prior fit done. σ0²=0.9594, ν0=3.89
# n=4, rep=63: computing p-values...
# n=4, rep=63 done → Power=0.386 | FDR=0.043 | TP@100=83
# n=4, rep=64: loading data...
# n=4, rep=64: computing statistics...
# n=4, rep=64: fitting Gauss-Legendre parametric prior...
#   8.912291 seconds (231.11 M allocations: 4.221 GiB, 2.11% gc time)
# n=4, rep=64: prior fit done. σ0²=1.0104, ν0=4.09
# n=4, rep=64: computing p-values...
# n=4, rep=64 done → Power=0.33 | FDR=0.0 | TP@100=84
# n=4, rep=65: loading data...
# n=4, rep=65: computing statistics...
# n=4, rep=65: fitting Gauss-Legendre parametric prior...
#   9.086509 seconds (233.99 M allocations: 4.274 GiB, 2.10% gc time)
# n=4, rep=65: prior fit done. σ0²=0.9501, ν0=3.543
# n=4, rep=65: computing p-values...
# n=4, rep=65 done → Power=0.367 | FDR=0.091 | TP@100=80
# n=4, rep=66: loading data...
# n=4, rep=66: computing statistics...
# n=4, rep=66: fitting Gauss-Legendre parametric prior...
#   8.823378 seconds (228.23 M allocations: 4.168 GiB, 2.11% gc time)
# n=4, rep=66: prior fit done. σ0²=0.9481, ν0=3.645
# n=4, rep=66: computing p-values...
# n=4, rep=66 done → Power=0.164 | FDR=0.0 | TP@100=85
# n=4, rep=67: loading data...
# n=4, rep=67: computing statistics...
# n=4, rep=67: fitting Gauss-Legendre parametric prior...
#   9.316400 seconds (239.84 M allocations: 4.380 GiB, 2.18% gc time)
# n=4, rep=67: prior fit done. σ0²=0.9423, ν0=3.789
# n=4, rep=67: computing p-values...
# n=4, rep=67 done → Power=0.257 | FDR=0.0 | TP@100=84
# n=4, rep=68: loading data...
# n=4, rep=68: computing statistics...
# n=4, rep=68: fitting Gauss-Legendre parametric prior...
#   8.723537 seconds (225.35 M allocations: 4.116 GiB, 2.15% gc time)
# n=4, rep=68: prior fit done. σ0²=0.9823, ν0=4.042
# n=4, rep=68: computing p-values...
# n=4, rep=68 done → Power=0.28 | FDR=0.0 | TP@100=86
# n=4, rep=69: loading data...
# n=4, rep=69: computing statistics...
# n=4, rep=69: fitting Gauss-Legendre parametric prior...
#   9.510796 seconds (245.55 M allocations: 4.485 GiB, 2.10% gc time)
# n=4, rep=69: prior fit done. σ0²=0.9786, ν0=3.77
# n=4, rep=69: computing p-values...
# n=4, rep=69 done → Power=0.311 | FDR=0.0 | TP@100=72
# n=4, rep=70: loading data...
# n=4, rep=70: computing statistics...
# n=4, rep=70: fitting Gauss-Legendre parametric prior...
#   9.671690 seconds (248.45 M allocations: 4.538 GiB, 2.10% gc time)
# n=4, rep=70: prior fit done. σ0²=1.0015, ν0=4.188
# n=4, rep=70: computing p-values...
# n=4, rep=70 done → Power=0.455 | FDR=0.048 | TP@100=78
# n=4, rep=71: loading data...
# n=4, rep=71: computing statistics...
# n=4, rep=71: fitting Gauss-Legendre parametric prior...
#   9.174101 seconds (236.87 M allocations: 4.326 GiB, 2.12% gc time)
# n=4, rep=71: prior fit done. σ0²=1.052, ν0=4.498
# n=4, rep=71: computing p-values...
# n=4, rep=71 done → Power=0.109 | FDR=0.0 | TP@100=80
# n=4, rep=72: loading data...
# n=4, rep=72: computing statistics...
# n=4, rep=72: fitting Gauss-Legendre parametric prior...
#   9.282127 seconds (239.81 M allocations: 4.380 GiB, 2.14% gc time)
# n=4, rep=72: prior fit done. σ0²=0.9215, ν0=3.833
# n=4, rep=72: computing p-values...
# n=4, rep=72 done → Power=0.474 | FDR=0.068 | TP@100=86
# n=4, rep=73: loading data...
# n=4, rep=73: computing statistics...
# n=4, rep=73: fitting Gauss-Legendre parametric prior...
#   8.547202 seconds (219.58 M allocations: 4.010 GiB, 2.10% gc time)
# n=4, rep=73: prior fit done. σ0²=0.9654, ν0=4.068
# n=4, rep=73: computing p-values...
# n=4, rep=73 done → Power=0.365 | FDR=0.028 | TP@100=78
# n=4, rep=74: loading data...
# n=4, rep=74: computing statistics...
# n=4, rep=74: fitting Gauss-Legendre parametric prior...
#   9.065381 seconds (234.03 M allocations: 4.274 GiB, 2.09% gc time)
# n=4, rep=74: prior fit done. σ0²=1.0179, ν0=4.263
# n=4, rep=74: computing p-values...
# n=4, rep=74 done → Power=0.224 | FDR=0.05 | TP@100=71
# n=4, rep=75: loading data...
# n=4, rep=75: computing statistics...
# n=4, rep=75: fitting Gauss-Legendre parametric prior...
#   9.551356 seconds (245.44 M allocations: 4.483 GiB, 2.09% gc time)
# n=4, rep=75: prior fit done. σ0²=1.0855, ν0=3.923
# n=4, rep=75: computing p-values...
# n=4, rep=75 done → Power=0.361 | FDR=0.079 | TP@100=76
# n=4, rep=76: loading data...
# n=4, rep=76: computing statistics...
# n=4, rep=76: fitting Gauss-Legendre parametric prior...
#   9.509575 seconds (245.52 M allocations: 4.484 GiB, 2.13% gc time)
# n=4, rep=76: prior fit done. σ0²=1.012, ν0=3.878
# n=4, rep=76: computing p-values...
# n=4, rep=76 done → Power=0.33 | FDR=0.0 | TP@100=80
# n=4, rep=77: loading data...
# n=4, rep=77: computing statistics...
# n=4, rep=77: fitting Gauss-Legendre parametric prior...
#   9.096747 seconds (234.02 M allocations: 4.274 GiB, 2.10% gc time)
# n=4, rep=77: prior fit done. σ0²=0.9183, ν0=3.689
# n=4, rep=77: computing p-values...
# n=4, rep=77 done → Power=0.557 | FDR=0.078 | TP@100=84
# n=4, rep=78: loading data...
# n=4, rep=78: computing statistics...
# n=4, rep=78: fitting Gauss-Legendre parametric prior...
#   9.454579 seconds (242.70 M allocations: 4.433 GiB, 2.11% gc time)
# n=4, rep=78: prior fit done. σ0²=0.9399, ν0=3.8
# n=4, rep=78: computing p-values...
# n=4, rep=78 done → Power=0.52 | FDR=0.073 | TP@100=82
# n=4, rep=79: loading data...
# n=4, rep=79: computing statistics...
# n=4, rep=79: fitting Gauss-Legendre parametric prior...
#   9.756857 seconds (251.30 M allocations: 4.590 GiB, 2.11% gc time)
# n=4, rep=79: prior fit done. σ0²=1.0655, ν0=4.217
# n=4, rep=79: computing p-values...
# n=4, rep=79 done → Power=0.396 | FDR=0.045 | TP@100=87
# n=4, rep=80: loading data...
# n=4, rep=80: computing statistics...
# n=4, rep=80: fitting Gauss-Legendre parametric prior...
#   9.195479 seconds (236.89 M allocations: 4.326 GiB, 2.10% gc time)
# n=4, rep=80: prior fit done. σ0²=1.0212, ν0=3.94
# n=4, rep=80: computing p-values...
# n=4, rep=80 done → Power=0.271 | FDR=0.0 | TP@100=83
# n=4, rep=81: loading data...
# n=4, rep=81: computing statistics...
# n=4, rep=81: fitting Gauss-Legendre parametric prior...
#   8.638428 seconds (222.39 M allocations: 4.062 GiB, 2.08% gc time)
# n=4, rep=81: prior fit done. σ0²=1.0446, ν0=3.962
# n=4, rep=81: computing p-values...
# n=4, rep=81 done → Power=0.485 | FDR=0.107 | TP@100=83
# n=4, rep=82: loading data...
# n=4, rep=82: computing statistics...
# n=4, rep=82: fitting Gauss-Legendre parametric prior...
#   9.199754 seconds (236.88 M allocations: 4.326 GiB, 2.10% gc time)
# n=4, rep=82: prior fit done. σ0²=0.9836, ν0=3.636
# n=4, rep=82: computing p-values...
# n=4, rep=82 done → Power=0.208 | FDR=0.0 | TP@100=76
# n=4, rep=83: loading data...
# n=4, rep=83: computing statistics...
# n=4, rep=83: fitting Gauss-Legendre parametric prior...
#   8.869641 seconds (228.19 M allocations: 4.168 GiB, 2.09% gc time)
# n=4, rep=83: prior fit done. σ0²=1.0085, ν0=3.884
# n=4, rep=83: computing p-values...
# n=4, rep=83 done → Power=0.244 | FDR=0.048 | TP@100=65
# n=4, rep=84: loading data...
# n=4, rep=84: computing statistics...
# n=4, rep=84: fitting Gauss-Legendre parametric prior...
#   9.199061 seconds (236.87 M allocations: 4.326 GiB, 2.09% gc time)
# n=4, rep=84: prior fit done. σ0²=1.0025, ν0=3.921
# n=4, rep=84: computing p-values...
# n=4, rep=84 done → Power=0.411 | FDR=0.026 | TP@100=76
# n=4, rep=85: loading data...
# n=4, rep=85: computing statistics...
# n=4, rep=85: fitting Gauss-Legendre parametric prior...
#   8.990977 seconds (231.10 M allocations: 4.221 GiB, 2.10% gc time)
# n=4, rep=85: prior fit done. σ0²=1.0359, ν0=3.928
# n=4, rep=85: computing p-values...
# n=4, rep=85 done → Power=0.207 | FDR=0.0 | TP@100=77
# n=4, rep=86: loading data...
# n=4, rep=86: computing statistics...
# n=4, rep=86: fitting Gauss-Legendre parametric prior...
#   9.332420 seconds (239.75 M allocations: 4.379 GiB, 2.12% gc time)
# n=4, rep=86: prior fit done. σ0²=1.0937, ν0=4.462
# n=4, rep=86: computing p-values...
# n=4, rep=86 done → Power=0.411 | FDR=0.098 | TP@100=86
# n=4, rep=87: loading data...
# n=4, rep=87: computing statistics...
# n=4, rep=87: fitting Gauss-Legendre parametric prior...
#   9.782038 seconds (251.39 M allocations: 4.591 GiB, 2.10% gc time)
# n=4, rep=87: prior fit done. σ0²=0.98, ν0=4.343
# n=4, rep=87: computing p-values...
# n=4, rep=87 done → Power=0.234 | FDR=0.043 | TP@100=78
# n=4, rep=88: loading data...
# n=4, rep=88: computing statistics...
# n=4, rep=88: fitting Gauss-Legendre parametric prior...
#   9.574694 seconds (245.57 M allocations: 4.485 GiB, 2.10% gc time)
# n=4, rep=88: prior fit done. σ0²=1.0146, ν0=4.329
# n=4, rep=88: computing p-values...
# n=4, rep=88 done → Power=0.235 | FDR=0.08 | TP@100=82
# n=4, rep=89: loading data...
# n=4, rep=89: computing statistics...
# n=4, rep=89: fitting Gauss-Legendre parametric prior...
#   9.460455 seconds (242.67 M allocations: 4.432 GiB, 2.12% gc time)
# n=4, rep=89: prior fit done. σ0²=0.9722, ν0=3.941
# n=4, rep=89: computing p-values...
# n=4, rep=89 done → Power=0.354 | FDR=0.0 | TP@100=77
# n=4, rep=90: loading data...
# n=4, rep=90: computing statistics...
# n=4, rep=90: fitting Gauss-Legendre parametric prior...
#   9.318420 seconds (239.80 M allocations: 4.380 GiB, 2.10% gc time)
# n=4, rep=90: prior fit done. σ0²=0.9657, ν0=3.87
# n=4, rep=90: computing p-values...
# n=4, rep=90 done → Power=0.243 | FDR=0.037 | TP@100=86
# n=4, rep=91: loading data...
# n=4, rep=91: computing statistics...
# n=4, rep=91: fitting Gauss-Legendre parametric prior...
#   9.235131 seconds (236.85 M allocations: 4.326 GiB, 2.10% gc time)
# n=4, rep=91: prior fit done. σ0²=1.0173, ν0=4.012
# n=4, rep=91: computing p-values...
# n=4, rep=91 done → Power=0.25 | FDR=0.04 | TP@100=80
# n=4, rep=92: loading data...
# n=4, rep=92: computing statistics...
# n=4, rep=92: fitting Gauss-Legendre parametric prior...
#   9.004591 seconds (231.12 M allocations: 4.221 GiB, 2.09% gc time)
# n=4, rep=92: prior fit done. σ0²=0.8902, ν0=3.386
# n=4, rep=92: computing p-values...
# n=4, rep=92 done → Power=0.34 | FDR=0.079 | TP@100=81
# n=4, rep=93: loading data...
# n=4, rep=93: computing statistics...
# n=4, rep=93: fitting Gauss-Legendre parametric prior...
#   8.780424 seconds (225.29 M allocations: 4.115 GiB, 2.10% gc time)
# n=4, rep=93: prior fit done. σ0²=1.0951, ν0=4.328
# n=4, rep=93: computing p-values...
# n=4, rep=93 done → Power=0.292 | FDR=0.037 | TP@100=77
# n=4, rep=94: loading data...
# n=4, rep=94: computing statistics...
# n=4, rep=94: fitting Gauss-Legendre parametric prior...
#   9.593299 seconds (245.56 M allocations: 4.485 GiB, 2.10% gc time)
# n=4, rep=94: prior fit done. σ0²=0.9921, ν0=3.846
# n=4, rep=94: computing p-values...
# n=4, rep=94 done → Power=0.363 | FDR=0.0 | TP@100=83
# n=4, rep=95: loading data...
# n=4, rep=95: computing statistics...
# n=4, rep=95: fitting Gauss-Legendre parametric prior...
#   8.989746 seconds (231.14 M allocations: 4.222 GiB, 2.10% gc time)
# n=4, rep=95: prior fit done. σ0²=1.0234, ν0=4.668
# n=4, rep=95: computing p-values...
# n=4, rep=95 done → Power=0.515 | FDR=0.036 | TP@100=84
# n=4, rep=96: loading data...
# n=4, rep=96: computing statistics...
# n=4, rep=96: fitting Gauss-Legendre parametric prior...
#   9.145950 seconds (234.04 M allocations: 4.274 GiB, 2.13% gc time)
# n=4, rep=96: prior fit done. σ0²=0.9433, ν0=3.935
# n=4, rep=96: computing p-values...
# n=4, rep=96 done → Power=0.479 | FDR=0.042 | TP@100=82
# n=4, rep=97: loading data...
# n=4, rep=97: computing statistics...
# n=4, rep=97: fitting Gauss-Legendre parametric prior...
#   9.113858 seconds (234.00 M allocations: 4.274 GiB, 2.09% gc time)
# n=4, rep=97: prior fit done. σ0²=1.0673, ν0=4.634
# n=4, rep=97: computing p-values...
# n=4, rep=97 done → Power=0.39 | FDR=0.093 | TP@100=80
# n=4, rep=98: loading data...
# n=4, rep=98: computing statistics...
# n=4, rep=98: fitting Gauss-Legendre parametric prior...
#   9.462999 seconds (242.60 M allocations: 4.431 GiB, 2.14% gc time)
# n=4, rep=98: prior fit done. σ0²=1.01, ν0=3.744
# n=4, rep=98: computing p-values...
# n=4, rep=98 done → Power=0.269 | FDR=0.03 | TP@100=86
# n=4, rep=99: loading data...
# n=4, rep=99: computing statistics...
# n=4, rep=99: fitting Gauss-Legendre parametric prior...
#   9.168363 seconds (234.04 M allocations: 4.275 GiB, 2.22% gc time)
# n=4, rep=99: prior fit done. σ0²=1.0201, ν0=4.743
# n=4, rep=99: computing p-values...
# n=4, rep=99 done → Power=0.414 | FDR=0.068 | TP@100=79
# n=4, rep=100: loading data...
# n=4, rep=100: computing statistics...
# n=4, rep=100: fitting Gauss-Legendre parametric prior...
#   9.100791 seconds (233.99 M allocations: 4.274 GiB, 2.11% gc time)
# n=4, rep=100: prior fit done. σ0²=0.9936, ν0=3.886
# n=4, rep=100: computing p-values...
# n=4, rep=100 done → Power=0.394 | FDR=0.065 | TP@100=87
# ✅ Done n=4 → Power=0.341 | FDR=0.041 | TP=34.2 | FP=1.7 | TP@100=80.7
#
# ========== Running MAD_mean + parametric prior (Gauss-Legendre) for n = 5 ==========
# n=5, rep=1: loading data...
# n=5, rep=1: computing statistics...
# n=5, rep=1: fitting Gauss-Legendre parametric prior...
#  12.837313 seconds (309.79 M allocations: 5.411 GiB, 1.89% gc time)
# n=5, rep=1: prior fit done. σ0²=0.9493, ν0=3.828
# n=5, rep=1: computing p-values...
# n=5, rep=1 done → Power=0.429 | FDR=0.027 | TP@100=78
# n=5, rep=2: loading data...
# n=5, rep=2: computing statistics...
# n=5, rep=2: fitting Gauss-Legendre parametric prior...
#  10.944467 seconds (264.35 M allocations: 4.617 GiB, 1.86% gc time)
# n=5, rep=2: prior fit done. σ0²=1.0032, ν0=3.721
# n=5, rep=2: computing p-values...
# n=5, rep=2 done → Power=0.49 | FDR=0.058 | TP@100=83
# n=5, rep=3: loading data...
# n=5, rep=3: computing statistics...
# n=5, rep=3: fitting Gauss-Legendre parametric prior...
#  12.950564 seconds (313.57 M allocations: 5.477 GiB, 1.90% gc time)
# n=5, rep=3: prior fit done. σ0²=0.9788, ν0=4.038
# n=5, rep=3: computing p-values...
# n=5, rep=3 done → Power=0.438 | FDR=0.058 | TP@100=91
# n=5, rep=4: loading data...
# n=5, rep=4: computing statistics...
# n=5, rep=4: fitting Gauss-Legendre parametric prior...
#  12.783853 seconds (309.72 M allocations: 5.409 GiB, 1.87% gc time)
# n=5, rep=4: prior fit done. σ0²=1.0818, ν0=4.301
# n=5, rep=4: computing p-values...
# n=5, rep=4 done → Power=0.36 | FDR=0.086 | TP@100=78
# n=5, rep=5: loading data...
# n=5, rep=5: computing statistics...
# n=5, rep=5: fitting Gauss-Legendre parametric prior...
#  12.820216 seconds (309.87 M allocations: 5.412 GiB, 1.89% gc time)
# n=5, rep=5: prior fit done. σ0²=0.9789, ν0=4.577
# n=5, rep=5: computing p-values...
# n=5, rep=5 done → Power=0.31 | FDR=0.129 | TP@100=78
# n=5, rep=6: loading data...
# n=5, rep=6: computing statistics...
# n=5, rep=6: fitting Gauss-Legendre parametric prior...
#  13.021947 seconds (309.74 M allocations: 5.410 GiB, 2.10% gc time)
# n=5, rep=6: prior fit done. σ0²=1.0227, ν0=4.007
# n=5, rep=6: computing p-values...
# n=5, rep=6 done → Power=0.419 | FDR=0.022 | TP@100=89
# n=5, rep=7: loading data...
# n=5, rep=7: computing statistics...
# n=5, rep=7: fitting Gauss-Legendre parametric prior...
#  13.291832 seconds (321.13 M allocations: 5.609 GiB, 1.92% gc time)
# n=5, rep=7: prior fit done. σ0²=0.9894, ν0=3.99
# n=5, rep=7: computing p-values...
# n=5, rep=7 done → Power=0.278 | FDR=0.069 | TP@100=83
# n=5, rep=8: loading data...
# n=5, rep=8: computing statistics...
# n=5, rep=8: fitting Gauss-Legendre parametric prior...
#  13.438251 seconds (324.84 M allocations: 5.674 GiB, 1.91% gc time)
# n=5, rep=8: prior fit done. σ0²=1.0196, ν0=3.986
# n=5, rep=8: computing p-values...
# n=5, rep=8 done → Power=0.385 | FDR=0.024 | TP@100=83
# n=5, rep=9: loading data...
# n=5, rep=9: computing statistics...
# n=5, rep=9: fitting Gauss-Legendre parametric prior...
#  12.352334 seconds (298.47 M allocations: 5.213 GiB, 1.92% gc time)
# n=5, rep=9: prior fit done. σ0²=0.9638, ν0=4.054
# n=5, rep=9: computing p-values...
# n=5, rep=9 done → Power=0.629 | FDR=0.0 | TP@100=91
# n=5, rep=10: loading data...
# n=5, rep=10: computing statistics...
# n=5, rep=10: fitting Gauss-Legendre parametric prior...
#  12.628542 seconds (305.92 M allocations: 5.343 GiB, 1.90% gc time)
# n=5, rep=10: prior fit done. σ0²=1.0078, ν0=3.8
# n=5, rep=10: computing p-values...
# n=5, rep=10 done → Power=0.436 | FDR=0.022 | TP@100=88
# n=5, rep=11: loading data...
# n=5, rep=11: computing statistics...
# n=5, rep=11: fitting Gauss-Legendre parametric prior...
#  13.327859 seconds (324.90 M allocations: 5.675 GiB, 1.94% gc time)
# n=5, rep=11: prior fit done. σ0²=0.9946, ν0=4.236
# n=5, rep=11: computing p-values...
# n=5, rep=11 done → Power=0.474 | FDR=0.053 | TP@100=85
# n=5, rep=12: loading data...
# n=5, rep=12: computing statistics...
# n=5, rep=12: fitting Gauss-Legendre parametric prior...
#  12.361052 seconds (302.19 M allocations: 5.278 GiB, 2.05% gc time)
# n=5, rep=12: prior fit done. σ0²=0.9782, ν0=3.904
# n=5, rep=12: computing p-values...
# n=5, rep=12 done → Power=0.341 | FDR=0.031 | TP@100=76
# n=5, rep=13: loading data...
# n=5, rep=13: computing statistics...
# n=5, rep=13: fitting Gauss-Legendre parametric prior...
#  13.094071 seconds (321.07 M allocations: 5.608 GiB, 1.95% gc time)
# n=5, rep=13: prior fit done. σ0²=1.0355, ν0=4.427
# n=5, rep=13: computing p-values...
# n=5, rep=13 done → Power=0.455 | FDR=0.022 | TP@100=89
# n=5, rep=14: loading data...
# n=5, rep=14: computing statistics...
# n=5, rep=14: fitting Gauss-Legendre parametric prior...
#  13.527998 seconds (332.47 M allocations: 5.807 GiB, 1.94% gc time)
# n=5, rep=14: prior fit done. σ0²=1.0313, ν0=4.583
# n=5, rep=14: computing p-values...
# n=5, rep=14 done → Power=0.544 | FDR=0.051 | TP@100=82
# n=5, rep=15: loading data...
# n=5, rep=15: computing statistics...
# n=5, rep=15: fitting Gauss-Legendre parametric prior...
#  13.031171 seconds (320.99 M allocations: 5.606 GiB, 1.95% gc time)
# n=5, rep=15: prior fit done. σ0²=1.0137, ν0=3.656
# n=5, rep=15: computing p-values...
# n=5, rep=15 done → Power=0.481 | FDR=0.073 | TP@100=88
# n=5, rep=16: loading data...
# n=5, rep=16: computing statistics...
# n=5, rep=16: fitting Gauss-Legendre parametric prior...
#  12.848034 seconds (317.34 M allocations: 5.543 GiB, 1.97% gc time)
# n=5, rep=16: prior fit done. σ0²=0.9667, ν0=3.87
# n=5, rep=16: computing p-values...
# n=5, rep=16 done → Power=0.526 | FDR=0.073 | TP@100=81
# n=5, rep=17: loading data...
# n=5, rep=17: computing statistics...
# n=5, rep=17: fitting Gauss-Legendre parametric prior...
#  12.371907 seconds (305.95 M allocations: 5.344 GiB, 1.97% gc time)
# n=5, rep=17: prior fit done. σ0²=0.9966, ν0=3.843
# n=5, rep=17: computing p-values...
# n=5, rep=17 done → Power=0.323 | FDR=0.03 | TP@100=86
# n=5, rep=18: loading data...
# n=5, rep=18: computing statistics...
# n=5, rep=18: fitting Gauss-Legendre parametric prior...
#  12.369673 seconds (306.06 M allocations: 5.346 GiB, 1.97% gc time)
# n=5, rep=18: prior fit done. σ0²=0.9579, ν0=4.118
# n=5, rep=18: computing p-values...
# n=5, rep=18 done → Power=0.505 | FDR=0.07 | TP@100=87
# n=5, rep=19: loading data...
# n=5, rep=19: computing statistics...
# n=5, rep=19: fitting Gauss-Legendre parametric prior...
#  12.672784 seconds (313.59 M allocations: 5.477 GiB, 1.97% gc time)
# n=5, rep=19: prior fit done. σ0²=0.9747, ν0=4.17
# n=5, rep=19: computing p-values...
# n=5, rep=19 done → Power=0.449 | FDR=0.0 | TP@100=76
# n=5, rep=20: loading data...
# n=5, rep=20: computing statistics...
# n=5, rep=20: fitting Gauss-Legendre parametric prior...
#  13.143061 seconds (324.88 M allocations: 5.674 GiB, 1.98% gc time)
# n=5, rep=20: prior fit done. σ0²=1.056, ν0=4.509
# n=5, rep=20: computing p-values...
# n=5, rep=20 done → Power=0.485 | FDR=0.041 | TP@100=80
# n=5, rep=21: loading data...
# n=5, rep=21: computing statistics...
# n=5, rep=21: fitting Gauss-Legendre parametric prior...
#  12.341389 seconds (306.05 M allocations: 5.346 GiB, 1.96% gc time)
# n=5, rep=21: prior fit done. σ0²=0.9507, ν0=4.154
# n=5, rep=21: computing p-values...
# n=5, rep=21 done → Power=0.418 | FDR=0.0 | TP@100=87
# n=5, rep=22: loading data...
# n=5, rep=22: computing statistics...
# n=5, rep=22: fitting Gauss-Legendre parametric prior...
#  12.055175 seconds (298.40 M allocations: 5.212 GiB, 1.99% gc time)
# n=5, rep=22: prior fit done. σ0²=1.0422, ν0=4.199
# n=5, rep=22: computing p-values...
# n=5, rep=22 done → Power=0.454 | FDR=0.022 | TP@100=85
# n=5, rep=23: loading data...
# n=5, rep=23: computing statistics...
# n=5, rep=23: fitting Gauss-Legendre parametric prior...
#  12.497355 seconds (309.67 M allocations: 5.409 GiB, 1.99% gc time)
# n=5, rep=23: prior fit done. σ0²=1.0766, ν0=3.861
# n=5, rep=23: computing p-values...
# n=5, rep=23 done → Power=0.475 | FDR=0.059 | TP@100=87
# n=5, rep=24: loading data...
# n=5, rep=24: computing statistics...
# n=5, rep=24: fitting Gauss-Legendre parametric prior...
#  12.484414 seconds (309.67 M allocations: 5.409 GiB, 1.98% gc time)
# n=5, rep=24: prior fit done. σ0²=0.9694, ν0=3.452
# n=5, rep=24: computing p-values...
# n=5, rep=24 done → Power=0.539 | FDR=0.068 | TP@100=84
# n=5, rep=25: loading data...
# n=5, rep=25: computing statistics...
# n=5, rep=25: fitting Gauss-Legendre parametric prior...
#  11.563882 seconds (287.16 M allocations: 5.016 GiB, 1.99% gc time)
# n=5, rep=25: prior fit done. σ0²=0.9301, ν0=3.654
# n=5, rep=25: computing p-values...
# n=5, rep=25 done → Power=0.326 | FDR=0.139 | TP@100=76
# n=5, rep=26: loading data...
# n=5, rep=26: computing statistics...
# n=5, rep=26: fitting Gauss-Legendre parametric prior...
#  12.623686 seconds (313.51 M allocations: 5.476 GiB, 1.99% gc time)
# n=5, rep=26: prior fit done. σ0²=0.9772, ν0=3.674
# n=5, rep=26: computing p-values...
# n=5, rep=26 done → Power=0.439 | FDR=0.041 | TP@100=90
# n=5, rep=27: loading data...
# n=5, rep=27: computing statistics...
# n=5, rep=27: fitting Gauss-Legendre parametric prior...
#  12.799728 seconds (317.42 M allocations: 5.544 GiB, 1.99% gc time)
# n=5, rep=27: prior fit done. σ0²=0.9712, ν0=4.45
# n=5, rep=27: computing p-values...
# n=5, rep=27 done → Power=0.496 | FDR=0.066 | TP@100=88
# n=5, rep=28: loading data...
# n=5, rep=28: computing statistics...
# n=5, rep=28: fitting Gauss-Legendre parametric prior...
#  12.158990 seconds (302.15 M allocations: 5.277 GiB, 2.00% gc time)
# n=5, rep=28: prior fit done. σ0²=0.977, ν0=3.605
# n=5, rep=28: computing p-values...
# n=5, rep=28 done → Power=0.445 | FDR=0.102 | TP@100=89
# n=5, rep=29: loading data...
# n=5, rep=29: computing statistics...
# n=5, rep=29: fitting Gauss-Legendre parametric prior...
#  12.461604 seconds (309.70 M allocations: 5.409 GiB, 1.99% gc time)
# n=5, rep=29: prior fit done. σ0²=1.0007, ν0=3.86
# n=5, rep=29: computing p-values...
# n=5, rep=29 done → Power=0.42 | FDR=0.0 | TP@100=82
# n=5, rep=30: loading data...
# n=5, rep=30: computing statistics...
# n=5, rep=30: fitting Gauss-Legendre parametric prior...
#  12.788860 seconds (317.35 M allocations: 5.543 GiB, 1.97% gc time)
# n=5, rep=30: prior fit done. σ0²=0.9926, ν0=4.256
# n=5, rep=30: computing p-values...
# n=5, rep=30 done → Power=0.436 | FDR=0.083 | TP@100=79
# n=5, rep=31: loading data...
# n=5, rep=31: computing statistics...
# n=5, rep=31: fitting Gauss-Legendre parametric prior...
#  12.624619 seconds (313.52 M allocations: 5.476 GiB, 1.97% gc time)
# n=5, rep=31: prior fit done. σ0²=0.9657, ν0=3.825
# n=5, rep=31: computing p-values...
# n=5, rep=31 done → Power=0.474 | FDR=0.043 | TP@100=84
# n=5, rep=32: loading data...
# n=5, rep=32: computing statistics...
# n=5, rep=32: fitting Gauss-Legendre parametric prior...
#  12.304156 seconds (305.93 M allocations: 5.343 GiB, 2.00% gc time)
# n=5, rep=32: prior fit done. σ0²=1.0163, ν0=3.961
# n=5, rep=32: computing p-values...
# n=5, rep=32 done → Power=0.412 | FDR=0.023 | TP@100=85
# n=5, rep=33: loading data...
# n=5, rep=33: computing statistics...
# n=5, rep=33: fitting Gauss-Legendre parametric prior...
#  12.470205 seconds (309.76 M allocations: 5.410 GiB, 1.98% gc time)
# n=5, rep=33: prior fit done. σ0²=1.0391, ν0=4.371
# n=5, rep=33: computing p-values...
# n=5, rep=33 done → Power=0.535 | FDR=0.019 | TP@100=80
# n=5, rep=34: loading data...
# n=5, rep=34: computing statistics...
# n=5, rep=34: fitting Gauss-Legendre parametric prior...
#  12.471265 seconds (309.64 M allocations: 5.408 GiB, 1.97% gc time)
# n=5, rep=34: prior fit done. σ0²=1.0096, ν0=3.589
# n=5, rep=34: computing p-values...
# n=5, rep=34 done → Power=0.423 | FDR=0.022 | TP@100=89
# n=5, rep=35: loading data...
# n=5, rep=35: computing statistics...
# n=5, rep=35: fitting Gauss-Legendre parametric prior...
#  12.471756 seconds (309.74 M allocations: 5.410 GiB, 1.97% gc time)
# n=5, rep=35: prior fit done. σ0²=1.0607, ν0=4.285
# n=5, rep=35: computing p-values...
# n=5, rep=35 done → Power=0.353 | FDR=0.1 | TP@100=77
# n=5, rep=36: loading data...
# n=5, rep=36: computing statistics...
# n=5, rep=36: fitting Gauss-Legendre parametric prior...
#  12.312374 seconds (306.02 M allocations: 5.345 GiB, 2.00% gc time)
# n=5, rep=36: prior fit done. σ0²=0.9284, ν0=3.822
# n=5, rep=36: computing p-values...
# n=5, rep=36 done → Power=0.5 | FDR=0.094 | TP@100=85
# n=5, rep=37: loading data...
# n=5, rep=37: computing statistics...
# n=5, rep=37: fitting Gauss-Legendre parametric prior...
#  11.700865 seconds (290.99 M allocations: 5.082 GiB, 2.00% gc time)
# n=5, rep=37: prior fit done. σ0²=1.01, ν0=4.973
# n=5, rep=37: computing p-values...
# n=5, rep=37 done → Power=0.68 | FDR=0.067 | TP@100=90
# n=5, rep=38: loading data...
# n=5, rep=38: computing statistics...
# n=5, rep=38: fitting Gauss-Legendre parametric prior...
#  12.293912 seconds (305.97 M allocations: 5.344 GiB, 1.98% gc time)
# n=5, rep=38: prior fit done. σ0²=1.0312, ν0=4.25
# n=5, rep=38: computing p-values...
# n=5, rep=38 done → Power=0.52 | FDR=0.073 | TP@100=83
# n=5, rep=39: loading data...
# n=5, rep=39: computing statistics...
# n=5, rep=39: fitting Gauss-Legendre parametric prior...
#  12.009167 seconds (298.33 M allocations: 5.211 GiB, 1.99% gc time)
# n=5, rep=39: prior fit done. σ0²=1.0817, ν0=4.187
# n=5, rep=39: computing p-values...
# n=5, rep=39 done → Power=0.375 | FDR=0.0 | TP@100=89
# n=5, rep=40: loading data...
# n=5, rep=40: computing statistics...
# n=5, rep=40: fitting Gauss-Legendre parametric prior...
#  12.008855 seconds (298.42 M allocations: 5.212 GiB, 1.97% gc time)
# n=5, rep=40: prior fit done. σ0²=1.0523, ν0=4.318
# n=5, rep=40: computing p-values...
# n=5, rep=40 done → Power=0.442 | FDR=0.0 | TP@100=84
# n=5, rep=41: loading data...
# n=5, rep=41: computing statistics...
# n=5, rep=41: fitting Gauss-Legendre parametric prior...
#  12.598660 seconds (313.57 M allocations: 5.477 GiB, 1.98% gc time)
# n=5, rep=41: prior fit done. σ0²=1.0101, ν0=4.321
# n=5, rep=41: computing p-values...
# n=5, rep=41 done → Power=0.545 | FDR=0.068 | TP@100=82
# n=5, rep=42: loading data...
# n=5, rep=42: computing statistics...
# n=5, rep=42: fitting Gauss-Legendre parametric prior...
#  12.448650 seconds (309.74 M allocations: 5.410 GiB, 2.02% gc time)
# n=5, rep=42: prior fit done. σ0²=0.9676, ν0=3.674
# n=5, rep=42: computing p-values...
# n=5, rep=42 done → Power=0.525 | FDR=0.019 | TP@100=82
# n=5, rep=43: loading data...
# n=5, rep=43: computing statistics...
# n=5, rep=43: fitting Gauss-Legendre parametric prior...
#  12.472205 seconds (309.72 M allocations: 5.410 GiB, 1.99% gc time)
# n=5, rep=43: prior fit done. σ0²=1.0479, ν0=4.208
# n=5, rep=43: computing p-values...
# n=5, rep=43 done → Power=0.42 | FDR=0.051 | TP@100=80
# n=5, rep=44: loading data...
# n=5, rep=44: computing statistics...
# n=5, rep=44: fitting Gauss-Legendre parametric prior...
#  12.002656 seconds (298.43 M allocations: 5.212 GiB, 2.00% gc time)
# n=5, rep=44: prior fit done. σ0²=0.9901, ν0=4.044
# n=5, rep=44: computing p-values...
# n=5, rep=44 done → Power=0.404 | FDR=0.05 | TP@100=83
# n=5, rep=45: loading data...
# n=5, rep=45: computing statistics...
# n=5, rep=45: fitting Gauss-Legendre parametric prior...
#  13.045944 seconds (324.86 M allocations: 5.674 GiB, 2.02% gc time)
# n=5, rep=45: prior fit done. σ0²=1.0058, ν0=4.123
# n=5, rep=45: computing p-values...
# n=5, rep=45 done → Power=0.471 | FDR=0.039 | TP@100=85
# n=5, rep=46: loading data...
# n=5, rep=46: computing statistics...
# n=5, rep=46: fitting Gauss-Legendre parametric prior...
# ...
# 195.433099 seconds (2.43 G allocations: 39.225 GiB, 1.00% gc time)
# n=40, rep=53: prior fit done. σ0²=0.993, ν0=4.143
# n=40, rep=53: computing p-values...
# n=40, rep=53 done → Power=0.8 | FDR=0.048 | TP@100=91
# n=40, rep=54: loading data...
# n=40, rep=54: computing statistics...
# n=40, rep=54: fitting Gauss-Legendre parametric prior...
# 200.606471 seconds (2.49 G allocations: 40.209 GiB, 1.00% gc time)
# n=40, rep=54: prior fit done. σ0²=0.9813, ν0=4.367
# n=40, rep=54: computing p-values...
# n=40, rep=54 done → Power=0.838 | FDR=0.079 | TP@100=92
# n=40, rep=55: loading data...
# n=40, rep=55: computing statistics...
# n=40, rep=55: fitting Gauss-Legendre parametric prior...
# 197.375139 seconds (2.45 G allocations: 39.677 GiB, 0.98% gc time)
# n=40, rep=55: prior fit done. σ0²=0.9934, ν0=3.889
# n=40, rep=55: computing p-values...
# n=40, rep=55 done → Power=0.779 | FDR=0.104 | TP@100=71
# n=40, rep=56: loading data...
# n=40, rep=56: computing statistics...
# n=40, rep=56: fitting Gauss-Legendre parametric prior...
# 189.899622 seconds (2.36 G allocations: 38.230 GiB, 1.00% gc time)
# n=40, rep=56: prior fit done. σ0²=1.0069, ν0=3.798
# n=40, rep=56: computing p-values...
# n=40, rep=56 done → Power=0.802 | FDR=0.028 | TP@100=79
# n=40, rep=57: loading data...
# n=40, rep=57: computing statistics...
# n=40, rep=57: fitting Gauss-Legendre parametric prior...
# 199.436887 seconds (2.48 G allocations: 40.159 GiB, 0.99% gc time)
# n=40, rep=57: prior fit done. σ0²=1.0199, ν0=3.915
# n=40, rep=57: computing p-values...
# n=40, rep=57 done → Power=0.75 | FDR=0.04 | TP@100=87
# n=40, rep=58: loading data...
# n=40, rep=58: computing statistics...
# n=40, rep=58: fitting Gauss-Legendre parametric prior...
# 197.276886 seconds (2.45 G allocations: 39.666 GiB, 1.00% gc time)
# n=40, rep=58: prior fit done. σ0²=0.9915, ν0=3.75
# n=40, rep=58: computing p-values...
# n=40, rep=58 done → Power=0.822 | FDR=0.074 | TP@100=92
# n=40, rep=59: loading data...
# n=40, rep=59: computing statistics...
# n=40, rep=59: fitting Gauss-Legendre parametric prior...
# 200.501980 seconds (2.45 G allocations: 39.685 GiB, 1.02% gc time)
# n=40, rep=59: prior fit done. σ0²=0.9753, ν0=3.974
# n=40, rep=59: computing p-values...
# n=40, rep=59 done → Power=0.835 | FDR=0.0 | TP@100=77
# n=40, rep=60: loading data...
# n=40, rep=60: computing statistics...
# n=40, rep=60: fitting Gauss-Legendre parametric prior...
# 195.758245 seconds (2.39 G allocations: 38.738 GiB, 1.10% gc time)
# n=40, rep=60: prior fit done. σ0²=0.9714, ν0=4.114
# n=40, rep=60: computing p-values...
# n=40, rep=60 done → Power=0.828 | FDR=0.057 | TP@100=88
# n=40, rep=61: loading data...
# n=40, rep=61: computing statistics...
# n=40, rep=61: fitting Gauss-Legendre parametric prior...
# 188.337883 seconds (2.33 G allocations: 37.757 GiB, 0.99% gc time)
# n=40, rep=61: prior fit done. σ0²=0.9651, ν0=3.896
# n=40, rep=61: computing p-values...
# n=40, rep=61 done → Power=0.771 | FDR=0.0 | TP@100=94
# n=40, rep=62: loading data...
# n=40, rep=62: computing statistics...
# n=40, rep=62: fitting Gauss-Legendre parametric prior...
# 197.586456 seconds (2.45 G allocations: 39.680 GiB, 1.02% gc time)
# n=40, rep=62: prior fit done. σ0²=1.008, ν0=3.957
# n=40, rep=62: computing p-values...
# n=40, rep=62 done → Power=0.765 | FDR=0.058 | TP@100=80
# n=40, rep=63: loading data...
# n=40, rep=63: computing statistics...
# n=40, rep=63: fitting Gauss-Legendre parametric prior...
# 187.671426 seconds (2.31 G allocations: 37.277 GiB, 1.02% gc time)
# n=40, rep=63: prior fit done. σ0²=0.9859, ν0=3.796
# n=40, rep=63: computing p-values...
# n=40, rep=63 done → Power=0.867 | FDR=0.034 | TP@100=92
# n=40, rep=64: loading data...
# n=40, rep=64: computing statistics...
# n=40, rep=64: fitting Gauss-Legendre parametric prior...
# 204.015915 seconds (2.45 G allocations: 39.694 GiB, 1.06% gc time)
# n=40, rep=64: prior fit done. σ0²=1.0032, ν0=3.953
# n=40, rep=64: computing p-values...
# n=40, rep=64 done → Power=0.764 | FDR=0.023 | TP@100=91
# n=40, rep=65: loading data...
# n=40, rep=65: computing statistics...
# n=40, rep=65: fitting Gauss-Legendre parametric prior...
# 188.840687 seconds (2.31 G allocations: 37.280 GiB, 1.02% gc time)
# n=40, rep=65: prior fit done. σ0²=0.9785, ν0=3.878
# n=40, rep=65: computing p-values...
# n=40, rep=65 done → Power=0.821 | FDR=0.025 | TP@100=88
# n=40, rep=66: loading data...
# n=40, rep=66: computing statistics...
# n=40, rep=66: fitting Gauss-Legendre parametric prior...
# 191.837629 seconds (2.31 G allocations: 37.328 GiB, 1.01% gc time)
# n=40, rep=66: prior fit done. σ0²=1.0474, ν0=4.128
# n=40, rep=66: computing p-values...
# n=40, rep=66 done → Power=0.703 | FDR=0.03 | TP@100=80
# n=40, rep=67: loading data...
# n=40, rep=67: computing statistics...
# n=40, rep=67: fitting Gauss-Legendre parametric prior...
# 204.741156 seconds (2.48 G allocations: 40.155 GiB, 0.99% gc time)
# n=40, rep=67: prior fit done. σ0²=0.9663, ν0=3.997
# n=40, rep=67: computing p-values...
# n=40, rep=67 done → Power=0.824 | FDR=0.096 | TP@100=82
# n=40, rep=68: loading data...
# n=40, rep=68: computing statistics...
# n=40, rep=68: fitting Gauss-Legendre parametric prior...
# 205.694699 seconds (2.45 G allocations: 39.697 GiB, 1.02% gc time)
# n=40, rep=68: prior fit done. σ0²=0.9963, ν0=4.173
# n=40, rep=68: computing p-values...
# n=40, rep=68 done → Power=0.859 | FDR=0.045 | TP@100=91
# n=40, rep=69: loading data...
# n=40, rep=69: computing statistics...
# n=40, rep=69: fitting Gauss-Legendre parametric prior...
# 197.780774 seconds (2.37 G allocations: 38.253 GiB, 1.03% gc time)
# n=40, rep=69: prior fit done. σ0²=1.0107, ν0=4.063
# n=40, rep=69: computing p-values...
# n=40, rep=69 done → Power=0.852 | FDR=0.019 | TP@100=100
# n=40, rep=70: loading data...
# n=40, rep=70: computing statistics...
# n=40, rep=70: fitting Gauss-Legendre parametric prior...
# 196.222901 seconds (2.33 G allocations: 37.762 GiB, 1.02% gc time)
# n=40, rep=70: prior fit done. σ0²=0.9866, ν0=3.974
# n=40, rep=70: computing p-values...
# n=40, rep=70 done → Power=0.78 | FDR=0.023 | TP@100=96
# n=40, rep=71: loading data...
# n=40, rep=71: computing statistics...
# n=40, rep=71: fitting Gauss-Legendre parametric prior...
# 202.801163 seconds (2.43 G allocations: 39.243 GiB, 0.99% gc time)
# n=40, rep=71: prior fit done. σ0²=0.9896, ν0=4.283
# n=40, rep=71: computing p-values...
# n=40, rep=71 done → Power=0.76 | FDR=0.027 | TP@100=85
# n=40, rep=72: loading data...
# n=40, rep=72: computing statistics...
# n=40, rep=72: fitting Gauss-Legendre parametric prior...
# 197.379464 seconds (2.34 G allocations: 37.792 GiB, 1.00% gc time)
# n=40, rep=72: prior fit done. σ0²=0.987, ν0=4.153
# n=40, rep=72: computing p-values...
# n=40, rep=72 done → Power=0.828 | FDR=0.025 | TP@100=88
# n=40, rep=73: loading data...
# n=40, rep=73: computing statistics...
# n=40, rep=73: fitting Gauss-Legendre parametric prior...
# 200.974941 seconds (2.42 G allocations: 39.211 GiB, 0.97% gc time)
# n=40, rep=73: prior fit done. σ0²=1.0005, ν0=3.999
# n=40, rep=73: computing p-values...
# n=40, rep=73 done → Power=0.78 | FDR=0.037 | TP@100=88
# n=40, rep=74: loading data...
# n=40, rep=74: computing statistics...
# n=40, rep=74: fitting Gauss-Legendre parametric prior...
# 202.648565 seconds (2.46 G allocations: 39.716 GiB, 0.99% gc time)
# n=40, rep=74: prior fit done. σ0²=1.0099, ν0=4.226
# n=40, rep=74: computing p-values...
# n=40, rep=74 done → Power=0.809 | FDR=0.05 | TP@100=86
# n=40, rep=75: loading data...
# n=40, rep=75: computing statistics...
# n=40, rep=75: fitting Gauss-Legendre parametric prior...
# 193.979633 seconds (2.36 G allocations: 38.243 GiB, 0.98% gc time)
# n=40, rep=75: prior fit done. σ0²=0.9993, ν0=3.951
# n=40, rep=75: computing p-values...
# n=40, rep=75 done → Power=0.86 | FDR=0.012 | TP@100=89
# n=40, rep=76: loading data...
# n=40, rep=76: computing statistics...
# n=40, rep=76: fitting Gauss-Legendre parametric prior...
# 190.805271 seconds (2.34 G allocations: 37.763 GiB, 0.98% gc time)
# n=40, rep=76: prior fit done. σ0²=0.9915, ν0=3.845
# n=40, rep=76: computing p-values...
# n=40, rep=76 done → Power=0.815 | FDR=0.085 | TP@100=83
# n=40, rep=77: loading data...
# n=40, rep=77: computing statistics...
# n=40, rep=77: fitting Gauss-Legendre parametric prior...
# 202.534962 seconds (2.48 G allocations: 40.163 GiB, 0.98% gc time)
# n=40, rep=77: prior fit done. σ0²=0.9823, ν0=3.97
# n=40, rep=77: computing p-values...
# n=40, rep=77 done → Power=0.92 | FDR=0.061 | TP@100=93
# n=40, rep=78: loading data...
# n=40, rep=78: computing statistics...
# n=40, rep=78: fitting Gauss-Legendre parametric prior...
# 212.036653 seconds (2.54 G allocations: 41.149 GiB, 1.02% gc time)
# n=40, rep=78: prior fit done. σ0²=1.0253, ν0=4.179
# n=40, rep=78: computing p-values...
# n=40, rep=78 done → Power=0.848 | FDR=0.034 | TP@100=89
# n=40, rep=79: loading data...
# n=40, rep=79: computing statistics...
# n=40, rep=79: fitting Gauss-Legendre parametric prior...
# 192.193131 seconds (2.34 G allocations: 37.780 GiB, 1.00% gc time)
# n=40, rep=79: prior fit done. σ0²=1.0134, ν0=4.247
# n=40, rep=79: computing p-values...
# n=40, rep=79 done → Power=0.848 | FDR=0.045 | TP@100=90
# n=40, rep=80: loading data...
# n=40, rep=80: computing statistics...
# n=40, rep=80: fitting Gauss-Legendre parametric prior...
# 208.494035 seconds (2.54 G allocations: 41.095 GiB, 1.00% gc time)
# n=40, rep=80: prior fit done. σ0²=1.0243, ν0=3.747
# n=40, rep=80: computing p-values...
# n=40, rep=80 done → Power=0.875 | FDR=0.045 | TP@100=87
# n=40, rep=81: loading data...
# n=40, rep=81: computing statistics...
# n=40, rep=81: fitting Gauss-Legendre parametric prior...
# 188.827063 seconds (2.33 G allocations: 37.755 GiB, 0.99% gc time)
# n=40, rep=81: prior fit done. σ0²=0.9771, ν0=3.771
# n=40, rep=81: computing p-values...
# n=40, rep=81 done → Power=0.891 | FDR=0.02 | TP@100=98
# n=40, rep=82: loading data...
# n=40, rep=82: computing statistics...
# n=40, rep=82: fitting Gauss-Legendre parametric prior...
# 185.366894 seconds (2.31 G allocations: 37.271 GiB, 1.00% gc time)
# n=40, rep=82: prior fit done. σ0²=1.0074, ν0=3.825
# n=40, rep=82: computing p-values...
# n=40, rep=82 done → Power=0.838 | FDR=0.056 | TP@100=77
# n=40, rep=83: loading data...
# n=40, rep=83: computing statistics...
# n=40, rep=83: fitting Gauss-Legendre parametric prior...
# 194.949942 seconds (2.43 G allocations: 39.215 GiB, 0.99% gc time)
# n=40, rep=83: prior fit done. σ0²=1.008, ν0=3.984
# n=40, rep=83: computing p-values...
# n=40, rep=83 done → Power=0.892 | FDR=0.075 | TP@100=95
# n=40, rep=84: loading data...
# n=40, rep=84: computing statistics...
# n=40, rep=84: fitting Gauss-Legendre parametric prior...
# 186.079656 seconds (2.31 G allocations: 37.337 GiB, 0.99% gc time)
# n=40, rep=84: prior fit done. σ0²=0.9813, ν0=4.314
# n=40, rep=84: computing p-values...
# n=40, rep=84 done → Power=0.824 | FDR=0.056 | TP@100=91
# n=40, rep=85: loading data...
# n=40, rep=85: computing statistics...
# n=40, rep=85: fitting Gauss-Legendre parametric prior...
# 194.265946 seconds (2.43 G allocations: 39.217 GiB, 1.00% gc time)
# n=40, rep=85: prior fit done. σ0²=1.0824, ν0=4.05
# n=40, rep=85: computing p-values...
# n=40, rep=85 done → Power=0.812 | FDR=0.013 | TP@100=87
# n=40, rep=86: loading data...
# n=40, rep=86: computing statistics...
# n=40, rep=86: fitting Gauss-Legendre parametric prior...
# 195.065857 seconds (2.42 G allocations: 39.215 GiB, 0.99% gc time)
# n=40, rep=86: prior fit done. σ0²=0.9997, ν0=4.18
# n=40, rep=86: computing p-values...
# n=40, rep=86 done → Power=0.83 | FDR=0.031 | TP@100=96
# n=40, rep=87: loading data...
# n=40, rep=87: computing statistics...
# n=40, rep=87: fitting Gauss-Legendre parametric prior...
# 199.932364 seconds (2.49 G allocations: 40.206 GiB, 0.99% gc time)
# n=40, rep=87: prior fit done. σ0²=1.0014, ν0=4.127
# n=40, rep=87: computing p-values...
# n=40, rep=87 done → Power=0.83 | FDR=0.024 | TP@100=90
# n=40, rep=88: loading data...
# n=40, rep=88: computing statistics...
# n=40, rep=88: fitting Gauss-Legendre parametric prior...
# 196.837552 seconds (2.43 G allocations: 39.227 GiB, 1.01% gc time)
# n=40, rep=88: prior fit done. σ0²=1.0251, ν0=4.152
# n=40, rep=88: computing p-values...
# n=40, rep=88 done → Power=0.74 | FDR=0.027 | TP@100=88
# n=40, rep=89: loading data...
# n=40, rep=89: computing statistics...
# n=40, rep=89: fitting Gauss-Legendre parametric prior...
# 190.387415 seconds (2.31 G allocations: 37.328 GiB, 1.04% gc time)
# n=40, rep=89: prior fit done. σ0²=0.9869, ν0=4.126
# n=40, rep=89: computing p-values...
# n=40, rep=89 done → Power=0.836 | FDR=0.036 | TP@100=98
# n=40, rep=90: loading data...
# n=40, rep=90: computing statistics...
# n=40, rep=90: fitting Gauss-Legendre parametric prior...
# 193.871658 seconds (2.34 G allocations: 37.800 GiB, 1.03% gc time)
# n=40, rep=90: prior fit done. σ0²=0.9803, ν0=4.166
# n=40, rep=90: computing p-values...
# n=40, rep=90 done → Power=0.891 | FDR=0.082 | TP@100=91
# n=40, rep=91: loading data...
# n=40, rep=91: computing statistics...
# n=40, rep=91: fitting Gauss-Legendre parametric prior...
# 209.333788 seconds (2.51 G allocations: 40.637 GiB, 1.05% gc time)
# n=40, rep=91: prior fit done. σ0²=0.9685, ν0=3.902
# n=40, rep=91: computing p-values...
# n=40, rep=91 done → Power=0.74 | FDR=0.026 | TP@100=90
# n=40, rep=92: loading data...
# n=40, rep=92: computing statistics...
# n=40, rep=92: fitting Gauss-Legendre parametric prior...
# 201.233904 seconds (2.43 G allocations: 39.224 GiB, 1.01% gc time)
# n=40, rep=92: prior fit done. σ0²=1.0114, ν0=3.846
# n=40, rep=92: computing p-values...
# n=40, rep=92 done → Power=0.748 | FDR=0.059 | TP@100=90
# n=40, rep=93: loading data...
# n=40, rep=93: computing statistics...
# n=40, rep=93: fitting Gauss-Legendre parametric prior...
# 195.414037 seconds (2.40 G allocations: 38.743 GiB, 1.02% gc time)
# n=40, rep=93: prior fit done. σ0²=0.9985, ν0=4.013
# n=40, rep=93: computing p-values...
# n=40, rep=93 done → Power=0.819 | FDR=0.075 | TP@100=89
# n=40, rep=94: loading data...
# n=40, rep=94: computing statistics...
# n=40, rep=94: fitting Gauss-Legendre parametric prior...
# 195.413127 seconds (2.42 G allocations: 39.193 GiB, 0.99% gc time)
# n=40, rep=94: prior fit done. σ0²=0.9591, ν0=3.863
# n=40, rep=94: computing p-values...
# n=40, rep=94 done → Power=0.804 | FDR=0.075 | TP@100=91
# n=40, rep=95: loading data...
# n=40, rep=95: computing statistics...
# n=40, rep=95: fitting Gauss-Legendre parametric prior...
# 183.260199 seconds (2.28 G allocations: 36.811 GiB, 0.99% gc time)
# n=40, rep=95: prior fit done. σ0²=0.9918, ν0=4.034
# n=40, rep=95: computing p-values...
# n=40, rep=95 done → Power=0.888 | FDR=0.04 | TP@100=96
# n=40, rep=96: loading data...
# n=40, rep=96: computing statistics...
# n=40, rep=96: fitting Gauss-Legendre parametric prior...
# 192.809666 seconds (2.40 G allocations: 38.766 GiB, 0.99% gc time)
# n=40, rep=96: prior fit done. σ0²=1.0149, ν0=4.197
# n=40, rep=96: computing p-values...
# n=40, rep=96 done → Power=0.86 | FDR=0.044 | TP@100=94
# n=40, rep=97: loading data...
# n=40, rep=97: computing statistics...
# n=40, rep=97: fitting Gauss-Legendre parametric prior...
# 197.673002 seconds (2.46 G allocations: 39.718 GiB, 0.99% gc time)
# n=40, rep=97: prior fit done. σ0²=1.0064, ν0=4.28
# n=40, rep=97: computing p-values...
# n=40, rep=97 done → Power=0.797 | FDR=0.0 | TP@100=76
# n=40, rep=98: loading data...
# n=40, rep=98: computing statistics...
# n=40, rep=98: fitting Gauss-Legendre parametric prior...
# 199.927443 seconds (2.48 G allocations: 40.155 GiB, 1.00% gc time)
# n=40, rep=98: prior fit done. σ0²=0.9888, ν0=3.891
# n=40, rep=98: computing p-values...
# n=40, rep=98 done → Power=0.83 | FDR=0.046 | TP@100=91
# n=40, rep=99: loading data...
# n=40, rep=99: computing statistics...
# n=40, rep=99: fitting Gauss-Legendre parametric prior...
# 185.458307 seconds (2.31 G allocations: 37.309 GiB, 0.99% gc time)
# n=40, rep=99: prior fit done. σ0²=1.0208, ν0=4.008
# n=40, rep=99: computing p-values...
# n=40, rep=99 done → Power=0.744 | FDR=0.059 | TP@100=77
# n=40, rep=100: loading data...
# n=40, rep=100: computing statistics...
# n=40, rep=100: fitting Gauss-Legendre parametric prior...
# 194.981968 seconds (2.42 G allocations: 39.202 GiB, 0.99% gc time)
# n=40, rep=100: prior fit done. σ0²=0.9832, ν0=3.933
# n=40, rep=100: computing p-values...
# n=40, rep=100 done → Power=0.874 | FDR=0.0 | TP@100=90
# ✅ Done n=40 → Power=0.823 | FDR=0.046 | TP=82.1 | FP=4.0 | TP@100=89.0

# %%
mad_param_gl_prior_summary
# Out:
# Dict{String, Vector} with 3 entries:
#   "sigma0_sq_mean" => [1.17757, 1.31108, 1.46904, 1.7392, 1.95597, 2.65593, 3.0…
#   "nu0_mean"       => [1.12326, 1.1584, 1.20799, 1.30435, 1.39848, 1.83332, 2.1…
#   "n"              => [4, 5, 6, 8, 10, 20, 30, 40]

# %%
# =========================================================
# Final summary
# =========================================================
println(
    "\n========== MAD NP SUMMARY ACROSS SAMPLE SIZES =========="
)

for i in eachindex(mad_param_gl_prior_summary["n"])

    println(
        "n = $(mad_param_gl_summary["n"][i]) → " *
        "TP=$(round(mad_param_gl_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_param_gl_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_param_gl_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_param_gl_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(mad_param_gl_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== MAD NP SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=34.16, FP=1.66, Power=0.3414, FDR=0.04142, TP@100=80.69
# n = 5 → TP=43.38, FP=2.2, Power=0.43097, FDR=0.04746, TP@100=82.16
# n = 6 → TP=49.86, FP=2.75, Power=0.49741, FDR=0.05082, TP@100=82.83
# n = 8 → TP=58.79, FP=2.96, Power=0.58614, FDR=0.04606, TP@100=84.61
# n = 10 → TP=65.51, FP=3.18, Power=0.65106, FDR=0.0455, TP@100=85.62
# n = 20 → TP=76.02, FP=3.69, Power=0.75787, FDR=0.04532, TP@100=87.71
# n = 30 → TP=79.44, FP=3.81, Power=0.80564, FDR=0.04476, TP@100=88.16
# n = 40 → TP=82.12, FP=4.0, Power=0.82318, FDR=0.04557, TP@100=89.0

# %% [markdown]
# ## MAD Np

# %%
using Distributions, ApproxFun, SpecialFunctions, QuadGK

# ---- distribution type ----
struct MADDistribution{T<:Real,S<:Integer} <: ContinuousUnivariateDistribution
    σ::T
    n::S
end

# ---- import functions we will EXTEND from Distributions ----
import Distributions: pdf, logpdf, insupport, minimum, maximum

# ---- your helpers (unchanged) ----
function G_recursive(max_r::Int; a=0.0, b=100)
    d = Interval(a, b)
    G = Vector{Fun}(undef, max_r+1)
    G[1] = Fun(x -> 1.0, d)
    for r in 1:max_r
        integrand = Fun(x -> exp(-(x^2)/(2r*(r+1))), d) * G[r]
        G[r+1] = cumsum(integrand)
    end
    return G
end

const _Gcache = Dict{Int,Vector{Fun}}()
_getG(n) = get!(_Gcache, n) do; G_recursive(n) end

function _pdf_sigma1(n::Int, m::Real)
    m < 0 && return zero(float(m))          # support m ≥ 0
    z   = n*m/2
    cst = n^(3/2) / (2^((n+1)/2) * π^((n-1)/2))
    G   = _getG(n)
    s   = 0.0
    @inbounds for k in 1:(n-1)
        s += binomial(n,k) * exp(-(m^2 * n^3)/(8k*(n-k))) * G[k](z) * G[n-k](z)
    end
    return cst*s
end

# ---- extend Distributions API ----
# support (MAD ≥ 0)
insupport(::MADDistribution, x::Real) = x ≥ 0
minimum(::MADDistribution) = 0.0
maximum(::MADDistribution) = Inf

# pdf / logpdf (general σ via scaling)
pdf(d::MADDistribution, m::Real) =
    m < 0 ? 0.0 : (1 / d.σ) * _pdf_sigma1(d.n, m / d.σ)

# logpdf(d::MADDistribution, m::Real) =
#     m < 0 ? -Inf : log(pdf(d, m))


# optional convenience
Base.:*(d::MADDistribution, s::Real) = MADDistribution(d.σ * s, d.n)
Base.:*(s::Real, d::MADDistribution) = d * s

using StatsFuns: logsumexp  # you may need to `Pkg.add("StatsFuns")`

function logpdf(d::MADDistribution, m::Real)
    m < 0 && return -Inf
    σ, n = d.σ, d.n

    # Constants
    z   = n * m / (2σ)
    logC = (3/2)*log(n) - ((n+1)/2)*log(2) - ((n-1)/2)*log(π)
    G = _getG(n)

    # Compute all log-terms (inside the sum)
    logs = Float64[]
    for k in 1:(n-1)
        val1 = G[k](z)
        val2 = G[n-k](z)
        if val1 > 0 && val2 > 0
            logterm = log(binomial(n,k)) -
                      (m^2 * n^3)/(8σ^2 * k*(n-k)) +
                      log(val1) + log(val2)
            push!(logs, logterm)
        end
    end

    # Combine safely
    logsum = isempty(logs) ? -Inf : logsumexp(logs)
    return -log(σ) + logC + logsum
end

using Empirikos, Distributions

# 1) evidence type — must subtype EBayesSample
struct MADSample{T,S} <: Empirikos.EBayesSample{T}
    Z::T   # observed MAD
    n::S   # sample size
end

# 2) likelihood at a given σ (must return a Distributions.jl object)
Empirikos.likelihood_distribution(Z::MADSample, σ) = MADDistribution(σ, Z.n)
# Ensure MADDistribution(σ, n) implements pdf/logpdf

# 3) components() for convex prior machinery (vector of likelihoods over σ-support)
Empirikos.components(convexclass::Empirikos.DiscretePriorClass, Z::MADSample) =
    Empirikos.likelihood_distribution.(Ref(Z), Empirikos.support(convexclass))



# limma-style p-value averaged over the posterior on σ
function Empirikos.limma_pvalue(β̂, Z::MADSample, prior::Empirikos.DiscreteNonParametric)
    post = Empirikos.posterior(Z, prior)
    # println("finish post: ")
    # print(post)

    # println(post)
    σs   = Empirikos.support(post)
    # println("finish σs")
    πs   = Empirikos.probs(post)
    # println("finish πs")
    tails = 2 .* ccdf.(Normal.(0, σs), abs(β̂))
    # println("finish tails")
    dot(tails, πs)
    # println("finish dot")
end

# %%
# =========================================================
# Storage for summary results
# =========================================================
mad_summary = Dict(
    "n" => Int[],
    "TP" => Float64[],
    "FP" => Float64[],
    "Power" => Float64[],
    "FDR" => Float64[],
    "TP_top100" => Float64[]
)

# Store full raw p-values for every successful replicate
mad_pvals_store = Dict{Tuple{Int,Int}, Vector{Float64}}()

# Store replicate-level TP@100
mad_top100_store = Dict{Tuple{Int,Int}, Int}()


# =========================================================
# Loop over sample sizes
# =========================================================
for n in n_values

    println("\n========== Running MAD (NP) simulation for n = $n ==========")

    tp_vals     = Float64[]
    fp_vals     = Float64[]
    power_vals  = Float64[]
    fdr_vals    = Float64[]
    top100_vals = Float64[]


    for r in 1:R

        try
            # -------------------------------------------------
            # Get simulated dataset
            # -------------------------------------------------
            Y     = datasets[(n,r)].Y
            is_DE = datasets[(n,r)].is_DE
            σ     = datasets[(n,r)].σ


            # -------------------------------------------------
            # Compute statistics
            # -------------------------------------------------
            β_hat = [
                mean(Y[i])
                for i in 1:G
            ]

            mad_obs = [
                mean(abs.(Y[i] .- β_hat[i]))
                for i in 1:G
            ]

            β_tilde = sqrt(n) .* β_hat


            # -------------------------------------------------
            # Fit NPMLE prior from MAD samples
            # -------------------------------------------------
            Zs_mad = [
                MADSample(mad_obs[i], n)
                for i in 1:G
            ]


            # Grid based on observed MAD values
            σ_grid_raw = sort(unique(mad_obs))

            n_grid = 200

            σ_grid = quantile(
                σ_grid_raw,
                range(0, 1; length=n_grid)
            )

            prior_class =
                Empirikos.DiscretePriorClass(σ_grid)

            npmle = Empirikos.NPMLE(
                prior_class,
                Hypatia.Optimizer
            )

            fitres = Empirikos.fit(
                npmle,
                Zs_mad
            )

            prior_hat =
                Empirikos.clean(fitres.prior)


            # -------------------------------------------------
            # Compute RAW MAD p-values
            # -------------------------------------------------
            pvals = [
                Empirikos.limma_pvalue(
                    β_tilde[i],
                    Zs_mad[i],
                    prior_hat
                )
                for i in 1:G
            ]


            # =================================================
            # SAVE RAW P-VALUES
            # =================================================
            mad_pvals_store[(n,r)] = copy(pvals)


            # -------------------------------------------------
            # BH adjustment for rejection-based analysis
            # -------------------------------------------------
            adj_p = adjust(
                pvals,
                BenjaminiHochberg()
            )

            rej = adj_p .<= 0.05


            # =================================================
            # Standard rejection-based metrics
            # =================================================
            TP = sum(rej .& is_DE)
            FP = sum(rej .& .!is_DE)

            power =
                TP / max(sum(is_DE), 1)

            fdr =
                FP / max(sum(rej), 1)


            # =================================================
            # Ranking metric:
            # true DE genes among 100 smallest RAW p-values
            # =================================================
            k = min(100, G)

            ord = sortperm(pvals)

            top_idx = ord[1:k]

            TP_top100 = sum(is_DE[top_idx])


            # Store replicate-level ranking result
            mad_top100_store[(n,r)] = TP_top100


            # -------------------------------------------------
            # Collect replicate metrics
            # -------------------------------------------------
            push!(tp_vals, TP)
            push!(fp_vals, FP)

            push!(power_vals, power)
            push!(fdr_vals, fdr)

            push!(top100_vals, TP_top100)


            if r % 10 == 0

                println(
                    "Rep $r → " *
                    "Power=$(round(power, digits=3)) | " *
                    "FDR=$(round(fdr, digits=3)) | " *
                    "TP@100=$TP_top100"
                )

            end


        catch e

            @warn "Skipping Rep $r for n=$n due to error: $e"

            continue
        end
    end


    # =========================================================
    # Summarize for this n
    # =========================================================
    mean_TP     = mean(tp_vals)
    mean_FP     = mean(fp_vals)

    mean_power  = mean(power_vals)
    mean_fdr    = mean(fdr_vals)

    mean_top100 = mean(top100_vals)


    push!(mad_summary["n"], n)

    push!(mad_summary["TP"], mean_TP)
    push!(mad_summary["FP"], mean_FP)

    push!(mad_summary["Power"], mean_power)
    push!(mad_summary["FDR"], mean_fdr)

    push!(
        mad_summary["TP_top100"],
        mean_top100
    )


    println(
        "✅ Done n=$n → " *
        "Power=$(round(mean_power, digits=3)) | " *
        "FDR=$(round(mean_fdr, digits=3)) | " *
        "TP=$(round(mean_TP, digits=1)) | " *
        "FP=$(round(mean_FP, digits=1)) | " *
        "TP@100=$(round(mean_top100, digits=1))"
    )
end


# =========================================================
# Final summary
# =========================================================
println(
    "\n========== MAD NP SUMMARY ACROSS SAMPLE SIZES =========="
)

for i in eachindex(mad_summary["n"])

    println(
        "n = $(mad_summary["n"][i]) → " *
        "TP=$(round(mad_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_summary["FDR"][i], digits=5)), " *
        "TP@100=$(round(mad_summary["TP_top100"][i], digits=3))"
    )
end
# Out:
# ========== Running MAD (NP) simulation for n = 4 ==========
#
#  iter        p_obj        d_obj |  abs_gap    x_feas    z_feas |      tau       kap        mu | dir_res     prox  step     alpha
#     0   3.2373e-02  -4.1835e+02 | 2.20e+03  1.90e+02  2.09e+00 | 1.00e+00  1.00e+00  1.00e+00 |
#     1  -4.6289e-01  -4.2501e+02 | 2.09e+03  1.93e+02  2.12e+00 | 9.36e-01  1.02e+00  9.50e-01 | 3.8e-12  8.8e-02  co-a  5.00e-02
#     2  -1.1290e+00  -4.2808e+02 | 1.99e+03  1.94e+02  2.13e+00 | 8.84e-01  1.02e+00  9.03e-01 | 9.9e-13  1.5e-01  co-a  5.00e-02
#     3  -3.0464e+00  -4.3120e+02 | 1.79e+03  1.95e+02  2.14e+00 | 7.93e-01  1.02e+00  8.12e-01 | 5.9e-13  4.4e-01  co-a  1.00e-01
#     4  -6.2407e+00  -4.3590e+02 | 1.61e+03  1.96e+02  2.14e+00 | 7.11e-01  1.03e+00  7.31e-01 | 6.8e-13  8.8e-02  co-a  1.00e-01
#     5  -1.1431e+01  -4.4134e+02 | 1.45e+03  1.96e+02  2.15e+00 | 6.39e-01  1.03e+00  6.58e-01 | 5.7e-12  5.1e-02  co-a  1.00e-01
#     6  -1.9841e+01  -4.4972e+02 | 1.30e+03  1.96e+02  2.15e+00 | 5.75e-01  1.03e+00  5.92e-01 | 3.0e-12  4.6e-02  co-a  1.00e-01
UMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=34.64, FP=1.73, Power=0.34597, FDR=0.04283, TP@100=80.44
# n = 5 → TP=44.32, FP=2.45, Power=0.44027, FDR=0.05143, TP@100=81.91
# n = 6 → TP=50.14, FP=2.93, Power=0.50072, FDR=0.05451, TP@100=82.6
# n = 8 → TP=59.13, FP=2.93, Power=0.58947, FDR=0.04538, TP@100=84.49
# n = 10 → TP=65.876, FP=3.351, Power=0.65494, FDR=0.04749, TP@100=85.474
# n = 20 → TP=76.17, FP=3.78, Power=0.75938, FDR=0.04638, TP@100=87.57
# n = 30 → TP=79.273, FP=4.01, Power=0.80424, FDR=0.0472, TP@100=88.111
# n = 40 → TP=82.01, FP=3.99, Power=0.82216, FDR=0.04574, TP@100=88.84

# %%
# =========================================================
# Store the true DE status for each dataset
# =========================================================
is_DE_store = Dict{Tuple{Int,Int}, BitVector}()

for n in n_values
    for r in 1:R
        is_DE_store[(n,r)] = BitVector(datasets[(n,r)].is_DE)
    end
end

simulation_params = (
    n_values = n_values,
    G = G,
    R = R,
    p_signal = p_signal,
    β_signal = β_signal,

    s0_sq_true = s0_sq_true,
    d0_true = d0_true,

    error_dist = "Normal Scaled",

    variance_standardized = true
)
# Out:
# (n_values = [4, 5, 6, 8, 10, 20, 30, 40], G = 1000, R = 100, p_signal = 0.1, β_signal = 4.0, s0_sq_true = 1.0, d0_true = 4.0, error_dist = "Normal Scaled", variance_standardized = true)

# %%
using JLD2

@save "method_pvalues(6.1).jld2" simulation_params limma_summary epb_summary mad_summary mad_param_gl_summary mad_param_gl_prior_summary mad_param_gl_prior_reps limma_pvals_store epb_pvals_store mad_pvals_store mad_param_pvals_store is_DE_store

# %%
## # eps_contam = 0.1
println("\n========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========")
for i in 1:length(limma_summary["n"])
    println("n = $(limma_summary["n"][i]) → TP=$(round(limma_summary["TP"][i], digits=3)), FP=$(round(limma_summary["FP"][i], digits=3)), Power=$(round(limma_summary["Power"][i], digits=5)), FDR=$(round(limma_summary["FDR"][i], digits=5))")
end


println("\n========== MAD_mean + parametric prior SUMMARY ==========")
for i in eachindex(mad_param_gl_summary["n"])
    println(
        "n = $(mad_param_gl_summary["n"][i]) → " *
        "TP=$(round(mad_param_gl_summary["TP"][i], digits=3)), " *
        "FP=$(round(mad_param_gl_summary["FP"][i], digits=3)), " *
        "Power=$(round(mad_param_gl_summary["Power"][i], digits=5)), " *
        "FDR=$(round(mad_param_gl_summary["FDR"][i], digits=5))"
    )
end

# println("\n========== Fitted prior hyperparameters (Gauss-Legendre) ==========")
# for i in eachindex(mad_param_gl_prior_summary["n"])
#     println(
#         "n = $(mad_param_gl_prior_summary["n"][i]) → " *
#         "mean σ0² = $(round(mad_param_gl_prior_summary["sigma0_sq_mean"][i], digits=5)), " *
#         "mean ν0 = $(round(mad_param_gl_prior_summary["nu0_mean"][i], digits=5))"
#     )
# end

#--- Final summary table ---
println("\n========== SD EPB (NPMLE) SUMMARY ==========")
for i in 1:length(epb_summary["n"])
    println("n = $(epb_summary["n"][i]) → TP=$(round(epb_summary["TP"][i], digits=3)), FP=$(round(epb_summary["FP"][i], digits=3)), Power=$(round(epb_summary["Power"][i], digits=5)), FDR=$(round(epb_summary["FDR"][i], digits=5))")
end


# --- Final summary ---
println("\n========== Mean + MAD SUMMARY ==========")
for i in 1:length(mad_summary["n"])
    println("n = $(mad_summary["n"][i]) → TP=$(round(mad_summary["TP"][i], digits=3)), FP=$(round(mad_summary["FP"][i], digits=3)), Power=$(round(mad_summary["Power"][i], digits=5)), FDR=$(round(mad_summary["FDR"][i], digits=5))")
end
# Out:
# ========== LIMMA SUMMARY ACROSS SAMPLE SIZES ==========
# n = 4 → TP=34.66, FP=1.67, Power=0.34649, FDR=0.04169
# n = 5 → TP=43.84, FP=2.32, Power=0.43545, FDR=0.04871
# n = 6 → TP=50.55, FP=2.84, Power=0.50459, FDR=0.05212
# n = 8 → TP=59.99, FP=2.85, Power=0.59826, FDR=0.04345
# n = 10 → TP=66.89, FP=3.16, Power=0.66482, FDR=0.04411
# n = 20 → TP=76.75, FP=3.66, Power=0.76542, FDR=0.04468
# n = 30 → TP=80.05, FP=3.86, Power=0.81162, FDR=0.045
# n = 40 → TP=82.8, FP=4.05, Power=0.83021, FDR=0.04594
#
# ========== MAD_mean + parametric prior SUMMARY ==========
# n = 4 → TP=34.16, FP=1.66, Power=0.3414, FDR=0.04142
# n = 5 → TP=43.38, FP=2.2, Power=0.43097, FDR=0.04746
# n = 6 → TP=49.86, FP=2.75, Power=0.49741, FDR=0.05082
# n = 8 → TP=58.79, FP=2.96, Power=0.58614, FDR=0.04606
# n = 10 → TP=65.51, FP=3.18, Power=0.65106, FDR=0.0455
# n = 20 → TP=76.02, FP=3.69, Power=0.75787, FDR=0.04532
# n = 30 → TP=79.44, FP=3.81, Power=0.80564, FDR=0.04476
# n = 40 → TP=82.12, FP=4.0, Power=0.82318, FDR=0.04557
#
# ========== SD EPB (NPMLE) SUMMARY ==========
# n = 4 → TP=35.556, FP=1.869, Power=0.35516, FDR=0.04589
# n = 5 → TP=45.01, FP=2.49, Power=0.44744, FDR=0.05073
# n = 6 → TP=50.99, FP=3.051, Power=0.50943, FDR=0.05549
# n = 8 → TP=60.48, FP=2.89, Power=0.60328, FDR=0.04386
# n = 10 → TP=67.14, FP=3.26, Power=0.66697, FDR=0.0453
# n = 20 → TP=77.03, FP=3.68, Power=0.76835, FDR=0.04462
# n = 30 → TP=80.222, FP=3.909, Power=0.81396, FDR=0.04547
# n = 40 → TP=82.67, FP=4.13, Power=0.82891, FDR=0.04685
#
# ========== Mean + MAD SUMMARY ==========
# n = 4 → TP=34.64, FP=1.73, Power=0.34597, FDR=0.04283
# n = 5 → TP=44.32, FP=2.45, Power=0.44027, FDR=0.05143
# n = 6 → TP=50.14, FP=2.93, Power=0.50072, FDR=0.05451
# n = 8 → TP=59.13, FP=2.93, Power=0.58947, FDR=0.04538
# n = 10 → TP=65.876, FP=3.351, Power=0.65494, FDR=0.04749
# n = 20 → TP=76.17, FP=3.78, Power=0.75938, FDR=0.04638
# n = 30 → TP=79.273, FP=4.01, Power=0.80424, FDR=0.0472
# n = 40 → TP=82.01, FP=3.99, Power=0.82216, FDR=0.04574

# %%
using Plots

# -------------------------------------------------
# 1. Build a common method dictionary
# -------------------------------------------------
method_summaries = Dict(
    "LIMMA" => limma_summary,
    "SD EPB (NP)" => epb_summary,
    "Mean + MAD (NP)" => mad_summary,
    "Mean + MAD(P)" => mad_param_gl_summary
)

# compute max FDR across all methods
max_fdr = maximum(vcat([summ["FDR"] for summ in values(method_summaries)]...))
fdr_upper = max(0.06, 1.05 * max_fdr)

# -------------------------------------------------
# 2. Power plot
# -------------------------------------------------
p_power = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power across sample sizes",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in method_summaries
    plot!(
        p_power,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle
    )
end

# -------------------------------------------------
# 3. FDR plot
# -------------------------------------------------
p_fdr = plot(
    xlabel = "Sample size n",
    ylabel = "FDR",
    title = "FDR across sample sizes",
    legend = :outerbottom,
    lw = 2,
    marker = :circle,
    ylims = (-0.01, fdr_upper)
)

for (method, summ) in method_summaries
    plot!(
        p_fdr,
        summ["n"],
        summ["FDR"];
        label = method,
        lw = 2,
        marker = :circle
    )
end

hline!(
    p_fdr,
    [0.05];
    label = "FDR = 0.05",
    lw = 2,
    ls = :dash,
    color = :black
)

# -------------------------------------------------
# 4. Show side by side
# -------------------------------------------------
plot(
    p_power,
    p_fdr;
    layout = (1, 2),
    size = (900, 450)
)

# %%
using Plots

# -------------------------------------------------
# 1. Split methods into two groups
# -------------------------------------------------
param_methods = Dict(
    "LIMMA" => limma_summary,
    "Mean + MAD(P)" => mad_param_gl_summary
)

nonparam_methods = Dict(
    "SD EPB (NP)" => epb_summary,
    "Mean + MAD (NP)" => mad_summary
)

# -------------------------------------------------
# 2. Shared colors
# -------------------------------------------------
method_colors = Dict(
    "LIMMA" => :blue,
    "SD EPB (NP)" => :blue,
    "Mean + MAD(P)" => :green,
    "Mean + MAD (NP)" => :green
)

# -------------------------------------------------
# 3. Power plot: parametric vs parametric
# -------------------------------------------------
p_power_param = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power: parametric vs parametric",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in param_methods
    plot!(
        p_power_param,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle,
        color = method_colors[method]
    )
end

# -------------------------------------------------
# 4. Power plot: nonparametric vs nonparametric
# -------------------------------------------------
p_power_nonparam = plot(
    xlabel = "Sample size n",
    ylabel = "Power",
    title = "Power: nonparametric vs nonparametric",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

for (method, summ) in nonparam_methods
    plot!(
        p_power_nonparam,
        summ["n"],
        summ["Power"];
        label = method,
        lw = 2,
        marker = :circle,
        color = method_colors[method]
    )
end

# -------------------------------------------------
# 5. Difference plot: Mean+MAD - SD
#    parametric: Mean+MAD(P) - LIMMA
#    nonparametric: Mean+MAD(NP) - SD EPB(NP)
# -------------------------------------------------
n_param = limma_summary["n"]
diff_param = mad_param_gl_summary["Power"] .- limma_summary["Power"]

n_nonparam = epb_summary["n"]
diff_nonparam = mad_summary["Power"] .- epb_summary["Power"]

p_diff = plot(
    xlabel = "Sample size n",
    ylabel = "Δ Power",
    title = "Difference in power (Mean+MAD - SD)",
    legend = :outerbottom,
    lw = 2,
    marker = :circle
)

plot!(
    p_diff,
    n_param,
    diff_param;
    label = "Parametric: Mean + MAD(P) - LIMMA",
    lw = 2,
    marker = :circle,
    color = :green
)

plot!(
    p_diff,
    n_nonparam,
    diff_nonparam;
    label = "Nonparametric: Mean + MAD(NP) - SD EPB (NP)",
    lw = 2,
    marker = :circle,
    color = :blue
)

hline!(
    p_diff,
    [0.0];
    label = "0",
    lw = 2,
    ls = :dash,
    color = :black
)

# -------------------------------------------------
# 6. Show all three
# -------------------------------------------------
plot(
    p_power_param,
    p_power_nonparam,
    p_diff;
    layout = (1, 3),
    size = (1350, 420)
)
